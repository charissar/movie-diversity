# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
for i in range(1,41):
    imports.append('genre_exports/export_%s.json' %(str(i)))   #rename to genre_export

# %%
imports
# Out:
# ['genre_exports/export_1.json',
#  'genre_exports/export_2.json',
#  'genre_exports/export_3.json',
#  'genre_exports/export_4.json',
#  'genre_exports/export_5.json',
#  'genre_exports/export_6.json',
#  'genre_exports/export_7.json',
#  'genre_exports/export_8.json',
#  'genre_exports/export_9.json',
#  'genre_exports/export_10.json',
#  'genre_exports/export_11.json',
#  'genre_exports/export_12.json',
#  'genre_exports/export_13.json',
#  'genre_exports/export_14.json',
#  'genre_exports/export_15.json',
#  'genre_exports/export_16.json',
#  'genre_exports/export_17.json',
#  'genre_exports/export_18.json',
#  'genre_exports/export_19.json',
#  'genre_exports/export_20.json',
#  'genre_exports/export_21.json',
#  'genre_exports/export_22.json',
#  'genre_exports/export_23.json',
#  'genre_exports/export_24.json',
#  'genre_exports/export_25.json',
#  'genre_exports/export_26.json',
#  'genre_exports/export_27.json',
#  'genre_exports/export_28.json',
#  'genre_exports/export_29.json',
#  'genre_exports/export_30.json',
#  'genre_exports/export_31.json',
#  'genre_exports/export_32.json',
#  'genre_exports/export_33.json',
#  'genre_exports/export_34.json',
#  'genre_exports/export_35.json',
#  'genre_exports/export_36.json',
#  'genre_exports/export_37.json',
#  'genre_exports/export_38.json',
#  'genre_exports/export_39.json',
#  'genre_exports/export_40.json']

# %%
movies_df = pd.DataFrame()

# %%
for imp in imports:
    movies_df = movies_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(movies_df)
# Out:
# 188326

# %% [markdown]
# ### Use New DataFrame

# %%
movies = pd.DataFrame(movies_df)

# %%
movies['ID'] = movies.index

# %% [raw]
# movies.sample(400)

# %%
movies = movies.drop_duplicates(subset='ID',keep='first')

# %%
len(movies)
# Out:
# 106906

# %% [markdown]
# ## Drop NaN Ratings

# %%
movies['Rating'].isnull().sum()
# Out:
# 29609

# %%
movies = movies.dropna(subset = ['Rating'])

# %%
len(movies)
# Out:
# 77297

# %% [markdown]
# ## Keep Only Movies with Drop Movies with 1000 Votes or More

# %%
movies['Votes'] = movies['Votes'].str.replace(',','')

# %%
movies['Votes']
# Out:
# http://www.imdb.com/title/tt0006206/     3519
# http://www.imdb.com/title/tt0009682/      541
# http://www.imdb.com/title/tt0014720/        9
# http://www.imdb.com/title/tt0015163/     7287
# http://www.imdb.com/title/tt0015324/    24694
# http://www.imdb.com/title/tt0017925/    61402
# http://www.imdb.com/title/tt0018578/     8998
# http://www.imdb.com/title/tt0019421/    10630
# http://www.imdb.com/title/tt0019532/      269
# http://www.imdb.com/title/tt0020815/     1325
# http://www.imdb.com/title/tt0021079/     9804
# http://www.imdb.com/title/tt0022753/      728
# http://www.imdb.com/title/tt0023427/    21444
# http://www.imdb.com/title/tt0023551/     5944
# http://www.imdb.com/title/tt0025004/     1958
# http://www.imdb.com/title/tt0025862/     4124
# http://www.imdb.com/title/tt0026164/     1433
# http://www.imdb.com/title/tt0026174/    10768
# http://www.imdb.com/title/tt0027438/     3741
# http://www.imdb.com/title/tt0027623/     1745
# http://www.imdb.com/title/tt0029047/     1707
# http://www.imdb.com/title/tt0029081/      835
# http://www.imdb.com/title/tt0029843/    41480
# http://www.imdb.com/title/tt0029850/     8927
# http://www.imdb.com/title/tt0031088/     4662
# http://www.imdb.com/title/tt0031747/     1717
# http://www.imdb.com/title/tt0031867/    10487
# http://www.imdb.com/title/tt0032484/    15145
# http://www.imdb.com/title/tt0032762/     8067
# http://www.imdb.com/title/tt0032850/     1199
#                                         ...
# http://www.imdb.com/title/tt0473191/       36
# http://www.imdb.com/title/tt0474798/        6
# http://www.imdb.com/title/tt0484283/       10
# http://www.imdb.com/title/tt0493287/       34
# http://www.imdb.com/title/tt0756286/       15
# http://www.imdb.com/title/tt0795362/      100
# http://www.imdb.com/title/tt0798798/       11
# http://www.imdb.com/title/tt0955291/        7
# http://www.imdb.com/title/tt0986271/        7
# http://www.imdb.com/title/tt1223141/       25
# http://www.imdb.com/title/tt1344659/       63
# http://www.imdb.com/title/tt1361857/       31
# http://www.imdb.com/title/tt1362468/        8
# http://www.imdb.com/title/tt1511469/       18
# http://www.imdb.com/title/tt1537920/       11
# http://www.imdb.com/title/tt1666711/        5
# http://www.imdb.com/title/tt1753916/       12
# http://www.imdb.com/title/tt1842394/        6
# http://www.imdb.com/title/tt1874644/       12
# http://www.imdb.com/title/tt1928157/        5
# http://www.imdb.com/title/tt2159768/        6
# http://www.imdb.com/title/tt2280644/        6
# http://www.imdb.com/title/tt2390968/       19
# http://www.imdb.com/title/tt2418150/       22
# http://www.imdb.com/title/tt2507106/        5
# http://www.imdb.com/title/tt2749034/       12
# http://www.imdb.com/title/tt2879728/        5
# http://www.imdb.com/title/tt3751082/       10
# http://www.imdb.com/title/tt3924776/       40
# http://www.imdb.com/title/tt4386364/       33
# Name: Votes, Length: 77297, dtype: object

# %%
movies['Votes'] = movies['Votes'].astype(int)

# %%
len(movies[movies['Votes'] >= 500])
# Out:
# 29717

# %%
movies = movies[movies['Votes'] >= 500]

# %% [markdown]
# # Scrape Details with Movie URL

# %%
len(movies.index)
# Out:
# 29717

# %%
movies.index
# Out:
# Index(['http://www.imdb.com/title/tt0006206/',
#        'http://www.imdb.com/title/tt0009682/',
#        'http://www.imdb.com/title/tt0015163/',
#        'http://www.imdb.com/title/tt0015324/',
#        'http://www.imdb.com/title/tt0017925/',
#        'http://www.imdb.com/title/tt0018578/',
#        'http://www.imdb.com/title/tt0019421/',
#        'http://www.imdb.com/title/tt0020815/',
#        'http://www.imdb.com/title/tt0021079/',
#        'http://www.imdb.com/title/tt0022753/',
#        ...
#        'http://www.imdb.com/title/tt0439504/',
#        'http://www.imdb.com/title/tt0457530/',
#        'http://www.imdb.com/title/tt0495747/',
#        'http://www.imdb.com/title/tt1384925/',
#        'http://www.imdb.com/title/tt1388402/',
#        'http://www.imdb.com/title/tt1555110/',
#        'http://www.imdb.com/title/tt2014202/',
#        'http://www.imdb.com/title/tt2140381/',
#        'http://www.imdb.com/title/tt4893452/',
#        'http://www.imdb.com/title/tt5143890/'],
#       dtype='object', length=29717)

# %%
movie_urls = list(movies.index)

# %%
len(movie_urls)
# Out:
# 29717

# %% [raw]
# movie_urls[2]

# %%
movie_urls = sorted(movie_urls,reverse = True)

# %% [raw]
# movie_urls[-200:]

# %%
movies.columns
# Out:
# Index(['Certificate', 'Director', 'Genre', 'Gross', 'Metascore', 'Rating',
#        'Runtime', 'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3',
#        'Star3_URL', 'Star4', 'Star4_URL', 'Title', 'Votes', 'Year', 'ID'],
#       dtype='object')

# %% [raw]
# movies.loc['http://www.imdb.com/title/tt0102926/']

# %%
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime

url = 'http://www.imdb.com/title/tt1084680/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

movie_details = {}
movie_details[url] = {}

# %%
plot_wrapper = soup.find('div', class_='plot_summary_wrapper')

if plot_wrapper:
    if plot_wrapper.find(text=re.compile('Director:')):
        directorURL = plot_wrapper.find(text=re.compile('Director:'))
    elif plot_wrapper.find(text=re.compile('Directors:')):
        directorURL = plot_wrapper.find(text=re.compile('Directors:'))
    else:
        directorURL = None
directorURL = directorURL.parent.parent if directorURL else None
directorURL = directorURL.find('a') if directorURL else None
director = directorURL.text if directorURL else None
directorURL = directorURL['href'] if directorURL else None
directorURL = prefix+directorURL.split("?")[0] if directorURL else None
movie_details[url]['Director'] = director
movie_details[url]['Director_URL'] = directorURL

if plot_wrapper:
    if plot_wrapper.find(text=re.compile('Stars:')):
        starURLs = plot_wrapper.find(text=re.compile('Stars:'))
    elif plot_wrapper.find(text=re.compile('Star:')):
        starURLs = plot_wrapper.find(text=re.compile('Star:'))
    else:
        starURLs = None
starURLs = starURLs.parent.parent if starURLs else None
starURLs = starURLs.findAll('a') if starURLs else None
if starURLs:
    if len(starURLs) == 4:
        starURLs = [[star['href'],star.text] for star in starURLs[:-1]]
    else:
        starURLs = [[star['href'],star.text] for star in starURLs]
if starURLs:
    i = 0
    while len(starURLs) >= i+1:
        for URL in starURLs:
            star = starURLs[i]
            movie_details[url]['Star%s' %str(i+1)] = star[1].split('\n')[0].strip() if star[1] else None
            movie_details[url]['Star%s_URL' %str(i+1)] = prefix+star[0].split("?")[0] if star[0] else None
        i += 1  
        
movie_details
# starURLs
# directorURL
# Out:
# {'http://www.imdb.com/title/tt1084680/': {'Director': 'Ádám Magyar',
#   'Director_URL': 'http://www.imdb.com/name/nm2745592'}}

# %% [raw]
# directorURL = soup.find('div', class_='plot_summary_wrapper')
# directorURL = directorURL.find(text=re.compile('Director')) if directorURL else None
# directorURL = directorURL.parent.parent if directorURL else None
# directorURL = directorURL.find('a') if directorURL else None
# director = directorURL.text if directorURL else None
# directorURL = directorURL['href'] if directorURL else None
# directorURL = prefix+directorURL.split("?")[0] if directorURL else None
# movie_details[url]['Director'] = director
# movie_details[url]['Director_URL'] = directorURL
#
# directorURL

# %% [raw]
# starURLs = soup.find('div', class_='plot_summary_wrapper')
# if starURLs:
#     if starURLs.find(text=re.compile('Stars:')):
#         starURLs = starURLs.find(text=re.compile('Stars:'))
#     elif starURLs.find(text=re.compile('Star:')):
#         starURLs = starURLs.find(text=re.compile('Star:'))
# starURLs = starURLs.parent.parent if starURLs else None
# starURLs = starURLs.findAll('a') if starURLs else None
# if starURLs:
#     if len(starURLs) == 4:
#         starURLs = [[star['href'],star.text] for star in starURLs[:-1]]
#     else:
#         starURLs = [[star['href'],star.text] for star in starURLs]
# if starURLs:
#     i = 0
#     while len(starURLs) >= i+1:
#         for URL in starURLs:
#             star = starURLs[i]
#             movie_details[url]['Star%s' %str(i+1)] = star[1].split('\n')[0].strip() if star[1] else None
#             movie_details[url]['Star%s_URL' %str(i+1)] = prefix+star[0].split("?")[0] if star[0] else None
#         i += 1
#
# movie_details

# %% [raw]
# prefix = 'http://www.imdb.com'
#
# movie_details = {}
# movie_details[url] = {}
#
#
# starURLs = soup.find('div', class_='plot_summary_wrapper')
# starURLs = starURLs.find(text=re.compile('Star')) if starURLs else None
# starURLs = starURLs.parent.parent if starURLs else None
# starURLs = starURLs.findAll('a') if starURLs else None
# if starURLs:
#     if len(starURLs) == 4:
#         starURLs = [[star['href'],star.text] for star in starURLs[:-1]]
#     else:
#         starURLs = [[star['href'],star.text] for star in starURLs]
# if starURLs:
#     i = 0
#     while len(starURLs) >= i+1:
#         for URL in starURLs:
#             star = starURLs[i]
#             movie_details[url]['Star%s' %str(i+1)] = star[1].split('\n')[0].strip() if star[1] else None
#             movie_details[url]['Star%s_URL' %str(i+1)] = prefix+star[0].split("?")[0] if star[0] else None
#         i += 1
# starURLs
# movie_details

# %% [raw]
# prefix = 'http://www.imdb.com'
#
# movie_details = {}
# movie_details[url] = {}
#
#
# starURLs = soup.find('div', class_='plot_summary_wrapper')
# starURLs = starURLs.find(text=re.compile('Star')) if starURLs else None
# starURLs = starURLs.parent.parent if starURLs else None
# starURLs = starURLs.findAll('a') if starURLs else None
# if starURLs:
#     if len(starURLs) == 4:
#         starURLs = [[star['href'],star.text] for star in starURLs[:-1] for star in starURLs]
#     else:
#         starURLs = [[star['href'],star.text] for star in starURLs for star in starURLs]
# if starURLs:
#     i = 0
#     while len(starURLs) >= i+1:
#         for URL in starURLs:
#             star = starURLs[i]
#             movie_details[url]['Star%s' %str(i+1)] = star[1].split('\n')[0].strip() if star[1] else None
#             movie_details[url]['Star%s_URL' %str(i+1)] = prefix+star[0].split("?")[0] if star[0] else None
#             i += 1
# movie_details
# # starURLs

# %% [raw]
# movie_details = {}
# movie_details[url] = {}
#
# title_details = soup.find(id='titleDetails')
#
# production_company = title_details.find(text=re.compile('Production Co')) if title_details else None
# production_company = production_company.parent.parent if production_company else None
# production_company = production_company.find('a') if production_company else None
# production_company = production_company.text if production_company else None
# movie_details[url]['Production Company'] = production_company
#
#
# # directorURL = soup.find('div', class_='plot_summary_wrapper')
# # directorURL = directorURL.find(text=re.compile('Director')) if directorURL else None
# # directorURL = directorURL.parent.parent if directorURL else None
# # directorURL = directorURL.find('a') if directorURL else None
# # director = directorURL.text if directorURL else None
# # directorURL = directorURL['href'] if directorURL else None
# # directorURL = prefix+directorURL.split("?")[0] if directorURL else None
# # movie_details[url]['Director'] = director
# # movie_details[url]['Director_URL'] = directorURL
#
# production_company

# %% [raw]
# prefix = 'http://www.imdb.com'
#
# movie_details = {}
# movie_details[url] = {}
#
# stars = soup.find(id='titleCast')
# stars = stars.find('table', class_='cast_list') if stars else None
# stars = stars.findAll('td', class_='itemprop') if stars else None
# starlisttemp = []
# stars = [starlisttemp.append([star.find('a')['href'],star.find('a').text]) for star in stars[0:10]] if stars else None
# starlist = []
# if starlisttemp: [starlist.append([prefix+combination[0].split('?')[0],combination[1].split('\n')[0].strip()]) for combination in starlisttemp]
#
#
# # starURLs = [star.find('a')['href'] for star in stars] if stars else None
# # starURLs = [prefix + URL.split('?')[0] for URL in starURLs] if starURLs else None
#
# # starnames = [star.find('a').text for star in stars] if stars else None
# # starnames = [name.split('\n')[0].strip() for name in starnames] if starnames else None
#
# # if starnames[0:4]:
# #     i = 0
# #     for star in starnames:
# #         star = starnames[i]
# #         movie_details[url]['Star%s' %str(i+1)] = star
# #         starURL = starURLs[i] if starURLs[i] else None
#
# #         movie_details[url]['Star%s_URL' %str(i+1)] = prefix+starURL
# #         i += 1
#
# # stars
# # starURLs
# # movie_details
# starlist

# %% [raw]
# starURLs = soup.find('div', class_='plot_summary_wrapper')
# starURLs = starURLs.find(text=re.compile('Stars:')) if starURLs else None
# starURLs = starURLs.parent.parent if starURLs else None
# starURLs = starURLs.findAll('a') if starURLs else None
# starURLs = [[star['href'],star.text] for star in starURLs[:-1]] if starURLs else None
# if starURLs:
#     i = 0
#     while len(starURLs) >= i+1:
#         for URL in starURLs:
#             star = starURLs[i]
#             movie_details[url]['Star%s' %str(i+1)] = star[1].split('\n')[0].strip() if star[1] else None
#             movie_details[url]['Star%s_URL' %str(i+1)] = prefix+star[0].split("?")[0] if star[0] else None
#             i += 1
#
# # director = starURLs.text if starURLs else None
# # starURLs = starURLs['href'] if starURLs else None
# # starURLs = prefix+starURLs.split("?")[0] if starURLs else None
# # movie_details[url]['Director'] = director
# # movie_details[url]['Director_URL'] = starURLs
#
# movie_details
# # stars
# # starURLs

# %%
# Movie Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

movies_scraped = 0
movie_details = {}
movie_index = 0                       
prefix = 'http://www.imdb.com'
export_number = 1
export_no = str(export_number)
load_attempts = 0

def movie_scraper():
    global movie_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in movie_urls[movie_index:3000]:
        if (movie_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(movie_index+1, url))
        page = request_page(url)
        get_movie_details(url, page)
        movie_index += 1
    
    export_to_json(movie_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_movie_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    movie_details[url] = {}
    
    plot_wrapper = soup.find('div', class_='plot_summary_wrapper')

    if plot_wrapper:
        if plot_wrapper.find(text=re.compile('Director:')):
            directorURL = plot_wrapper.find(text=re.compile('Director:'))
        elif plot_wrapper.find(text=re.compile('Directors:')):
            directorURL = plot_wrapper.find(text=re.compile('Directors:'))
        else:
            directorURL = None
    directorURL = directorURL.parent.parent if directorURL else None
    directorURL = directorURL.find('a') if directorURL else None
    director = directorURL.text if directorURL else None
    directorURL = directorURL['href'] if directorURL else None
    directorURL = prefix+directorURL.split("?")[0] if directorURL else None
    movie_details[url]['Director'] = director
    movie_details[url]['Director_URL'] = directorURL

    if plot_wrapper:
        if plot_wrapper.find(text=re.compile('Stars:')):
            starURLs = plot_wrapper.find(text=re.compile('Stars:'))
        elif plot_wrapper.find(text=re.compile('Star:')):
            starURLs = plot_wrapper.find(text=re.compile('Star:'))
        else:
            starURLs = None
    starURLs = starURLs.parent.parent if starURLs else None
    starURLs = starURLs.findAll('a') if starURLs else None
    if starURLs:
        if len(starURLs) == 4:
            starURLs = [[star['href'],star.text] for star in starURLs[:-1]]
        else:
            starURLs = [[star['href'],star.text] for star in starURLs]
    if starURLs:
        i = 0
        while len(starURLs) >= i+1:
            for URL in starURLs:
                star = starURLs[i]
                movie_details[url]['Star%s' %str(i+1)] = star[1].split('\n')[0].strip() if star[1] else None
                movie_details[url]['Star%s_URL' %str(i+1)] = prefix+star[0].split("?")[0] if star[0] else None
            i += 1 
    
    title = soup.find('div', class_='title_wrapper').find('h1',itemprop='name')
    title = title.contents[0].replace(u'\xa0', u'')
    movie_details[url]['Title'] = title

    release_date = soup.find('div', class_='title_wrapper')
    release_date = release_date.findAll('a') if release_date else None
    release_date = release_date[-1] if release_date else None
    release_date = release_date.find('meta') if release_date else None
    release_date = str(release_date) if release_date else None
    release_date = re.sub('[^0-9-]+','', release_date) if release_date else None
    movie_details[url]['Release Date'] = release_date

    title_details = soup.find(id='titleDetails')
    
    production_company = title_details.find(text=re.compile('Production Co:')) if title_details else None
    production_company = production_company.parent.parent if production_company else None
    production_company = production_company.find('a') if production_company else None
    production_company = production_company.text if production_company else None
    movie_details[url]['Production Company'] = production_company

    country = title_details.find(text=re.compile('Country:')) if title_details else None
    country = country.parent.parent if country else None
    country = country.find('a') if country else None
    country = country.text if country else None
    movie_details[url]['Country'] = country

    language = title_details.find(text=re.compile('Language:')) if title_details else None
    language = language.parent.parent if language else None
    language = language.find('a') if language else None
    language = language.text if language else None
    movie_details[url]['Language'] = language

    primary_filming_location = title_details.find(text=re.compile('Filming Locations:')) if title_details else None
    primary_filming_location = primary_filming_location.parent.parent if primary_filming_location else None
    primary_filming_location = primary_filming_location.find('a') if primary_filming_location else None
    primary_filming_location= primary_filming_location.text if primary_filming_location else None
    movie_details[url]['Primary Filming Location'] = primary_filming_location

    budget = title_details.find(text=re.compile('Budget:')) if title_details else None
    budget = budget.parent.parent if budget else None
    budget = budget.text.strip() if budget else None
    budget = re.sub('[^0-9]+','', budget) if budget else None
    movie_details[url]['Budget'] = budget

    opening_weekend_usa = title_details.find(text=re.compile('Opening Weekend USA:')) if title_details else None
    opening_weekend_usa = opening_weekend_usa.parent.parent if opening_weekend_usa else None
    opening_weekend_usa = opening_weekend_usa.text.strip() if opening_weekend_usa else None
    opening_weekend_usa = re.sub('[^0-9]+','', opening_weekend_usa) if opening_weekend_usa else None
    movie_details[url]['Opening Weekend USA'] = opening_weekend_usa

    #rename gross to gross USA in listing scrape
    global_gross = title_details.find(text=re.compile('Cumulative Worldwide Gross:')) if title_details else None
    global_gross = global_gross.parent.parent if global_gross else None
    global_gross = global_gross.text.strip() if global_gross else None
    global_gross = re.sub('[^0-9]+','', global_gross) if global_gross else None
    movie_details[url]['Cumulative Worldwide Gross'] = global_gross

    gross_usa = title_details.find(text=re.compile('Gross USA:')) if title_details else None
    gross_usa = gross_usa.parent.parent if gross_usa else None
    gross_usa = gross_usa.text.strip() if gross_usa else None
    gross_usa = re.sub('[^0-9]+','', gross_usa) if gross_usa else None
    movie_details[url]['Gross USA'] = gross_usa

    go_to_next_and_export()

def go_to_next_and_export():
    global movies_scraped
    global movie_details
    
    movies_scraped+=1

    if len(movie_details) == 1000:                                         
        export_to_json(movie_details)
        movies_scraped = 0
        movie_details = {}

def export_to_json(movie_details):
    global export_no
    global export_number
    with open('movie_details_export_%s.json' %(export_no),'w')  as f:
        json.dump(movie_details,f)

    export_number += 1
    export_no = str(export_number)
    print(str(datetime.now()),': working on export ' + export_no)

movie_scraper()
# Out:
# 2018-01-29 21:02:48.049060 : working on export 1
# 20: http://www.imdb.com/title/tt7431894/
# 40: http://www.imdb.com/title/tt7180544/
# 60: http://www.imdb.com/title/tt6973386/
# 80: http://www.imdb.com/title/tt6789174/
# 100: http://www.imdb.com/title/tt6697582/
# 120: http://www.imdb.com/title/tt6574272/
# 140: http://www.imdb.com/title/tt6462506/
# 160: http://www.imdb.com/title/tt6366854/
# 180: http://www.imdb.com/title/tt6306400/
# 200: http://www.imdb.com/title/tt6265988/
# 220: http://www.imdb.com/title/tt6201292/
# 240: http://www.imdb.com/title/tt6133130/
# 260: http://www.imdb.com/title/tt6083388/
# 280: http://www.imdb.com/title/tt6027478/
# 300: http://www.imdb.com/title/tt5987402/
# 320: http://www.imdb.com/title/tt5946128/
# 340: http://www.imdb.com/title/tt5910280/
# 360: http://www.imdb.com/title/tt5861630/
# 380: http://www.imdb.com/title/tt5829040/
# 400: http://www.imdb.com/title/tt5804948/
# 420: http://www.imdb.com/title/tt5764096/
# 440: http://www.imdb.com/title/tt5735464/
# 460: http://www.imdb.com/title/tt5716380/
# 480: http://www.imdb.com/title/tt5687416/
# 500: http://www.imdb.com/title/tt5644740/
# 520: http://www.imdb.com/title/tt5614612/
# 540: http://www.imdb.com/title/tt5589768/
# 560: http://www.imdb.com/title/tt5539054/
# 580: http://www.imdb.com/title/tt5503688/
# 600: http://www.imdb.com/title/tt5472758/
# 620: http://www.imdb.com/title/tt5457840/
# 640: http://www.imdb.com/title/tt5431600/
# 660: http://www.imdb.com/title/tt5354664/
# 680: http://www.imdb.com/title/tt5328350/
# 700: http://www.imdb.com/title/tt5309844/
# 720: http://www.imdb.com/title/tt5285050/
# 740: http://www.imdb.com/title/tt5254868/
# 760: http://www.imdb.com/title/tt5226512/
# 780: http://www.imdb.com/title/tt5193784/
# 800: http://www.imdb.com/title/tt5164412/
# 820: http://www.imdb.com/title/tt5147214/
# 840: http://www.imdb.com/title/tt5122374/
# 860: http://www.imdb.com/title/tt5096536/
# 880: http://www.imdb.com/title/tt5076792/
# 900: http://www.imdb.com/title/tt5050788/
# 920: http://www.imdb.com/title/tt5029208/
# 940: http://www.imdb.com/title/tt4995748/
# 960: http://www.imdb.com/title/tt4975280/
# 980: http://www.imdb.com/title/tt4955566/
# 1000: http://www.imdb.com/title/tt4937564/
# 2018-01-29 21:20:36.748912 : working on export 2
# 1020: http://www.imdb.com/title/tt4919484/
# 1040: http://www.imdb.com/title/tt4897908/
# 1060: http://www.imdb.com/title/tt4859246/
# 1080: http://www.imdb.com/title/tt4836110/
# 1100: http://www.imdb.com/title/tt4817256/
# 1120: http://www.imdb.com/title/tt4788638/
# 1140: http://www.imdb.com/title/tt4759902/
# 1160: http://www.imdb.com/title/tt4729990/
# 1180: http://www.imdb.com/title/tt4701688/
# 1200: http://www.imdb.com/title/tt4687276/
# 1220: http://www.imdb.com/title/tt4675030/
# 1240: http://www.imdb.com/title/tt4655630/
# 1260: http://www.imdb.com/title/tt4641248/
# 1280: http://www.imdb.com/title/tt4623812/
# 1300: http://www.imdb.com/title/tt4593236/
# 1320: http://www.imdb.com/title/tt4572514/
# 1340: http://www.imdb.com/title/tt4550420/
# 1360: http://www.imdb.com/title/tt4519006/
# 1380: http://www.imdb.com/title/tt4501454/
# 1400: http://www.imdb.com/title/tt4468634/
# 1420: http://www.imdb.com/title/tt4450706/
# 1440: http://www.imdb.com/title/tt4437046/
# 1460: http://www.imdb.com/title/tt4424722/
# 1480: http://www.imdb.com/title/tt4404474/
# 1500: http://www.imdb.com/title/tt4383288/
# 1520: http://www.imdb.com/title/tt4361050/
# 1540: http://www.imdb.com/title/tt4335650/
# 1560: http://www.imdb.com/title/tt4310772/
# 1580: http://www.imdb.com/title/tt4291590/
# 1600: http://www.imdb.com/title/tt4272866/
# 1620: http://www.imdb.com/title/tt4255304/
# 1640: http://www.imdb.com/title/tt4235342/
# 1660: http://www.imdb.com/title/tt4211044/
# 1680: http://www.imdb.com/title/tt4189494/
# 1700: http://www.imdb.com/title/tt4172430/
# 1720: http://www.imdb.com/title/tt4148400/
# 1740: http://www.imdb.com/title/tt4126438/
# 1760: http://www.imdb.com/title/tt4104022/
# 1780: http://www.imdb.com/title/tt4080858/
# 1800: http://www.imdb.com/title/tt4067084/
# 1820: http://www.imdb.com/title/tt4048168/
# 1840: http://www.imdb.com/title/tt4027504/
# 1860: http://www.imdb.com/title/tt4009278/
# 1880: http://www.imdb.com/title/tt3982468/
# 1900: http://www.imdb.com/title/tt3958780/
# 1920: http://www.imdb.com/title/tt3946300/
# 1940: http://www.imdb.com/title/tt3916700/
# 1960: http://www.imdb.com/title/tt3896198/
# 1980: http://www.imdb.com/title/tt3881784/
# 2000: http://www.imdb.com/title/tt3856300/
# 2018-01-29 21:38:08.179382 : working on export 3
# 2020: http://www.imdb.com/title/tt3838992/
# 2040: http://www.imdb.com/title/tt3824432/
# 2060: http://www.imdb.com/title/tt3810602/
# 2080: http://www.imdb.com/title/tt3794028/
# 2100: http://www.imdb.com/title/tt3776826/
# 2120: http://www.imdb.com/title/tt3760966/
# 2140: http://www.imdb.com/title/tt3742378/
# 2160: http://www.imdb.com/title/tt3727824/
# 2180: http://www.imdb.com/title/tt3717532/
# 2200: http://www.imdb.com/title/tt3705412/
# 2220: http://www.imdb.com/title/tt3698118/
# 2240: http://www.imdb.com/title/tt3685622/
# 2260: http://www.imdb.com/title/tt3667792/
# 2280: http://www.imdb.com/title/tt3647498/
# 2300: http://www.imdb.com/title/tt3627488/
# 2320: http://www.imdb.com/title/tt3614922/
# 2340: http://www.imdb.com/title/tt3605418/
# 2360: http://www.imdb.com/title/tt3585004/
# 2380: http://www.imdb.com/title/tt3567288/
# 2400: http://www.imdb.com/title/tt3554976/
# 2420: http://www.imdb.com/title/tt3543258/
# 2440: http://www.imdb.com/title/tt3530002/
# 2460: http://www.imdb.com/title/tt3517192/
# 2480: http://www.imdb.com/title/tt3503460/
# 2500: http://www.imdb.com/title/tt3492838/
# 2520: http://www.imdb.com/title/tt3480886/
# 2540: http://www.imdb.com/title/tt3471472/
# 2560: http://www.imdb.com/title/tt3462710/
# 2580: http://www.imdb.com/title/tt3450134/
# 2600: http://www.imdb.com/title/tt3430548/
# 2620: http://www.imdb.com/title/tt3416532/
# 2640: http://www.imdb.com/title/tt3401882/
# 2660: http://www.imdb.com/title/tt3397082/
# 2680: http://www.imdb.com/title/tt3382842/
# 2700: http://www.imdb.com/title/tt3359290/
# 2720: http://www.imdb.com/title/tt3343868/
# 2740: http://www.imdb.com/title/tt3328720/
# 2760: http://www.imdb.com/title/tt3316960/
# 2780: http://www.imdb.com/title/tt3303446/
# 2800: http://www.imdb.com/title/tt3291148/
# 2820: http://www.imdb.com/title/tt3278330/
# 2840: http://www.imdb.com/title/tt3262990/
# 2860: http://www.imdb.com/title/tt3245656/
# 2880: http://www.imdb.com/title/tt3230300/
# 2900: http://www.imdb.com/title/tt3213622/
# 2920: http://www.imdb.com/title/tt3201722/
# 2940: http://www.imdb.com/title/tt3183402/
# 2960: http://www.imdb.com/title/tt3173594/
# 2980: http://www.imdb.com/title/tt3163224/
# 3000: http://www.imdb.com/title/tt3149640/
# 2018-01-29 21:55:40.718095 : working on export 4
# 2018-01-29 21:55:40.720448 : working on export 5
# Done

# %%
import json
import pandas as pd

details_df = pd.read_json('movie_details_exports/movie_details_export_7.json',orient='index')

# %%
details_df
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt1826593/          NaN       Sweden
# http://www.imdb.com/title/tt1826660/   84000000.0       Russia
# http://www.imdb.com/title/tt1826714/          NaN  South Korea
# http://www.imdb.com/title/tt1826813/          NaN          USA
# http://www.imdb.com/title/tt1827354/    1200000.0           UK
# http://www.imdb.com/title/tt1827358/    1000000.0       Sweden
# http://www.imdb.com/title/tt1827372/          NaN       Brazil
# http://www.imdb.com/title/tt1827487/          NaN       Turkey
# http://www.imdb.com/title/tt1827512/          NaN      Belgium
# http://www.imdb.com/title/tt1827528/          NaN      Germany
# http://www.imdb.com/title/tt1827578/          NaN          USA
# http://www.imdb.com/title/tt1827579/          NaN           UK
# http://www.imdb.com/title/tt1828148/    9238000.0       Brazil
# http://www.imdb.com/title/tt1828229/          NaN       France
# http://www.imdb.com/title/tt1828289/          NaN        India
# http://www.imdb.com/title/tt1828959/   15000000.0  South Korea
# http://www.imdb.com/title/tt1828968/          NaN          USA
# http://www.imdb.com/title/tt1828970/          NaN          USA
# http://www.imdb.com/title/tt1828995/    7000000.0       France
# http://www.imdb.com/title/tt1829012/   20000000.0       France
# http://www.imdb.com/title/tt1829735/     200000.0          USA
# http://www.imdb.com/title/tt1830495/          NaN      Germany
# http://www.imdb.com/title/tt1830713/          NaN          USA
# http://www.imdb.com/title/tt1830786/          NaN        India
# http://www.imdb.com/title/tt1830792/          NaN      Germany
# http://www.imdb.com/title/tt1830802/          NaN        India
# http://www.imdb.com/title/tt1831806/    3000000.0          USA
# http://www.imdb.com/title/tt1832381/          NaN  South Korea
# http://www.imdb.com/title/tt1832382/     500000.0         Iran
# http://www.imdb.com/title/tt1833673/          NaN        India
# ...                                           ...          ...
# http://www.imdb.com/title/tt2121382/          NaN       Sweden
# http://www.imdb.com/title/tt2122313/          NaN       Sweden
# http://www.imdb.com/title/tt2122340/          NaN        India
# http://www.imdb.com/title/tt2122424/          NaN          USA
# http://www.imdb.com/title/tt2122518/          NaN       France
# http://www.imdb.com/title/tt2123129/  220000000.0        India
# http://www.imdb.com/title/tt2123146/     325927.0          USA
# http://www.imdb.com/title/tt2123342/    2500000.0          USA
# http://www.imdb.com/title/tt2124074/          NaN          USA
# http://www.imdb.com/title/tt2124186/     600000.0       Turkey
# http://www.imdb.com/title/tt2124787/    8000000.0       Canada
# http://www.imdb.com/title/tt2125425/          NaN       Brazil
# http://www.imdb.com/title/tt2125435/    1800000.0          USA
# http://www.imdb.com/title/tt2125472/          NaN          USA
# http://www.imdb.com/title/tt2125500/          NaN    Argentina
# http://www.imdb.com/title/tt2125685/          NaN          USA
# http://www.imdb.com/title/tt2125698/          NaN        Chile
# http://www.imdb.com/title/tt2126235/   21500000.0           UK
# http://www.imdb.com/title/tt2126282/          NaN        India
# http://www.imdb.com/title/tt2126355/  110000000.0          USA
# http://www.imdb.com/title/tt2126362/          NaN      Ireland
# http://www.imdb.com/title/tt2129887/          NaN       France
# http://www.imdb.com/title/tt2130242/          NaN        India
# http://www.imdb.com/title/tt2130270/          NaN    Australia
# http://www.imdb.com/title/tt2131523/          NaN  Philippines
# http://www.imdb.com/title/tt2131532/          NaN          USA
# http://www.imdb.com/title/tt2131586/          NaN        Japan
# http://www.imdb.com/title/tt2131698/    8000000.0           UK
# http://www.imdb.com/title/tt2132285/    8000000.0          USA
# http://www.imdb.com/title/tt2132374/    4000000.0      Ireland
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt1826593/                         NaN
# http://www.imdb.com/title/tt1826660/                         NaN
# http://www.imdb.com/title/tt1826714/                         NaN
# http://www.imdb.com/title/tt1826813/                         NaN
# http://www.imdb.com/title/tt1827354/                         NaN
# http://www.imdb.com/title/tt1827358/                         NaN
# http://www.imdb.com/title/tt1827372/                         NaN
# http://www.imdb.com/title/tt1827487/                         NaN
# http://www.imdb.com/title/tt1827512/                         NaN
# http://www.imdb.com/title/tt1827528/                         NaN
# http://www.imdb.com/title/tt1827578/                         NaN
# http://www.imdb.com/title/tt1827579/                         NaN
# http://www.imdb.com/title/tt1828148/                         NaN
# http://www.imdb.com/title/tt1828229/                         NaN
# http://www.imdb.com/title/tt1828289/                         NaN
# http://www.imdb.com/title/tt1828959/                         NaN
# http://www.imdb.com/title/tt1828968/                         NaN
# http://www.imdb.com/title/tt1828970/                         NaN
# http://www.imdb.com/title/tt1828995/                         NaN
# http://www.imdb.com/title/tt1829012/                         NaN
# http://www.imdb.com/title/tt1829735/                         NaN
# http://www.imdb.com/title/tt1830495/                         NaN
# http://www.imdb.com/title/tt1830713/                         NaN
# http://www.imdb.com/title/tt1830786/                         NaN
# http://www.imdb.com/title/tt1830792/                         NaN
# http://www.imdb.com/title/tt1830802/                         NaN
# http://www.imdb.com/title/tt1831806/                         NaN
# http://www.imdb.com/title/tt1832381/                         NaN
# http://www.imdb.com/title/tt1832382/                2.442617e+07
# http://www.imdb.com/title/tt1833673/                8.803196e+07
# ...                                                          ...
# http://www.imdb.com/title/tt2121382/                         NaN
# http://www.imdb.com/title/tt2122313/                         NaN
# http://www.imdb.com/title/tt2122340/                         NaN
# http://www.imdb.com/title/tt2122424/                         NaN
# http://www.imdb.com/title/tt2122518/                         NaN
# http://www.imdb.com/title/tt2123129/                         NaN
# http://www.imdb.com/title/tt2123146/                         NaN
# http://www.imdb.com/title/tt2123342/                         NaN
# http://www.imdb.com/title/tt2124074/                         NaN
# http://www.imdb.com/title/tt2124186/                         NaN
# http://www.imdb.com/title/tt2124787/                         NaN
# http://www.imdb.com/title/tt2125425/                         NaN
# http://www.imdb.com/title/tt2125435/                2.108006e+07
# http://www.imdb.com/title/tt2125472/                         NaN
# http://www.imdb.com/title/tt2125500/                         NaN
# http://www.imdb.com/title/tt2125685/                         NaN
# http://www.imdb.com/title/tt2125698/                         NaN
# http://www.imdb.com/title/tt2126235/                2.531522e+11
# http://www.imdb.com/title/tt2126282/                         NaN
# http://www.imdb.com/title/tt2126355/                4.739908e+08
# http://www.imdb.com/title/tt2126362/                         NaN
# http://www.imdb.com/title/tt2129887/                         NaN
# http://www.imdb.com/title/tt2130242/                         NaN
# http://www.imdb.com/title/tt2130270/                         NaN
# http://www.imdb.com/title/tt2131523/                         NaN
# http://www.imdb.com/title/tt2131532/                         NaN
# http://www.imdb.com/title/tt2131586/                         NaN
# http://www.imdb.com/title/tt2131698/                         NaN
# http://www.imdb.com/title/tt2132285/                         NaN
# http://www.imdb.com/title/tt2132374/                         NaN
#
#                                                         Director  \
# http://www.imdb.com/title/tt1826593/               Axel Petersén
# http://www.imdb.com/title/tt1826660/              Roman Prygunov
# http://www.imdb.com/title/tt1826714/             You-jeong Chang
# http://www.imdb.com/title/tt1826813/               Ash Christian
# http://www.imdb.com/title/tt1827354/               Dominic Burns
# http://www.imdb.com/title/tt1827358/                 Lisa Aschan
# http://www.imdb.com/title/tt1827372/            Flavio Frederico
# http://www.imdb.com/title/tt1827487/           Nuri Bilge Ceylan
# http://www.imdb.com/title/tt1827512/        Jean-Pierre Dardenne
# http://www.imdb.com/title/tt1827528/              Benjamin Cantu
# http://www.imdb.com/title/tt1827578/                 Mark Webber
# http://www.imdb.com/title/tt1827579/              Mat Whitecross
# http://www.imdb.com/title/tt1828148/               Cecília Amado
# http://www.imdb.com/title/tt1828229/               Michel Ocelot
# http://www.imdb.com/title/tt1828289/            Tigmanshu Dhulia
# http://www.imdb.com/title/tt1828959/                 Duane Adler
# http://www.imdb.com/title/tt1828968/          Michael Canzoniero
# http://www.imdb.com/title/tt1828970/          Olatunde Osunsanmi
# http://www.imdb.com/title/tt1828995/             David Foenkinos
# http://www.imdb.com/title/tt1829012/              Brian De Palma
# http://www.imdb.com/title/tt1829735/           Tim T. Cunningham
# http://www.imdb.com/title/tt1830495/             Lucien Förstner
# http://www.imdb.com/title/tt1830713/                 Mike Mendez
# http://www.imdb.com/title/tt1830786/                David Dhawan
# http://www.imdb.com/title/tt1830792/             Sabine Bernardi
# http://www.imdb.com/title/tt1830802/                Sujay Dahake
# http://www.imdb.com/title/tt1831806/            Mitchell Altieri
# http://www.imdb.com/title/tt1832381/                Kim Suk-Yoon
# http://www.imdb.com/title/tt1832382/              Asghar Farhadi
# http://www.imdb.com/title/tt1833673/       Vijay Krishna Acharya
# ...                                                          ...
# http://www.imdb.com/title/tt2121382/               Ruben Östlund
# http://www.imdb.com/title/tt2122313/                  Levan Akin
# http://www.imdb.com/title/tt2122340/             Rajesh Mapuskar
# http://www.imdb.com/title/tt2122424/                 Patrick Rea
# http://www.imdb.com/title/tt2122518/           Philippe Lefebvre
# http://www.imdb.com/title/tt2123129/           Aishwarya Dhanush
# http://www.imdb.com/title/tt2123146/                  Kevin Finn
# http://www.imdb.com/title/tt2123342/                 Doug Dearth
# http://www.imdb.com/title/tt2124074/                   Matt Ross
# http://www.imdb.com/title/tt2124186/                   Onur Ünlü
# http://www.imdb.com/title/tt2124787/               Tyler Shields
# http://www.imdb.com/title/tt2125425/               Luciano Moura
# http://www.imdb.com/title/tt2125435/                Benh Zeitlin
# http://www.imdb.com/title/tt2125472/  Anthony J. Rickert-Epstein
# http://www.imdb.com/title/tt2125500/                  Armando Bo
# http://www.imdb.com/title/tt2125685/               Bryan Bertino
# http://www.imdb.com/title/tt2125698/               Marialy Rivas
# http://www.imdb.com/title/tt2126235/                 Eran Creevy
# http://www.imdb.com/title/tt2126282/               Gautham Menon
# http://www.imdb.com/title/tt2126355/                 Brad Peyton
# http://www.imdb.com/title/tt2126362/               Conor McMahon
# http://www.imdb.com/title/tt2129887/                Nicolas Bary
# http://www.imdb.com/title/tt2130242/               Mandeep Kumar
# http://www.imdb.com/title/tt2130270/                 Tony Mahony
# http://www.imdb.com/title/tt2131523/                 Ron Morales
# http://www.imdb.com/title/tt2131532/                 Matt Duffer
# http://www.imdb.com/title/tt2131586/               Kôbun Shizuno
# http://www.imdb.com/title/tt2131698/                 Eran Riklis
# http://www.imdb.com/title/tt2132285/               Sofia Coppola
# http://www.imdb.com/title/tt2132374/                  Lance Daly
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt1826593/  http://www.imdb.com/name/nm1490822
# http://www.imdb.com/title/tt1826660/  http://www.imdb.com/name/nm1213790
# http://www.imdb.com/title/tt1826714/  http://www.imdb.com/name/nm4287208
# http://www.imdb.com/title/tt1826813/  http://www.imdb.com/name/nm1101381
# http://www.imdb.com/title/tt1827354/  http://www.imdb.com/name/nm2403079
# http://www.imdb.com/title/tt1827358/  http://www.imdb.com/name/nm2132286
# http://www.imdb.com/title/tt1827372/  http://www.imdb.com/name/nm0292889
# http://www.imdb.com/title/tt1827487/  http://www.imdb.com/name/nm0149196
# http://www.imdb.com/title/tt1827512/  http://www.imdb.com/name/nm0201094
# http://www.imdb.com/title/tt1827528/  http://www.imdb.com/name/nm1992380
# http://www.imdb.com/title/tt1827578/  http://www.imdb.com/name/nm0916406
# http://www.imdb.com/title/tt1827579/  http://www.imdb.com/name/nm1475971
# http://www.imdb.com/title/tt1828148/  http://www.imdb.com/name/nm0023753
# http://www.imdb.com/title/tt1828229/  http://www.imdb.com/name/nm0643664
# http://www.imdb.com/title/tt1828289/  http://www.imdb.com/name/nm0223606
# http://www.imdb.com/title/tt1828959/  http://www.imdb.com/name/nm0012137
# http://www.imdb.com/title/tt1828968/  http://www.imdb.com/name/nm0134857
# http://www.imdb.com/title/tt1828970/  http://www.imdb.com/name/nm1069989
# http://www.imdb.com/title/tt1828995/  http://www.imdb.com/name/nm2271931
# http://www.imdb.com/title/tt1829012/  http://www.imdb.com/name/nm0000361
# http://www.imdb.com/title/tt1829735/  http://www.imdb.com/name/nm0192466
# http://www.imdb.com/title/tt1830495/  http://www.imdb.com/name/nm4293384
# http://www.imdb.com/title/tt1830713/  http://www.imdb.com/name/nm0579079
# http://www.imdb.com/title/tt1830786/  http://www.imdb.com/name/nm0223522
# http://www.imdb.com/title/tt1830792/  http://www.imdb.com/name/nm0076473
# http://www.imdb.com/title/tt1830802/  http://www.imdb.com/name/nm3524177
# http://www.imdb.com/title/tt1831806/  http://www.imdb.com/name/nm1243970
# http://www.imdb.com/title/tt1832381/  http://www.imdb.com/name/nm2577763
# http://www.imdb.com/title/tt1832382/  http://www.imdb.com/name/nm1410815
# http://www.imdb.com/title/tt1833673/  http://www.imdb.com/name/nm1715502
# ...                                                                  ...
# http://www.imdb.com/title/tt2121382/  http://www.imdb.com/name/nm1128037
# http://www.imdb.com/title/tt2122313/  http://www.imdb.com/name/nm2172605
# http://www.imdb.com/title/tt2122340/  http://www.imdb.com/name/nm1907581
# http://www.imdb.com/title/tt2122424/  http://www.imdb.com/name/nm1408696
# http://www.imdb.com/title/tt2122518/  http://www.imdb.com/name/nm0498898
# http://www.imdb.com/title/tt2123129/  http://www.imdb.com/name/nm1957070
# http://www.imdb.com/title/tt2123146/  http://www.imdb.com/name/nm3075905
# http://www.imdb.com/title/tt2123342/  http://www.imdb.com/name/nm0213191
# http://www.imdb.com/title/tt2124074/  http://www.imdb.com/name/nm0743671
# http://www.imdb.com/title/tt2124186/  http://www.imdb.com/name/nm1729447
# http://www.imdb.com/title/tt2124787/  http://www.imdb.com/name/nm2574176
# http://www.imdb.com/title/tt2125425/  http://www.imdb.com/name/nm0609931
# http://www.imdb.com/title/tt2125435/  http://www.imdb.com/name/nm1022455
# http://www.imdb.com/title/tt2125472/  http://www.imdb.com/name/nm2204477
# http://www.imdb.com/title/tt2125500/  http://www.imdb.com/name/nm3174584
# http://www.imdb.com/title/tt2125685/  http://www.imdb.com/name/nm1052162
# http://www.imdb.com/title/tt2125698/  http://www.imdb.com/name/nm0729086
# http://www.imdb.com/title/tt2126235/  http://www.imdb.com/name/nm2123102
# http://www.imdb.com/title/tt2126282/  http://www.imdb.com/name/nm1069826
# http://www.imdb.com/title/tt2126355/  http://www.imdb.com/name/nm0679031
# http://www.imdb.com/title/tt2126362/  http://www.imdb.com/name/nm1114700
# http://www.imdb.com/title/tt2129887/  http://www.imdb.com/name/nm1388428
# http://www.imdb.com/title/tt2130242/  http://www.imdb.com/name/nm4562662
# http://www.imdb.com/title/tt2130270/  http://www.imdb.com/name/nm0537211
# http://www.imdb.com/title/tt2131523/  http://www.imdb.com/name/nm1269545
# http://www.imdb.com/title/tt2131532/  http://www.imdb.com/name/nm1819972
# http://www.imdb.com/title/tt2131586/  http://www.imdb.com/name/nm2032664
# http://www.imdb.com/title/tt2131698/  http://www.imdb.com/name/nm0726954
# http://www.imdb.com/title/tt2132285/  http://www.imdb.com/name/nm0001068
# http://www.imdb.com/title/tt2132374/  http://www.imdb.com/name/nm0198472
#
#                                          Gross USA    Language  \
# http://www.imdb.com/title/tt1826593/           NaN     Swedish
# http://www.imdb.com/title/tt1826660/           NaN     Russian
# http://www.imdb.com/title/tt1826714/           NaN      Korean
# http://www.imdb.com/title/tt1826813/           NaN     English
# http://www.imdb.com/title/tt1827354/           NaN     English
# http://www.imdb.com/title/tt1827358/           NaN     Swedish
# http://www.imdb.com/title/tt1827372/           NaN  Portuguese
# http://www.imdb.com/title/tt1827487/  1.387303e+10     Turkish
# http://www.imdb.com/title/tt1827512/  1.384749e+12      French
# http://www.imdb.com/title/tt1827528/           NaN      German
# http://www.imdb.com/title/tt1827578/  8.326312e+09     English
# http://www.imdb.com/title/tt1827579/           NaN     English
# http://www.imdb.com/title/tt1828148/           NaN  Portuguese
# http://www.imdb.com/title/tt1828229/  1.097530e+10      French
# http://www.imdb.com/title/tt1828289/           NaN       Hindi
# http://www.imdb.com/title/tt1828959/  1.222933e+11     English
# http://www.imdb.com/title/tt1828968/           NaN     English
# http://www.imdb.com/title/tt1828970/           NaN     English
# http://www.imdb.com/title/tt1828995/           NaN      French
# http://www.imdb.com/title/tt1829012/  9.118622e+10     English
# http://www.imdb.com/title/tt1829735/           NaN     English
# http://www.imdb.com/title/tt1830495/           NaN      German
# http://www.imdb.com/title/tt1830713/           NaN     English
# http://www.imdb.com/title/tt1830786/  2.611562e+11       Hindi
# http://www.imdb.com/title/tt1830792/  7.731820e+08      German
# http://www.imdb.com/title/tt1830802/           NaN     Marathi
# http://www.imdb.com/title/tt1831806/           NaN     English
# http://www.imdb.com/title/tt1832381/           NaN      Korean
# http://www.imdb.com/title/tt1832382/  7.098492e+06     Persian
# http://www.imdb.com/title/tt1833673/  8.031955e+06       Hindi
# ...                                            ...         ...
# http://www.imdb.com/title/tt2121382/  1.358561e+11     Swedish
# http://www.imdb.com/title/tt2122313/           NaN     Swedish
# http://www.imdb.com/title/tt2122340/  4.200461e+10       Hindi
# http://www.imdb.com/title/tt2122424/           NaN     English
# http://www.imdb.com/title/tt2122518/           NaN      French
# http://www.imdb.com/title/tt2123129/           NaN       Tamil
# http://www.imdb.com/title/tt2123146/           NaN     English
# http://www.imdb.com/title/tt2123342/  3.481062e+09     English
# http://www.imdb.com/title/tt2124074/  1.601722e+09     English
# http://www.imdb.com/title/tt2124186/           NaN     Turkish
# http://www.imdb.com/title/tt2124787/  5.500000e+12     English
# http://www.imdb.com/title/tt2125425/           NaN  Portuguese
# http://www.imdb.com/title/tt2125435/  1.279575e+07     English
# http://www.imdb.com/title/tt2125472/           NaN     English
# http://www.imdb.com/title/tt2125500/           NaN     Spanish
# http://www.imdb.com/title/tt2125685/           NaN     English
# http://www.imdb.com/title/tt2125698/  3.798220e+08     Spanish
# http://www.imdb.com/title/tt2126235/  2.280005e+11     English
# http://www.imdb.com/title/tt2126282/           NaN       Hindi
# http://www.imdb.com/title/tt2126355/  1.551908e+08     English
# http://www.imdb.com/title/tt2126362/           NaN     English
# http://www.imdb.com/title/tt2129887/           NaN      French
# http://www.imdb.com/title/tt2130242/  1.774722e+11       Hindi
# http://www.imdb.com/title/tt2130270/           NaN     English
# http://www.imdb.com/title/tt2131523/  2.079152e+09     Tagalog
# http://www.imdb.com/title/tt2131532/           NaN     English
# http://www.imdb.com/title/tt2131586/           NaN    Japanese
# http://www.imdb.com/title/tt2131698/  4.228615e+10     English
# http://www.imdb.com/title/tt2132285/  5.841047e+11     English
# http://www.imdb.com/title/tt2132374/  3.450320e+08     English
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt1826593/                  NaN
# http://www.imdb.com/title/tt1826660/                  NaN
# http://www.imdb.com/title/tt1826714/                  NaN
# http://www.imdb.com/title/tt1826813/                  NaN
# http://www.imdb.com/title/tt1827354/                  NaN
# http://www.imdb.com/title/tt1827358/                  NaN
# http://www.imdb.com/title/tt1827372/                  NaN
# http://www.imdb.com/title/tt1827487/         1.065282e+09
# http://www.imdb.com/title/tt1827512/         4.593318e+10
# http://www.imdb.com/title/tt1827528/                  NaN
# http://www.imdb.com/title/tt1827578/         1.955320e+08
# http://www.imdb.com/title/tt1827579/                  NaN
# http://www.imdb.com/title/tt1828148/                  NaN
# http://www.imdb.com/title/tt1828229/         7.154302e+09
# http://www.imdb.com/title/tt1828289/                  NaN
# http://www.imdb.com/title/tt1828959/         8.117220e+10
# http://www.imdb.com/title/tt1828968/                  NaN
# http://www.imdb.com/title/tt1828970/                  NaN
# http://www.imdb.com/title/tt1828995/                  NaN
# http://www.imdb.com/title/tt1829012/         4.010012e+09
# http://www.imdb.com/title/tt1829735/                  NaN
# http://www.imdb.com/title/tt1830495/                  NaN
# http://www.imdb.com/title/tt1830713/                  NaN
# http://www.imdb.com/title/tt1830786/         1.680829e+10
# http://www.imdb.com/title/tt1830792/         7.731820e+08
# http://www.imdb.com/title/tt1830802/                  NaN
# http://www.imdb.com/title/tt1831806/                  NaN
# http://www.imdb.com/title/tt1832381/                  NaN
# http://www.imdb.com/title/tt1832382/         5.948112e+09
# http://www.imdb.com/title/tt1833673/         3.305000e+12
# ...                                                   ...
# http://www.imdb.com/title/tt2121382/                  NaN
# http://www.imdb.com/title/tt2122313/                  NaN
# http://www.imdb.com/title/tt2122340/         2.407922e+11
# http://www.imdb.com/title/tt2122424/                  NaN
# http://www.imdb.com/title/tt2122518/                  NaN
# http://www.imdb.com/title/tt2123129/                  NaN
# http://www.imdb.com/title/tt2123146/                  NaN
# http://www.imdb.com/title/tt2123342/         5.371232e+09
# http://www.imdb.com/title/tt2124074/         1.869112e+09
# http://www.imdb.com/title/tt2124186/                  NaN
# http://www.imdb.com/title/tt2124787/                  NaN
# http://www.imdb.com/title/tt2125425/                  NaN
# http://www.imdb.com/title/tt2125435/         1.697021e+10
# http://www.imdb.com/title/tt2125472/                  NaN
# http://www.imdb.com/title/tt2125500/                  NaN
# http://www.imdb.com/title/tt2125685/                  NaN
# http://www.imdb.com/title/tt2125698/         3.798220e+08
# http://www.imdb.com/title/tt2126235/         1.512824e+12
# http://www.imdb.com/title/tt2126282/                  NaN
# http://www.imdb.com/title/tt2126355/         5.458817e+13
# http://www.imdb.com/title/tt2126362/                  NaN
# http://www.imdb.com/title/tt2129887/                  NaN
# http://www.imdb.com/title/tt2130242/         9.458326e+10
# http://www.imdb.com/title/tt2130270/                  NaN
# http://www.imdb.com/title/tt2131523/         1.305928e+10
# http://www.imdb.com/title/tt2131532/                  NaN
# http://www.imdb.com/title/tt2131586/                  NaN
# http://www.imdb.com/title/tt2131698/         4.100222e+09
# http://www.imdb.com/title/tt2132285/         2.125372e+11
# http://www.imdb.com/title/tt2132374/         1.361192e+09
#
#                                                                Primary Filming Location  \
# http://www.imdb.com/title/tt1826593/                          Båstad, Skåne län, Sweden
# http://www.imdb.com/title/tt1826660/                                               None
# http://www.imdb.com/title/tt1826714/                                               None
# http://www.imdb.com/title/tt1826813/      DUMBO, Brooklyn, New York City, New York, USA
# http://www.imdb.com/title/tt1827354/                                London, England, UK
# http://www.imdb.com/title/tt1827358/           Gothenburg, Västra Götalands län, Sweden
# http://www.imdb.com/title/tt1827372/                                               None
# http://www.imdb.com/title/tt1827487/                                             Turkey
# http://www.imdb.com/title/tt1827512/                                            Belgium
# http://www.imdb.com/title/tt1827528/            Nuthe-Urmstromtal, Brandenburg, Germany
# http://www.imdb.com/title/tt1827578/                       Los Angeles, California, USA
# http://www.imdb.com/title/tt1827579/                      Widnes, Cheshire, England, UK
# http://www.imdb.com/title/tt1828148/                            Salvador, Bahia, Brazil
# http://www.imdb.com/title/tt1828229/                                               None
# http://www.imdb.com/title/tt1828289/                                               None
# http://www.imdb.com/title/tt1828959/                        New Orleans, Louisiana, USA
# http://www.imdb.com/title/tt1828968/                                               None
# http://www.imdb.com/title/tt1828970/                     Santa Clarita, California, USA
# http://www.imdb.com/title/tt1828995/  Gare de Montgeroult - Courcelles, Rue du Mouli...
# http://www.imdb.com/title/tt1829012/                                            Germany
# http://www.imdb.com/title/tt1829735/                                 Austin, Texas, USA
# http://www.imdb.com/title/tt1830495/                                               None
# http://www.imdb.com/title/tt1830713/                       Los Angeles, California, USA
# http://www.imdb.com/title/tt1830786/                                  Bangkok, Thailand
# http://www.imdb.com/title/tt1830792/           Cologne, North Rhine-Westphalia, Germany
# http://www.imdb.com/title/tt1830802/                         Panhala, Mahrashtra, India
# http://www.imdb.com/title/tt1831806/                         Ashford, Kent, England, UK
# http://www.imdb.com/title/tt1832381/                                               None
# http://www.imdb.com/title/tt1832382/                                       Tehran, Iran
# http://www.imdb.com/title/tt1833673/                             Chicago, Illinois, USA
# ...                                                                                 ...
# http://www.imdb.com/title/tt2121382/                           Les Arcs, Savoie, France
# http://www.imdb.com/title/tt2122313/                                               None
# http://www.imdb.com/title/tt2122340/                         Mumbai, Maharashtra, India
# http://www.imdb.com/title/tt2122424/  Clinton Store - 598 N 1190 Rd, Lawrence, Kansa...
# http://www.imdb.com/title/tt2122518/                                      Paris, France
# http://www.imdb.com/title/tt2123129/                                               None
# http://www.imdb.com/title/tt2123146/                       Los Angeles, California, USA
# http://www.imdb.com/title/tt2123342/                            North Canton, Ohio, USA
# http://www.imdb.com/title/tt2124074/                    West Hollywood, California, USA
# http://www.imdb.com/title/tt2124186/                                  Eskisehir, Turkey
# http://www.imdb.com/title/tt2124787/                Vancouver, British Columbia, Canada
# http://www.imdb.com/title/tt2125425/                                               None
# http://www.imdb.com/title/tt2125435/                                     Louisiana, USA
# http://www.imdb.com/title/tt2125472/                                               None
# http://www.imdb.com/title/tt2125500/                                          Argentina
# http://www.imdb.com/title/tt2125685/                       Los Angeles, California, USA
# http://www.imdb.com/title/tt2125698/                                    Santiago, Chile
# http://www.imdb.com/title/tt2126235/           Cologne, North Rhine-Westphalia, Germany
# http://www.imdb.com/title/tt2126282/        Alleppey, Alappuzha District, Kerala, India
# http://www.imdb.com/title/tt2126355/  Village Roadshow Studios, Oxenford, Queensland...
# http://www.imdb.com/title/tt2126362/                                    Dublin, Ireland
# http://www.imdb.com/title/tt2129887/                                      Paris, France
# http://www.imdb.com/title/tt2130242/                             Patiala, Punjab, India
# http://www.imdb.com/title/tt2130270/                                               None
# http://www.imdb.com/title/tt2131523/                          Metro Manila, Philippines
# http://www.imdb.com/title/tt2131532/                Vancouver, British Columbia, Canada
# http://www.imdb.com/title/tt2131586/                                               None
# http://www.imdb.com/title/tt2131698/                                      Haifa, Israel
# http://www.imdb.com/title/tt2132285/                       Los Angeles, California, USA
# http://www.imdb.com/title/tt2132374/                     Dublin, County Dublin, Ireland
#
#                                                 Production Company  \
# http://www.imdb.com/title/tt1826593/          Fasad Postproduktion
# http://www.imdb.com/title/tt1826660/           Art Pictures Studio
# http://www.imdb.com/title/tt1826714/              Soo Film Company
# http://www.imdb.com/title/tt1826813/         Cranium Entertainment
# http://www.imdb.com/title/tt1827354/             Press On Features
# http://www.imdb.com/title/tt1827358/            Atmo Media Network
# http://www.imdb.com/title/tt1827372/                    Kinoscopio
# http://www.imdb.com/title/tt1827487/                     Zeynofilm
# http://www.imdb.com/title/tt1827512/           Les Films du Fleuve
# http://www.imdb.com/title/tt1827528/    Salzgeber & Company Medien
# http://www.imdb.com/title/tt1827578/                Poor Rich Kids
# http://www.imdb.com/title/tt1827579/                Bankside Films
# http://www.imdb.com/title/tt1828148/    Lagoa Cultural & Esportiva
# http://www.imdb.com/title/tt1828229/        Nord-Ouest Productions
# http://www.imdb.com/title/tt1828289/            Faizee Productions
# http://www.imdb.com/title/tt1828959/              CJ Entertainment
# http://www.imdb.com/title/tt1828968/                      Studio13
# http://www.imdb.com/title/tt1828970/                    Bold Films
# http://www.imdb.com/title/tt1828995/                  2.4.7. Films
# http://www.imdb.com/title/tt1829012/               SBS Productions
# http://www.imdb.com/title/tt1829735/               Goat Man's Hill
# http://www.imdb.com/title/tt1830495/                   Mirror Maze
# http://www.imdb.com/title/tt1830713/           Epic Pictures Group
# http://www.imdb.com/title/tt1830786/  M/s Rupali Aum Entertainment
# http://www.imdb.com/title/tt1830792/                    Boogiefilm
# http://www.imdb.com/title/tt1830802/      Concepts & Conversations
# http://www.imdb.com/title/tt1831806/                  Film Harvest
# http://www.imdb.com/title/tt1832381/         Generation Blue Films
# http://www.imdb.com/title/tt1832382/    Asghar Farhadi Productions
# http://www.imdb.com/title/tt1833673/          CounterPunch Studios
# ...                                                            ...
# http://www.imdb.com/title/tt2121382/                       Beofilm
# http://www.imdb.com/title/tt2122313/                      RMV Film
# http://www.imdb.com/title/tt2122340/      Vinod Chopra Productions
# http://www.imdb.com/title/tt2122424/  Ministry Machine Productions
# http://www.imdb.com/title/tt2122518/         Les Films Manuel Munz
# http://www.imdb.com/title/tt2123129/               R.K Productions
# http://www.imdb.com/title/tt2123146/      Cinemassacre Productions
# http://www.imdb.com/title/tt2123342/     Media Service Corporation
# http://www.imdb.com/title/tt2124074/          Mott Street Pictures
# http://www.imdb.com/title/tt2124186/                  Eflatun Film
# http://www.imdb.com/title/tt2124787/               NGN Productions
# http://www.imdb.com/title/tt2125425/                  Globo Filmes
# http://www.imdb.com/title/tt2125435/                     Cinereach
# http://www.imdb.com/title/tt2125472/            Mane Entertainment
# http://www.imdb.com/title/tt2125500/             Anonymous Content
# http://www.imdb.com/title/tt2125685/         Blumhouse Productions
# http://www.imdb.com/title/tt2125698/                        Fabula
# http://www.imdb.com/title/tt2126235/                            42
# http://www.imdb.com/title/tt2126282/                Photon Kathaas
# http://www.imdb.com/title/tt2126355/     Village Roadshow Pictures
# http://www.imdb.com/title/tt2126362/               MPI Media Group
# http://www.imdb.com/title/tt2129887/                     Chapter 2
# http://www.imdb.com/title/tt2130242/               Tips Industries
# http://www.imdb.com/title/tt2130270/                         4Cows
# http://www.imdb.com/title/tt2131523/              Imprint Pictures
# http://www.imdb.com/title/tt2131532/          Primal Pictures (II)
# http://www.imdb.com/title/tt2131586/             TMS Entertainment
# http://www.imdb.com/title/tt2131698/            Bedlam Productions
# http://www.imdb.com/title/tt2132285/             American Zoetrope
# http://www.imdb.com/title/tt2132374/                 Fastnet Films
#
#                                      Release Date                  Star1  \
# http://www.imdb.com/title/tt1826593/   2012-02-24         Johannes Brost
# http://www.imdb.com/title/tt1826660/   2012-10-04       Danila Kozlovsky
# http://www.imdb.com/title/tt1826714/   2010-12-08           Soo-jung Lim
# http://www.imdb.com/title/tt1826813/   2013-06-28           Tobias Segal
# http://www.imdb.com/title/tt1827354/   2013-02-06           Craig Conway
# http://www.imdb.com/title/tt1827358/   2011-09-02    Mathilda Paradeiser
# http://www.imdb.com/title/tt1827372/   2010-10-02     Daniel de Oliveira
# http://www.imdb.com/title/tt1827487/   2011-09-23        Muhammet Uzuner
# http://www.imdb.com/title/tt1827512/   2011-05-18           Thomas Doret
# http://www.imdb.com/title/tt1827528/   2011-05-19         Lukas Steltner
# http://www.imdb.com/title/tt1827578/   2012-01-21            Mark Webber
# http://www.imdb.com/title/tt1827579/   2015-05-08      Elliott Tittensor
# http://www.imdb.com/title/tt1828148/   2011-10-07       Jean Luis Amorim
# http://www.imdb.com/title/tt1828229/   2011-07-20         Julien Béramis
# http://www.imdb.com/title/tt1828289/   2011-05-13           Nana Patekar
# http://www.imdb.com/title/tt1828959/   2014-04-17            Derek Hough
# http://www.imdb.com/title/tt1828968/   2014-05-09          Anne Hathaway
# http://www.imdb.com/title/tt1828970/   2013-07-19         Torrey DeVitto
# http://www.imdb.com/title/tt1828995/   2011-12-21          Audrey Tautou
# http://www.imdb.com/title/tt1829012/   2013-08-30         Rachel McAdams
# http://www.imdb.com/title/tt1829735/         2012  Skye McCole Bartusiak
# http://www.imdb.com/title/tt1830495/   2013-12-03     Andreas Wisniewski
# http://www.imdb.com/title/tt1830713/   2014-10-10          Greg Grunberg
# http://www.imdb.com/title/tt1830786/   2011-10-06             Ajay Devgn
# http://www.imdb.com/title/tt1830792/   2011-12-08              Rick Okon
# http://www.imdb.com/title/tt1830802/   2012-01-20         Anshuman Joshi
# http://www.imdb.com/title/tt1831806/   2012-12-31             Cory Knauf
# http://www.imdb.com/title/tt1832381/   2011-01-27          Myung-min Kim
# http://www.imdb.com/title/tt1832382/   2011-03-16           Payman Maadi
# http://www.imdb.com/title/tt1833673/   2013-12-20             Aamir Khan
# ...                                           ...                    ...
# http://www.imdb.com/title/tt2121382/   2014-12-30        Johannes Kuhnke
# http://www.imdb.com/title/tt2122313/   2015-02-18        Josefin Asplund
# http://www.imdb.com/title/tt2122340/   2012-06-15          Sharman Joshi
# http://www.imdb.com/title/tt2122424/   2013-05-28           Erin McGrane
# http://www.imdb.com/title/tt2122518/   2012-01-04            Roschdy Zem
# http://www.imdb.com/title/tt2123129/   2012-03-30                Dhanush
# http://www.imdb.com/title/tt2123146/   2014-07-21            James Rolfe
# http://www.imdb.com/title/tt2123342/   2013-04-06           D.B. Sweeney
# http://www.imdb.com/title/tt2124074/   2012-11-09          Marin Ireland
# http://www.imdb.com/title/tt2124186/   2011-11-18          Selçuk Yöntem
# http://www.imdb.com/title/tt2124787/   2015-08-14        Abigail Breslin
# http://www.imdb.com/title/tt2125425/   2013-03-15           Wagner Moura
# http://www.imdb.com/title/tt2125435/   2012-07-05      Quvenzhané Wallis
# http://www.imdb.com/title/tt2125472/   2015-02-04             Tyler Mane
# http://www.imdb.com/title/tt2125500/   2012-04-26          John McInerny
# http://www.imdb.com/title/tt2125685/   2014-10-07        Alexandra Lydon
# http://www.imdb.com/title/tt2125698/   2012-11-30       Alicia Rodríguez
# http://www.imdb.com/title/tt2126235/   2017-02-24         Nicholas Hoult
# http://www.imdb.com/title/tt2126282/   2012-02-17                Prateik
# http://www.imdb.com/title/tt2126355/   2015-05-29         Dwayne Johnson
# http://www.imdb.com/title/tt2126362/   2012-10-26             Ross Noble
# http://www.imdb.com/title/tt2129887/   2013-10-16      Raphaël Personnaz
# http://www.imdb.com/title/tt2130242/   2012-02-24       Riteish Deshmukh
# http://www.imdb.com/title/tt2130270/   2014-11-21           Hugo Weaving
# http://www.imdb.com/title/tt2131523/   2013-04-26           Arnold Reyes
# http://www.imdb.com/title/tt2131532/   2015-09-15    Alexander Skarsgård
# http://www.imdb.com/title/tt2131586/   2012-04-14        Minami Takayama
# http://www.imdb.com/title/tt2131698/   2013-09-20          Stephen Dorff
# http://www.imdb.com/title/tt2132285/   2013-06-21            Katie Chang
# http://www.imdb.com/title/tt2132374/   2013-07-19         Kelly Thornton
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt1826593/  http://www.imdb.com/name/nm0112549
# http://www.imdb.com/title/tt1826660/  http://www.imdb.com/name/nm1572716
# http://www.imdb.com/title/tt1826714/  http://www.imdb.com/name/nm1280145
# http://www.imdb.com/title/tt1826813/  http://www.imdb.com/name/nm1708414
# http://www.imdb.com/title/tt1827354/  http://www.imdb.com/name/nm0176660
# http://www.imdb.com/title/tt1827358/  http://www.imdb.com/name/nm4288659
# http://www.imdb.com/title/tt1827372/  http://www.imdb.com/name/nm0210655
# http://www.imdb.com/title/tt1827487/  http://www.imdb.com/name/nm1959252
# http://www.imdb.com/title/tt1827512/  http://www.imdb.com/name/nm4461361
# http://www.imdb.com/title/tt1827528/  http://www.imdb.com/name/nm2597657
# http://www.imdb.com/title/tt1827578/  http://www.imdb.com/name/nm0916406
# http://www.imdb.com/title/tt1827579/  http://www.imdb.com/name/nm1541685
# http://www.imdb.com/title/tt1828148/  http://www.imdb.com/name/nm4289532
# http://www.imdb.com/title/tt1828229/  http://www.imdb.com/name/nm2246504
# http://www.imdb.com/title/tt1828289/  http://www.imdb.com/name/nm0007113
# http://www.imdb.com/title/tt1828959/  http://www.imdb.com/name/nm2625538
# http://www.imdb.com/title/tt1828968/  http://www.imdb.com/name/nm0004266
# http://www.imdb.com/title/tt1828970/  http://www.imdb.com/name/nm1722914
# http://www.imdb.com/title/tt1828995/  http://www.imdb.com/name/nm0851582
# http://www.imdb.com/title/tt1829012/  http://www.imdb.com/name/nm1046097
# http://www.imdb.com/title/tt1829735/  http://www.imdb.com/name/nm0566084
# http://www.imdb.com/title/tt1830495/  http://www.imdb.com/name/nm0936591
# http://www.imdb.com/title/tt1830713/  http://www.imdb.com/name/nm0342399
# http://www.imdb.com/title/tt1830786/  http://www.imdb.com/name/nm0222426
# http://www.imdb.com/title/tt1830792/  http://www.imdb.com/name/nm2903245
# http://www.imdb.com/title/tt1830802/  http://www.imdb.com/name/nm4308385
# http://www.imdb.com/title/tt1831806/  http://www.imdb.com/name/nm1816540
# http://www.imdb.com/title/tt1832381/  http://www.imdb.com/name/nm1047988
# http://www.imdb.com/title/tt1832382/  http://www.imdb.com/name/nm1818216
# http://www.imdb.com/title/tt1833673/  http://www.imdb.com/name/nm0451148
# ...                                                                  ...
# http://www.imdb.com/title/tt2121382/  http://www.imdb.com/name/nm1090326
# http://www.imdb.com/title/tt2122313/  http://www.imdb.com/name/nm4739140
# http://www.imdb.com/title/tt2122340/  http://www.imdb.com/name/nm0430817
# http://www.imdb.com/title/tt2122424/  http://www.imdb.com/name/nm0569753
# http://www.imdb.com/title/tt2122518/  http://www.imdb.com/name/nm0954704
# http://www.imdb.com/title/tt2123129/  http://www.imdb.com/name/nm1333687
# http://www.imdb.com/title/tt2123146/  http://www.imdb.com/name/nm3005544
# http://www.imdb.com/title/tt2123342/  http://www.imdb.com/name/nm0000665
# http://www.imdb.com/title/tt2124074/  http://www.imdb.com/name/nm1677477
# http://www.imdb.com/title/tt2124186/  http://www.imdb.com/name/nm1008511
# http://www.imdb.com/title/tt2124787/  http://www.imdb.com/name/nm1113550
# http://www.imdb.com/title/tt2125425/  http://www.imdb.com/name/nm0609944
# http://www.imdb.com/title/tt2125435/  http://www.imdb.com/name/nm4832920
# http://www.imdb.com/title/tt2125472/  http://www.imdb.com/name/nm0541932
# http://www.imdb.com/title/tt2125500/  http://www.imdb.com/name/nm4796490
# http://www.imdb.com/title/tt2125685/  http://www.imdb.com/name/nm1605097
# http://www.imdb.com/title/tt2125698/  http://www.imdb.com/name/nm3396723
# http://www.imdb.com/title/tt2126235/  http://www.imdb.com/name/nm0396558
# http://www.imdb.com/title/tt2126282/  http://www.imdb.com/name/nm3070408
# http://www.imdb.com/title/tt2126355/  http://www.imdb.com/name/nm0425005
# http://www.imdb.com/title/tt2126362/  http://www.imdb.com/name/nm0633665
# http://www.imdb.com/title/tt2129887/  http://www.imdb.com/name/nm0675521
# http://www.imdb.com/title/tt2130242/  http://www.imdb.com/name/nm1299011
# http://www.imdb.com/title/tt2130270/  http://www.imdb.com/name/nm0915989
# http://www.imdb.com/title/tt2131523/  http://www.imdb.com/name/nm1851576
# http://www.imdb.com/title/tt2131532/  http://www.imdb.com/name/nm0002907
# http://www.imdb.com/title/tt2131586/  http://www.imdb.com/name/nm0847439
# http://www.imdb.com/title/tt2131698/  http://www.imdb.com/name/nm0001151
# http://www.imdb.com/title/tt2132285/  http://www.imdb.com/name/nm4583512
# http://www.imdb.com/title/tt2132374/  http://www.imdb.com/name/nm5801651
#
#                                                     Star2  \
# http://www.imdb.com/title/tt1826593/       Peter Carlberg
# http://www.imdb.com/title/tt1826660/      Mariya Andreeva
# http://www.imdb.com/title/tt1826714/             Yoo Gong
# http://www.imdb.com/title/tt1826813/          Thora Birch
# http://www.imdb.com/title/tt1827354/       Simon Phillips
# http://www.imdb.com/title/tt1827358/          Linda Molin
# http://www.imdb.com/title/tt1827372/       Hermila Guedes
# http://www.imdb.com/title/tt1827487/       Yilmaz Erdogan
# http://www.imdb.com/title/tt1827512/     Cécile de France
# http://www.imdb.com/title/tt1827528/   Kai Michael Müller
# http://www.imdb.com/title/tt1827578/         Alia Shawkat
# http://www.imdb.com/title/tt1827579/      Nico Mirallegro
# http://www.imdb.com/title/tt1828148/         Ana Graciela
# http://www.imdb.com/title/tt1828229/        Marine Griset
# http://www.imdb.com/title/tt1828289/        Mohit Ahlawat
# http://www.imdb.com/title/tt1828959/                  BoA
# http://www.imdb.com/title/tt1828968/         Josh Duhamel
# http://www.imdb.com/title/tt1828970/       Caitlin Stasey
# http://www.imdb.com/title/tt1828995/     François Damiens
# http://www.imdb.com/title/tt1829012/         Noomi Rapace
# http://www.imdb.com/title/tt1829735/          Marc Donato
# http://www.imdb.com/title/tt1830495/         Steven Weber
# http://www.imdb.com/title/tt1830713/            Lin Shaye
# http://www.imdb.com/title/tt1830786/          Sanjay Dutt
# http://www.imdb.com/title/tt1830792/           Max Befort
# http://www.imdb.com/title/tt1830802/   Ketaki Mategaonkar
# http://www.imdb.com/title/tt1831806/         Samuel Child
# http://www.imdb.com/title/tt1832381/            Dal-su Oh
# http://www.imdb.com/title/tt1832382/         Leila Hatami
# http://www.imdb.com/title/tt1833673/         Katrina Kaif
# ...                                                   ...
# http://www.imdb.com/title/tt2121382/   Lisa Loven Kongsli
# http://www.imdb.com/title/tt2122313/      Helena Engström
# http://www.imdb.com/title/tt2122340/          Boman Irani
# http://www.imdb.com/title/tt2122424/          Meg Saricks
# http://www.imdb.com/title/tt2122518/       Sara Forestier
# http://www.imdb.com/title/tt2123129/        Shruti Haasan
# http://www.imdb.com/title/tt2123146/        Jeremy Suarez
# http://www.imdb.com/title/tt2123342/     William Mapother
# http://www.imdb.com/title/tt2124074/        Chris Messina
# http://www.imdb.com/title/tt2124186/            Ezgi Mola
# http://www.imdb.com/title/tt2124787/          Wes Bentley
# http://www.imdb.com/title/tt2125425/          Lima Duarte
# http://www.imdb.com/title/tt2125435/         Dwight Henry
# http://www.imdb.com/title/tt2125472/          Muse Watson
# http://www.imdb.com/title/tt2125500/   Griselda Siciliani
# http://www.imdb.com/title/tt2125685/       Todd Stashwick
# http://www.imdb.com/title/tt2125698/     Aline Küppenheim
# http://www.imdb.com/title/tt2126235/       Felicity Jones
# http://www.imdb.com/title/tt2126282/          Amy Jackson
# http://www.imdb.com/title/tt2126355/         Carla Gugino
# http://www.imdb.com/title/tt2126362/         Tommy Knight
# http://www.imdb.com/title/tt2129887/        Bérénice Bejo
# http://www.imdb.com/title/tt2130242/      Genelia D'Souza
# http://www.imdb.com/title/tt2130270/        Angus Sampson
# ...
# http://www.imdb.com/title/tt2122518/  http://www.imdb.com/name/nm1271759
# http://www.imdb.com/title/tt2123129/  http://www.imdb.com/name/nm1599046
# http://www.imdb.com/title/tt2123146/  http://www.imdb.com/name/nm0836836
# http://www.imdb.com/title/tt2123342/  http://www.imdb.com/name/nm0544611
# http://www.imdb.com/title/tt2124074/  http://www.imdb.com/name/nm0582149
# http://www.imdb.com/title/tt2124186/  http://www.imdb.com/name/nm1759326
# http://www.imdb.com/title/tt2124787/  http://www.imdb.com/name/nm0004747
# http://www.imdb.com/title/tt2125425/  http://www.imdb.com/name/nm0239114
# http://www.imdb.com/title/tt2125435/  http://www.imdb.com/name/nm4833412
# http://www.imdb.com/title/tt2125472/  http://www.imdb.com/name/nm0002901
# http://www.imdb.com/title/tt2125500/  http://www.imdb.com/name/nm2155527
# http://www.imdb.com/title/tt2125685/  http://www.imdb.com/name/nm0823693
# http://www.imdb.com/title/tt2125698/  http://www.imdb.com/name/nm0478202
# http://www.imdb.com/title/tt2126235/  http://www.imdb.com/name/nm0428065
# http://www.imdb.com/title/tt2126282/  http://www.imdb.com/name/nm3367112
# http://www.imdb.com/title/tt2126355/  http://www.imdb.com/name/nm0001303
# http://www.imdb.com/title/tt2126362/  http://www.imdb.com/name/nm1740366
# http://www.imdb.com/title/tt2129887/  http://www.imdb.com/name/nm0067367
# http://www.imdb.com/title/tt2130242/  http://www.imdb.com/name/nm1299510
# http://www.imdb.com/title/tt2130270/  http://www.imdb.com/name/nm0760151
# http://www.imdb.com/title/tt2131523/  http://www.imdb.com/name/nm0167728
# http://www.imdb.com/title/tt2131532/  http://www.imdb.com/name/nm2057859
# http://www.imdb.com/title/tt2131586/  http://www.imdb.com/name/nm0468711
# http://www.imdb.com/title/tt2131698/  http://www.imdb.com/name/nm2713320
# http://www.imdb.com/title/tt2132285/  http://www.imdb.com/name/nm3441152
# http://www.imdb.com/title/tt2132374/  http://www.imdb.com/name/nm0001217
#
#                                                        Star3  \
# http://www.imdb.com/title/tt1826593/        Léonore Ekstrand
# http://www.imdb.com/title/tt1826660/        Artyom Mikhalkov
# http://www.imdb.com/title/tt1826714/            Seung-su Ryu
# http://www.imdb.com/title/tt1826813/         Christine Lahti
# http://www.imdb.com/title/tt1827354/          Gemma Atkinson
# http://www.imdb.com/title/tt1827358/      Isabella Lindquist
# http://www.imdb.com/title/tt1827372/        Jefferson Brasil
# http://www.imdb.com/title/tt1827487/            Taner Birsel
# http://www.imdb.com/title/tt1827512/          Jérémie Renier
# http://www.imdb.com/title/tt1827528/            Steven Baade
# http://www.imdb.com/title/tt1827578/        Shannyn Sossamon
# http://www.imdb.com/title/tt1827579/               Adam Long
# http://www.imdb.com/title/tt1828148/            Roberio Lima
# http://www.imdb.com/title/tt1828229/            Michel Elias
# http://www.imdb.com/title/tt1828289/                Rimi Sen
# http://www.imdb.com/title/tt1828959/            Will Yun Lee
# http://www.imdb.com/title/tt1828968/            Topher Grace
# http://www.imdb.com/title/tt1828970/            Harry Lennix
# http://www.imdb.com/title/tt1828995/        Bruno Todeschini
# http://www.imdb.com/title/tt1829012/       Karoline Herfurth
# http://www.imdb.com/title/tt1829735/           Debbie Rochon
# http://www.imdb.com/title/tt1830495/        Joachim Günthner
# http://www.imdb.com/title/tt1830713/               Ruben Pla
# http://www.imdb.com/title/tt1830786/          Kangana Ranaut
# http://www.imdb.com/title/tt1830792/          Liv Lisa Fries
# http://www.imdb.com/title/tt1830802/      Dilip Prabhavalkar
# http://www.imdb.com/title/tt1831806/       Mackenzie Firgens
# http://www.imdb.com/title/tt1832381/              Ji-min Han
# http://www.imdb.com/title/tt1832382/             Sareh Bayat
# http://www.imdb.com/title/tt1833673/       Abhishek Bachchan
# ...                                                      ...
# http://www.imdb.com/title/tt2121382/        Clara Wettergren
# http://www.imdb.com/title/tt2122313/         Miranda Frydman
# http://www.imdb.com/title/tt2122340/           Ritvik Sahore
# http://www.imdb.com/title/tt2122424/           Emily Boresow
# http://www.imdb.com/title/tt2122518/         Samuel Le Bihan
# http://www.imdb.com/title/tt2123129/                  Prabhu
# http://www.imdb.com/title/tt2123146/        Sarah Glendening
# http://www.imdb.com/title/tt2123342/         Richard Portnow
# http://www.imdb.com/title/tt2124074/           Robert Deamer
# http://www.imdb.com/title/tt2124186/       Bülent Emin Yarar
# http://www.imdb.com/title/tt2124787/           Logan Huffman
# http://www.imdb.com/title/tt2125425/            Mariana Lima
# http://www.imdb.com/title/tt2125435/           Levy Easterly
# http://www.imdb.com/title/tt2125472/             Derek Mears
# http://www.imdb.com/title/tt2125500/         Margarita Lopez
# http://www.imdb.com/title/tt2125685/   Audrey Marie Anderson
# http://www.imdb.com/title/tt2125698/     María Gracia Omegna
# http://www.imdb.com/title/tt2126235/         Anthony Hopkins
# http://www.imdb.com/title/tt2126282/         Sachin Khedekar
# http://www.imdb.com/title/tt2126355/      Alexandra Daddario
# http://www.imdb.com/title/tt2126362/          Eoghan McQuinn
# http://www.imdb.com/title/tt2129887/  Guillaume de Tonquédec
# http://www.imdb.com/title/tt2130242/                 Om Puri
# http://www.imdb.com/title/tt2130270/          Leigh Whannell
# http://www.imdb.com/title/tt2131523/          Dido de la Paz
# http://www.imdb.com/title/tt2131532/         Emily Alyn Lind
# http://www.imdb.com/title/tt2131586/         Wakana Yamazaki
# http://www.imdb.com/title/tt2131698/          Alice Taglioni
# http://www.imdb.com/title/tt2132285/             Emma Watson
# http://www.imdb.com/title/tt2132374/              Pat Shortt
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt1826593/  http://www.imdb.com/name/nm5149400
# http://www.imdb.com/title/tt1826660/  http://www.imdb.com/name/nm0586480
# http://www.imdb.com/title/tt1826714/  http://www.imdb.com/name/nm1422733
# http://www.imdb.com/title/tt1826813/  http://www.imdb.com/name/nm0001441
# http://www.imdb.com/title/tt1827354/  http://www.imdb.com/name/nm1074432
# http://www.imdb.com/title/tt1827358/  http://www.imdb.com/name/nm4288407
# http://www.imdb.com/title/tt1827372/  http://www.imdb.com/name/nm2946500
# http://www.imdb.com/title/tt1827487/  http://www.imdb.com/name/nm0083777
# http://www.imdb.com/title/tt1827512/  http://www.imdb.com/name/nm0753737
# http://www.imdb.com/title/tt1827528/  http://www.imdb.com/name/nm4414528
# http://www.imdb.com/title/tt1827578/  http://www.imdb.com/name/nm0815370
# http://www.imdb.com/title/tt1827579/  http://www.imdb.com/name/nm3072420
# http://www.imdb.com/title/tt1828148/  http://www.imdb.com/name/nm4289063
# http://www.imdb.com/title/tt1828229/  http://www.imdb.com/name/nm0253502
# http://www.imdb.com/title/tt1828289/  http://www.imdb.com/name/nm1267008
# http://www.imdb.com/title/tt1828959/  http://www.imdb.com/name/nm0498449
# http://www.imdb.com/title/tt1828968/  http://www.imdb.com/name/nm0333410
# http://www.imdb.com/title/tt1828970/  http://www.imdb.com/name/nm0502015
# http://www.imdb.com/title/tt1828995/  http://www.imdb.com/name/nm0865333
# http://www.imdb.com/title/tt1829012/  http://www.imdb.com/name/nm0378932
# http://www.imdb.com/title/tt1829735/  http://www.imdb.com/name/nm0004193
# http://www.imdb.com/title/tt1830495/  http://www.imdb.com/name/nm4293904
# http://www.imdb.com/title/tt1830713/  http://www.imdb.com/name/nm0006604
# http://www.imdb.com/title/tt1830786/  http://www.imdb.com/name/nm2144007
# http://www.imdb.com/title/tt1830792/  http://www.imdb.com/name/nm2939186
# http://www.imdb.com/title/tt1830802/  http://www.imdb.com/name/nm1242068
# http://www.imdb.com/title/tt1831806/  http://www.imdb.com/name/nm0278673
# http://www.imdb.com/title/tt1832381/  http://www.imdb.com/name/nm1617711
# http://www.imdb.com/title/tt1832382/  http://www.imdb.com/name/nm4299147
# http://www.imdb.com/title/tt1833673/  http://www.imdb.com/name/nm0045393
# ...                                                                  ...
# http://www.imdb.com/title/tt2121382/  http://www.imdb.com/name/nm6425836
# http://www.imdb.com/title/tt2122313/  http://www.imdb.com/name/nm6568131
# http://www.imdb.com/title/tt2122340/  http://www.imdb.com/name/nm5057209
# http://www.imdb.com/title/tt2122424/  http://www.imdb.com/name/nm4791129
# http://www.imdb.com/title/tt2122518/  http://www.imdb.com/name/nm0494078
# http://www.imdb.com/title/tt2123129/  http://www.imdb.com/name/nm0694893
# http://www.imdb.com/title/tt2123146/  http://www.imdb.com/name/nm2262265
# http://www.imdb.com/title/tt2123342/  http://www.imdb.com/name/nm0692466
# http://www.imdb.com/title/tt2124074/  http://www.imdb.com/name/nm1219374
# http://www.imdb.com/title/tt2124186/  http://www.imdb.com/name/nm0946352
# http://www.imdb.com/title/tt2124787/  http://www.imdb.com/name/nm2943468
# http://www.imdb.com/title/tt2125425/  http://www.imdb.com/name/nm0510678
# http://www.imdb.com/title/tt2125435/  http://www.imdb.com/name/nm3017611
# http://www.imdb.com/title/tt2125472/  http://www.imdb.com/name/nm0575216
# http://www.imdb.com/title/tt2125500/  http://www.imdb.com/name/nm4796463
# http://www.imdb.com/title/tt2125685/  http://www.imdb.com/name/nm1017524
# http://www.imdb.com/title/tt2125698/  http://www.imdb.com/name/nm3014822
# http://www.imdb.com/title/tt2126235/  http://www.imdb.com/name/nm0000164
# http://www.imdb.com/title/tt2126282/  http://www.imdb.com/name/nm0451561
# http://www.imdb.com/title/tt2126355/  http://www.imdb.com/name/nm1275259
# http://www.imdb.com/title/tt2126362/  http://www.imdb.com/name/nm4308537
# http://www.imdb.com/title/tt2129887/  http://www.imdb.com/name/nm0211956
# http://www.imdb.com/title/tt2130242/  http://www.imdb.com/name/nm0700875
# http://www.imdb.com/title/tt2130270/  http://www.imdb.com/name/nm1191481
# http://www.imdb.com/title/tt2131523/  http://www.imdb.com/name/nm0209337
# http://www.imdb.com/title/tt2131532/  http://www.imdb.com/name/nm3014840
# http://www.imdb.com/title/tt2131586/  http://www.imdb.com/name/nm0906722
# http://www.imdb.com/title/tt2131698/  http://www.imdb.com/name/nm0998117
# http://www.imdb.com/title/tt2132285/  http://www.imdb.com/name/nm0914612
# http://www.imdb.com/title/tt2132374/  http://www.imdb.com/name/nm0795169
#
#                                                                              Title
# http://www.imdb.com/title/tt1826593/                                        Avalon
# http://www.imdb.com/title/tt1826660/                                      Dukhless
# http://www.imdb.com/title/tt1826714/                         Kim-jong-wook-chat-gi
# http://www.imdb.com/title/tt1826813/                                       Petunia
# http://www.imdb.com/title/tt1827354/                                      Airborne
# http://www.imdb.com/title/tt1827358/                                   Apflickorna
# http://www.imdb.com/title/tt1827372/                                  Boca do Lixo
# http://www.imdb.com/title/tt1827487/                       Bir Zamanlar Anadolu'da
# http://www.imdb.com/title/tt1827512/                           The Kid with a Bike
# http://www.imdb.com/title/tt1827528/                              Stadt Land Fluss
# http://www.imdb.com/title/tt1827578/                               The End of Love
# http://www.imdb.com/title/tt1827579/                                  Spike Island
# http://www.imdb.com/title/tt1828148/                             Capitães da Areia
# http://www.imdb.com/title/tt1828229/                         Les contes de la nuit
# http://www.imdb.com/title/tt1828289/                                       Shagird
# http://www.imdb.com/title/tt1828959/                                Make Your Move
# http://www.imdb.com/title/tt1828968/                                    Don Peyote
# http://www.imdb.com/title/tt1828970/                                      Evidence
# http://www.imdb.com/title/tt1828995/                                La délicatesse
# http://www.imdb.com/title/tt1829012/                                       Passion
# http://www.imdb.com/title/tt1829735/                                      Sick Boy
# http://www.imdb.com/title/tt1830495/                           Bela Kiss: Prologue
# http://www.imdb.com/title/tt1830713/                               Big Ass Spider!
# http://www.imdb.com/title/tt1830786/                                       Rascals
# http://www.imdb.com/title/tt1830792/                                        Romeos
# http://www.imdb.com/title/tt1830802/                                         Shala
# http://www.imdb.com/title/tt1831806/                                 The Thompsons
# http://www.imdb.com/title/tt1832381/   Joseon myungtamjung: Gakshituku ggotui biil
# http://www.imdb.com/title/tt1832382/                                  A Separation
# http://www.imdb.com/title/tt1833673/                                       Dhoom 3
# ...                                                                            ...
# http://www.imdb.com/title/tt2121382/                                        Turist
# http://www.imdb.com/title/tt2122313/                                       Cirkeln
# http://www.imdb.com/title/tt2122340/                            Ferrari Ki Sawaari
# http://www.imdb.com/title/tt2122424/                                     Nailbiter
# http://www.imdb.com/title/tt2122518/                                      Une nuit
# http://www.imdb.com/title/tt2123129/                                             3
# http://www.imdb.com/title/tt2123146/              Angry Video Game Nerd: The Movie
# http://www.imdb.com/title/tt2123342/                                     Underdogs
# http://www.imdb.com/title/tt2124074/                                28 Hotel Rooms
# http://www.imdb.com/title/tt2124186/  Celal Tan ve Ailesinin Asiri Acikli Hikayesi
# http://www.imdb.com/title/tt2124787/                                    Final Girl
# http://www.imdb.com/title/tt2125425/                                Father's Chair
# http://www.imdb.com/title/tt2125435/                   Beasts of the Southern Wild
# http://www.imdb.com/title/tt2125472/                             Compound Fracture
# http://www.imdb.com/title/tt2125500/                                The Last Elvis
# http://www.imdb.com/title/tt2125685/                                   Mockingbird
# http://www.imdb.com/title/tt2125698/                               Joven y Alocada
# http://www.imdb.com/title/tt2126235/                                       Collide
# http://www.imdb.com/title/tt2126282/                               Ekk Deewana Tha
# http://www.imdb.com/title/tt2126355/                                   San Andreas
# http://www.imdb.com/title/tt2126362/                                      Stitches
# http://www.imdb.com/title/tt2129887/                          Au bonheur des ogres
# http://www.imdb.com/title/tt2130242/                        Tere Naal Love Ho Gaya
# http://www.imdb.com/title/tt2130270/                                      The Mule
# http://www.imdb.com/title/tt2131523/                                     Graceland
# http://www.imdb.com/title/tt2131532/                                        Hidden
# http://www.imdb.com/title/tt2131586/      Meitantei Conan: Juichi-ninme no Striker
# http://www.imdb.com/title/tt2131698/                                       Zaytoun
# http://www.imdb.com/title/tt2132285/                                The Bling Ring
# http://www.imdb.com/title/tt2132374/                               Life's a Breeze
#
# [1000 rows x 18 columns]

# %%
details_df['Release Date'].isnull().sum()
# Out:
# 1

# %%
details_df[details_df['Release Date'].isnull()]
# Out:
#                                         Budget Country  \
# http://www.imdb.com/title/tt6063014/  150000.0     USA
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt6063014/                         NaN
#
#                                                   Director  \
# http://www.imdb.com/title/tt6063014/  The Brothers Freeman
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt6063014/  http://www.imdb.com/name/nm8443576
#
#                                       Gross USA Language  Opening Weekend USA  \
# http://www.imdb.com/title/tt6063014/        NaN  English                  NaN
#
#                                        Primary Filming Location  \
# http://www.imdb.com/title/tt6063014/  SW, Portland, Oregon, USA
#
#                                             Production Company Release Date  \
# http://www.imdb.com/title/tt6063014/  Wooden Frame Productions         None
#
#                                                 Star1  \
# http://www.imdb.com/title/tt6063014/  Robert McKeehen
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt6063014/  http://www.imdb.com/name/nm1422609
#
#                                                    Star2  \
# http://www.imdb.com/title/tt6063014/  Michael J. Prosser
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt6063014/  http://www.imdb.com/name/nm1508214
#
#                                            Star3  \
# http://www.imdb.com/title/tt6063014/  Nouel Riel
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt6063014/  http://www.imdb.com/name/nm3661744
#
#                                              Title
# http://www.imdb.com/title/tt6063014/  Before I Die

# %% [raw]
# details_df[['Star1','Star2','Star3']]

# %% [raw]
# movies_df2 = pd.read_json('movie_details_exports/movie_details_export_1.json',orient='index',)

# %% [raw]
# movies_df2.loc['http://www.imdb.com/title/tt7056732/']
