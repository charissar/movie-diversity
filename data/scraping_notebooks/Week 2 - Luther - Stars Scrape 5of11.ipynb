# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %% [markdown]
# # Get List of unique Stars and URLS

# %%
star1_df = details_df[['Star1_URL','Star1']].copy()

# %%
star1_df.rename(columns = {'Star1_URL':'StarURL','Star1':'Star'}, inplace=True)

# %%
star2_df = details_df[['Star2_URL','Star2']].copy()

# %%
star2_df.rename(columns = {'Star2_URL':'StarURL','Star2':'Star'}, inplace=True)

# %%
star3_df = details_df[['Star3_URL','Star3']].copy()

# %%
star3_df.rename(columns = {'Star3_URL':'StarURL','Star3':'Star'}, inplace=True)

# %%
stars_df = pd.concat([star1_df,star2_df,star3_df])

# %%
stars_df.head()
# Out:
#                                                                  StarURL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                      Star
# http://www.imdb.com/title/tt4937564/         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/         Kamal Haasan
# http://www.imdb.com/title/tt4939066/          Liam Neeson
# http://www.imdb.com/title/tt4940370/    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/  Harshvardhan Kapoor

# %%
len(stars_df)
# Out:
# 89151

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
stars_df = stars_df.dropna(subset = ['StarURL'])

# %%
len(stars_df)
# Out:
# 89075

# %%
stars_df = stars_df.drop_duplicates(subset='StarURL',keep='first')

# %%
len(stars_df)
# Out:
# 33838

# %%
star_urls = list(stars_df['StarURL'])

# %%
star_urls = sorted(star_urls, reverse = True)

# %%
star_urls[:10]
# Out:
# ['http://www.imdb.com/name/nm9585396',
#  'http://www.imdb.com/name/nm9578606',
#  'http://www.imdb.com/name/nm9572036',
#  'http://www.imdb.com/name/nm9572029',
#  'http://www.imdb.com/name/nm9557596',
#  'http://www.imdb.com/name/nm9557587',
#  'http://www.imdb.com/name/nm9557586',
#  'http://www.imdb.com/name/nm9552585',
#  'http://www.imdb.com/name/nm9549343',
#  'http://www.imdb.com/name/nm9521432']

# %% [raw]
# star_urls.pop()

# %% [raw]
# star_urls[22525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# url = 'http://www.imdb.com/name/nm0000233/'
# # url= 'http://www.imdb.com/name/nm0002354/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# star_details = {}
# star_details[url] = {}

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a') if gender else None
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = soup.find(id='name-bio-text')
#         gender = gender.text if gender else None
#         gender = re.sub('\n', '', gender) if gender else None
#         gender = re.sub('  +',' ', gender) if gender else None
#         gender = gender.split(' ') if gender else None
#         male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
#         female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
#         if gender:
#             if male_count > female_count:
#                 gender = 'Male'
#             elif female_count > male_count:
#                 gender = 'Female'
#             else:
#                 gender = None
#
# gender

# %% [raw]
# height = soup.find('h2',text=re.compile('Personal Details'))
# height = height.parent if height else None
# height = height.find(id='details-height') if height else None
# height = height.text if height else None
# height = height.split('(')[-1] if height else None
# height = re.sub('[^0-9.]+','',height) if height else None
# # star_details[url]['Height in m'] = height
# height

# %% [raw]
# publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
# publicity_listings = publicity_listings.parent if publicity_listings else None
# publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
# publicity_listings = publicity_listings.text if publicity_listings else None
# publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
# publicity_listings = publicity_listings.strip() if publicity_listings else None
# publicity_listings = publicity_listings.split(' ') if publicity_listings else None
# publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
# publicity_listings = sum(publicity_listings) if publicity_listings else None
# star_details[url]['Publicity Listings'] = publicity_listings
# publicity_listings

# %% [raw]
# star_sign = soup.find('h4',text=re.compile('Star Sign'))
# star_sign = star_sign.parent if star_sign else None
# star_sign = star_sign.text if star_sign else None
# star_sign = star_sign.strip() if star_sign else None
# star_sign = star_sign.split('\n')[-1] if star_sign else None
# star_details[url]['Star Sign'] = star_sign
#
# star_sign

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a')
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = None
# star_details[url]['Gender'] = gender
#
# gender

# %% [raw]
# born_info = soup.find(id='name-born-info')
#
# birthdate = born_info.find('time') if born_info else None
# if birthdate.has_attr('datetime'):
#     birthdate = birthdate['datetime']
# else:
#     birthdate = None
# # star_details[url]['Birthdate'] = birthdate
#
# birthplace = born_info.findAll('a') if born_info else None
# birthplace = birthplace[-1] if birthplace else None
# birthplace = birthplace.text if birthplace else None
# # star_details[url]['Birthplace'] = birthplace
#
# birthcountry = birthplace.split(', ') if birthplace else None
# birthcountry = birthcountry[-1] if len(birthcountry)>2 else None
# # star_details[url]['Birth Country'] = birthcountry
#
# birthdate
# # birthplace
# # birthcountry

# %% [raw]
# acting_roles = soup.find(id='filmo-head-actor')
# acting_roles = acting_roles.text if acting_roles else None
# acting_roles = acting_roles.strip() if acting_roles else None
# acting_roles = acting_roles.split('(')[-1] if acting_roles else None
# acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
# acting_roles = int(acting_roles) if acting_roles else None
# # star_details[url]['Acting Roles'] = action_roles
#
# acting_roles

# %% [raw]
# tv_appearances = soup.find(id='filmo-head-self')
# tv_appearances = tv_appearances.text if tv_appearances else None
# tv_appearances = tv_appearances.strip() if tv_appearances else None
# tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
# tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
# star_details[url]['producing Roles'] = tv_appearances
# tv_appearances
#
#
# # star_details[url]['producing Roles'] = tv_appearances

# %% [raw]
# star_name = soup.find('h1')
# star_name = star_name.text if star_name else None
# star_name = star_name.strip() if star_name else None
# star_name = star_name.split('\n') if star_name else None
#
# deathyear = star_name[-1] if len(star_name)>=2 else None
# deathyear = deathyear.split('–')[-1] if deathyear else None
# deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
# deathyear = int(deathyear) if deathyear else None
#
# star_name = star_name[0] if star_name else None
#
# birthyear = birthdate[0:4] if birthdate and len(birthdate)>=10 else None
# birthyear = int(birthyear) if birthyear else None
#
# age_at_death = deathyear-birthyear if deathyear and birthyear else None
#
# birthyear

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.find('span') if award_highlight else None
# award_highlight = award_highlight.text if award_highlight else None
# award_highlight = award_highlight.strip() if award_highlight else None
# award_highlight = award_highlight.split('\n') if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# #     star_details[url]['Award Info'] = award_highlight
# award_highlight

# %% [raw]
# star_details

# %%
len(star_urls)
# Out:
# 33838

# %% [markdown]
# ## Scrape Star Details

# %%
# star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

stars_scraped = 0
star_details = {}
star_index = 12000                    
prefix = 'http://www.imdb.com'
export_number = 20
export_no = str(export_number)
load_attempts = 0

def star_scraper():
    global star_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in star_urls[star_index:15000]:
#         print(url)
        if (star_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(star_index+1, url))
        page = request_page(url)
        get_star_details(url, page)
        star_index += 1
    
    export_to_json(star_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_star_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    star_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    star_details[url]['Gender'] = gender
    
    
    star_name = soup.find('h1')
    star_name = star_name.text if star_name else None
    star_name = star_name.strip() if star_name else None
    star_name = star_name.split('\n') if star_name else None

    deathyear = star_name[-1] if len(star_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
# 14300: http://www.imdb.com/name/nm0866336
# 14320: http://www.imdb.com/name/nm0865575
# 14340: http://www.imdb.com/name/nm0864937
# 14360: http://www.imdb.com/name/nm0863816
# 14380: http://www.imdb.com/name/nm0862907
# 14400: http://www.imdb.com/name/nm0861910
# 14420: http://www.imdb.com/name/nm0861034
# 14440: http://www.imdb.com/name/nm0860233
# 14460: http://www.imdb.com/name/nm0858747
# 14480: http://www.imdb.com/name/nm0857775
# 14500: http://www.imdb.com/name/nm0856908
# 14520: http://www.imdb.com/name/nm0856027
# 14540: http://www.imdb.com/name/nm0855103
# 14560: http://www.imdb.com/name/nm0853764
# 14580: http://www.imdb.com/name/nm0853079
# 14600: http://www.imdb.com/name/nm0852305
# 14620: http://www.imdb.com/name/nm0851302
# 14640: http://www.imdb.com/name/nm0849493
# 14660: http://www.imdb.com/name/nm0848968
# 14680: http://www.imdb.com/name/nm0848188
# 14700: http://www.imdb.com/name/nm0847562
# 14720: http://www.imdb.com/name/nm0847054
# 14740: http://www.imdb.com/name/nm0846181
# 14760: http://www.imdb.com/name/nm0844983
# 14780: http://www.imdb.com/name/nm0843306
# 14800: http://www.imdb.com/name/nm0842425
# 14820: http://www.imdb.com/name/nm0840889
# 14840: http://www.imdb.com/name/nm0840059
# 14860: http://www.imdb.com/name/nm0838935
# 14880: http://www.imdb.com/name/nm0837925
# 14900: http://www.imdb.com/name/nm0837177
# 14920: http://www.imdb.com/name/nm0836176
# 14940: http://www.imdb.com/name/nm0835415
# 14960: http://www.imdb.com/name/nm0834230
# 14980: http://www.imdb.com/name/nm0832622
# 15000: http://www.imdb.com/name/nm0831838
# 2018-01-30 01:18:13.762751 : working on export 23
# 2018-01-30 01:18:13.764297 : working on export 24
# Done
# 4678.6

# %%
import json
import pandas as pd
stars_import = pd.read_json('star_details_exports/star_details_export_21.json',orient='index')

# %%
len(stars_import)
# Out:
# 1000

# %%
stars_import
# Out:
#                                     Acting Roles  Age at Death  \
# http://www.imdb.com/name/nm0880949          47.0          73.0
# http://www.imdb.com/name/nm0881005           1.0           NaN
# http://www.imdb.com/name/nm0881307           NaN           NaN
# http://www.imdb.com/name/nm0881451          23.0           NaN
# http://www.imdb.com/name/nm0881520           4.0           NaN
# http://www.imdb.com/name/nm0881555          49.0          68.0
# http://www.imdb.com/name/nm0881631          46.0           NaN
# http://www.imdb.com/name/nm0881672         139.0           NaN
# http://www.imdb.com/name/nm0881802          21.0          59.0
# http://www.imdb.com/name/nm0881817           1.0           NaN
# http://www.imdb.com/name/nm0881829           NaN          42.0
# http://www.imdb.com/name/nm0881948          40.0           NaN
# http://www.imdb.com/name/nm0881993          69.0           NaN
# http://www.imdb.com/name/nm0882048         121.0          74.0
# http://www.imdb.com/name/nm0882151           NaN           NaN
# http://www.imdb.com/name/nm0882162           NaN           NaN
# http://www.imdb.com/name/nm0882219           NaN           NaN
# http://www.imdb.com/name/nm0882237          95.0          66.0
# http://www.imdb.com/name/nm0882267           NaN           NaN
# http://www.imdb.com/name/nm0882354          58.0          91.0
# http://www.imdb.com/name/nm0882395          88.0          67.0
# http://www.imdb.com/name/nm0882447           NaN           NaN
# http://www.imdb.com/name/nm0882573          27.0           NaN
# http://www.imdb.com/name/nm0882581         132.0          76.0
# http://www.imdb.com/name/nm0882607           3.0          87.0
# http://www.imdb.com/name/nm0882691          51.0           NaN
# http://www.imdb.com/name/nm0882731          37.0           NaN
# http://www.imdb.com/name/nm0882853           NaN           NaN
# http://www.imdb.com/name/nm0882892         122.0          52.0
# http://www.imdb.com/name/nm0882943           NaN           NaN
# ...                                          ...           ...
# http://www.imdb.com/name/nm0935663           NaN           NaN
# http://www.imdb.com/name/nm0935664          26.0           NaN
# http://www.imdb.com/name/nm0935807           NaN           NaN
# http://www.imdb.com/name/nm0935844          11.0          51.0
# http://www.imdb.com/name/nm0935870           2.0           NaN
# http://www.imdb.com/name/nm0935921          55.0           NaN
# http://www.imdb.com/name/nm0935922           NaN           NaN
# http://www.imdb.com/name/nm0935939           NaN           NaN
# http://www.imdb.com/name/nm0935981           2.0           NaN
# http://www.imdb.com/name/nm0936079           NaN          54.0
# http://www.imdb.com/name/nm0936087          40.0           NaN
# http://www.imdb.com/name/nm0936115           NaN         101.0
# http://www.imdb.com/name/nm0936198          54.0           NaN
# http://www.imdb.com/name/nm0936231           1.0           NaN
# http://www.imdb.com/name/nm0936257           NaN           NaN
# http://www.imdb.com/name/nm0936295          48.0          95.0
# http://www.imdb.com/name/nm0936298          93.0           NaN
# http://www.imdb.com/name/nm0936300          26.0           NaN
# http://www.imdb.com/name/nm0936311           NaN           NaN
# http://www.imdb.com/name/nm0936353          60.0           NaN
# http://www.imdb.com/name/nm0936403         235.0           NaN
# http://www.imdb.com/name/nm0936470          11.0           NaN
# http://www.imdb.com/name/nm0936488          62.0           NaN
# http://www.imdb.com/name/nm0936591          40.0           NaN
# http://www.imdb.com/name/nm0936618           7.0           NaN
# http://www.imdb.com/name/nm0936727           NaN          94.0
# http://www.imdb.com/name/nm0936728         202.0          54.0
# http://www.imdb.com/name/nm0936755           NaN          67.0
# http://www.imdb.com/name/nm0936757           7.0          57.0
# http://www.imdb.com/name/nm0936762          79.0           NaN
#
#                                                                            Award Info  \
# http://www.imdb.com/name/nm0880949                                               None
# http://www.imdb.com/name/nm0881005                                               None
# http://www.imdb.com/name/nm0881307                                               None
# http://www.imdb.com/name/nm0881451                                               None
# http://www.imdb.com/name/nm0881520                                               None
# http://www.imdb.com/name/nm0881555                                               None
# http://www.imdb.com/name/nm0881631                            8 wins & 8 nominations.
# http://www.imdb.com/name/nm0881672                                            2 wins.
# http://www.imdb.com/name/nm0881802                            2 wins & 6 nominations.
# http://www.imdb.com/name/nm0881817                                               None
# http://www.imdb.com/name/nm0881829       Nominated for 1 Oscar. Another 1 nomination.
# http://www.imdb.com/name/nm0881948                                               None
# http://www.imdb.com/name/nm0881993                                               None
# http://www.imdb.com/name/nm0882048                                               None
# http://www.imdb.com/name/nm0882151                                               None
# http://www.imdb.com/name/nm0882162                                               None
# http://www.imdb.com/name/nm0882219                                            2 wins.
# http://www.imdb.com/name/nm0882237                             4 wins & 1 nomination.
# http://www.imdb.com/name/nm0882267                            5 wins & 6 nominations.
# http://www.imdb.com/name/nm0882354                                               None
# http://www.imdb.com/name/nm0882395                                             1 win.
# http://www.imdb.com/name/nm0882447                                               None
# http://www.imdb.com/name/nm0882573                                               None
# http://www.imdb.com/name/nm0882581                                               None
# http://www.imdb.com/name/nm0882607                                            2 wins.
# http://www.imdb.com/name/nm0882691                            3 wins & 4 nominations.
# http://www.imdb.com/name/nm0882731                                               None
# http://www.imdb.com/name/nm0882853  Nominated for 1 Oscar. Another 9 wins & 8 nomi...
# http://www.imdb.com/name/nm0882892                                               None
# http://www.imdb.com/name/nm0882943                             1 win & 4 nominations.
# ...                                                                               ...
# http://www.imdb.com/name/nm0935663                                               None
# http://www.imdb.com/name/nm0935664                            2 wins & 6 nominations.
# http://www.imdb.com/name/nm0935807                                               None
# http://www.imdb.com/name/nm0935844                                             1 win.
# http://www.imdb.com/name/nm0935870                                               None
# http://www.imdb.com/name/nm0935921                                     2 nominations.
# http://www.imdb.com/name/nm0935922                                               None
# http://www.imdb.com/name/nm0935939                                               None
# http://www.imdb.com/name/nm0935981                                               None
# http://www.imdb.com/name/nm0936079                                               None
# http://www.imdb.com/name/nm0936087                                               None
# http://www.imdb.com/name/nm0936115                                               None
# http://www.imdb.com/name/nm0936198                                     2 nominations.
# http://www.imdb.com/name/nm0936231                              1 win & 1 nomination.
# http://www.imdb.com/name/nm0936257                                               None
# http://www.imdb.com/name/nm0936295             Won 1 BAFTA Film Award. Another 1 win.
# http://www.imdb.com/name/nm0936298                                               None
# http://www.imdb.com/name/nm0936300                                               None
# http://www.imdb.com/name/nm0936311                                               None
# http://www.imdb.com/name/nm0936353                                     2 nominations.
# http://www.imdb.com/name/nm0936403                            4 wins & 6 nominations.
# http://www.imdb.com/name/nm0936470                                               None
# http://www.imdb.com/name/nm0936488                                               None
# http://www.imdb.com/name/nm0936591                                               None
# http://www.imdb.com/name/nm0936618                                               None
# http://www.imdb.com/name/nm0936727                             2 wins & 1 nomination.
# http://www.imdb.com/name/nm0936728                                               None
# http://www.imdb.com/name/nm0936755                                               None
# http://www.imdb.com/name/nm0936757                                               None
# http://www.imdb.com/name/nm0936762                                      1 nomination.
#
#                                                    Birth Country   Birthdate  \
# http://www.imdb.com/name/nm0880949                         Italy   1935-1-12
# http://www.imdb.com/name/nm0881005                           USA   1939-5-22
# http://www.imdb.com/name/nm0881307                          None        None
# http://www.imdb.com/name/nm0881451                          None        None
# http://www.imdb.com/name/nm0881520                          None        None
# http://www.imdb.com/name/nm0881555                       Russia]   1887-8-28
# http://www.imdb.com/name/nm0881631                   New Zealand    1972-6-7
# http://www.imdb.com/name/nm0881672                           USA   1963-9-17
# http://www.imdb.com/name/nm0881802                       Uruguay   1954-3-10
# http://www.imdb.com/name/nm0881817                          None        None
# http://www.imdb.com/name/nm0936311                                               None
# http://www.imdb.com/name/nm0936353                             Newcastle, England, UK
# http://www.imdb.com/name/nm0936403                                   Akron, Ohio, USA
# http://www.imdb.com/name/nm0936470                                Houston, Texas, USA
# http://www.imdb.com/name/nm0936488                           Northern California, USA
# http://www.imdb.com/name/nm0936591                          West Berlin, West Germany
# http://www.imdb.com/name/nm0936618                                               None
# http://www.imdb.com/name/nm0936727                      Karachi, Sindh, British India
# http://www.imdb.com/name/nm0936728                              Pueblo, Colorado, USA
# http://www.imdb.com/name/nm0936755                        New Orleans, Louisiana, USA
# http://www.imdb.com/name/nm0936757                                 Denton, Texas, USA
# http://www.imdb.com/name/nm0936762                             Detroit, Michigan, USA
#
#                                     Birthyear  Deathyear  Directing Roles  \
# http://www.imdb.com/name/nm0880949     1935.0     2008.0              NaN
# http://www.imdb.com/name/nm0881005     1939.0        NaN              NaN
# http://www.imdb.com/name/nm0881307        NaN        NaN              NaN
# http://www.imdb.com/name/nm0881451        NaN        NaN              NaN
# http://www.imdb.com/name/nm0881520        NaN        NaN              3.0
# http://www.imdb.com/name/nm0881555     1887.0     1955.0              NaN
# http://www.imdb.com/name/nm0881631     1972.0        NaN              NaN
# http://www.imdb.com/name/nm0881672     1963.0        NaN              NaN
# http://www.imdb.com/name/nm0881802     1954.0     2013.0              NaN
# http://www.imdb.com/name/nm0881817        NaN        NaN              NaN
# http://www.imdb.com/name/nm0881829     1933.0     1975.0              NaN
# http://www.imdb.com/name/nm0881948     1978.0        NaN              NaN
# http://www.imdb.com/name/nm0881993     1963.0        NaN              NaN
# http://www.imdb.com/name/nm0882048     1921.0     1995.0              NaN
# http://www.imdb.com/name/nm0882151        NaN        NaN              NaN
# http://www.imdb.com/name/nm0882162     1970.0        NaN              NaN
# http://www.imdb.com/name/nm0882219        NaN        NaN              NaN
# http://www.imdb.com/name/nm0882237     1913.0     1979.0              NaN
# http://www.imdb.com/name/nm0882267     1951.0        NaN              NaN
# http://www.imdb.com/name/nm0882354     1909.0     2000.0              NaN
# http://www.imdb.com/name/nm0882395     1937.0     2004.0              NaN
# http://www.imdb.com/name/nm0882447        NaN        NaN              NaN
# http://www.imdb.com/name/nm0882573     1943.0        NaN              NaN
# http://www.imdb.com/name/nm0882581     1937.0     2013.0              NaN
# http://www.imdb.com/name/nm0882607     1895.0     1982.0              NaN
# http://www.imdb.com/name/nm0882691     1946.0        NaN              2.0
# http://www.imdb.com/name/nm0882731        NaN        NaN              NaN
# http://www.imdb.com/name/nm0882853     1939.0        NaN              NaN
# http://www.imdb.com/name/nm0882892     1951.0     2003.0              NaN
# http://www.imdb.com/name/nm0882943        NaN        NaN              NaN
# ...                                       ...        ...              ...
# http://www.imdb.com/name/nm0935663     1966.0        NaN              NaN
# http://www.imdb.com/name/nm0935664     1965.0        NaN             30.0
# http://www.imdb.com/name/nm0935807     1974.0        NaN              NaN
# http://www.imdb.com/name/nm0935844     1947.0     1998.0              NaN
# http://www.imdb.com/name/nm0935870        NaN        NaN              1.0
# http://www.imdb.com/name/nm0935921     1964.0        NaN              NaN
# http://www.imdb.com/name/nm0935922     1953.0        NaN              NaN
# http://www.imdb.com/name/nm0935939        NaN        NaN              NaN
# http://www.imdb.com/name/nm0935981     1975.0        NaN              NaN
# http://www.imdb.com/name/nm0936079     1905.0     1959.0              NaN
# http://www.imdb.com/name/nm0936087        NaN        NaN              NaN
# http://www.imdb.com/name/nm0936115     1883.0     1984.0              NaN
# http://www.imdb.com/name/nm0936198     1962.0        NaN              2.0
# http://www.imdb.com/name/nm0936231     1952.0        NaN              NaN
# http://www.imdb.com/name/nm0936257     1965.0        NaN              NaN
# http://www.imdb.com/name/nm0936295     1915.0     2010.0              NaN
# http://www.imdb.com/name/nm0936298     1953.0        NaN              NaN
# http://www.imdb.com/name/nm0936300     1973.0        NaN              NaN
# http://www.imdb.com/name/nm0936311        NaN        NaN              NaN
# http://www.imdb.com/name/nm0936353     1966.0        NaN              NaN
# http://www.imdb.com/name/nm0936403     1947.0        NaN              NaN
# http://www.imdb.com/name/nm0936470     1967.0        NaN              NaN
# http://www.imdb.com/name/nm0936488     1967.0        NaN              NaN
# http://www.imdb.com/name/nm0936591     1959.0        NaN              1.0
# http://www.imdb.com/name/nm0936618        NaN        NaN              NaN
# http://www.imdb.com/name/nm0936727     1917.0     2011.0              NaN
# http://www.imdb.com/name/nm0936728     1905.0     1959.0              NaN
# http://www.imdb.com/name/nm0936755     1890.0     1957.0              NaN
# http://www.imdb.com/name/nm0936757     1957.0     2014.0              NaN
# http://www.imdb.com/name/nm0936762     1942.0        NaN              NaN
#
#                                     Gender  Height in m  \
# http://www.imdb.com/name/nm0880949    Male         1.97
# http://www.imdb.com/name/nm0881005    Male          NaN
# http://www.imdb.com/name/nm0881307  Female          NaN
# http://www.imdb.com/name/nm0881451    Male          NaN
# http://www.imdb.com/name/nm0881520    Male          NaN
# http://www.imdb.com/name/nm0881555    Male          NaN
# http://www.imdb.com/name/nm0881631    Male         1.85
# http://www.imdb.com/name/nm0881672    Male          NaN
# http://www.imdb.com/name/nm0881802    Male          NaN
# http://www.imdb.com/name/nm0881817    Male          NaN
# http://www.imdb.com/name/nm0881829  Female         1.65
# http://www.imdb.com/name/nm0881948    Male          NaN
# http://www.imdb.com/name/nm0881993    Male         1.90
# http://www.imdb.com/name/nm0882048    Male          NaN
# http://www.imdb.com/name/nm0882151  Female          NaN
# http://www.imdb.com/name/nm0882162  Female         1.32
# http://www.imdb.com/name/nm0882219  Female          NaN
# http://www.imdb.com/name/nm0882237    Male          NaN
# http://www.imdb.com/name/nm0882267  Female          NaN
# http://www.imdb.com/name/nm0882354    Male          NaN
# http://www.imdb.com/name/nm0882395    Male          NaN
# http://www.imdb.com/name/nm0882447  Female          NaN
# http://www.imdb.com/name/nm0882573    Male          NaN
# http://www.imdb.com/name/nm0882581    Male         1.62
# http://www.imdb.com/name/nm0882607    Male          NaN
# http://www.imdb.com/name/nm0882691    Male          NaN
# http://www.imdb.com/name/nm0882731    Male          NaN
# http://www.imdb.com/name/nm0882853  Female         1.65
# http://www.imdb.com/name/nm0882892    Male          NaN
# http://www.imdb.com/name/nm0882943  Female          NaN
# ...                                    ...          ...
# http://www.imdb.com/name/nm0935663  Female         1.71
# http://www.imdb.com/name/nm0935664    Male         1.70
# http://www.imdb.com/name/nm0935807  Female         1.72
# http://www.imdb.com/name/nm0935844    Male          NaN
# http://www.imdb.com/name/nm0935870    Male          NaN
# http://www.imdb.com/name/nm0935921    Male         1.87
# http://www.imdb.com/name/nm0935922  Female          NaN
# http://www.imdb.com/name/nm0935939  Female          NaN
# http://www.imdb.com/name/nm0935981    Male          NaN
# http://www.imdb.com/name/nm0936079  Female         1.66
# http://www.imdb.com/name/nm0936087    Male          NaN
# http://www.imdb.com/name/nm0936115  Female          NaN
# http://www.imdb.com/name/nm0936198    Male         1.83
# http://www.imdb.com/name/nm0936231    Male          NaN
# http://www.imdb.com/name/nm0936257  Female          NaN
# http://www.imdb.com/name/nm0936295    Male         1.57
# http://www.imdb.com/name/nm0936298    Male         1.85
# http://www.imdb.com/name/nm0936300    Male         1.91
# http://www.imdb.com/name/nm0936311  Female          NaN
# http://www.imdb.com/name/nm0936353    Male         1.88
# http://www.imdb.com/name/nm0936403    Male         1.77
# http://www.imdb.com/name/nm0936470    Male         1.84
# http://www.imdb.com/name/nm0936488    Male          NaN
# http://www.imdb.com/name/nm0936591    Male         1.92
# http://www.imdb.com/name/nm0936618    Male          NaN
# http://www.imdb.com/name/nm0936727  Female         1.65
# http://www.imdb.com/name/nm0936728    Male         1.91
# http://www.imdb.com/name/nm0936755  Female          NaN
# http://www.imdb.com/name/nm0936757    Male          NaN
# http://www.imdb.com/name/nm0936762    Male         1.78
#
#                                                       Name  Producing Roles  \
# http://www.imdb.com/name/nm0880949          Claudio Undari              NaN
# http://www.imdb.com/name/nm0881005           Ian Underwood              NaN
# http://www.imdb.com/name/nm0881307               Naomi Uno              NaN
# http://www.imdb.com/name/nm0881451          William Upjohn              NaN
# http://www.imdb.com/name/nm0881520              Nick Upton              1.0
# http://www.imdb.com/name/nm0881555       Vladimir Uralskiy              NaN
# http://www.imdb.com/name/nm0881631              Karl Urban              NaN
# http://www.imdb.com/name/nm0881672          James Urbaniak              3.0
# http://www.imdb.com/name/nm0881802   Alejandro Urdapilleta              NaN
# http://www.imdb.com/name/nm0881817    Gabriel Cosmin Urdes              NaN
# http://www.imdb.com/name/nm0881829                Mary Ure              NaN
# http://www.imdb.com/name/nm0881948            Justin Urich              NaN
# http://www.imdb.com/name/nm0881993            Farin Urlaub              NaN
# http://www.imdb.com/name/nm0882048         Robert Urquhart              NaN
# http://www.imdb.com/name/nm0882151           Susan Ursitti              2.0
# http://www.imdb.com/name/nm0882162      Christine Urspruch              NaN
# http://www.imdb.com/name/nm0882219                 Urvashi              1.0
# http://www.imdb.com/name/nm0882237               Saro Urzì              NaN
# http://www.imdb.com/name/nm0882267            Nina Usatova              NaN
# http://www.imdb.com/name/nm0882354           Mantarô Ushio              NaN
# http://www.imdb.com/name/nm0882395           Kamran Usluer              NaN
# http://www.imdb.com/name/nm0882447           Sevil Ustekin              NaN
# http://www.imdb.com/name/nm0882573               Nils Utsi              NaN
# http://www.imdb.com/name/nm0882581            Kenji Utsumi              NaN
# http://www.imdb.com/name/nm0882607          Leonid Utyosov              NaN
# http://www.imdb.com/name/nm0882691             Ryûdô Uzaki              NaN
# http://www.imdb.com/name/nm0882731      Mustafa Uzunyilmaz              NaN
# http://www.imdb.com/name/nm0882853          Brenda Vaccaro              NaN
# http://www.imdb.com/name/nm0882892            Ajit Vachani              NaN
# http://www.imdb.com/name/nm0882943            Sonia Vachon              NaN
# ...                                                    ...              ...
# http://www.imdb.com/name/nm0935663     Agnes-Nicole Winter              2.0
# http://www.imdb.com/name/nm0935664             Alex Winter             12.0
# http://www.imdb.com/name/nm0935807          Ophélie Winter              NaN
# http://www.imdb.com/name/nm0935844          Vincent Winter              2.0
# http://www.imdb.com/name/nm0935870         John Wintergate              NaN
# http://www.imdb.com/name/nm0935921            Dean Winters              1.0
# http://www.imdb.com/name/nm0935922         Deborah Winters              1.0
# http://www.imdb.com/name/nm0935939           J'Len Winters              NaN
# http://www.imdb.com/name/nm0935981  Nathan Forrest Winters              NaN
# http://www.imdb.com/name/nm0936079             Jane Winton              NaN
# http://www.imdb.com/name/nm0936087            Sandy Winton              NaN
# http://www.imdb.com/name/nm0936115         Estelle Winwood              NaN
# http://www.imdb.com/name/nm0936198             Billy Wirth              5.0
# http://www.imdb.com/name/nm0936231               Aad Wirtz              NaN
# http://www.imdb.com/name/nm0936257            Lena Wisborg              NaN
# http://www.imdb.com/name/nm0936295           Norman Wisdom              1.0
# http://www.imdb.com/name/nm0936298           Robert Wisdom              NaN
# http://www.imdb.com/name/nm0936300              Tom Wisdom              NaN
# http://www.imdb.com/name/nm0936311              Audra Wise              NaN
# http://www.imdb.com/name/nm0936353               Greg Wise              1.0
# http://www.imdb.com/name/nm0936403                Ray Wise              NaN
# http://www.imdb.com/name/nm0936470              Jw Wiseman              NaN
# http://www.imdb.com/name/nm0936488         Michael Wiseman              NaN
# http://www.imdb.com/name/nm0936591      Andreas Wisniewski              NaN
# http://www.imdb.com/name/nm0936618            David Wissak              NaN
# http://www.imdb.com/name/nm0936727          Googie Withers              NaN
# http://www.imdb.com/name/nm0936728           Grant Withers              6.0
# http://www.imdb.com/name/nm0936755        Cora Witherspoon              NaN
# http://www.imdb.com/name/nm0936757        Dane Witherspoon              NaN
# http://www.imdb.com/name/nm0936762        John Witherspoon              1.0
#
#                                     Publicity Listings    Star Sign  \
# http://www.imdb.com/name/nm0880949                 NaN    Capricorn
# http://www.imdb.com/name/nm0881005                 NaN       Gemini
# http://www.imdb.com/name/nm0881307                 NaN         None
# http://www.imdb.com/name/nm0881451                 NaN         None
# http://www.imdb.com/name/nm0881520                 NaN         None
# http://www.imdb.com/name/nm0881555                 NaN        Virgo
# http://www.imdb.com/name/nm0881631                 8.0       Gemini
# http://www.imdb.com/name/nm0881672                 NaN        Virgo
# http://www.imdb.com/name/nm0881802                 NaN       Pisces
# http://www.imdb.com/name/nm0881817                 NaN         None
# http://www.imdb.com/name/nm0881829                 NaN     Aquarius
# http://www.imdb.com/name/nm0881948                 NaN         None
# http://www.imdb.com/name/nm0881993                 1.0      Scorpio
# http://www.imdb.com/name/nm0882048                 1.0        Libra
# http://www.imdb.com/name/nm0882151                 NaN         None
# http://www.imdb.com/name/nm0882162                 NaN        Virgo
# http://www.imdb.com/name/nm0882219                 NaN         None
# http://www.imdb.com/name/nm0882237                 NaN       Pisces
# http://www.imdb.com/name/nm0882267                 NaN        Libra
# http://www.imdb.com/name/nm0882354                 NaN     Aquarius
# http://www.imdb.com/name/nm0882395                 NaN         None
# http://www.imdb.com/name/nm0882447                 NaN         None
# http://www.imdb.com/name/nm0882573                 NaN       Cancer
# http://www.imdb.com/name/nm0882581                 NaN        Virgo
# http://www.imdb.com/name/nm0882607                 1.0        Aries
# http://www.imdb.com/name/nm0882691                 NaN       Pisces
# http://www.imdb.com/name/nm0882731                 NaN         None
# http://www.imdb.com/name/nm0882853                 5.0      Scorpio
# http://www.imdb.com/name/nm0882892                 NaN         None
# http://www.imdb.com/name/nm0882943                 NaN         None
# ...                                                ...          ...
# http://www.imdb.com/name/nm0935663                 2.0        Aries
# http://www.imdb.com/name/nm0935664                 6.0       Cancer
# http://www.imdb.com/name/nm0935807                 9.0       Pisces
# http://www.imdb.com/name/nm0935844                 NaN    Capricorn
# http://www.imdb.com/name/nm0935870                 1.0         None
# http://www.imdb.com/name/nm0935921                 NaN       Cancer
# http://www.imdb.com/name/nm0935922                 NaN  Sagittarius
# http://www.imdb.com/name/nm0935939                 NaN         None
# http://www.imdb.com/name/nm0935981                 NaN       Cancer
# http://www.imdb.com/name/nm0936079                 4.0        Libra
# http://www.imdb.com/name/nm0936087                 NaN         None
# http://www.imdb.com/name/nm0936115                 NaN     Aquarius
# http://www.imdb.com/name/nm0936198                 5.0       Cancer
# http://www.imdb.com/name/nm0936231                 NaN     Aquarius
# http://www.imdb.com/name/nm0936257                 NaN        Libra
# http://www.imdb.com/name/nm0936295               105.0     Aquarius
# http://www.imdb.com/name/nm0936298                 NaN        Virgo
# http://www.imdb.com/name/nm0936300                 1.0     Aquarius
# http://www.imdb.com/name/nm0936311                 NaN         None
# http://www.imdb.com/name/nm0936353                 2.0       Taurus
# http://www.imdb.com/name/nm0936403                 2.0          Leo
# http://www.imdb.com/name/nm0936470                 NaN    Capricorn
# http://www.imdb.com/name/nm0936488                 NaN        Aries
# http://www.imdb.com/name/nm0936591                 NaN       Cancer
# http://www.imdb.com/name/nm0936618                 1.0         None
# http://www.imdb.com/name/nm0936727                 5.0       Pisces
# http://www.imdb.com/name/nm0936728                 2.0    Capricorn
