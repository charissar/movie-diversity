# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %% [markdown]
# # Get List of unique Stars and URLS

# %%
star1_df = details_df[['Star1_URL','Star1']].copy()

# %%
star1_df.rename(columns = {'Star1_URL':'StarURL','Star1':'Star'}, inplace=True)

# %%
star2_df = details_df[['Star2_URL','Star2']].copy()

# %%
star2_df.rename(columns = {'Star2_URL':'StarURL','Star2':'Star'}, inplace=True)

# %%
star3_df = details_df[['Star3_URL','Star3']].copy()

# %%
star3_df.rename(columns = {'Star3_URL':'StarURL','Star3':'Star'}, inplace=True)

# %%
stars_df = pd.concat([star1_df,star2_df,star3_df])

# %%
stars_df.head()
# Out:
#                                                                  StarURL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                      Star
# http://www.imdb.com/title/tt4937564/         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/         Kamal Haasan
# http://www.imdb.com/title/tt4939066/          Liam Neeson
# http://www.imdb.com/title/tt4940370/    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/  Harshvardhan Kapoor

# %%
len(stars_df)
# Out:
# 89151

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
stars_df = stars_df.dropna(subset = ['StarURL'])

# %%
len(stars_df)
# Out:
# 89075

# %%
stars_df = stars_df.drop_duplicates(subset='StarURL',keep='first')

# %%
len(stars_df)
# Out:
# 33838

# %%
star_urls = list(stars_df['StarURL'])

# %%
star_urls = sorted(star_urls, reverse = True)

# %%
star_urls[:10]
# Out:
# ['http://www.imdb.com/name/nm9585396',
#  'http://www.imdb.com/name/nm9578606',
#  'http://www.imdb.com/name/nm9572036',
#  'http://www.imdb.com/name/nm9572029',
#  'http://www.imdb.com/name/nm9557596',
#  'http://www.imdb.com/name/nm9557587',
#  'http://www.imdb.com/name/nm9557586',
#  'http://www.imdb.com/name/nm9552585',
#  'http://www.imdb.com/name/nm9549343',
#  'http://www.imdb.com/name/nm9521432']

# %% [raw]
# star_urls.pop()

# %% [raw]
# star_urls[22525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# url = 'http://www.imdb.com/name/nm0000233/'
# # url= 'http://www.imdb.com/name/nm0002354/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# star_details = {}
# star_details[url] = {}

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a') if gender else None
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = soup.find(id='name-bio-text')
#         gender = gender.text if gender else None
#         gender = re.sub('\n', '', gender) if gender else None
#         gender = re.sub('  +',' ', gender) if gender else None
#         gender = gender.split(' ') if gender else None
#         male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
#         female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
#         if gender:
#             if male_count > female_count:
#                 gender = 'Male'
#             elif female_count > male_count:
#                 gender = 'Female'
#             else:
#                 gender = None
#
# gender

# %% [raw]
# height = soup.find('h2',text=re.compile('Personal Details'))
# height = height.parent if height else None
# height = height.find(id='details-height') if height else None
# height = height.text if height else None
# height = height.split('(')[-1] if height else None
# height = re.sub('[^0-9.]+','',height) if height else None
# # star_details[url]['Height in m'] = height
# height

# %% [raw]
# publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
# publicity_listings = publicity_listings.parent if publicity_listings else None
# publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
# publicity_listings = publicity_listings.text if publicity_listings else None
# publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
# publicity_listings = publicity_listings.strip() if publicity_listings else None
# publicity_listings = publicity_listings.split(' ') if publicity_listings else None
# publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
# publicity_listings = sum(publicity_listings) if publicity_listings else None
# star_details[url]['Publicity Listings'] = publicity_listings
# publicity_listings

# %% [raw]
# star_sign = soup.find('h4',text=re.compile('Star Sign'))
# star_sign = star_sign.parent if star_sign else None
# star_sign = star_sign.text if star_sign else None
# star_sign = star_sign.strip() if star_sign else None
# star_sign = star_sign.split('\n')[-1] if star_sign else None
# star_details[url]['Star Sign'] = star_sign
#
# star_sign

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a')
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = None
# star_details[url]['Gender'] = gender
#
# gender

# %% [raw]
# born_info = soup.find(id='name-born-info')
#
# birthdate = born_info.find('time') if born_info else None
# if birthdate.has_attr('datetime'):
#     birthdate = birthdate['datetime']
# else:
#     birthdate = None
# # star_details[url]['Birthdate'] = birthdate
#
# birthplace = born_info.findAll('a') if born_info else None
# birthplace = birthplace[-1] if birthplace else None
# birthplace = birthplace.text if birthplace else None
# # star_details[url]['Birthplace'] = birthplace
#
# birthcountry = birthplace.split(', ') if birthplace else None
# birthcountry = birthcountry[-1] if len(birthcountry)>2 else None
# # star_details[url]['Birth Country'] = birthcountry
#
# birthdate
# # birthplace
# # birthcountry

# %% [raw]
# acting_roles = soup.find(id='filmo-head-actor')
# acting_roles = acting_roles.text if acting_roles else None
# acting_roles = acting_roles.strip() if acting_roles else None
# acting_roles = acting_roles.split('(')[-1] if acting_roles else None
# acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
# acting_roles = int(acting_roles) if acting_roles else None
# # star_details[url]['Acting Roles'] = action_roles
#
# acting_roles

# %% [raw]
# tv_appearances = soup.find(id='filmo-head-self')
# tv_appearances = tv_appearances.text if tv_appearances else None
# tv_appearances = tv_appearances.strip() if tv_appearances else None
# tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
# tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
# star_details[url]['producing Roles'] = tv_appearances
# tv_appearances
#
#
# # star_details[url]['producing Roles'] = tv_appearances

# %% [raw]
# star_name = soup.find('h1')
# star_name = star_name.text if star_name else None
# star_name = star_name.strip() if star_name else None
# star_name = star_name.split('\n') if star_name else None
#
# deathyear = star_name[-1] if len(star_name)>=2 else None
# deathyear = deathyear.split('–')[-1] if deathyear else None
# deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
# deathyear = int(deathyear) if deathyear else None
#
# star_name = star_name[0] if star_name else None
#
# birthyear = birthdate[0:4] if birthdate and len(birthdate)>=10 else None
# birthyear = int(birthyear) if birthyear else None
#
# age_at_death = deathyear-birthyear if deathyear and birthyear else None
#
# birthyear

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.find('span') if award_highlight else None
# award_highlight = award_highlight.text if award_highlight else None
# award_highlight = award_highlight.strip() if award_highlight else None
# award_highlight = award_highlight.split('\n') if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# #     star_details[url]['Award Info'] = award_highlight
# award_highlight

# %% [raw]
# star_details

# %%
len(star_urls)
# Out:
# 33838

# %% [markdown]
# ## Scrape Star Details

# %%
# star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

stars_scraped = 0
star_details = {}
star_index = 18000                    
prefix = 'http://www.imdb.com'
export_number = 30
export_no = str(export_number)
load_attempts = 0

def star_scraper():
    global star_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in star_urls[star_index:21000]:
#         print(url)
        if (star_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(star_index+1, url))
        page = request_page(url)
        get_star_details(url, page)
        star_index += 1
    
    export_to_json(star_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_star_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    star_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    star_details[url]['Gender'] = gender
    
    
    star_name = soup.find('h1')
    star_name = star_name.text if star_name else None
    star_name = star_name.strip() if star_name else None
    star_name = star_name.split('\n') if star_name else None

    deathyear = star_name[-1] if len(star_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
# 20320: http://www.imdb.com/name/nm0547462
# 20340: http://www.imdb.com/name/nm0546515
# 20360: http://www.imdb.com/name/nm0545294
# 20380: http://www.imdb.com/name/nm0543806
# 20400: http://www.imdb.com/name/nm0542990
# 20420: http://www.imdb.com/name/nm0541932
# 20440: http://www.imdb.com/name/nm0541048
# 20460: http://www.imdb.com/name/nm0540038
# 20480: http://www.imdb.com/name/nm0539078
# 20500: http://www.imdb.com/name/nm0538449
# 20520: http://www.imdb.com/name/nm0537392
# 20540: http://www.imdb.com/name/nm0536167
# 20560: http://www.imdb.com/name/nm0535329
# 20580: http://www.imdb.com/name/nm0534387
# 20600: http://www.imdb.com/name/nm0533323
# 20620: http://www.imdb.com/name/nm0532461
# 20640: http://www.imdb.com/name/nm0531589
# 20660: http://www.imdb.com/name/nm0530804
# 20680: http://www.imdb.com/name/nm0529635
# 20700: http://www.imdb.com/name/nm0529050
# 20720: http://www.imdb.com/name/nm0528101
# 20740: http://www.imdb.com/name/nm0526958
# 20760: http://www.imdb.com/name/nm0526157
# 20780: http://www.imdb.com/name/nm0524893
# 20800: http://www.imdb.com/name/nm0524217
# 20820: http://www.imdb.com/name/nm0523225
# 20840: http://www.imdb.com/name/nm0522281
# 20860: http://www.imdb.com/name/nm0520700
# 20880: http://www.imdb.com/name/nm0519489
# 20900: http://www.imdb.com/name/nm0518739
# 20920: http://www.imdb.com/name/nm0518085
# 20940: http://www.imdb.com/name/nm0517099
# 20960: http://www.imdb.com/name/nm0516496
# 20980: http://www.imdb.com/name/nm0515753
# 21000: http://www.imdb.com/name/nm0514944
# 2018-01-30 01:23:32.655577 : working on export 33
# 2018-01-30 01:23:32.657118 : working on export 34
# Done
# 4867.751

# %%
import json
import pandas as pd
stars_import = pd.read_json('star_details_exports/star_details_export_32.json',orient='index')

# %%
len(stars_import)
# Out:
# 1000

# %%
stars_import
# Out:
#                                     Acting Roles  Age at Death  \
# http://www.imdb.com/name/nm0514944          30.0           NaN
# http://www.imdb.com/name/nm0514956          24.0           NaN
# http://www.imdb.com/name/nm0514971           3.0           NaN
# http://www.imdb.com/name/nm0514976          19.0           NaN
# http://www.imdb.com/name/nm0514988          22.0           NaN
# http://www.imdb.com/name/nm0514997           1.0           NaN
# http://www.imdb.com/name/nm0514998          89.0           NaN
# http://www.imdb.com/name/nm0515002           NaN           NaN
# http://www.imdb.com/name/nm0515043           NaN           NaN
# http://www.imdb.com/name/nm0515057           7.0           NaN
# http://www.imdb.com/name/nm0515104          35.0          68.0
# http://www.imdb.com/name/nm0515106          88.0           NaN
# http://www.imdb.com/name/nm0515116           NaN           NaN
# http://www.imdb.com/name/nm0515123          29.0           NaN
# http://www.imdb.com/name/nm0515128          15.0           NaN
# http://www.imdb.com/name/nm0515193          67.0          70.0
# http://www.imdb.com/name/nm0515207           NaN           NaN
# http://www.imdb.com/name/nm0515272           NaN          89.0
# http://www.imdb.com/name/nm0515296          88.0           NaN
# http://www.imdb.com/name/nm0515700           NaN          74.0
# http://www.imdb.com/name/nm0515753          39.0           NaN
# http://www.imdb.com/name/nm0515934          26.0           NaN
# http://www.imdb.com/name/nm0515950           2.0           NaN
# http://www.imdb.com/name/nm0515967           NaN          72.0
# http://www.imdb.com/name/nm0516001         213.0          78.0
# http://www.imdb.com/name/nm0516003          36.0           NaN
# http://www.imdb.com/name/nm0516049           NaN           NaN
# http://www.imdb.com/name/nm0516145           NaN          72.0
# http://www.imdb.com/name/nm0516180           7.0           NaN
# http://www.imdb.com/name/nm0516181         124.0          70.0
# ...                                          ...           ...
# http://www.imdb.com/name/nm0563695          58.0          79.0
# http://www.imdb.com/name/nm0563740           NaN           NaN
# http://www.imdb.com/name/nm0563826          12.0           NaN
# http://www.imdb.com/name/nm0563884           NaN           NaN
# http://www.imdb.com/name/nm0563950           NaN           NaN
# http://www.imdb.com/name/nm0563983           NaN           NaN
# http://www.imdb.com/name/nm0564044          65.0          63.0
# http://www.imdb.com/name/nm0564059           NaN           NaN
# http://www.imdb.com/name/nm0564107          55.0           NaN
# http://www.imdb.com/name/nm0564124          10.0          70.0
# http://www.imdb.com/name/nm0564129           NaN           NaN
# http://www.imdb.com/name/nm0564206          83.0           NaN
# http://www.imdb.com/name/nm0564215          50.0           NaN
# http://www.imdb.com/name/nm0564219           NaN          85.0
# http://www.imdb.com/name/nm0564223           NaN           NaN
# http://www.imdb.com/name/nm0564277          66.0           NaN
# http://www.imdb.com/name/nm0564304           NaN           NaN
# http://www.imdb.com/name/nm0564327          14.0           NaN
# http://www.imdb.com/name/nm0564394           NaN           NaN
# http://www.imdb.com/name/nm0564500          55.0           NaN
# http://www.imdb.com/name/nm0564513           2.0           NaN
# http://www.imdb.com/name/nm0564534          31.0           NaN
# http://www.imdb.com/name/nm0564680          54.0           NaN
# http://www.imdb.com/name/nm0564697          80.0           NaN
# http://www.imdb.com/name/nm0564708          48.0          82.0
# http://www.imdb.com/name/nm0564724         134.0           NaN
# http://www.imdb.com/name/nm0564738          33.0          92.0
# http://www.imdb.com/name/nm0564790           NaN          88.0
# http://www.imdb.com/name/nm0564805          82.0           NaN
# http://www.imdb.com/name/nm0564841         164.0           NaN
#
#                                                                            Award Info  \
# http://www.imdb.com/name/nm0514944                                               None
# http://www.imdb.com/name/nm0514956                                               None
# http://www.imdb.com/name/nm0514971                                               None
# http://www.imdb.com/name/nm0514976                                               None
# http://www.imdb.com/name/nm0514988                            8 wins & 2 nominations.
# http://www.imdb.com/name/nm0514997                                               None
# http://www.imdb.com/name/nm0514998                                     2 nominations.
# http://www.imdb.com/name/nm0515002                          14 wins & 11 nominations.
# http://www.imdb.com/name/nm0515043                            8 wins & 5 nominations.
# http://www.imdb.com/name/nm0515057                                               None
# http://www.imdb.com/name/nm0515104                                            4 wins.
# http://www.imdb.com/name/nm0515106                                            2 wins.
# http://www.imdb.com/name/nm0515116                           8 wins & 21 nominations.
# http://www.imdb.com/name/nm0515123                                     4 nominations.
# http://www.imdb.com/name/nm0515128                                     3 nominations.
# http://www.imdb.com/name/nm0515193                                             1 win.
# http://www.imdb.com/name/nm0515207                              1 win & 1 nomination.
# http://www.imdb.com/name/nm0515272                                               None
# http://www.imdb.com/name/nm0515296  Nominated for 1 Golden Globe. Another 2 nomina...
# http://www.imdb.com/name/nm0515700                             1 win & 2 nominations.
# http://www.imdb.com/name/nm0515753                                               None
# http://www.imdb.com/name/nm0515934                                               None
# http://www.imdb.com/name/nm0515950                                               None
# http://www.imdb.com/name/nm0515967                                               None
# http://www.imdb.com/name/nm0516001      Nominated for 1 Golden Globe. Another 3 wins.
# http://www.imdb.com/name/nm0516003                                     3 nominations.
# http://www.imdb.com/name/nm0516049                                               None
# http://www.imdb.com/name/nm0516145                                               None
# http://www.imdb.com/name/nm0516180                                               None
# http://www.imdb.com/name/nm0516181                                               None
# ...                                                                               ...
# http://www.imdb.com/name/nm0563695                                               None
# http://www.imdb.com/name/nm0563740                             4 wins & 1 nomination.
# http://www.imdb.com/name/nm0563826                            4 wins & 2 nominations.
# http://www.imdb.com/name/nm0563884                             1 win & 6 nominations.
# http://www.imdb.com/name/nm0563950                                               None
# http://www.imdb.com/name/nm0563983                                               None
# http://www.imdb.com/name/nm0564044  Won 2 BAFTA Film Awards. Another 3 wins & 1 no...
# http://www.imdb.com/name/nm0564059                     Nominated for 2 Golden Globes.
# http://www.imdb.com/name/nm0564107                                      1 nomination.
# http://www.imdb.com/name/nm0564124                                               None
# http://www.imdb.com/name/nm0564129                                               None
# http://www.imdb.com/name/nm0564206                                     5 nominations.
# http://www.imdb.com/name/nm0564215  Nominated for 1 Golden Globe. Another 13 wins ...
# http://www.imdb.com/name/nm0564219                                             1 win.
# http://www.imdb.com/name/nm0564223                                      1 nomination.
# http://www.imdb.com/name/nm0564277                                     8 nominations.
# http://www.imdb.com/name/nm0564304                                               None
# http://www.imdb.com/name/nm0564327                                               None
# http://www.imdb.com/name/nm0564394                                               None
# http://www.imdb.com/name/nm0564500                                               None
# http://www.imdb.com/name/nm0564513                                               None
# http://www.imdb.com/name/nm0564534                                             1 win.
# http://www.imdb.com/name/nm0564680                                               None
# http://www.imdb.com/name/nm0564697                                               None
# http://www.imdb.com/name/nm0564708                                               None
# http://www.imdb.com/name/nm0564724  Nominated for 1 Golden Globe. Another 1 win & ...
# http://www.imdb.com/name/nm0564738                                               None
# http://www.imdb.com/name/nm0564790       Won 1 Oscar. Another 4 wins & 2 nominations.
# http://www.imdb.com/name/nm0564805                            5 wins & 3 nominations.
# http://www.imdb.com/name/nm0564841                                      1 nomination.
#
#                                                   Birth Country   Birthdate  \
# http://www.imdb.com/name/nm0514944                       Taiwan   1962-3-22
# http://www.imdb.com/name/nm0514956                       Taiwan   1944-5-20
# http://www.imdb.com/name/nm0514971                         None        None
# http://www.imdb.com/name/nm0514976                         None        None
# http://www.imdb.com/name/nm0514988                         None        None
# http://www.imdb.com/name/nm0514997                         None        None
# http://www.imdb.com/name/nm0514998                      Vietnam  1956-12-22
# http://www.imdb.com/name/nm0515002                       Taiwan    1969-6-1
# http://www.imdb.com/name/nm0564304                       Los Angeles, California, USA
# http://www.imdb.com/name/nm0564327                                               None
# http://www.imdb.com/name/nm0564394                       New York City, New York, USA
# http://www.imdb.com/name/nm0564500                              Glasgow, Scotland, UK
# http://www.imdb.com/name/nm0564513                                               None
# http://www.imdb.com/name/nm0564534                                               None
# http://www.imdb.com/name/nm0564680                         Port Glasgow, Scotland, UK
# http://www.imdb.com/name/nm0564697                       New York City, New York, USA
# http://www.imdb.com/name/nm0564708                       Los Angeles, California, USA
# http://www.imdb.com/name/nm0564724                              Glasgow, Scotland, UK
# http://www.imdb.com/name/nm0564738                    Brisbane, Queensland, Australia
# http://www.imdb.com/name/nm0564790                              Joliet, Illinois, USA
# http://www.imdb.com/name/nm0564805                         Winnipeg, Manitoba, Canada
# http://www.imdb.com/name/nm0564841             Brooklyn, New York City, New York, USA
#
#                                     Birthyear  Deathyear  Directing Roles  \
# http://www.imdb.com/name/nm0514944     1962.0        NaN              NaN
# http://www.imdb.com/name/nm0514956     1944.0        NaN              3.0
# http://www.imdb.com/name/nm0514971        NaN        NaN              NaN
# http://www.imdb.com/name/nm0514976        NaN        NaN              NaN
# http://www.imdb.com/name/nm0514988        NaN        NaN              NaN
# http://www.imdb.com/name/nm0514997        NaN        NaN              NaN
# http://www.imdb.com/name/nm0514998     1956.0        NaN              NaN
# http://www.imdb.com/name/nm0515002     1969.0        NaN              NaN
# http://www.imdb.com/name/nm0515043     1955.0        NaN              NaN
# http://www.imdb.com/name/nm0515057        NaN        NaN              NaN
# http://www.imdb.com/name/nm0515104     1904.0     1972.0              NaN
# http://www.imdb.com/name/nm0515106     1935.0        NaN              4.0
# http://www.imdb.com/name/nm0515116     1987.0        NaN              NaN
# http://www.imdb.com/name/nm0515123     1981.0        NaN              NaN
# http://www.imdb.com/name/nm0515128     1968.0        NaN              2.0
# http://www.imdb.com/name/nm0515193     1906.0     1976.0              NaN
# http://www.imdb.com/name/nm0515207        NaN        NaN              NaN
# http://www.imdb.com/name/nm0515272     1895.0     1984.0              NaN
# http://www.imdb.com/name/nm0515296     1967.0        NaN              NaN
# http://www.imdb.com/name/nm0515700     1929.0     2003.0              NaN
# http://www.imdb.com/name/nm0515753     1956.0        NaN              1.0
# http://www.imdb.com/name/nm0515934        NaN        NaN              NaN
# http://www.imdb.com/name/nm0515950     1973.0        NaN              NaN
# http://www.imdb.com/name/nm0515967     1896.0     1968.0              NaN
# http://www.imdb.com/name/nm0516001     1893.0     1971.0             11.0
# http://www.imdb.com/name/nm0516003     1983.0        NaN              1.0
# http://www.imdb.com/name/nm0516049     1948.0        NaN              NaN
# http://www.imdb.com/name/nm0516145     1939.0     2011.0              NaN
# http://www.imdb.com/name/nm0516180        NaN        NaN              NaN
# http://www.imdb.com/name/nm0516181     1944.0     2014.0              NaN
# ...                                       ...        ...              ...
# http://www.imdb.com/name/nm0563695     1923.0     2002.0              NaN
# http://www.imdb.com/name/nm0563740     1975.0        NaN              NaN
# http://www.imdb.com/name/nm0563826     1961.0        NaN              7.0
# http://www.imdb.com/name/nm0563884     1979.0        NaN              NaN
# http://www.imdb.com/name/nm0563950        NaN        NaN              NaN
# http://www.imdb.com/name/nm0563983     1964.0        NaN              NaN
# http://www.imdb.com/name/nm0564044     1926.0     1989.0              NaN
# http://www.imdb.com/name/nm0564059     1942.0        NaN              NaN
# http://www.imdb.com/name/nm0564107     1957.0        NaN              NaN
# http://www.imdb.com/name/nm0564124     1905.0     1975.0              NaN
# http://www.imdb.com/name/nm0564129     1963.0        NaN              NaN
# http://www.imdb.com/name/nm0564206     1952.0        NaN              NaN
# http://www.imdb.com/name/nm0564215     1979.0        NaN              NaN
# http://www.imdb.com/name/nm0564219     1899.0     1984.0              NaN
# http://www.imdb.com/name/nm0564223     1941.0        NaN              NaN
# http://www.imdb.com/name/nm0564277     1961.0        NaN              NaN
# http://www.imdb.com/name/nm0564304     1948.0        NaN              NaN
# http://www.imdb.com/name/nm0564327        NaN        NaN             11.0
# http://www.imdb.com/name/nm0564394     1947.0        NaN              NaN
# http://www.imdb.com/name/nm0564500     1960.0        NaN              NaN
# http://www.imdb.com/name/nm0564513        NaN     1968.0              NaN
# http://www.imdb.com/name/nm0564534        NaN        NaN              3.0
# http://www.imdb.com/name/nm0564680     1976.0        NaN              NaN
# http://www.imdb.com/name/nm0564697     1963.0        NaN              NaN
# http://www.imdb.com/name/nm0564708     1923.0     2005.0              NaN
# http://www.imdb.com/name/nm0564724     1933.0        NaN              NaN
# http://www.imdb.com/name/nm0564738     1918.0     2010.0              2.0
# http://www.imdb.com/name/nm0564790     1916.0     2004.0              NaN
# http://www.imdb.com/name/nm0564805     1955.0        NaN              NaN
# http://www.imdb.com/name/nm0564841     1934.0        NaN              1.0
#
#                                     Gender  Height in m  \
# http://www.imdb.com/name/nm0514944    Male          NaN
# http://www.imdb.com/name/nm0514956    Male          NaN
# http://www.imdb.com/name/nm0514971    Male          NaN
# http://www.imdb.com/name/nm0514976    Male         1.73
# http://www.imdb.com/name/nm0514988    Male          NaN
# http://www.imdb.com/name/nm0514997    Male          NaN
# http://www.imdb.com/name/nm0514998    Male         1.76
# http://www.imdb.com/name/nm0515002  Female         1.60
# http://www.imdb.com/name/nm0515043  Female          NaN
# http://www.imdb.com/name/nm0515057    Male          NaN
# http://www.imdb.com/name/nm0515104    Male          NaN
# http://www.imdb.com/name/nm0515106    Male         1.77
# http://www.imdb.com/name/nm0515116  Female         1.78
# http://www.imdb.com/name/nm0515123    Male         1.88
# http://www.imdb.com/name/nm0515128    Male         1.88
# http://www.imdb.com/name/nm0515193    Male         1.83
# http://www.imdb.com/name/nm0515207  Female          NaN
# http://www.imdb.com/name/nm0515272  Female         1.60
# http://www.imdb.com/name/nm0515296    Male         1.79
# http://www.imdb.com/name/nm0515700  Female          NaN
# http://www.imdb.com/name/nm0515753    Male         1.83
# http://www.imdb.com/name/nm0515934    Male         1.83
# http://www.imdb.com/name/nm0515950    Male          NaN
# http://www.imdb.com/name/nm0515967  Female          NaN
# http://www.imdb.com/name/nm0516001    Male         1.71
# http://www.imdb.com/name/nm0516003    Male         1.83
# http://www.imdb.com/name/nm0516049  Female          NaN
# http://www.imdb.com/name/nm0516145  Female         1.73
# http://www.imdb.com/name/nm0516180    Male          NaN
# http://www.imdb.com/name/nm0516181    Male         1.88
# ...                                    ...          ...
# http://www.imdb.com/name/nm0563695    Male          NaN
# http://www.imdb.com/name/nm0563740  Female         1.69
# http://www.imdb.com/name/nm0563826    Male          NaN
# http://www.imdb.com/name/nm0563884  Female          NaN
# http://www.imdb.com/name/nm0563950  Female          NaN
# http://www.imdb.com/name/nm0563983  Female          NaN
# http://www.imdb.com/name/nm0564044    Male          NaN
# http://www.imdb.com/name/nm0564059  Female         1.75
# http://www.imdb.com/name/nm0564107    Male         1.85
# http://www.imdb.com/name/nm0564124    Male          NaN
# http://www.imdb.com/name/nm0564129  Female         1.60
# http://www.imdb.com/name/nm0564206    Male          NaN
# http://www.imdb.com/name/nm0564215    Male         1.70
# http://www.imdb.com/name/nm0564219  Female         1.50
# http://www.imdb.com/name/nm0564223  Female         1.71
# http://www.imdb.com/name/nm0564277    Male         1.95
# http://www.imdb.com/name/nm0564304  Female          NaN
# http://www.imdb.com/name/nm0564327    Male          NaN
# http://www.imdb.com/name/nm0564394  Female          NaN
# http://www.imdb.com/name/nm0564500    Male          NaN
# http://www.imdb.com/name/nm0564513    Male          NaN
# http://www.imdb.com/name/nm0564534    Male         1.80
# http://www.imdb.com/name/nm0564680    Male         1.75
# http://www.imdb.com/name/nm0564697    Male         1.85
# http://www.imdb.com/name/nm0564708    Male         1.68
# http://www.imdb.com/name/nm0564724    Male         1.70
# http://www.imdb.com/name/nm0564738    Male         1.85
# http://www.imdb.com/name/nm0564790  Female         1.60
# http://www.imdb.com/name/nm0564805    Male         1.78
# http://www.imdb.com/name/nm0564841    Male         1.91
#
#                                                      Name  Producing Roles  \
# http://www.imdb.com/name/nm0514944            Jackson Lou              NaN
# http://www.imdb.com/name/nm0514956               John Liu              4.0
# http://www.imdb.com/name/nm0514971             Linian Liu              NaN
# http://www.imdb.com/name/nm0514976              Matty Liu              NaN
# http://www.imdb.com/name/nm0514988              Peiqi Liu              NaN
# http://www.imdb.com/name/nm0514997             Quiang Liu              NaN
# http://www.imdb.com/name/nm0514998                Ray Lui              NaN
# http://www.imdb.com/name/nm0515002               Rene Liu              NaN
# http://www.imdb.com/name/nm0515043           Xiaoqing Liu              NaN
# http://www.imdb.com/name/nm0515057          Zhongyuan Liu              NaN
# http://www.imdb.com/name/nm0515104          Boris Livanov              NaN
# http://www.imdb.com/name/nm0515106        Vasiliy Livanov              NaN
# http://www.imdb.com/name/nm0515116           Blake Lively              1.0
# http://www.imdb.com/name/nm0515123            Eric Lively              NaN
# http://www.imdb.com/name/nm0515128           Jason Lively              1.0
# http://www.imdb.com/name/nm0515193          Roger Livesey              NaN
# http://www.imdb.com/name/nm0515207            Ruth Livier              NaN
# http://www.imdb.com/name/nm0515272    Margaret Livingston              NaN
# http://www.imdb.com/name/nm0515296         Ron Livingston              1.0
# http://www.imdb.com/name/nm0515700         Leonor Llausás              NaN
# http://www.imdb.com/name/nm0515753       Robert Llewellyn              2.0
# http://www.imdb.com/name/nm0515934            Brian Lloyd              NaN
# http://www.imdb.com/name/nm0515950            Danny Lloyd              NaN
# http://www.imdb.com/name/nm0515967            Doris Lloyd              NaN
# http://www.imdb.com/name/nm0516001           Harold Lloyd             25.0
# http://www.imdb.com/name/nm0516003            Harry Lloyd              3.0
# http://www.imdb.com/name/nm0516049         Kathleen Lloyd              NaN
# http://www.imdb.com/name/nm0516145              Sue Lloyd              NaN
# http://www.imdb.com/name/nm0516180     Howard Lloyd-Lewis              NaN
# http://www.imdb.com/name/nm0516181       Roger Lloyd Pack              NaN
# ...                                                   ...              ...
# http://www.imdb.com/name/nm0563695        Pascal Mazzotti              NaN
# http://www.imdb.com/name/nm0563740            Aïssa Maïga              NaN
# http://www.imdb.com/name/nm0563826            Cory McAbee              2.0
# http://www.imdb.com/name/nm0563884           Anndi McAfee              NaN
# http://www.imdb.com/name/nm0563950  Kathleen Rowe McAllen              NaN
# http://www.imdb.com/name/nm0563983    Jennifer McAllister              NaN
# http://www.imdb.com/name/nm0564044           Ray McAnally              NaN
# http://www.imdb.com/name/nm0564059      Marianne McAndrew              NaN
# http://www.imdb.com/name/nm0564107          Alex McArthur              NaN
# http://www.imdb.com/name/nm0564124          Hugh McArthur              NaN
# http://www.imdb.com/name/nm0564129      Kimberly McArthur              NaN
# http://www.imdb.com/name/nm0564206            Andy McAvin              NaN
# http://www.imdb.com/name/nm0564215           James McAvoy              1.0
# http://www.imdb.com/name/nm0564219             May McAvoy              NaN
# http://www.imdb.com/name/nm0564223           Diane McBain              NaN
# http://www.imdb.com/name/nm0564277            Chi McBride              1.0
# http://www.imdb.com/name/nm0564304         Harlee McBride              1.0
# http://www.imdb.com/name/nm0564327            Jon McBride             10.0
# http://www.imdb.com/name/nm0564394         Marcia McBroom              NaN
# http://www.imdb.com/name/nm0564500         Richard McCabe              NaN
# http://www.imdb.com/name/nm0564513            Tony McCabe              NaN
# http://www.imdb.com/name/nm0564534         Tom McCafferty              4.0
# http://www.imdb.com/name/nm0564680            Ross McCall              3.0
# http://www.imdb.com/name/nm0564697         Holt McCallany              NaN
# http://www.imdb.com/name/nm0564708        Lon McCallister              NaN
# http://www.imdb.com/name/nm0564724         David McCallum              NaN
# http://www.imdb.com/name/nm0564738          John McCallum              9.0
# http://www.imdb.com/name/nm0564790   Mercedes McCambridge              NaN
# http://www.imdb.com/name/nm0564805            Tom McCamus              NaN
# http://www.imdb.com/name/nm0564841           Chuck McCann              3.0
#
#                                     Publicity Listings    Star Sign  \
# http://www.imdb.com/name/nm0514944                 NaN        Aries
# http://www.imdb.com/name/nm0514956                 NaN       Taurus
# http://www.imdb.com/name/nm0514971                 NaN         None
# http://www.imdb.com/name/nm0514976                 NaN         None
# http://www.imdb.com/name/nm0514988                 NaN         None
# http://www.imdb.com/name/nm0514997                 NaN         None
# http://www.imdb.com/name/nm0514998                 NaN    Capricorn
# http://www.imdb.com/name/nm0515002                 5.0       Gemini
# http://www.imdb.com/name/nm0515043                 3.0      Scorpio
# http://www.imdb.com/name/nm0515057                 NaN         None
# http://www.imdb.com/name/nm0515104                 NaN       Taurus
# http://www.imdb.com/name/nm0515106                 NaN       Cancer
# http://www.imdb.com/name/nm0515116                60.0        Virgo
# http://www.imdb.com/name/nm0515123                 5.0          Leo
# http://www.imdb.com/name/nm0515128                 NaN       Pisces
# http://www.imdb.com/name/nm0515193                 5.0       Cancer
# http://www.imdb.com/name/nm0515207                 3.0         None
# http://www.imdb.com/name/nm0515272                11.0  Sagittarius
# http://www.imdb.com/name/nm0515296                 5.0       Gemini
# http://www.imdb.com/name/nm0515700                 NaN          Leo
# http://www.imdb.com/name/nm0515753                 3.0       Pisces
# http://www.imdb.com/name/nm0515934                 NaN         None
# http://www.imdb.com/name/nm0515950                 NaN    Capricorn
# http://www.imdb.com/name/nm0515967                 4.0       Cancer
# http://www.imdb.com/name/nm0516001               111.0       Taurus
# http://www.imdb.com/name/nm0516003                 NaN      Scorpio
# http://www.imdb.com/name/nm0516049                 NaN        Virgo
# http://www.imdb.com/name/nm0516145                 1.0          Leo
# http://www.imdb.com/name/nm0516180                 NaN         None
# http://www.imdb.com/name/nm0516181                 1.0     Aquarius
# ...                                                ...          ...
# http://www.imdb.com/name/nm0563695                 NaN  Sagittarius
# http://www.imdb.com/name/nm0563740                 NaN         None
# http://www.imdb.com/name/nm0563826                 NaN        Virgo
# http://www.imdb.com/name/nm0563884                 NaN        Libra
# http://www.imdb.com/name/nm0563950                 NaN         None
# http://www.imdb.com/name/nm0563983                 NaN        Aries
# http://www.imdb.com/name/nm0564044                 5.0        Aries
# http://www.imdb.com/name/nm0564059                 1.0  Sagittarius
# http://www.imdb.com/name/nm0564107                 NaN       Pisces
# http://www.imdb.com/name/nm0564124                 NaN     Aquarius
# http://www.imdb.com/name/nm0564129                27.0        Virgo
# http://www.imdb.com/name/nm0564206                 NaN    Capricorn
# http://www.imdb.com/name/nm0564215                12.0       Taurus
# http://www.imdb.com/name/nm0564219                17.0        Virgo
# http://www.imdb.com/name/nm0564223                 4.0       Taurus
# http://www.imdb.com/name/nm0564277                 1.0        Libra
# http://www.imdb.com/name/nm0564304                 2.0      Scorpio
# http://www.imdb.com/name/nm0564327                 NaN         None
# http://www.imdb.com/name/nm0564394                 1.0          Leo
# http://www.imdb.com/name/nm0564500                 NaN         None
# http://www.imdb.com/name/nm0564513                 NaN         None
# http://www.imdb.com/name/nm0564534                 NaN         None
# http://www.imdb.com/name/nm0564680                 NaN    Capricorn
# http://www.imdb.com/name/nm0564697                 NaN        Virgo
# http://www.imdb.com/name/nm0564708                33.0        Aries
# http://www.imdb.com/name/nm0564724                 9.0        Virgo
# http://www.imdb.com/name/nm0564738                 3.0       Pisces
