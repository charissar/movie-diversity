# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %% [markdown]
# # Get List of unique Stars and URLS

# %%
star1_df = details_df[['Star1_URL','Star1']].copy()

# %%
star1_df.rename(columns = {'Star1_URL':'StarURL','Star1':'Star'}, inplace=True)

# %%
star2_df = details_df[['Star2_URL','Star2']].copy()

# %%
star2_df.rename(columns = {'Star2_URL':'StarURL','Star2':'Star'}, inplace=True)

# %%
star3_df = details_df[['Star3_URL','Star3']].copy()

# %%
star3_df.rename(columns = {'Star3_URL':'StarURL','Star3':'Star'}, inplace=True)

# %%
stars_df = pd.concat([star1_df,star2_df,star3_df])

# %%
stars_df.head()
# Out:
#                                                                  StarURL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                      Star
# http://www.imdb.com/title/tt4937564/         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/         Kamal Haasan
# http://www.imdb.com/title/tt4939066/          Liam Neeson
# http://www.imdb.com/title/tt4940370/    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/  Harshvardhan Kapoor

# %%
len(stars_df)
# Out:
# 89151

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
stars_df = stars_df.dropna(subset = ['StarURL'])

# %%
len(stars_df)
# Out:
# 89075

# %%
stars_df = stars_df.drop_duplicates(subset='StarURL',keep='first')

# %%
len(stars_df)
# Out:
# 33838

# %%
star_urls = list(stars_df['StarURL'])

# %%
star_urls = sorted(star_urls, reverse = True)

# %%
star_urls[:10]
# Out:
# ['http://www.imdb.com/name/nm9585396',
#  'http://www.imdb.com/name/nm9578606',
#  'http://www.imdb.com/name/nm9572036',
#  'http://www.imdb.com/name/nm9572029',
#  'http://www.imdb.com/name/nm9557596',
#  'http://www.imdb.com/name/nm9557587',
#  'http://www.imdb.com/name/nm9557586',
#  'http://www.imdb.com/name/nm9552585',
#  'http://www.imdb.com/name/nm9549343',
#  'http://www.imdb.com/name/nm9521432']

# %% [raw]
# star_urls.pop()

# %% [raw]
# star_urls[22525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# url = 'http://www.imdb.com/name/nm0000233/'
# # url= 'http://www.imdb.com/name/nm0002354/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# star_details = {}
# star_details[url] = {}

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a') if gender else None
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = soup.find(id='name-bio-text')
#         gender = gender.text if gender else None
#         gender = re.sub('\n', '', gender) if gender else None
#         gender = re.sub('  +',' ', gender) if gender else None
#         gender = gender.split(' ') if gender else None
#         male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
#         female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
#         if gender:
#             if male_count > female_count:
#                 gender = 'Male'
#             elif female_count > male_count:
#                 gender = 'Female'
#             else:
#                 gender = None
#
# gender

# %% [raw]
# height = soup.find('h2',text=re.compile('Personal Details'))
# height = height.parent if height else None
# height = height.find(id='details-height') if height else None
# height = height.text if height else None
# height = height.split('(')[-1] if height else None
# height = re.sub('[^0-9.]+','',height) if height else None
# # star_details[url]['Height in m'] = height
# height

# %% [raw]
# publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
# publicity_listings = publicity_listings.parent if publicity_listings else None
# publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
# publicity_listings = publicity_listings.text if publicity_listings else None
# publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
# publicity_listings = publicity_listings.strip() if publicity_listings else None
# publicity_listings = publicity_listings.split(' ') if publicity_listings else None
# publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
# publicity_listings = sum(publicity_listings) if publicity_listings else None
# star_details[url]['Publicity Listings'] = publicity_listings
# publicity_listings

# %% [raw]
# star_sign = soup.find('h4',text=re.compile('Star Sign'))
# star_sign = star_sign.parent if star_sign else None
# star_sign = star_sign.text if star_sign else None
# star_sign = star_sign.strip() if star_sign else None
# star_sign = star_sign.split('\n')[-1] if star_sign else None
# star_details[url]['Star Sign'] = star_sign
#
# star_sign

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a')
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = None
# star_details[url]['Gender'] = gender
#
# gender

# %% [raw]
# born_info = soup.find(id='name-born-info')
#
# birthdate = born_info.find('time') if born_info else None
# if birthdate.has_attr('datetime'):
#     birthdate = birthdate['datetime']
# else:
#     birthdate = None
# # star_details[url]['Birthdate'] = birthdate
#
# birthplace = born_info.findAll('a') if born_info else None
# birthplace = birthplace[-1] if birthplace else None
# birthplace = birthplace.text if birthplace else None
# # star_details[url]['Birthplace'] = birthplace
#
# birthcountry = birthplace.split(', ') if birthplace else None
# birthcountry = birthcountry[-1] if len(birthcountry)>2 else None
# # star_details[url]['Birth Country'] = birthcountry
#
# birthdate
# # birthplace
# # birthcountry

# %% [raw]
# acting_roles = soup.find(id='filmo-head-actor')
# acting_roles = acting_roles.text if acting_roles else None
# acting_roles = acting_roles.strip() if acting_roles else None
# acting_roles = acting_roles.split('(')[-1] if acting_roles else None
# acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
# acting_roles = int(acting_roles) if acting_roles else None
# # star_details[url]['Acting Roles'] = action_roles
#
# acting_roles

# %% [raw]
# tv_appearances = soup.find(id='filmo-head-self')
# tv_appearances = tv_appearances.text if tv_appearances else None
# tv_appearances = tv_appearances.strip() if tv_appearances else None
# tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
# tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
# star_details[url]['producing Roles'] = tv_appearances
# tv_appearances
#
#
# # star_details[url]['producing Roles'] = tv_appearances

# %% [raw]
# star_name = soup.find('h1')
# star_name = star_name.text if star_name else None
# star_name = star_name.strip() if star_name else None
# star_name = star_name.split('\n') if star_name else None
#
# deathyear = star_name[-1] if len(star_name)>=2 else None
# deathyear = deathyear.split('–')[-1] if deathyear else None
# deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
# deathyear = int(deathyear) if deathyear else None
#
# star_name = star_name[0] if star_name else None
#
# birthyear = birthdate[0:4] if birthdate and len(birthdate)>=10 else None
# birthyear = int(birthyear) if birthyear else None
#
# age_at_death = deathyear-birthyear if deathyear and birthyear else None
#
# birthyear

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.find('span') if award_highlight else None
# award_highlight = award_highlight.text if award_highlight else None
# award_highlight = award_highlight.strip() if award_highlight else None
# award_highlight = award_highlight.split('\n') if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# #     star_details[url]['Award Info'] = award_highlight
# award_highlight

# %% [raw]
# star_details

# %%
len(star_urls)
# Out:
# 33838

# %% [markdown]
# ## Scrape Star Details

# %%
# star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

stars_scraped = 0
star_details = {}
star_index = 30000                    
prefix = 'http://www.imdb.com'
export_number = 50
export_no = str(export_number)
load_attempts = 0

def star_scraper():
    global star_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in star_urls[star_index:33000]:
#         print(url)
        if (star_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(star_index+1, url))
        page = request_page(url)
        get_star_details(url, page)
        star_index += 1
    
    export_to_json(star_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_star_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    star_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    star_details[url]['Gender'] = gender
    
    
    star_name = soup.find('h1')
    star_name = star_name.text if star_name else None
    star_name = star_name.strip() if star_name else None
    star_name = star_name.split('\n') if star_name else None

    deathyear = star_name[-1] if len(star_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
    star_details[url]['Deathyear'] = deathyear
    

    star_name = star_name[0] if star_name else None
    star_details[url]['Name'] = star_name    
    
    
    born_info = soup.find(id='name-born-info')

    birthdate = born_info.find('time') if born_info else None
    if birthdate:
        if birthdate.has_attr('datetime'):
            birthdate = birthdate['datetime']
        else:
            birthdate = None
    star_details[url]['Birthdate'] = birthdate

    birthyear = birthdate[0:4] if birthdate and len(birthdate)>=8 else None
    birthyear = int(birthyear) if birthyear else None
    star_details[url]['Birthyear'] = birthyear

    age_at_death = deathyear-birthyear if deathyear and birthyear else None
    star_details[url]['Age at Death'] = age_at_death

    
    birthplace = born_info.findAll('a') if born_info else None
    birthplace = birthplace[-1] if birthplace else None
    birthplace = birthplace.text if birthplace else None
# 32460: http://www.imdb.com/name/nm0001694
# 32480: http://www.imdb.com/name/nm0001668
# 32500: http://www.imdb.com/name/nm0001646
# 32520: http://www.imdb.com/name/nm0001623
# 32540: http://www.imdb.com/name/nm0001600
# 32560: http://www.imdb.com/name/nm0001575
# 32580: http://www.imdb.com/name/nm0001550
# 32600: http://www.imdb.com/name/nm0001528
# 32620: http://www.imdb.com/name/nm0001505
# 32640: http://www.imdb.com/name/nm0001480
# 32660: http://www.imdb.com/name/nm0001454
# 32680: http://www.imdb.com/name/nm0001433
# 32700: http://www.imdb.com/name/nm0001411
# 32720: http://www.imdb.com/name/nm0001385
# 32740: http://www.imdb.com/name/nm0001364
# 32760: http://www.imdb.com/name/nm0001335
# 32780: http://www.imdb.com/name/nm0001309
# 32800: http://www.imdb.com/name/nm0001285
# 32820: http://www.imdb.com/name/nm0001258
# 32840: http://www.imdb.com/name/nm0001234
# 32860: http://www.imdb.com/name/nm0001209
# 32880: http://www.imdb.com/name/nm0001184
# 32900: http://www.imdb.com/name/nm0001159
# 32920: http://www.imdb.com/name/nm0001131
# 32940: http://www.imdb.com/name/nm0001105
# 32960: http://www.imdb.com/name/nm0001079
# 32980: http://www.imdb.com/name/nm0001055
# 33000: http://www.imdb.com/name/nm0001029
# 2018-01-30 01:47:54.728076 : working on export 53
# 2018-01-30 01:47:54.730328 : working on export 54
# Done
# 5431.106

# %%
import json
import pandas as pd
stars_import = pd.read_json('star_details_exports/star_details_export_52.json',orient='index')

# %%
len(stars_import)
# Out:
# 1000

# %%
stars_import
# Out:
#                                     Acting Roles  Age at Death  \
# http://www.imdb.com/name/nm0001029          40.0           NaN
# http://www.imdb.com/name/nm0001030           8.0          43.0
# http://www.imdb.com/name/nm0001032           NaN          57.0
# http://www.imdb.com/name/nm0001033         197.0          67.0
# http://www.imdb.com/name/nm0001034           NaN           NaN
# http://www.imdb.com/name/nm0001035          50.0           NaN
# http://www.imdb.com/name/nm0001036           NaN           NaN
# http://www.imdb.com/name/nm0001037          28.0          48.0
# http://www.imdb.com/name/nm0001038          54.0           NaN
# http://www.imdb.com/name/nm0001039          11.0           NaN
# http://www.imdb.com/name/nm0001040           NaN           NaN
# http://www.imdb.com/name/nm0001041           NaN           NaN
# http://www.imdb.com/name/nm0001042           NaN           NaN
# http://www.imdb.com/name/nm0001043           NaN           NaN
# http://www.imdb.com/name/nm0001044           NaN           NaN
# http://www.imdb.com/name/nm0001045          57.0           NaN
# http://www.imdb.com/name/nm0001046           NaN           NaN
# http://www.imdb.com/name/nm0001048          40.0           NaN
# http://www.imdb.com/name/nm0001049           NaN          66.0
# http://www.imdb.com/name/nm0001050          18.0          46.0
# http://www.imdb.com/name/nm0001055           NaN          93.0
# http://www.imdb.com/name/nm0001056         173.0           NaN
# http://www.imdb.com/name/nm0001057           NaN           NaN
# http://www.imdb.com/name/nm0001058           NaN           NaN
# http://www.imdb.com/name/nm0001059         108.0           NaN
# http://www.imdb.com/name/nm0001061           NaN           NaN
# http://www.imdb.com/name/nm0001062         129.0           NaN
# http://www.imdb.com/name/nm0001064          73.0           NaN
# http://www.imdb.com/name/nm0001065          29.0           NaN
# http://www.imdb.com/name/nm0001066          80.0           NaN
# ...                                          ...           ...
# http://www.imdb.com/name/nm0004133           NaN           NaN
# http://www.imdb.com/name/nm0004134           NaN           NaN
# http://www.imdb.com/name/nm0004147          38.0           NaN
# http://www.imdb.com/name/nm0004149         118.0           NaN
# http://www.imdb.com/name/nm0004193           NaN           NaN
# http://www.imdb.com/name/nm0004236          52.0           NaN
# http://www.imdb.com/name/nm0004244          16.0          75.0
# http://www.imdb.com/name/nm0004248          87.0           NaN
# http://www.imdb.com/name/nm0004254           2.0           NaN
# http://www.imdb.com/name/nm0004266           NaN           NaN
# http://www.imdb.com/name/nm0004282           NaN          81.0
# http://www.imdb.com/name/nm0004286         111.0           NaN
# http://www.imdb.com/name/nm0004291           NaN          52.0
# http://www.imdb.com/name/nm0004292          69.0          64.0
# http://www.imdb.com/name/nm0004294           NaN           NaN
# http://www.imdb.com/name/nm0004309           NaN           NaN
# http://www.imdb.com/name/nm0004310         234.0          73.0
# http://www.imdb.com/name/nm0004334           NaN           NaN
# http://www.imdb.com/name/nm0004335          35.0           NaN
# http://www.imdb.com/name/nm0004349           NaN           NaN
# http://www.imdb.com/name/nm0004354          17.0           NaN
# http://www.imdb.com/name/nm0004363          91.0           NaN
# http://www.imdb.com/name/nm0004365         129.0           NaN
# http://www.imdb.com/name/nm0004376           NaN           NaN
# http://www.imdb.com/name/nm0004380          36.0           NaN
# http://www.imdb.com/name/nm0004381           NaN           NaN
# http://www.imdb.com/name/nm0004395         111.0           NaN
# http://www.imdb.com/name/nm0004416          33.0           NaN
# http://www.imdb.com/name/nm0004417         259.0          73.0
# http://www.imdb.com/name/nm0004418           NaN           NaN
#
#                                                                            Award Info  \
# http://www.imdb.com/name/nm0001029                            4 wins & 6 nominations.
# http://www.imdb.com/name/nm0001030                      Nominated for 1 Golden Globe.
# http://www.imdb.com/name/nm0001032                             4 wins & 1 nomination.
# http://www.imdb.com/name/nm0001033                                               None
# http://www.imdb.com/name/nm0001034                             1 win & 2 nominations.
# http://www.imdb.com/name/nm0001035                                             1 win.
# http://www.imdb.com/name/nm0001036  Nominated for 3 Golden Globes. Another 24 wins...
# http://www.imdb.com/name/nm0001037                                      1 nomination.
# http://www.imdb.com/name/nm0001038  Nominated for 1 Golden Globe. Another 1 win & ...
# http://www.imdb.com/name/nm0001039                                      1 nomination.
# http://www.imdb.com/name/nm0001040                          22 wins & 13 nominations.
# http://www.imdb.com/name/nm0001041                          24 wins & 14 nominations.
# http://www.imdb.com/name/nm0001042                                               None
# http://www.imdb.com/name/nm0001043  Nominated for 5 Primetime Emmys. Another 8 win...
# http://www.imdb.com/name/nm0001044                                             1 win.
# http://www.imdb.com/name/nm0001045                             1 win & 4 nominations.
# http://www.imdb.com/name/nm0001046     Won 1 Oscar. Another 46 wins & 28 nominations.
# http://www.imdb.com/name/nm0001048                             1 win & 4 nominations.
# http://www.imdb.com/name/nm0001049  Nominated for 2 Oscars. Another 2 wins & 15 no...
# http://www.imdb.com/name/nm0001050  Nominated for 4 Oscars. Another 2 wins & 3 nom...
# http://www.imdb.com/name/nm0001055       Won 1 Oscar. Another 5 wins & 3 nominations.
# http://www.imdb.com/name/nm0001056  Won 1 Golden Globe. Another 5 wins & 8 nominat...
# http://www.imdb.com/name/nm0001057  Nominated for 1 Oscar. Another 26 wins & 51 no...
# http://www.imdb.com/name/nm0001058  Won 1 Golden Globe. Another 7 wins & 15 nomina...
# http://www.imdb.com/name/nm0001059  Nominated for 1 BAFTA Film Award. Another 11 w...
# http://www.imdb.com/name/nm0001061                             1 win & 3 nominations.
# http://www.imdb.com/name/nm0001062                            4 wins & 5 nominations.
# http://www.imdb.com/name/nm0001064                              1 win & 1 nomination.
# http://www.imdb.com/name/nm0001065      Won 2 Primetime Emmys. Another 4 nominations.
# http://www.imdb.com/name/nm0001066      Nominated for 1 Golden Globe. Another 2 wins.
# ...                                                                               ...
# http://www.imdb.com/name/nm0004133                              1 win & 1 nomination.
# http://www.imdb.com/name/nm0004134                            2 wins & 3 nominations.
# http://www.imdb.com/name/nm0004147                                      1 nomination.
# http://www.imdb.com/name/nm0004149                          15 wins & 19 nominations.
# http://www.imdb.com/name/nm0004193                          16 wins & 10 nominations.
# http://www.imdb.com/name/nm0004236                            7 wins & 7 nominations.
# http://www.imdb.com/name/nm0004244  Nominated for 1 Oscar. Another 8 wins & 5 nomi...
# http://www.imdb.com/name/nm0004248                             5 wins & 1 nomination.
# http://www.imdb.com/name/nm0004254                                               None
# http://www.imdb.com/name/nm0004266    Won 1 Oscar. Another 64 wins & 104 nominations.
# http://www.imdb.com/name/nm0004282  Won 1 Golden Globe. Another 1 win & 1 nomination.
# http://www.imdb.com/name/nm0004286  Nominated for 1 Primetime Emmy. Another 4 wins...
# http://www.imdb.com/name/nm0004291                                            2 wins.
# http://www.imdb.com/name/nm0004292                           12 wins & 5 nominations.
# http://www.imdb.com/name/nm0004294                                      1 nomination.
# http://www.imdb.com/name/nm0004309  Nominated for 2 Oscars. Another 6 wins & 16 no...
# http://www.imdb.com/name/nm0004310                                            2 wins.
# http://www.imdb.com/name/nm0004334                           9 wins & 14 nominations.
# http://www.imdb.com/name/nm0004335                          28 wins & 23 nominations.
# http://www.imdb.com/name/nm0004349                                               None
# http://www.imdb.com/name/nm0004354                            3 wins & 5 nominations.
# http://www.imdb.com/name/nm0004363                          14 wins & 14 nominations.
# http://www.imdb.com/name/nm0004365                                     2 nominations.
# http://www.imdb.com/name/nm0004376                            9 wins & 7 nominations.
# http://www.imdb.com/name/nm0004380                             4 wins & 1 nomination.
# http://www.imdb.com/name/nm0004381                             3 wins & 1 nomination.
# http://www.imdb.com/name/nm0004395                            2 wins & 9 nominations.
# http://www.imdb.com/name/nm0004416                            6 wins & 3 nominations.
# http://www.imdb.com/name/nm0004417                                               None
# http://www.imdb.com/name/nm0004418                           13 wins & 7 nominations.
#
#                                     Birth Country   Birthdate  \
# http://www.imdb.com/name/nm0001029            USA   1968-9-26
# http://www.imdb.com/name/nm0001030            USA   1935-8-12
# http://www.imdb.com/name/nm0001032            USA   1952-4-22
# http://www.imdb.com/name/nm0004291         Calcutta, Bengal Presidency, British India
# http://www.imdb.com/name/nm0004292  Peshawar, North-West Frontier Province, Britis...
# http://www.imdb.com/name/nm0004294                         Newport, Rhode Island, USA
# http://www.imdb.com/name/nm0004309                               Goessel, Kansas, USA
# http://www.imdb.com/name/nm0004310                    Philadelphia, Pennsylvania, USA
# http://www.imdb.com/name/nm0004334                        Madras, Madras State, India
# http://www.imdb.com/name/nm0004335                         Bombay, Maharashtra, India
# http://www.imdb.com/name/nm0004349                     Grand Forks, North Dakota, USA
# http://www.imdb.com/name/nm0004354              Washington, District of Columbia, USA
# http://www.imdb.com/name/nm0004363                     Bombay, State of Bombay, India
# http://www.imdb.com/name/nm0004365                                 Gary, Indiana, USA
# http://www.imdb.com/name/nm0004376           Münster, North Rhine-Westphalia, Germany
# http://www.imdb.com/name/nm0004380                                      Paris, France
# http://www.imdb.com/name/nm0004381                                      Paris, France
# http://www.imdb.com/name/nm0004395                        Santa Cruz, California, USA
# http://www.imdb.com/name/nm0004416  Konetampet, Pallipattu, Chittoor District, And...
# http://www.imdb.com/name/nm0004417  Nimmakuru, Krishna District, Andhra Pradesh, I...
# http://www.imdb.com/name/nm0004418                         Bombay, Maharashtra, India
#
#                                     Birthyear  Deathyear  Directing Roles  \
# http://www.imdb.com/name/nm0001029     1968.0        NaN              NaN
# http://www.imdb.com/name/nm0001030     1935.0     1978.0              NaN
# http://www.imdb.com/name/nm0001032     1952.0     2009.0              NaN
# http://www.imdb.com/name/nm0001033     1906.0     1973.0              NaN
# http://www.imdb.com/name/nm0001034     1957.0        NaN              NaN
# http://www.imdb.com/name/nm0001035     1970.0        NaN              NaN
# http://www.imdb.com/name/nm0001036     1944.0        NaN              NaN
# http://www.imdb.com/name/nm0001037     1941.0     1989.0              NaN
# http://www.imdb.com/name/nm0001038     1971.0        NaN              1.0
# http://www.imdb.com/name/nm0001039     1972.0        NaN              NaN
# http://www.imdb.com/name/nm0001040     1961.0        NaN              3.0
# http://www.imdb.com/name/nm0001041     1964.0        NaN              NaN
# http://www.imdb.com/name/nm0001042     1947.0        NaN              NaN
# http://www.imdb.com/name/nm0001043     1980.0        NaN              NaN
# http://www.imdb.com/name/nm0001044     1961.0        NaN              1.0
# http://www.imdb.com/name/nm0001045     1938.0        NaN              6.0
# http://www.imdb.com/name/nm0001046     1940.0        NaN              NaN
# http://www.imdb.com/name/nm0001048     1957.0        NaN              NaN
# http://www.imdb.com/name/nm0001049     1944.0     2010.0              NaN
# http://www.imdb.com/name/nm0001050     1920.0     1966.0              NaN
# http://www.imdb.com/name/nm0001055     1903.0     1996.0              NaN
# http://www.imdb.com/name/nm0001056     1932.0        NaN              NaN
# http://www.imdb.com/name/nm0001057     1972.0        NaN              NaN
# http://www.imdb.com/name/nm0001058     1933.0        NaN              NaN
# http://www.imdb.com/name/nm0001059     1950.0        NaN              1.0
# http://www.imdb.com/name/nm0001061     1973.0        NaN              NaN
# http://www.imdb.com/name/nm0001062     1954.0        NaN              NaN
# http://www.imdb.com/name/nm0001064     1963.0        NaN              5.0
# http://www.imdb.com/name/nm0001065     1967.0        NaN              NaN
# http://www.imdb.com/name/nm0001066     1935.0        NaN              8.0
# ...                                       ...        ...              ...
# http://www.imdb.com/name/nm0004133     1970.0        NaN              2.0
# http://www.imdb.com/name/nm0004134     1973.0        NaN              NaN
# http://www.imdb.com/name/nm0004147     1975.0        NaN              NaN
# http://www.imdb.com/name/nm0004149     1941.0        NaN              8.0
# http://www.imdb.com/name/nm0004193     1968.0        NaN              3.0
# http://www.imdb.com/name/nm0004236     1964.0        NaN              NaN
# http://www.imdb.com/name/nm0004244     1907.0     1982.0              8.0
# http://www.imdb.com/name/nm0004248     1952.0        NaN              NaN
# http://www.imdb.com/name/nm0004254        NaN        NaN              NaN
# http://www.imdb.com/name/nm0004266     1982.0        NaN              NaN
# http://www.imdb.com/name/nm0004282     1930.0     2011.0              NaN
# http://www.imdb.com/name/nm0004286     1970.0        NaN              2.0
# http://www.imdb.com/name/nm0004291     1929.0     1981.0              NaN
# http://www.imdb.com/name/nm0004292     1924.0     1988.0             10.0
# http://www.imdb.com/name/nm0004294     1980.0        NaN              NaN
# http://www.imdb.com/name/nm0004309     1936.0        NaN              NaN
# http://www.imdb.com/name/nm0004310     1902.0     1975.0              NaN
# http://www.imdb.com/name/nm0004334     1954.0        NaN              NaN
# http://www.imdb.com/name/nm0004335     1974.0        NaN              NaN
# http://www.imdb.com/name/nm0004349     1973.0        NaN              NaN
# http://www.imdb.com/name/nm0004354     1960.0        NaN             16.0
# http://www.imdb.com/name/nm0004363     1949.0        NaN             14.0
# http://www.imdb.com/name/nm0004365     1938.0        NaN             23.0
# http://www.imdb.com/name/nm0004376     1974.0        NaN              1.0
# http://www.imdb.com/name/nm0004380     1953.0        NaN              8.0
# http://www.imdb.com/name/nm0004381     1976.0        NaN              1.0
# http://www.imdb.com/name/nm0004395     1973.0        NaN              3.0
# http://www.imdb.com/name/nm0004416     1946.0        NaN              NaN
# http://www.imdb.com/name/nm0004417     1923.0     1996.0             16.0
# http://www.imdb.com/name/nm0004418     1974.0        NaN              NaN
#
#                                     Gender  Height in m  \
# http://www.imdb.com/name/nm0001029    Male         1.88
# http://www.imdb.com/name/nm0001030    Male         1.79
# http://www.imdb.com/name/nm0001032  Female         1.70
# http://www.imdb.com/name/nm0001033    Male         1.88
# http://www.imdb.com/name/nm0001034  Female         1.68
# http://www.imdb.com/name/nm0001035    Male         1.80
# http://www.imdb.com/name/nm0001036  Female         1.65
# http://www.imdb.com/name/nm0001037    Male         1.93
# http://www.imdb.com/name/nm0001038    Male         1.80
# http://www.imdb.com/name/nm0001039    Male         1.80
# http://www.imdb.com/name/nm0001040  Female         1.63
# http://www.imdb.com/name/nm0001041  Female         1.68
# http://www.imdb.com/name/nm0001042  Female         1.71
# http://www.imdb.com/name/nm0001043  Female         1.57
# http://www.imdb.com/name/nm0001044  Female         1.73
# http://www.imdb.com/name/nm0001045    Male         1.78
# http://www.imdb.com/name/nm0001046  Female         1.60
# http://www.imdb.com/name/nm0001048    Male         1.80
# http://www.imdb.com/name/nm0001049  Female         1.73
# http://www.imdb.com/name/nm0001050    Male         1.78
# http://www.imdb.com/name/nm0001055  Female         1.64
# http://www.imdb.com/name/nm0001056    Male         1.85
# http://www.imdb.com/name/nm0001057  Female         1.73
# http://www.imdb.com/name/nm0001058  Female         1.63
# http://www.imdb.com/name/nm0001059    Male         1.85
# http://www.imdb.com/name/nm0001061  Female         1.57
# http://www.imdb.com/name/nm0001062    Male         1.70
# http://www.imdb.com/name/nm0001064    Male         1.83
# http://www.imdb.com/name/nm0001065    Male         1.85
# http://www.imdb.com/name/nm0001066    Male         1.73
# ...                                    ...          ...
# http://www.imdb.com/name/nm0004133  Female         1.75
# http://www.imdb.com/name/nm0004134  Female          NaN
# http://www.imdb.com/name/nm0004147    Male         1.87
# http://www.imdb.com/name/nm0004149    Male         1.97
# http://www.imdb.com/name/nm0004193  Female         1.65
# http://www.imdb.com/name/nm0004236    Male          NaN
# http://www.imdb.com/name/nm0004244    Male         1.91
# http://www.imdb.com/name/nm0004248    Male         1.83
# http://www.imdb.com/name/nm0004254    Male         1.70
# http://www.imdb.com/name/nm0004266  Female         1.73
# http://www.imdb.com/name/nm0004282  Female         1.73
# http://www.imdb.com/name/nm0004286    Male         1.73
# http://www.imdb.com/name/nm0004291  Female          NaN
# http://www.imdb.com/name/nm0004292    Male         1.70
# http://www.imdb.com/name/nm0004294  Female         1.73
# http://www.imdb.com/name/nm0004309  Female          NaN
# http://www.imdb.com/name/nm0004310    Male         1.63
# http://www.imdb.com/name/nm0004334  Female         1.70
# http://www.imdb.com/name/nm0004335    Male         1.78
# http://www.imdb.com/name/nm0004349  Female         1.70
# http://www.imdb.com/name/nm0004354    Male          NaN
# http://www.imdb.com/name/nm0004363    Male          NaN
# http://www.imdb.com/name/nm0004365    Male         1.91
# http://www.imdb.com/name/nm0004376  Female         1.74
# http://www.imdb.com/name/nm0004380    Male          NaN
# http://www.imdb.com/name/nm0004381  Female         1.65
# http://www.imdb.com/name/nm0004395    Male         1.75
# http://www.imdb.com/name/nm0004416    Male          NaN
# http://www.imdb.com/name/nm0004417    Male          NaN
# http://www.imdb.com/name/nm0004418  Female         1.60
#
#                                                          Name  \
# http://www.imdb.com/name/nm0001029               Jim Caviezel
# http://www.imdb.com/name/nm0001030                John Cazale
# http://www.imdb.com/name/nm0001032           Marilyn Chambers
# http://www.imdb.com/name/nm0001033             Lon Chaney Jr.
# http://www.imdb.com/name/nm0001034              Rosalind Chao
# http://www.imdb.com/name/nm0001035                Ben Chaplin
# http://www.imdb.com/name/nm0001036          Geraldine Chaplin
# http://www.imdb.com/name/nm0001037             Graham Chapman
# http://www.imdb.com/name/nm0001038               Josh Charles
# http://www.imdb.com/name/nm0001039              David Charvet
# http://www.imdb.com/name/nm0001040                  Joan Chen
# http://www.imdb.com/name/nm0001041              Maggie Cheung
# http://www.imdb.com/name/nm0001042                Lois Chiles
# http://www.imdb.com/name/nm0001043              Anna Chlumsky
# http://www.imdb.com/name/nm0001044             Rae Dawn Chong
# http://www.imdb.com/name/nm0001045                Tommy Chong
