# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %% [markdown]
# # Get List of unique Stars and URLS

# %%
star1_df = details_df[['Star1_URL','Star1']].copy()

# %%
star1_df.rename(columns = {'Star1_URL':'StarURL','Star1':'Star'}, inplace=True)

# %%
star2_df = details_df[['Star2_URL','Star2']].copy()

# %%
star2_df.rename(columns = {'Star2_URL':'StarURL','Star2':'Star'}, inplace=True)

# %%
star3_df = details_df[['Star3_URL','Star3']].copy()

# %%
star3_df.rename(columns = {'Star3_URL':'StarURL','Star3':'Star'}, inplace=True)

# %%
stars_df = pd.concat([star1_df,star2_df,star3_df])

# %%
stars_df.head()
# Out:
#                                                                  StarURL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                      Star
# http://www.imdb.com/title/tt4937564/         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/         Kamal Haasan
# http://www.imdb.com/title/tt4939066/          Liam Neeson
# http://www.imdb.com/title/tt4940370/    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/  Harshvardhan Kapoor

# %%
len(stars_df)
# Out:
# 89151

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
stars_df = stars_df.dropna(subset = ['StarURL'])

# %%
len(stars_df)
# Out:
# 89075

# %%
stars_df = stars_df.drop_duplicates(subset='StarURL',keep='first')

# %%
len(stars_df)
# Out:
# 33838

# %%
star_urls = list(stars_df['StarURL'])

# %%
star_urls = sorted(star_urls, reverse = True)

# %%
star_urls[:10]
# Out:
# ['http://www.imdb.com/name/nm9585396',
#  'http://www.imdb.com/name/nm9578606',
#  'http://www.imdb.com/name/nm9572036',
#  'http://www.imdb.com/name/nm9572029',
#  'http://www.imdb.com/name/nm9557596',
#  'http://www.imdb.com/name/nm9557587',
#  'http://www.imdb.com/name/nm9557586',
#  'http://www.imdb.com/name/nm9552585',
#  'http://www.imdb.com/name/nm9549343',
#  'http://www.imdb.com/name/nm9521432']

# %% [raw]
# star_urls.pop()

# %% [raw]
# star_urls[22525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# url = 'http://www.imdb.com/name/nm0000233/'
# # url= 'http://www.imdb.com/name/nm0002354/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# star_details = {}
# star_details[url] = {}

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a') if gender else None
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = soup.find(id='name-bio-text')
#         gender = gender.text if gender else None
#         gender = re.sub('\n', '', gender) if gender else None
#         gender = re.sub('  +',' ', gender) if gender else None
#         gender = gender.split(' ') if gender else None
#         male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
#         female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
#         if gender:
#             if male_count > female_count:
#                 gender = 'Male'
#             elif female_count > male_count:
#                 gender = 'Female'
#             else:
#                 gender = None
#
# gender

# %% [raw]
# height = soup.find('h2',text=re.compile('Personal Details'))
# height = height.parent if height else None
# height = height.find(id='details-height') if height else None
# height = height.text if height else None
# height = height.split('(')[-1] if height else None
# height = re.sub('[^0-9.]+','',height) if height else None
# # star_details[url]['Height in m'] = height
# height

# %% [raw]
# publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
# publicity_listings = publicity_listings.parent if publicity_listings else None
# publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
# publicity_listings = publicity_listings.text if publicity_listings else None
# publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
# publicity_listings = publicity_listings.strip() if publicity_listings else None
# publicity_listings = publicity_listings.split(' ') if publicity_listings else None
# publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
# publicity_listings = sum(publicity_listings) if publicity_listings else None
# star_details[url]['Publicity Listings'] = publicity_listings
# publicity_listings

# %% [raw]
# star_sign = soup.find('h4',text=re.compile('Star Sign'))
# star_sign = star_sign.parent if star_sign else None
# star_sign = star_sign.text if star_sign else None
# star_sign = star_sign.strip() if star_sign else None
# star_sign = star_sign.split('\n')[-1] if star_sign else None
# star_details[url]['Star Sign'] = star_sign
#
# star_sign

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a')
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = None
# star_details[url]['Gender'] = gender
#
# gender

# %% [raw]
# born_info = soup.find(id='name-born-info')
#
# birthdate = born_info.find('time') if born_info else None
# if birthdate.has_attr('datetime'):
#     birthdate = birthdate['datetime']
# else:
#     birthdate = None
# # star_details[url]['Birthdate'] = birthdate
#
# birthplace = born_info.findAll('a') if born_info else None
# birthplace = birthplace[-1] if birthplace else None
# birthplace = birthplace.text if birthplace else None
# # star_details[url]['Birthplace'] = birthplace
#
# birthcountry = birthplace.split(', ') if birthplace else None
# birthcountry = birthcountry[-1] if len(birthcountry)>2 else None
# # star_details[url]['Birth Country'] = birthcountry
#
# birthdate
# # birthplace
# # birthcountry

# %% [raw]
# acting_roles = soup.find(id='filmo-head-actor')
# acting_roles = acting_roles.text if acting_roles else None
# acting_roles = acting_roles.strip() if acting_roles else None
# acting_roles = acting_roles.split('(')[-1] if acting_roles else None
# acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
# acting_roles = int(acting_roles) if acting_roles else None
# # star_details[url]['Acting Roles'] = action_roles
#
# acting_roles

# %% [raw]
# tv_appearances = soup.find(id='filmo-head-self')
# tv_appearances = tv_appearances.text if tv_appearances else None
# tv_appearances = tv_appearances.strip() if tv_appearances else None
# tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
# tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
# star_details[url]['producing Roles'] = tv_appearances
# tv_appearances
#
#
# # star_details[url]['producing Roles'] = tv_appearances

# %% [raw]
# star_name = soup.find('h1')
# star_name = star_name.text if star_name else None
# star_name = star_name.strip() if star_name else None
# star_name = star_name.split('\n') if star_name else None
#
# deathyear = star_name[-1] if len(star_name)>=2 else None
# deathyear = deathyear.split('–')[-1] if deathyear else None
# deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
# deathyear = int(deathyear) if deathyear else None
#
# star_name = star_name[0] if star_name else None
#
# birthyear = birthdate[0:4] if birthdate and len(birthdate)>=10 else None
# birthyear = int(birthyear) if birthyear else None
#
# age_at_death = deathyear-birthyear if deathyear and birthyear else None
#
# birthyear

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.find('span') if award_highlight else None
# award_highlight = award_highlight.text if award_highlight else None
# award_highlight = award_highlight.strip() if award_highlight else None
# award_highlight = award_highlight.split('\n') if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# #     star_details[url]['Award Info'] = award_highlight
# award_highlight

# %% [raw]
# star_details

# %%
len(star_urls)
# Out:
# 33838

# %% [markdown]
# ## Scrape Star Details

# %%
# star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

stars_scraped = 0
star_details = {}
star_index = 27000                    
prefix = 'http://www.imdb.com'
export_number = 45
export_no = str(export_number)
load_attempts = 0

def star_scraper():
    global star_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in star_urls[star_index:30000]:
#         print(url)
        if (star_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(star_index+1, url))
        page = request_page(url)
        get_star_details(url, page)
        star_index += 1
    
    export_to_json(star_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_star_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    star_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    star_details[url]['Gender'] = gender
    
    
    star_name = soup.find('h1')
    star_name = star_name.text if star_name else None
    star_name = star_name.strip() if star_name else None
    star_name = star_name.split('\n') if star_name else None

    deathyear = star_name[-1] if len(star_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
    star_details[url]['Deathyear'] = deathyear
    

    star_name = star_name[0] if star_name else None
    star_details[url]['Name'] = star_name    
    
    
    born_info = soup.find(id='name-born-info')

    birthdate = born_info.find('time') if born_info else None
    if birthdate:
        if birthdate.has_attr('datetime'):
            birthdate = birthdate['datetime']
        else:
            birthdate = None
    star_details[url]['Birthdate'] = birthdate

    birthyear = birthdate[0:4] if birthdate and len(birthdate)>=8 else None
    birthyear = int(birthyear) if birthyear else None
    star_details[url]['Birthyear'] = birthyear

    age_at_death = deathyear-birthyear if deathyear and birthyear else None
    star_details[url]['Age at Death'] = age_at_death

    
    birthplace = born_info.findAll('a') if born_info else None
    birthplace = birthplace[-1] if birthplace else None
    birthplace = birthplace.text if birthplace else None
    star_details[url]['Birthplace'] = birthplace

    
    birthcountry = birthplace.split(', ') if birthplace else None
    birthcountry = birthcountry[-1] if birthcountry and len(birthcountry)>=1 else None
    star_details[url]['Birth Country'] = birthcountry
 

    award_highlight = soup.find('div', class_='article highlighted')
    award_highlight = award_highlight.findAll('span') if award_highlight else None
    award_highlight = [x.text for x in award_highlight] if award_highlight else None
    award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
    award_highlight = [x.split('\n') for x in award_highlight] if award_highlight else None
    award_highlight = [''.join(x) for x in award_highlight[:-1]] if award_highlight else None
    award_highlight = [re.sub("  +", " ", x) for x in award_highlight] if award_highlight else None
    award_highlight = ' '.join(award_highlight) if award_highlight else None    
    star_details[url]['Award Info'] = award_highlight    
    
    acting_roles = soup.find(id='filmo-head-actor')
    acting_roles = acting_roles.text if acting_roles else None
    acting_roles = acting_roles.strip() if acting_roles else None
    acting_roles = acting_roles.split('(')[-1] if acting_roles else None
    acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
    acting_roles = int(acting_roles) if acting_roles else None
    star_details[url]['Acting Roles'] = acting_roles
    
    directing_roles = soup.find(id='filmo-head-director')
    directing_roles = directing_roles.text if directing_roles else None
    directing_roles = directing_roles.strip() if directing_roles else None
    directing_roles = directing_roles.split('(')[-1] if directing_roles else None
    directing_roles = re.sub('[^0-9]+','',directing_roles) if directing_roles else None
    directing_roles = int(directing_roles) if directing_roles else None
    star_details[url]['Directing Roles'] = directing_roles  
    
    producing_roles = soup.find(id='filmo-head-producer')
    producing_roles = producing_roles.text if producing_roles else None
    producing_roles = producing_roles.strip() if producing_roles else None
    producing_roles = producing_roles.split('(')[-1] if producing_roles else None
    producing_roles = re.sub('[^0-9]+','',producing_roles) if producing_roles else None
    producing_roles = int(producing_roles) if producing_roles else None
    star_details[url]['Producing Roles'] = producing_roles 
    
    tv_appearances = soup.find(id='filmo-head-self')
    tv_appearances = tv_appearances.text if tv_appearances else None
    tv_appearances = tv_appearances.strip() if tv_appearances else None
    tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
    tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
    tv_appearances = int(tv_appearances) if tv_appearances else None
    star_details[url]['TV Appearances'] = tv_appearances
    

    height = soup.find('h2',text=re.compile('Personal Details'))
    height = height.parent if height else None
    height = height.find(id='details-height') if height else None
    height = height.text if height else None
    height = height.split('(')[-1] if height else None
    height = re.sub('[^0-9.]+','',height) if height else None
    star_details[url]['Height in m'] = height

    publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
    publicity_listings = publicity_listings.parent if publicity_listings else None
    publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
    publicity_listings = publicity_listings.text if publicity_listings else None
    publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
    publicity_listings = publicity_listings.strip() if publicity_listings else None
    publicity_listings = publicity_listings.split(' ') if publicity_listings else None
    publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
    publicity_listings = sum(publicity_listings) if publicity_listings else None
    star_details[url]['Publicity Listings'] = publicity_listings
        
    star_sign = soup.find('h4',text=re.compile('Star Sign'))
    star_sign = star_sign.parent if star_sign else None
    star_sign = star_sign.text if star_sign else None
    star_sign = star_sign.strip() if star_sign else None
    star_sign = star_sign.split('\n')[-1] if star_sign else None
    star_details[url]['Star Sign'] = star_sign

    go_to_next_and_export()

def go_to_next_and_export():
    global stars_scraped
    global star_details
    
    stars_scraped+=1

    if len(star_details) == 1000:                                         
        export_to_json(star_details)
        stars_scraped = 0
        star_details = {}

def export_to_json(star_details):
    global export_no
    global export_number
    with open('star_details_exports/star_details_export_%s.json' %(export_no),'w')  as f:
        json.dump(star_details,f)

    export_number += 1
    export_no = str(export_number)
    print(str(datetime.now()),': working on export ' + export_no)

start = time.time()
star_scraper()
end = time.time()
print(round(end-start,3))
# Out:
# 2018-01-30 00:12:00.418025 : working on export 45
# 27020: http://www.imdb.com/name/nm0214419
# 27040: http://www.imdb.com/name/nm0213034
# 27060: http://www.imdb.com/name/nm0211922
# 27080: http://www.imdb.com/name/nm0211089
# 27100: http://www.imdb.com/name/nm0209428
# 27120: http://www.imdb.com/name/nm0208735
# 27140: http://www.imdb.com/name/nm0207101
# 27160: http://www.imdb.com/name/nm0206247
# 27180: http://www.imdb.com/name/nm0205423
# 27200: http://www.imdb.com/name/nm0204547
# 27220: http://www.imdb.com/name/nm0202589
# 27240: http://www.imdb.com/name/nm0201669
# 27260: http://www.imdb.com/name/nm0200626
# 27280: http://www.imdb.com/name/nm0199841
# 27300: http://www.imdb.com/name/nm0199047
# 27320: http://www.imdb.com/name/nm0198059
# 27340: http://www.imdb.com/name/nm0197164
# 27360: http://www.imdb.com/name/nm0195929
# 27380: http://www.imdb.com/name/nm0194759
# 27400: http://www.imdb.com/name/nm0193836
# 27420: http://www.imdb.com/name/nm0193149
# 27440: http://www.imdb.com/name/nm0192035
# 27460: http://www.imdb.com/name/nm0191412
# 27480: http://www.imdb.com/name/nm0190441
# 27500: http://www.imdb.com/name/nm0188678
# 27520: http://www.imdb.com/name/nm0187584
# 27540: http://www.imdb.com/name/nm0186567
# 27560: http://www.imdb.com/name/nm0185819
# 27580: http://www.imdb.com/name/nm0184578
# 27600: http://www.imdb.com/name/nm0183573
# 27620: http://www.imdb.com/name/nm0182626
# 27640: http://www.imdb.com/name/nm0181246
# 27660: http://www.imdb.com/name/nm0179982
# 27680: http://www.imdb.com/name/nm0179154
# 27700: http://www.imdb.com/name/nm0178376
# 27720: http://www.imdb.com/name/nm0177158
# 27740: http://www.imdb.com/name/nm0176460
# 27760: http://www.imdb.com/name/nm0175621
# 27780: http://www.imdb.com/name/nm0174780
# 27800: http://www.imdb.com/name/nm0173577
# 27820: http://www.imdb.com/name/nm0172604
# 27840: http://www.imdb.com/name/nm0171499
# 27860: http://www.imdb.com/name/nm0170306
# 27880: http://www.imdb.com/name/nm0168568
# 27900: http://www.imdb.com/name/nm0167649
# 27920: http://www.imdb.com/name/nm0166972
# 27940: http://www.imdb.com/name/nm0165905
# 27960: http://www.imdb.com/name/nm0164950
# 27980: http://www.imdb.com/name/nm0164019
# 28000: http://www.imdb.com/name/nm0163214
# 2018-01-30 00:38:11.665375 : working on export 46
# 28020: http://www.imdb.com/name/nm0161710
# http://www.imdb.com/name/nm0071847          30.0           NaN
# http://www.imdb.com/name/nm0071848          11.0           NaN
# http://www.imdb.com/name/nm0071855           NaN           NaN
# http://www.imdb.com/name/nm0072124          90.0           NaN
# http://www.imdb.com/name/nm0072279           1.0           NaN
# http://www.imdb.com/name/nm0072344         100.0           NaN
# http://www.imdb.com/name/nm0072435           NaN           NaN
# http://www.imdb.com/name/nm0072504          43.0           NaN
# ...                                          ...           ...
# http://www.imdb.com/name/nm0117022          47.0           NaN
# http://www.imdb.com/name/nm0117028         115.0           NaN
# http://www.imdb.com/name/nm0117035           6.0           NaN
# http://www.imdb.com/name/nm0117146           NaN           NaN
# http://www.imdb.com/name/nm0117188          68.0          74.0
# http://www.imdb.com/name/nm0117200           NaN          51.0
# http://www.imdb.com/name/nm0117250           5.0           NaN
# http://www.imdb.com/name/nm0117252         231.0          77.0
# http://www.imdb.com/name/nm0117307           NaN           NaN
# http://www.imdb.com/name/nm0117339          75.0           NaN
# http://www.imdb.com/name/nm0117368          65.0           NaN
# http://www.imdb.com/name/nm0117374          80.0           NaN
# http://www.imdb.com/name/nm0117412          47.0           NaN
# http://www.imdb.com/name/nm0117420          41.0           NaN
# http://www.imdb.com/name/nm0117429          79.0           NaN
# http://www.imdb.com/name/nm0117546           NaN           NaN
# http://www.imdb.com/name/nm0117561          53.0          60.0
# http://www.imdb.com/name/nm0117568           NaN           NaN
# http://www.imdb.com/name/nm0117580           NaN           NaN
# http://www.imdb.com/name/nm0117623         101.0           NaN
# http://www.imdb.com/name/nm0117673          74.0           NaN
# http://www.imdb.com/name/nm0117691           NaN           NaN
# http://www.imdb.com/name/nm0117709          70.0           NaN
# http://www.imdb.com/name/nm0117711           NaN          49.0
# http://www.imdb.com/name/nm0117756           2.0           NaN
# http://www.imdb.com/name/nm0117762           1.0           NaN
# http://www.imdb.com/name/nm0117790           8.0           NaN
# http://www.imdb.com/name/nm0117816           NaN           NaN
# http://www.imdb.com/name/nm0117834          28.0          79.0
# http://www.imdb.com/name/nm0117857          46.0           NaN
#
#                                                                            Award Info  \
# http://www.imdb.com/name/nm0070911                                               None
# http://www.imdb.com/name/nm0070933                                               None
# http://www.imdb.com/name/nm0070987                                               None
# http://www.imdb.com/name/nm0070991                                               None
# http://www.imdb.com/name/nm0071031                                               None
# http://www.imdb.com/name/nm0071034                             5 wins & 1 nomination.
# http://www.imdb.com/name/nm0071044                                               None
# http://www.imdb.com/name/nm0071078                                               None
# http://www.imdb.com/name/nm0071116                                             1 win.
# http://www.imdb.com/name/nm0071179                              1 win & 1 nomination.
# http://www.imdb.com/name/nm0071239                                               None
# http://www.imdb.com/name/nm0071275                           2 wins & 12 nominations.
# http://www.imdb.com/name/nm0071290                                               None
# http://www.imdb.com/name/nm0071428                                               None
# http://www.imdb.com/name/nm0071501                                               None
# http://www.imdb.com/name/nm0071602                                             1 win.
# http://www.imdb.com/name/nm0071636                                               None
# http://www.imdb.com/name/nm0071746                                               None
# http://www.imdb.com/name/nm0071799                                               None
# http://www.imdb.com/name/nm0117834  Sukovo, Moscow Governorate [now Stupino Distri...
# http://www.imdb.com/name/nm0117857                       New York City, New York, USA
#
#                                     Birthyear  Deathyear  Directing Roles  \
# http://www.imdb.com/name/nm0070911     1918.0     2007.0              NaN
# http://www.imdb.com/name/nm0070933     1947.0        NaN              NaN
# http://www.imdb.com/name/nm0070987     1946.0        NaN              NaN
# http://www.imdb.com/name/nm0070991        NaN        NaN              NaN
# http://www.imdb.com/name/nm0071031     1875.0     1955.0              NaN
# http://www.imdb.com/name/nm0071034     1935.0     2013.0              3.0
# http://www.imdb.com/name/nm0071044     1948.0        NaN              NaN
# http://www.imdb.com/name/nm0071078     1973.0        NaN              NaN
# http://www.imdb.com/name/nm0071116     1965.0     2013.0              NaN
# http://www.imdb.com/name/nm0071179     1967.0        NaN              NaN
# http://www.imdb.com/name/nm0071239        NaN        NaN              NaN
# http://www.imdb.com/name/nm0071275     1975.0        NaN              NaN
# http://www.imdb.com/name/nm0071290     1934.0        NaN              NaN
# http://www.imdb.com/name/nm0071428     1947.0        NaN              NaN
# http://www.imdb.com/name/nm0071501     1963.0        NaN              NaN
# http://www.imdb.com/name/nm0071602     1891.0     1932.0              NaN
# http://www.imdb.com/name/nm0071636     1906.0     2007.0              NaN
# http://www.imdb.com/name/nm0071746     1893.0     1969.0              NaN
# http://www.imdb.com/name/nm0071799     1944.0     2017.0              NaN
# http://www.imdb.com/name/nm0071824     1931.0     1990.0              NaN
# http://www.imdb.com/name/nm0071825     1975.0        NaN              3.0
# http://www.imdb.com/name/nm0071838     1928.0     2005.0              NaN
# http://www.imdb.com/name/nm0071847     1969.0        NaN              1.0
# http://www.imdb.com/name/nm0071848     1952.0        NaN              NaN
# http://www.imdb.com/name/nm0071855     1933.0        NaN              NaN
# http://www.imdb.com/name/nm0072124     1980.0        NaN              1.0
# http://www.imdb.com/name/nm0072279        NaN        NaN              NaN
# http://www.imdb.com/name/nm0072344     1969.0        NaN              NaN
# http://www.imdb.com/name/nm0072435     1977.0        NaN              6.0
# http://www.imdb.com/name/nm0072504     1968.0        NaN              7.0
# ...                                       ...        ...              ...
# http://www.imdb.com/name/nm0117022     1981.0        NaN              NaN
# http://www.imdb.com/name/nm0117028        NaN     1989.0              NaN
# http://www.imdb.com/name/nm0117035        NaN        NaN              NaN
# http://www.imdb.com/name/nm0117146     1974.0        NaN              NaN
# http://www.imdb.com/name/nm0117188     1928.0     2002.0              NaN
# http://www.imdb.com/name/nm0117200     1959.0     2010.0              NaN
# http://www.imdb.com/name/nm0117250        NaN        NaN              NaN
# http://www.imdb.com/name/nm0117252     1924.0     2001.0              NaN
# http://www.imdb.com/name/nm0117307     1961.0        NaN              NaN
# http://www.imdb.com/name/nm0117339     1965.0        NaN              NaN
# http://www.imdb.com/name/nm0117368     1957.0        NaN              NaN
# http://www.imdb.com/name/nm0117374     1972.0        NaN              NaN
# http://www.imdb.com/name/nm0117412     1947.0        NaN              2.0
# http://www.imdb.com/name/nm0117420     1969.0        NaN              NaN
# http://www.imdb.com/name/nm0117429     1953.0        NaN              NaN
# http://www.imdb.com/name/nm0117546     1953.0        NaN              NaN
# http://www.imdb.com/name/nm0117561     1953.0     2013.0              NaN
# http://www.imdb.com/name/nm0117568     1945.0        NaN              NaN
# http://www.imdb.com/name/nm0117580     1972.0        NaN              NaN
# http://www.imdb.com/name/nm0117623     1977.0        NaN              NaN
# http://www.imdb.com/name/nm0117673     1943.0        NaN              NaN
# http://www.imdb.com/name/nm0117691     1972.0        NaN              NaN
# http://www.imdb.com/name/nm0117709     1978.0        NaN              NaN
# http://www.imdb.com/name/nm0117711     1942.0     1991.0              NaN
# http://www.imdb.com/name/nm0117756     1924.0        NaN              NaN
# http://www.imdb.com/name/nm0117762        NaN        NaN              NaN
# http://www.imdb.com/name/nm0117790        NaN        NaN              NaN
# http://www.imdb.com/name/nm0117816        NaN        NaN              NaN
# http://www.imdb.com/name/nm0117834     1917.0     1996.0              NaN
# http://www.imdb.com/name/nm0117857     1965.0        NaN              3.0
#
#                                     Gender  Height in m                  Name  \
# http://www.imdb.com/name/nm0070911    Male          NaN       Svatopluk Benes
# http://www.imdb.com/name/nm0070933  Female         1.68          Alicia Bonet
# http://www.imdb.com/name/nm0070987    Male          NaN         Yves Beneyton
# http://www.imdb.com/name/nm0070991    Male          NaN       Pascal Benezech
# http://www.imdb.com/name/nm0071031    Male         1.75          Wilson Benge
# http://www.imdb.com/name/nm0071034  Female          NaN         Norma Bengell
# http://www.imdb.com/name/nm0071044    Male          NaN         Sinan Bengier
# http://www.imdb.com/name/nm0071078    Male         1.79       Björn Bengtsson
# http://www.imdb.com/name/nm0071116  Female          NaN     Valérie Benguigui
# http://www.imdb.com/name/nm0071179    Male          NaN     Francesco Benigno
# http://www.imdb.com/name/nm0071239  Female          NaN         Claire Benito
# http://www.imdb.com/name/nm0071275    Male         1.78        André Benjamin
# http://www.imdb.com/name/nm0071290    Male         1.83  Christopher Benjamin
# http://www.imdb.com/name/nm0071428    Male          NaN           Péter Benkö
# http://www.imdb.com/name/nm0071501  Female         1.68          Anne Bennent
# http://www.imdb.com/name/nm0071602  Female          NaN         Belle Bennett
# http://www.imdb.com/name/nm0071636    Male         1.91         Bruce Bennett
# http://www.imdb.com/name/nm0071746  Female         1.60          Enid Bennett
# http://www.imdb.com/name/nm0071799    Male         1.78         Hywel Bennett
# http://www.imdb.com/name/nm0071824  Female          NaN          Jill Bennett
# http://www.imdb.com/name/nm0071825  Female         1.65          Jill Bennett
# http://www.imdb.com/name/nm0071838    Male          NaN          John Bennett
# http://www.imdb.com/name/nm0071847    Male         1.80          Manu Bennett
# http://www.imdb.com/name/nm0071848    Male          NaN        Jordan Bennett
# http://www.imdb.com/name/nm0071855  Female          NaN         Julie Bennett
# http://www.imdb.com/name/nm0072124    Male          NaN       Zachary Bennett
# http://www.imdb.com/name/nm0072279    Male          NaN         Mehdi Benoufa
# http://www.imdb.com/name/nm0072344    Male         2.01       Abraham Benrubi
# http://www.imdb.com/name/nm0072435  Female         1.63          Amber Benson
# http://www.imdb.com/name/nm0072504    Male          NaN           Greg Benson
# ...                                    ...          ...                   ...
# http://www.imdb.com/name/nm0117022    Male         1.80      Zachery Ty Bryan
# http://www.imdb.com/name/nm0117028    Male          NaN           John Bryans
# http://www.imdb.com/name/nm0117035    Male          NaN           Adam Bryant
# http://www.imdb.com/name/nm0117146  Female         1.75            Joy Bryant
# http://www.imdb.com/name/nm0117188    Male          NaN        Michael Bryant
# http://www.imdb.com/name/nm0117200  Female         1.65    Pamela Jean Bryant
# http://www.imdb.com/name/nm0117250    Male          NaN         Walter Bryant
# http://www.imdb.com/name/nm0117252    Male         1.80        William Bryant
# http://www.imdb.com/name/nm0117307  Female          NaN         Edita Brychta
# http://www.imdb.com/name/nm0117339    Male         1.70            Rob Brydon
# http://www.imdb.com/name/nm0117368    Male         1.85         Lars Brygmann
# http://www.imdb.com/name/nm0117374    Male         1.85             Greg Bryk
# http://www.imdb.com/name/nm0117412    Male         1.88      Hugh Keays-Byrne
# http://www.imdb.com/name/nm0117420    Male         1.97     Andrew Bryniarski
# http://www.imdb.com/name/nm0117429    Male         1.78     Reine Brynolfsson
# http://www.imdb.com/name/nm0117546  Female          NaN             Li Brådhe
# http://www.imdb.com/name/nm0117561    Male          NaN          Trond Brænne
# http://www.imdb.com/name/nm0117568  Female          NaN          Sylvie Bréal
# http://www.imdb.com/name/nm0117580  Female          NaN       Leticia Brédice
# http://www.imdb.com/name/nm0117623    Male         1.80        Oliver Bröcker
# http://www.imdb.com/name/nm0117673    Male         1.80    Christian Brückner
# http://www.imdb.com/name/nm0117691  Female          NaN            Kaya Brüel
# http://www.imdb.com/name/nm0117709    Male         1.76          Daniel Brühl
# http://www.imdb.com/name/nm0117711  Female         1.74           Heidi Brühl
# http://www.imdb.com/name/nm0117756    Male          NaN         Freddy Buache
# http://www.imdb.com/name/nm0117762    Male          NaN          Daniel Buain
# http://www.imdb.com/name/nm0117790    Male          NaN              Les Bubb
# http://www.imdb.com/name/nm0117816  Female          NaN      Nilgün Bubikoglu
# http://www.imdb.com/name/nm0117834    Male          NaN         Stepan Bubnov
# http://www.imdb.com/name/nm0117857    Male         1.73        Dan Bucatinsky
#
#                                     Producing Roles  Publicity Listings  \
# http://www.imdb.com/name/nm0070911              NaN                 NaN
# http://www.imdb.com/name/nm0070933              NaN                 NaN
# http://www.imdb.com/name/nm0070987              NaN                 1.0
# http://www.imdb.com/name/nm0070991              NaN                 NaN
# http://www.imdb.com/name/nm0071031              NaN                 1.0
# http://www.imdb.com/name/nm0071034              2.0                 4.0
# http://www.imdb.com/name/nm0071044              NaN                 NaN
# http://www.imdb.com/name/nm0071078              NaN                 NaN
# http://www.imdb.com/name/nm0071116              NaN                 2.0
# http://www.imdb.com/name/nm0071179              NaN                 NaN
# http://www.imdb.com/name/nm0071239              NaN                 NaN
# http://www.imdb.com/name/nm0071275              2.0                 5.0
# http://www.imdb.com/name/nm0071290              NaN                 NaN
# http://www.imdb.com/name/nm0071428              NaN                 NaN
# http://www.imdb.com/name/nm0071501              NaN                 1.0
# http://www.imdb.com/name/nm0071602              NaN                11.0
# http://www.imdb.com/name/nm0071636              NaN                 5.0
# http://www.imdb.com/name/nm0071746              NaN                 8.0
# http://www.imdb.com/name/nm0071799              NaN                 1.0
# http://www.imdb.com/name/nm0071824              NaN                 NaN
# http://www.imdb.com/name/nm0071825              6.0                 4.0
# http://www.imdb.com/name/nm0071838              NaN                 NaN
# http://www.imdb.com/name/nm0071847              2.0                 5.0
# http://www.imdb.com/name/nm0071848              NaN                 NaN
# http://www.imdb.com/name/nm0071855              NaN                 NaN
# http://www.imdb.com/name/nm0072124              1.0                 NaN
# http://www.imdb.com/name/nm0072279              NaN                 NaN
# http://www.imdb.com/name/nm0072344              NaN                 1.0
# http://www.imdb.com/name/nm0072435              6.0                 9.0
# http://www.imdb.com/name/nm0072504              5.0                 NaN
# ...                                             ...                 ...
# http://www.imdb.com/name/nm0117022             10.0                 5.0
# http://www.imdb.com/name/nm0117028              NaN                 NaN
# http://www.imdb.com/name/nm0117035              NaN                 NaN
# http://www.imdb.com/name/nm0117146              1.0                 8.0
# http://www.imdb.com/name/nm0117188              NaN                 2.0
# http://www.imdb.com/name/nm0117200              NaN                 9.0
# http://www.imdb.com/name/nm0117250              NaN                 NaN
# http://www.imdb.com/name/nm0117252              NaN                 NaN
# http://www.imdb.com/name/nm0117307              NaN                 NaN
# http://www.imdb.com/name/nm0117339              8.0                16.0
# http://www.imdb.com/name/nm0117368              NaN                 NaN
# http://www.imdb.com/name/nm0117374              NaN                 NaN
# http://www.imdb.com/name/nm0117412              NaN                 2.0
# http://www.imdb.com/name/nm0117420              2.0                 NaN
# http://www.imdb.com/name/nm0117429              NaN                 1.0
# http://www.imdb.com/name/nm0117546              NaN                 NaN
# http://www.imdb.com/name/nm0117561              NaN                 NaN
# http://www.imdb.com/name/nm0117568              NaN                 NaN
# http://www.imdb.com/name/nm0117580              NaN                55.0
# http://www.imdb.com/name/nm0117623              NaN                 NaN
# http://www.imdb.com/name/nm0117673              NaN                 1.0
# http://www.imdb.com/name/nm0117691              NaN                 NaN
# http://www.imdb.com/name/nm0117709              NaN                10.0
# http://www.imdb.com/name/nm0117711              NaN                15.0
# http://www.imdb.com/name/nm0117756              NaN                 NaN
# http://www.imdb.com/name/nm0117762              NaN                 NaN
# http://www.imdb.com/name/nm0117790              NaN                 NaN
# http://www.imdb.com/name/nm0117816              NaN                 NaN
# http://www.imdb.com/name/nm0117834              NaN                 NaN
# http://www.imdb.com/name/nm0117857             20.0                 6.0
#
#                                     Star Sign  TV Appearances
# http://www.imdb.com/name/nm0070911     Pisces             6.0
# http://www.imdb.com/name/nm0070933     Taurus             1.0
# http://www.imdb.com/name/nm0070987        Leo             NaN
# http://www.imdb.com/name/nm0070991       None             NaN
# http://www.imdb.com/name/nm0071031     Pisces             NaN
# http://www.imdb.com/name/nm0071034     Pisces            11.0
