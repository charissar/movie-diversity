# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %% [markdown]
# # Get List of unique Stars and URLS

# %%
star1_df = details_df[['Star1_URL','Star1']].copy()

# %%
star1_df.rename(columns = {'Star1_URL':'StarURL','Star1':'Star'}, inplace=True)

# %%
star2_df = details_df[['Star2_URL','Star2']].copy()

# %%
star2_df.rename(columns = {'Star2_URL':'StarURL','Star2':'Star'}, inplace=True)

# %%
star3_df = details_df[['Star3_URL','Star3']].copy()

# %%
star3_df.rename(columns = {'Star3_URL':'StarURL','Star3':'Star'}, inplace=True)

# %%
stars_df = pd.concat([star1_df,star2_df,star3_df])

# %%
stars_df.head()
# Out:
#                                                                  StarURL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                      Star
# http://www.imdb.com/title/tt4937564/         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/         Kamal Haasan
# http://www.imdb.com/title/tt4939066/          Liam Neeson
# http://www.imdb.com/title/tt4940370/    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/  Harshvardhan Kapoor

# %%
len(stars_df)
# Out:
# 89151

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
stars_df = stars_df.dropna(subset = ['StarURL'])

# %%
len(stars_df)
# Out:
# 89075

# %%
stars_df = stars_df.drop_duplicates(subset='StarURL',keep='first')

# %%
len(stars_df)
# Out:
# 33838

# %%
star_urls = list(stars_df['StarURL'])

# %%
star_urls = sorted(star_urls, reverse = True)

# %%
star_urls[:10]
# Out:
# ['http://www.imdb.com/name/nm9585396',
#  'http://www.imdb.com/name/nm9578606',
#  'http://www.imdb.com/name/nm9572036',
#  'http://www.imdb.com/name/nm9572029',
#  'http://www.imdb.com/name/nm9557596',
#  'http://www.imdb.com/name/nm9557587',
#  'http://www.imdb.com/name/nm9557586',
#  'http://www.imdb.com/name/nm9552585',
#  'http://www.imdb.com/name/nm9549343',
#  'http://www.imdb.com/name/nm9521432']

# %% [raw]
# star_urls.pop()

# %% [raw]
# star_urls[22525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# url = 'http://www.imdb.com/name/nm0000233/'
# # url= 'http://www.imdb.com/name/nm0002354/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# star_details = {}
# star_details[url] = {}

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a') if gender else None
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = soup.find(id='name-bio-text')
#         gender = gender.text if gender else None
#         gender = re.sub('\n', '', gender) if gender else None
#         gender = re.sub('  +',' ', gender) if gender else None
#         gender = gender.split(' ') if gender else None
#         male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
#         female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
#         if gender:
#             if male_count > female_count:
#                 gender = 'Male'
#             elif female_count > male_count:
#                 gender = 'Female'
#             else:
#                 gender = None
#
# gender

# %% [raw]
# height = soup.find('h2',text=re.compile('Personal Details'))
# height = height.parent if height else None
# height = height.find(id='details-height') if height else None
# height = height.text if height else None
# height = height.split('(')[-1] if height else None
# height = re.sub('[^0-9.]+','',height) if height else None
# # star_details[url]['Height in m'] = height
# height

# %% [raw]
# publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
# publicity_listings = publicity_listings.parent if publicity_listings else None
# publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
# publicity_listings = publicity_listings.text if publicity_listings else None
# publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
# publicity_listings = publicity_listings.strip() if publicity_listings else None
# publicity_listings = publicity_listings.split(' ') if publicity_listings else None
# publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
# publicity_listings = sum(publicity_listings) if publicity_listings else None
# star_details[url]['Publicity Listings'] = publicity_listings
# publicity_listings

# %% [raw]
# star_sign = soup.find('h4',text=re.compile('Star Sign'))
# star_sign = star_sign.parent if star_sign else None
# star_sign = star_sign.text if star_sign else None
# star_sign = star_sign.strip() if star_sign else None
# star_sign = star_sign.split('\n')[-1] if star_sign else None
# star_details[url]['Star Sign'] = star_sign
#
# star_sign

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a')
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = None
# star_details[url]['Gender'] = gender
#
# gender

# %% [raw]
# born_info = soup.find(id='name-born-info')
#
# birthdate = born_info.find('time') if born_info else None
# if birthdate.has_attr('datetime'):
#     birthdate = birthdate['datetime']
# else:
#     birthdate = None
# # star_details[url]['Birthdate'] = birthdate
#
# birthplace = born_info.findAll('a') if born_info else None
# birthplace = birthplace[-1] if birthplace else None
# birthplace = birthplace.text if birthplace else None
# # star_details[url]['Birthplace'] = birthplace
#
# birthcountry = birthplace.split(', ') if birthplace else None
# birthcountry = birthcountry[-1] if len(birthcountry)>2 else None
# # star_details[url]['Birth Country'] = birthcountry
#
# birthdate
# # birthplace
# # birthcountry

# %% [raw]
# acting_roles = soup.find(id='filmo-head-actor')
# acting_roles = acting_roles.text if acting_roles else None
# acting_roles = acting_roles.strip() if acting_roles else None
# acting_roles = acting_roles.split('(')[-1] if acting_roles else None
# acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
# acting_roles = int(acting_roles) if acting_roles else None
# # star_details[url]['Acting Roles'] = action_roles
#
# acting_roles

# %% [raw]
# tv_appearances = soup.find(id='filmo-head-self')
# tv_appearances = tv_appearances.text if tv_appearances else None
# tv_appearances = tv_appearances.strip() if tv_appearances else None
# tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
# tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
# star_details[url]['producing Roles'] = tv_appearances
# tv_appearances
#
#
# # star_details[url]['producing Roles'] = tv_appearances

# %% [raw]
# star_name = soup.find('h1')
# star_name = star_name.text if star_name else None
# star_name = star_name.strip() if star_name else None
# star_name = star_name.split('\n') if star_name else None
#
# deathyear = star_name[-1] if len(star_name)>=2 else None
# deathyear = deathyear.split('–')[-1] if deathyear else None
# deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
# deathyear = int(deathyear) if deathyear else None
#
# star_name = star_name[0] if star_name else None
#
# birthyear = birthdate[0:4] if birthdate and len(birthdate)>=10 else None
# birthyear = int(birthyear) if birthyear else None
#
# age_at_death = deathyear-birthyear if deathyear and birthyear else None
#
# birthyear

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.find('span') if award_highlight else None
# award_highlight = award_highlight.text if award_highlight else None
# award_highlight = award_highlight.strip() if award_highlight else None
# award_highlight = award_highlight.split('\n') if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# #     star_details[url]['Award Info'] = award_highlight
# award_highlight

# %% [raw]
# star_details

# %%
len(star_urls)
# Out:
# 33838

# %% [markdown]
# ## Scrape Star Details

# %%
# star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

stars_scraped = 0
star_details = {}
star_index = 24000                    
prefix = 'http://www.imdb.com'
export_number = 40
export_no = str(export_number)
load_attempts = 0

def star_scraper():
    global star_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in star_urls[star_index:27000]:
#         print(url)
        if (star_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(star_index+1, url))
        page = request_page(url)
        get_star_details(url, page)
        star_index += 1
    
    export_to_json(star_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_star_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    star_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    star_details[url]['Gender'] = gender
    
    
    star_name = soup.find('h1')
    star_name = star_name.text if star_name else None
    star_name = star_name.strip() if star_name else None
    star_name = star_name.split('\n') if star_name else None

    deathyear = star_name[-1] if len(star_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
    star_details[url]['Deathyear'] = deathyear
    

    star_name = star_name[0] if star_name else None
    star_details[url]['Name'] = star_name    
    
    
    born_info = soup.find(id='name-born-info')

    birthdate = born_info.find('time') if born_info else None
    if birthdate:
        if birthdate.has_attr('datetime'):
            birthdate = birthdate['datetime']
        else:
            birthdate = None
    star_details[url]['Birthdate'] = birthdate

    birthyear = birthdate[0:4] if birthdate and len(birthdate)>=8 else None
    birthyear = int(birthyear) if birthyear else None
    star_details[url]['Birthyear'] = birthyear

    age_at_death = deathyear-birthyear if deathyear and birthyear else None
    star_details[url]['Age at Death'] = age_at_death

    
    birthplace = born_info.findAll('a') if born_info else None
    birthplace = birthplace[-1] if birthplace else None
    birthplace = birthplace.text if birthplace else None
    star_details[url]['Birthplace'] = birthplace

    
    birthcountry = birthplace.split(', ') if birthplace else None
    birthcountry = birthcountry[-1] if birthcountry and len(birthcountry)>=1 else None
    star_details[url]['Birth Country'] = birthcountry
 

    award_highlight = soup.find('div', class_='article highlighted')
    award_highlight = award_highlight.findAll('span') if award_highlight else None
    award_highlight = [x.text for x in award_highlight] if award_highlight else None
    award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
    award_highlight = [x.split('\n') for x in award_highlight] if award_highlight else None
    award_highlight = [''.join(x) for x in award_highlight[:-1]] if award_highlight else None
    award_highlight = [re.sub("  +", " ", x) for x in award_highlight] if award_highlight else None
    award_highlight = ' '.join(award_highlight) if award_highlight else None    
    star_details[url]['Award Info'] = award_highlight    
    
    acting_roles = soup.find(id='filmo-head-actor')
    acting_roles = acting_roles.text if acting_roles else None
    acting_roles = acting_roles.strip() if acting_roles else None
    acting_roles = acting_roles.split('(')[-1] if acting_roles else None
    acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
    acting_roles = int(acting_roles) if acting_roles else None
    star_details[url]['Acting Roles'] = acting_roles
    
    directing_roles = soup.find(id='filmo-head-director')
    directing_roles = directing_roles.text if directing_roles else None
    directing_roles = directing_roles.strip() if directing_roles else None
    directing_roles = directing_roles.split('(')[-1] if directing_roles else None
    directing_roles = re.sub('[^0-9]+','',directing_roles) if directing_roles else None
    directing_roles = int(directing_roles) if directing_roles else None
    star_details[url]['Directing Roles'] = directing_roles  
    
    producing_roles = soup.find(id='filmo-head-producer')
    producing_roles = producing_roles.text if producing_roles else None
    producing_roles = producing_roles.strip() if producing_roles else None
    producing_roles = producing_roles.split('(')[-1] if producing_roles else None
    producing_roles = re.sub('[^0-9]+','',producing_roles) if producing_roles else None
    producing_roles = int(producing_roles) if producing_roles else None
# 26580: http://www.imdb.com/name/nm0236329
# 26600: http://www.imdb.com/name/nm0235426
# 26620: http://www.imdb.com/name/nm0234807
# 26640: http://www.imdb.com/name/nm0233807
# 26660: http://www.imdb.com/name/nm0233107
# 26680: http://www.imdb.com/name/nm0232278
# 26700: http://www.imdb.com/name/nm0230990
# 26720: http://www.imdb.com/name/nm0229983
# 26740: http://www.imdb.com/name/nm0229309
# 26760: http://www.imdb.com/name/nm0228086
# 26780: http://www.imdb.com/name/nm0227042
# 26800: http://www.imdb.com/name/nm0226387
# 26820: http://www.imdb.com/name/nm0225255
# 26840: http://www.imdb.com/name/nm0223532
# 26860: http://www.imdb.com/name/nm0222596
# 26880: http://www.imdb.com/name/nm0221902
# 26900: http://www.imdb.com/name/nm0220898
# 26920: http://www.imdb.com/name/nm0220346
# 26940: http://www.imdb.com/name/nm0219342
# 26960: http://www.imdb.com/name/nm0218633
# 26980: http://www.imdb.com/name/nm0217677
# 27000: http://www.imdb.com/name/nm0215770
# 2018-01-30 01:28:03.438852 : working on export 43
# 2018-01-30 01:28:03.440422 : working on export 44
# Done
# 4642.811

# %%
import json
import pandas as pd
stars_import = pd.read_json('star_details_exports/star_details_export_42.json',orient='index')

# %%
len(stars_import)
# Out:
# 1000

# %%
stars_import
# Out:
#                                     Acting Roles  Age at Death  \
# http://www.imdb.com/name/nm0215770          46.0          60.0
# http://www.imdb.com/name/nm0215803           7.0           NaN
# http://www.imdb.com/name/nm0215805          65.0          63.0
# http://www.imdb.com/name/nm0215938          32.0           NaN
# http://www.imdb.com/name/nm0216177           NaN           NaN
# http://www.imdb.com/name/nm0216209           NaN          93.0
# http://www.imdb.com/name/nm0216221          28.0           NaN
# http://www.imdb.com/name/nm0216928          27.0           NaN
# http://www.imdb.com/name/nm0217148           NaN           NaN
# http://www.imdb.com/name/nm0217255          43.0           NaN
# http://www.imdb.com/name/nm0217260          80.0           NaN
# http://www.imdb.com/name/nm0217280          13.0           NaN
# http://www.imdb.com/name/nm0217306           NaN          19.0
# http://www.imdb.com/name/nm0217320          32.0           NaN
# http://www.imdb.com/name/nm0217386           5.0           NaN
# http://www.imdb.com/name/nm0217454           NaN           NaN
# http://www.imdb.com/name/nm0217466         117.0           NaN
# http://www.imdb.com/name/nm0217481           NaN           NaN
# http://www.imdb.com/name/nm0217493           NaN           NaN
# http://www.imdb.com/name/nm0217645           NaN           NaN
# http://www.imdb.com/name/nm0217677           NaN           NaN
# http://www.imdb.com/name/nm0217684           NaN           NaN
# http://www.imdb.com/name/nm0217695          11.0           NaN
# http://www.imdb.com/name/nm0217716          57.0           NaN
# http://www.imdb.com/name/nm0217735           NaN          89.0
# http://www.imdb.com/name/nm0217795           NaN           NaN
# http://www.imdb.com/name/nm0217817         138.0           NaN
# http://www.imdb.com/name/nm0217822           3.0           NaN
# http://www.imdb.com/name/nm0217848           NaN          97.0
# http://www.imdb.com/name/nm0217868           NaN           NaN
# ...                                          ...           ...
# http://www.imdb.com/name/nm0264134          54.0           NaN
# http://www.imdb.com/name/nm0264155          21.0           NaN
# http://www.imdb.com/name/nm0264278          23.0          39.0
# http://www.imdb.com/name/nm0264303           NaN           NaN
# http://www.imdb.com/name/nm0264411           NaN           NaN
# http://www.imdb.com/name/nm0264512          92.0           NaN
# http://www.imdb.com/name/nm0264554           NaN           NaN
# http://www.imdb.com/name/nm0264579         131.0           NaN
# http://www.imdb.com/name/nm0264660           NaN           NaN
# http://www.imdb.com/name/nm0264688          16.0          73.0
# http://www.imdb.com/name/nm0264692          84.0          77.0
# http://www.imdb.com/name/nm0264762          82.0          85.0
# http://www.imdb.com/name/nm0264770         127.0          79.0
# http://www.imdb.com/name/nm0264847           NaN           NaN
# http://www.imdb.com/name/nm0264870           7.0          57.0
# http://www.imdb.com/name/nm0265067         118.0           NaN
# http://www.imdb.com/name/nm0265155          92.0           NaN
# http://www.imdb.com/name/nm0265189           NaN           NaN
# http://www.imdb.com/name/nm0265196           NaN          40.0
# http://www.imdb.com/name/nm0265309           NaN           NaN
# http://www.imdb.com/name/nm0265361          10.0           NaN
# http://www.imdb.com/name/nm0265457         132.0           NaN
# http://www.imdb.com/name/nm0265492          76.0           NaN
# http://www.imdb.com/name/nm0265519           NaN           NaN
# http://www.imdb.com/name/nm0265551           NaN          76.0
# http://www.imdb.com/name/nm0265562           NaN           NaN
# http://www.imdb.com/name/nm0265610           NaN           NaN
# http://www.imdb.com/name/nm0265628          11.0           NaN
# http://www.imdb.com/name/nm0265631           6.0          73.0
# http://www.imdb.com/name/nm0265668          74.0           NaN
#
#                                                                 Award Info  \
# http://www.imdb.com/name/nm0215770                   1 win & 1 nomination.
# http://www.imdb.com/name/nm0215803                                    None
# http://www.imdb.com/name/nm0215805                                    None
# http://www.imdb.com/name/nm0215938               13 wins & 10 nominations.
# http://www.imdb.com/name/nm0216177                                    None
# http://www.imdb.com/name/nm0216209                                    None
# http://www.imdb.com/name/nm0216221                                    None
# http://www.imdb.com/name/nm0216928                                    None
# http://www.imdb.com/name/nm0217148                  3 wins & 1 nomination.
# http://www.imdb.com/name/nm0217255                                    None
# http://www.imdb.com/name/nm0217260                                    None
# http://www.imdb.com/name/nm0217280                           1 nomination.
# http://www.imdb.com/name/nm0217306                                    None
# http://www.imdb.com/name/nm0217320                                    None
# http://www.imdb.com/name/nm0217386                                    None
# http://www.imdb.com/name/nm0217454                                  1 win.
# http://www.imdb.com/name/nm0217466                 4 wins & 3 nominations.
# http://www.imdb.com/name/nm0217481                                    None
# http://www.imdb.com/name/nm0217493                                    None
# http://www.imdb.com/name/nm0217645                                  1 win.
# http://www.imdb.com/name/nm0217677                           1 nomination.
# http://www.imdb.com/name/nm0217684                                    None
# http://www.imdb.com/name/nm0217695                                    None
# http://www.imdb.com/name/nm0217716                 4 wins & 4 nominations.
# http://www.imdb.com/name/nm0217735                          2 nominations.
# http://www.imdb.com/name/nm0217795                                    None
# http://www.imdb.com/name/nm0217817                                    None
# http://www.imdb.com/name/nm0217822                                    None
# http://www.imdb.com/name/nm0217848                                  1 win.
# http://www.imdb.com/name/nm0217868                                    None
# ...                                                                    ...
# http://www.imdb.com/name/nm0264134                                    None
# http://www.imdb.com/name/nm0264155                                 2 wins.
# http://www.imdb.com/name/nm0264278                                    None
# http://www.imdb.com/name/nm0264303                                    None
# http://www.imdb.com/name/nm0264411                                    None
# http://www.imdb.com/name/nm0217695     1949.0        NaN              NaN
# http://www.imdb.com/name/nm0217716     1959.0        NaN              4.0
# http://www.imdb.com/name/nm0217735     1926.0     2015.0              NaN
# http://www.imdb.com/name/nm0217795        NaN        NaN              NaN
# http://www.imdb.com/name/nm0217817     1941.0        NaN              NaN
# http://www.imdb.com/name/nm0217822        NaN        NaN              NaN
# http://www.imdb.com/name/nm0217848     1898.0     1995.0              NaN
# http://www.imdb.com/name/nm0217868     1970.0        NaN              NaN
# ...                                       ...        ...              ...
# http://www.imdb.com/name/nm0264134     1945.0        NaN              NaN
# http://www.imdb.com/name/nm0264155     1926.0        NaN              NaN
# http://www.imdb.com/name/nm0264278     1918.0     1957.0              NaN
# http://www.imdb.com/name/nm0264303     1939.0        NaN              NaN
# http://www.imdb.com/name/nm0264411        NaN        NaN              NaN
# http://www.imdb.com/name/nm0264512     1943.0        NaN              NaN
# http://www.imdb.com/name/nm0264554     1933.0        NaN              NaN
# http://www.imdb.com/name/nm0264579     1964.0        NaN              NaN
# http://www.imdb.com/name/nm0264660     1920.0        NaN              NaN
# http://www.imdb.com/name/nm0264688     1933.0     2006.0              1.0
# http://www.imdb.com/name/nm0264692     1884.0     1961.0              NaN
# http://www.imdb.com/name/nm0264762     1905.0     1990.0              9.0
# http://www.imdb.com/name/nm0264770     1916.0     1995.0              NaN
# http://www.imdb.com/name/nm0264847     1973.0        NaN              NaN
# http://www.imdb.com/name/nm0264870     1925.0     1982.0              2.0
# http://www.imdb.com/name/nm0265067     1957.0        NaN              1.0
# http://www.imdb.com/name/nm0265155     1949.0        NaN              NaN
# http://www.imdb.com/name/nm0265189        NaN        NaN              NaN
# http://www.imdb.com/name/nm0265196     1933.0     1973.0              NaN
# http://www.imdb.com/name/nm0265309     1968.0        NaN              3.0
# http://www.imdb.com/name/nm0265361        NaN        NaN              NaN
# http://www.imdb.com/name/nm0265457     1953.0        NaN              NaN
# http://www.imdb.com/name/nm0265492     1964.0        NaN              NaN
# http://www.imdb.com/name/nm0265519        NaN        NaN              NaN
# http://www.imdb.com/name/nm0265551     1904.0     1980.0              NaN
# http://www.imdb.com/name/nm0265562     1951.0        NaN              NaN
# http://www.imdb.com/name/nm0265610        NaN        NaN              NaN
# http://www.imdb.com/name/nm0265628        NaN        NaN              NaN
# http://www.imdb.com/name/nm0265631     1924.0     1997.0              NaN
# http://www.imdb.com/name/nm0265668     1974.0        NaN              NaN
#
#                                     Gender  Height in m  \
# http://www.imdb.com/name/nm0215770    Male          NaN
# http://www.imdb.com/name/nm0215803    Male          NaN
# http://www.imdb.com/name/nm0215805    Male          NaN
# http://www.imdb.com/name/nm0215938    Male         1.83
# http://www.imdb.com/name/nm0216177  Female          NaN
# http://www.imdb.com/name/nm0216209  Female          NaN
# http://www.imdb.com/name/nm0216221    Male          NaN
# http://www.imdb.com/name/nm0216928    Male          NaN
# http://www.imdb.com/name/nm0217148  Female          NaN
# http://www.imdb.com/name/nm0217255    Male          NaN
# http://www.imdb.com/name/nm0217260    Male         1.83
# http://www.imdb.com/name/nm0217280    Male          NaN
# http://www.imdb.com/name/nm0217306  Female         1.68
# http://www.imdb.com/name/nm0217320    Male         1.88
# http://www.imdb.com/name/nm0217386    Male         1.83
# http://www.imdb.com/name/nm0217454  Female         1.60
# http://www.imdb.com/name/nm0217466    Male         1.60
# http://www.imdb.com/name/nm0217481  Female         1.69
# http://www.imdb.com/name/nm0217493  Female          NaN
# http://www.imdb.com/name/nm0217645  Female         1.65
# http://www.imdb.com/name/nm0217677  Female          NaN
# http://www.imdb.com/name/nm0217684  Female          NaN
# http://www.imdb.com/name/nm0217695    Male          NaN
# http://www.imdb.com/name/nm0217716    Male         1.78
# http://www.imdb.com/name/nm0217735  Female          NaN
# http://www.imdb.com/name/nm0217795  Female          NaN
# http://www.imdb.com/name/nm0217817    Male          NaN
# http://www.imdb.com/name/nm0217822    Male         1.80
# http://www.imdb.com/name/nm0217848  Female          NaN
# http://www.imdb.com/name/nm0217868  Female          NaN
# ...                                    ...          ...
# http://www.imdb.com/name/nm0264134    Male          NaN
# http://www.imdb.com/name/nm0264155    Male          NaN
# http://www.imdb.com/name/nm0264278    Male         1.78
# http://www.imdb.com/name/nm0264303  Female         1.58
# http://www.imdb.com/name/nm0264411  Female          NaN
# http://www.imdb.com/name/nm0264512    Male          NaN
# http://www.imdb.com/name/nm0264554  Female         1.67
# http://www.imdb.com/name/nm0264579    Male         1.84
# http://www.imdb.com/name/nm0264660  Female         1.73
# http://www.imdb.com/name/nm0264688    Male          NaN
# http://www.imdb.com/name/nm0264692    Male         1.78
# http://www.imdb.com/name/nm0264762    Male         1.70
# http://www.imdb.com/name/nm0264770    Male         1.80
# http://www.imdb.com/name/nm0264847  Female          NaN
# http://www.imdb.com/name/nm0264870    Male          NaN
# http://www.imdb.com/name/nm0265067    Male         1.98
# http://www.imdb.com/name/nm0265155    Male          NaN
# http://www.imdb.com/name/nm0265189  Female          NaN
# http://www.imdb.com/name/nm0265196  Female          NaN
# http://www.imdb.com/name/nm0265309  Female          NaN
# http://www.imdb.com/name/nm0265361    Male          NaN
# http://www.imdb.com/name/nm0265457    Male          NaN
# http://www.imdb.com/name/nm0265492    Male         1.91
# http://www.imdb.com/name/nm0265519  Female          NaN
# http://www.imdb.com/name/nm0265551  Female         1.54
# http://www.imdb.com/name/nm0265562  Female          NaN
# http://www.imdb.com/name/nm0265610  Female         1.65
# http://www.imdb.com/name/nm0265628    Male          NaN
# http://www.imdb.com/name/nm0265631    Male          NaN
# http://www.imdb.com/name/nm0265668    Male         1.81
#
#                                                      Name  Producing Roles  \
# http://www.imdb.com/name/nm0215770       Duilio Del Prete              NaN
# http://www.imdb.com/name/nm0215803  David Sánchez del Rey              NaN
# http://www.imdb.com/name/nm0215805        Geraldo Del Rey              NaN
# http://www.imdb.com/name/nm0215938     Salvador del Solar              NaN
# http://www.imdb.com/name/nm0216177            Suzy Delair              NaN
# http://www.imdb.com/name/nm0216209          Lise Delamare              NaN
# http://www.imdb.com/name/nm0216221       Matthew Delamere              NaN
# http://www.imdb.com/name/nm0216928         Damián Delgado              NaN
# http://www.imdb.com/name/nm0217148          Fejria Deliba              NaN
# http://www.imdb.com/name/nm0217255     Alberto Dell'Acqua              NaN
# http://www.imdb.com/name/nm0217260   Ottaviano Dell'Acqua              NaN
# http://www.imdb.com/name/nm0217280     Patrick Dell'Isola              1.0
# http://www.imdb.com/name/nm0217306           Dorothy Dell              NaN
# http://www.imdb.com/name/nm0217320            Howard Dell              NaN
# http://www.imdb.com/name/nm0217386      David Della Rocco              NaN
# http://www.imdb.com/name/nm0217454           Ruby Larocca             11.0
# http://www.imdb.com/name/nm0217466      Carlo Delle Piane              NaN
# http://www.imdb.com/name/nm0217481      Francesca Dellera              NaN
# http://www.imdb.com/name/nm0217493  Alexandra Delli Colli              NaN
# http://www.imdb.com/name/nm0217645          Nikki Deloach              NaN
# http://www.imdb.com/name/nm0217677         Nathalie Delon              1.0
# http://www.imdb.com/name/nm0217684        Barbara Deloney              NaN
# http://www.imdb.com/name/nm0217695           Jerry Delony              NaN
# http://www.imdb.com/name/nm0217716      Michael DeLorenzo              2.0
# http://www.imdb.com/name/nm0217735        Danièle Delorme             26.0
# http://www.imdb.com/name/nm0217795    Dominique Delpierre              NaN
# http://www.imdb.com/name/nm0217817           Albert Delpy              NaN
# http://www.imdb.com/name/nm0217822     Richard DeManincor              NaN
# http://www.imdb.com/name/nm0217848         Maly Delschaft              NaN
# http://www.imdb.com/name/nm0217868        Marine Delterme              NaN
# ...                                                   ...              ...
# http://www.imdb.com/name/nm0264134           Richard Eyer              NaN
# http://www.imdb.com/name/nm0264155      Gunnar Eyjólfsson              NaN
# http://www.imdb.com/name/nm0264278          William Eythe              NaN
# http://www.imdb.com/name/nm0264303            Moeko Ezawa              NaN
# http://www.imdb.com/name/nm0264411              Lady Pink              NaN
# http://www.imdb.com/name/nm0264512            Peter Faber              NaN
# http://www.imdb.com/name/nm0264554       Françoise Fabian              NaN
# http://www.imdb.com/name/nm0264579         Patrick Fabian              1.0
# http://www.imdb.com/name/nm0264660         Nanette Fabray              NaN
# http://www.imdb.com/name/nm0264688           Pierre Fabre              NaN
# http://www.imdb.com/name/nm0264692         Saturnin Fabre              NaN
# http://www.imdb.com/name/nm0264762           Aldo Fabrizi              4.0
# http://www.imdb.com/name/nm0264770         Franco Fabrizi              NaN
# http://www.imdb.com/name/nm0264847          Rebecca Facey              NaN
# http://www.imdb.com/name/nm0264870        Alan Jay Factor              8.0
# http://www.imdb.com/name/nm0265067        Bill Fagerbakke              NaN
# http://www.imdb.com/name/nm0265155       Antônio Fagundes              1.0
# http://www.imdb.com/name/nm0265189              Kate Fahy              NaN
# http://www.imdb.com/name/nm0265196            Myrna Fahey              NaN
# http://www.imdb.com/name/nm0265309             Renee Faia              1.0
# http://www.imdb.com/name/nm0265361             J.W. Fails              NaN
# http://www.imdb.com/name/nm0265457   Christopher Fairbank              NaN
# http://www.imdb.com/name/nm0265492        Craig Fairbrass              3.0
# http://www.imdb.com/name/nm0265519       Krisha Fairchild              NaN
# http://www.imdb.com/name/nm0265551   Virginia Brown Faire              NaN
# http://www.imdb.com/name/nm0265562        Deborah Fairfax              NaN
# http://www.imdb.com/name/nm0265610       Michelle Fairley              NaN
# http://www.imdb.com/name/nm0265628            Ben Fairman              NaN
# http://www.imdb.com/name/nm0265631             Mike Raven              1.0
# http://www.imdb.com/name/nm0265668          Donald Faison              2.0
#
#                                     Publicity Listings    Star Sign  \
# http://www.imdb.com/name/nm0215770                 NaN       Cancer
# http://www.imdb.com/name/nm0215803                 NaN         None
# http://www.imdb.com/name/nm0215805                 NaN      Scorpio
# http://www.imdb.com/name/nm0215938                 NaN       Taurus
# http://www.imdb.com/name/nm0216177                 7.0    Capricorn
# http://www.imdb.com/name/nm0216209                 1.0        Aries
# http://www.imdb.com/name/nm0216221                 1.0         None
# http://www.imdb.com/name/nm0216928                 NaN         None
# http://www.imdb.com/name/nm0217148                 NaN         None
# http://www.imdb.com/name/nm0217255                 NaN         None
# http://www.imdb.com/name/nm0217260                 NaN         None
# http://www.imdb.com/name/nm0217280                 NaN         None
# http://www.imdb.com/name/nm0217306                 1.0     Aquarius
# http://www.imdb.com/name/nm0217320                 NaN         None
# http://www.imdb.com/name/nm0217386                 NaN       Taurus
# http://www.imdb.com/name/nm0217454                 NaN      Scorpio
# http://www.imdb.com/name/nm0217466                 NaN     Aquarius
# http://www.imdb.com/name/nm0217481                11.0        Libra
# http://www.imdb.com/name/nm0217493                 1.0        Virgo
# http://www.imdb.com/name/nm0217645                 NaN        Virgo
# http://www.imdb.com/name/nm0217677                21.0          Leo
# http://www.imdb.com/name/nm0217684                 NaN         None
# http://www.imdb.com/name/nm0217695                 NaN         None
# http://www.imdb.com/name/nm0217716                 1.0      Scorpio
# http://www.imdb.com/name/nm0217735                 7.0        Libra
# http://www.imdb.com/name/nm0217795                 NaN         None
# http://www.imdb.com/name/nm0217817                 NaN        Virgo
# http://www.imdb.com/name/nm0217822                 NaN         None
# http://www.imdb.com/name/nm0217848                 NaN  Sagittarius
# http://www.imdb.com/name/nm0217868                 1.0       Pisces
# ...                                                ...          ...
# http://www.imdb.com/name/nm0264134                 6.0       Taurus
# http://www.imdb.com/name/nm0264155                 NaN       Pisces
# http://www.imdb.com/name/nm0264278                19.0        Aries
# http://www.imdb.com/name/nm0264303                 NaN        Aries
# http://www.imdb.com/name/nm0264411                 NaN         None
# http://www.imdb.com/name/nm0264512                 3.0        Libra
# http://www.imdb.com/name/nm0264554                 4.0       Taurus
# http://www.imdb.com/name/nm0264579                 1.0  Sagittarius
# http://www.imdb.com/name/nm0264660                 NaN      Scorpio
# http://www.imdb.com/name/nm0264688                 1.0        Libra
# http://www.imdb.com/name/nm0264692                 NaN        Aries
# http://www.imdb.com/name/nm0264762                 3.0      Scorpio
# http://www.imdb.com/name/nm0264770                 NaN     Aquarius
# http://www.imdb.com/name/nm0264847                 NaN         None
# http://www.imdb.com/name/nm0264870                 NaN    Capricorn
# http://www.imdb.com/name/nm0265067                 NaN        Libra
# http://www.imdb.com/name/nm0265155                 3.0        Aries
# http://www.imdb.com/name/nm0265189                 NaN         None
# http://www.imdb.com/name/nm0265196                 1.0       Pisces
# http://www.imdb.com/name/nm0265309                 1.0        Aries
# http://www.imdb.com/name/nm0265361                 NaN         None
# http://www.imdb.com/name/nm0265457                 2.0        Libra
# http://www.imdb.com/name/nm0265492                 9.0         None
# http://www.imdb.com/name/nm0265519                 2.0         None
