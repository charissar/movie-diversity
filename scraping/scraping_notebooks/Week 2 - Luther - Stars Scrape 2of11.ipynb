# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %% [markdown]
# # Get List of unique Stars and URLS

# %%
star1_df = details_df[['Star1_URL','Star1']].copy()

# %%
star1_df.rename(columns = {'Star1_URL':'StarURL','Star1':'Star'}, inplace=True)

# %%
star2_df = details_df[['Star2_URL','Star2']].copy()

# %%
star2_df.rename(columns = {'Star2_URL':'StarURL','Star2':'Star'}, inplace=True)

# %%
star3_df = details_df[['Star3_URL','Star3']].copy()

# %%
star3_df.rename(columns = {'Star3_URL':'StarURL','Star3':'Star'}, inplace=True)

# %%
stars_df = pd.concat([star1_df,star2_df,star3_df])

# %%
stars_df.head()
# Out:
#                                                                  StarURL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                      Star
# http://www.imdb.com/title/tt4937564/         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/         Kamal Haasan
# http://www.imdb.com/title/tt4939066/          Liam Neeson
# http://www.imdb.com/title/tt4940370/    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/  Harshvardhan Kapoor

# %%
len(stars_df)
# Out:
# 89151

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
stars_df = stars_df.dropna(subset = ['StarURL'])

# %%
len(stars_df)
# Out:
# 89075

# %%
stars_df = stars_df.drop_duplicates(subset='StarURL',keep='first')

# %%
len(stars_df)
# Out:
# 33838

# %%
star_urls = list(stars_df['StarURL'])

# %%
star_urls = sorted(star_urls, reverse = True)

# %%
star_urls[:10]
# Out:
# ['http://www.imdb.com/name/nm9585396',
#  'http://www.imdb.com/name/nm9578606',
#  'http://www.imdb.com/name/nm9572036',
#  'http://www.imdb.com/name/nm9572029',
#  'http://www.imdb.com/name/nm9557596',
#  'http://www.imdb.com/name/nm9557587',
#  'http://www.imdb.com/name/nm9557586',
#  'http://www.imdb.com/name/nm9552585',
#  'http://www.imdb.com/name/nm9549343',
#  'http://www.imdb.com/name/nm9521432']

# %% [raw]
# star_urls.pop()

# %% [raw]
# star_urls[22525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# url = 'http://www.imdb.com/name/nm0000233/'
# # url= 'http://www.imdb.com/name/nm0002354/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# star_details = {}
# star_details[url] = {}

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a') if gender else None
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = soup.find(id='name-bio-text')
#         gender = gender.text if gender else None
#         gender = re.sub('\n', '', gender) if gender else None
#         gender = re.sub('  +',' ', gender) if gender else None
#         gender = gender.split(' ') if gender else None
#         male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
#         female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
#         if gender:
#             if male_count > female_count:
#                 gender = 'Male'
#             elif female_count > male_count:
#                 gender = 'Female'
#             else:
#                 gender = None
#
# gender

# %% [raw]
# height = soup.find('h2',text=re.compile('Personal Details'))
# height = height.parent if height else None
# height = height.find(id='details-height') if height else None
# height = height.text if height else None
# height = height.split('(')[-1] if height else None
# height = re.sub('[^0-9.]+','',height) if height else None
# # star_details[url]['Height in m'] = height
# height

# %% [raw]
# publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
# publicity_listings = publicity_listings.parent if publicity_listings else None
# publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
# publicity_listings = publicity_listings.text if publicity_listings else None
# publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
# publicity_listings = publicity_listings.strip() if publicity_listings else None
# publicity_listings = publicity_listings.split(' ') if publicity_listings else None
# publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
# publicity_listings = sum(publicity_listings) if publicity_listings else None
# star_details[url]['Publicity Listings'] = publicity_listings
# publicity_listings

# %% [raw]
# star_sign = soup.find('h4',text=re.compile('Star Sign'))
# star_sign = star_sign.parent if star_sign else None
# star_sign = star_sign.text if star_sign else None
# star_sign = star_sign.strip() if star_sign else None
# star_sign = star_sign.split('\n')[-1] if star_sign else None
# star_details[url]['Star Sign'] = star_sign
#
# star_sign

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a')
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = None
# star_details[url]['Gender'] = gender
#
# gender

# %% [raw]
# born_info = soup.find(id='name-born-info')
#
# birthdate = born_info.find('time') if born_info else None
# if birthdate.has_attr('datetime'):
#     birthdate = birthdate['datetime']
# else:
#     birthdate = None
# # star_details[url]['Birthdate'] = birthdate
#
# birthplace = born_info.findAll('a') if born_info else None
# birthplace = birthplace[-1] if birthplace else None
# birthplace = birthplace.text if birthplace else None
# # star_details[url]['Birthplace'] = birthplace
#
# birthcountry = birthplace.split(', ') if birthplace else None
# birthcountry = birthcountry[-1] if len(birthcountry)>2 else None
# # star_details[url]['Birth Country'] = birthcountry
#
# birthdate
# # birthplace
# # birthcountry

# %% [raw]
# acting_roles = soup.find(id='filmo-head-actor')
# acting_roles = acting_roles.text if acting_roles else None
# acting_roles = acting_roles.strip() if acting_roles else None
# acting_roles = acting_roles.split('(')[-1] if acting_roles else None
# acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
# acting_roles = int(acting_roles) if acting_roles else None
# # star_details[url]['Acting Roles'] = action_roles
#
# acting_roles

# %% [raw]
# tv_appearances = soup.find(id='filmo-head-self')
# tv_appearances = tv_appearances.text if tv_appearances else None
# tv_appearances = tv_appearances.strip() if tv_appearances else None
# tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
# tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
# star_details[url]['producing Roles'] = tv_appearances
# tv_appearances
#
#
# # star_details[url]['producing Roles'] = tv_appearances

# %% [raw]
# star_name = soup.find('h1')
# star_name = star_name.text if star_name else None
# star_name = star_name.strip() if star_name else None
# star_name = star_name.split('\n') if star_name else None
#
# deathyear = star_name[-1] if len(star_name)>=2 else None
# deathyear = deathyear.split('–')[-1] if deathyear else None
# deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
# deathyear = int(deathyear) if deathyear else None
#
# star_name = star_name[0] if star_name else None
#
# birthyear = birthdate[0:4] if birthdate and len(birthdate)>=10 else None
# birthyear = int(birthyear) if birthyear else None
#
# age_at_death = deathyear-birthyear if deathyear and birthyear else None
#
# birthyear

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.find('span') if award_highlight else None
# award_highlight = award_highlight.text if award_highlight else None
# award_highlight = award_highlight.strip() if award_highlight else None
# award_highlight = award_highlight.split('\n') if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# #     star_details[url]['Award Info'] = award_highlight
# award_highlight

# %% [raw]
# star_details

# %%
len(star_urls)
# Out:
# 33838

# %% [markdown]
# ## Scrape Star Details

# %%
# star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

stars_scraped = 0
star_details = {}
star_index = 3000                    
prefix = 'http://www.imdb.com'
export_number = 5
export_no = str(export_number)
load_attempts = 0

def star_scraper():
    global star_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in star_urls[star_index:6000]:
#         print(url)
        if (star_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(star_index+1, url))
        page = request_page(url)
        get_star_details(url, page)
        star_index += 1
    
    export_to_json(star_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_star_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    star_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    star_details[url]['Gender'] = gender
    
    
    star_name = soup.find('h1')
    star_name = star_name.text if star_name else None
    star_name = star_name.strip() if star_name else None
    star_name = star_name.split('\n') if star_name else None

    deathyear = star_name[-1] if len(star_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
    star_details[url]['Deathyear'] = deathyear
    

    star_name = star_name[0] if star_name else None
    star_details[url]['Name'] = star_name    
    
    
    born_info = soup.find(id='name-born-info')

    birthdate = born_info.find('time') if born_info else None
    if birthdate:
        if birthdate.has_attr('datetime'):
            birthdate = birthdate['datetime']
        else:
            birthdate = None
    star_details[url]['Birthdate'] = birthdate

    birthyear = birthdate[0:4] if birthdate and len(birthdate)>=8 else None
    birthyear = int(birthyear) if birthyear else None
    star_details[url]['Birthyear'] = birthyear

    age_at_death = deathyear-birthyear if deathyear and birthyear else None
    star_details[url]['Age at Death'] = age_at_death

    
    birthplace = born_info.findAll('a') if born_info else None
    birthplace = birthplace[-1] if birthplace else None
    birthplace = birthplace.text if birthplace else None
    star_details[url]['Birthplace'] = birthplace

    
    birthcountry = birthplace.split(', ') if birthplace else None
    birthcountry = birthcountry[-1] if birthcountry and len(birthcountry)
# 5460: http://www.imdb.com/name/nm2742329
# 5480: http://www.imdb.com/name/nm2731933
# 5500: http://www.imdb.com/name/nm2721366
# 5520: http://www.imdb.com/name/nm2713320
# 5540: http://www.imdb.com/name/nm2704055
# 5560: http://www.imdb.com/name/nm2698115
# 5580: http://www.imdb.com/name/nm2686747
# 5600: http://www.imdb.com/name/nm2678312
# 5620: http://www.imdb.com/name/nm2670576
# 5640: http://www.imdb.com/name/nm2658780
# 5660: http://www.imdb.com/name/nm2647420
# 5680: http://www.imdb.com/name/nm2639419
# 5700: http://www.imdb.com/name/nm2632545
# 5720: http://www.imdb.com/name/nm2618735
# 5740: http://www.imdb.com/name/nm2608287
# 5760: http://www.imdb.com/name/nm2601707
# 5780: http://www.imdb.com/name/nm2596846
# 5800: http://www.imdb.com/name/nm2592497
# 5820: http://www.imdb.com/name/nm2586680
# 5840: http://www.imdb.com/name/nm2580347
# 5860: http://www.imdb.com/name/nm2570429
# 5880: http://www.imdb.com/name/nm2564837
# 5900: http://www.imdb.com/name/nm2556652
# 5920: http://www.imdb.com/name/nm2549865
# 5940: http://www.imdb.com/name/nm2540339
# 5960: http://www.imdb.com/name/nm2528451
# 5980: http://www.imdb.com/name/nm2523119
# 6000: http://www.imdb.com/name/nm2515564
# 2018-01-30 00:12:26.425168 : working on export 8
# 2018-01-30 00:12:26.426607 : working on export 9
# Done
# 3511.275

# %%
import json
import pandas as pd
stars_import = pd.read_json('star_details_exports/star_details_export_5.json',orient='index')

# %%
len(stars_import)
# Out:
# 1000

# %%
stars_import
# Out:
#                                     Acting Roles  Age at Death  \
# http://www.imdb.com/name/nm3449847           NaN           NaN
# http://www.imdb.com/name/nm3452356           NaN           NaN
# http://www.imdb.com/name/nm3453345          10.0           NaN
# http://www.imdb.com/name/nm3453460           NaN           NaN
# http://www.imdb.com/name/nm3453476           NaN           NaN
# http://www.imdb.com/name/nm3453549           NaN           NaN
# http://www.imdb.com/name/nm3455204           NaN           NaN
# http://www.imdb.com/name/nm3455998           7.0           NaN
# http://www.imdb.com/name/nm3456417           2.0           NaN
# http://www.imdb.com/name/nm3457928           2.0           NaN
# http://www.imdb.com/name/nm3458185           NaN           NaN
# http://www.imdb.com/name/nm3458761          16.0           NaN
# http://www.imdb.com/name/nm3459140           NaN           NaN
# http://www.imdb.com/name/nm3459539           NaN           NaN
# http://www.imdb.com/name/nm3460467           NaN           NaN
# http://www.imdb.com/name/nm3460483           6.0           NaN
# http://www.imdb.com/name/nm3461216          11.0           NaN
# http://www.imdb.com/name/nm3462008          10.0           NaN
# http://www.imdb.com/name/nm3462228           2.0           NaN
# http://www.imdb.com/name/nm3462447          37.0           NaN
# http://www.imdb.com/name/nm3462502          77.0           NaN
# http://www.imdb.com/name/nm3462742           NaN           NaN
# http://www.imdb.com/name/nm3464911          12.0          53.0
# http://www.imdb.com/name/nm3466163           2.0           NaN
# http://www.imdb.com/name/nm3466196          19.0           NaN
# http://www.imdb.com/name/nm3466570           1.0           NaN
# http://www.imdb.com/name/nm3467401           NaN           NaN
# http://www.imdb.com/name/nm3467471          18.0           NaN
# http://www.imdb.com/name/nm3467663           NaN           NaN
# http://www.imdb.com/name/nm3467835           NaN           NaN
# ...                                          ...           ...
# http://www.imdb.com/name/nm4030776          27.0           NaN
# http://www.imdb.com/name/nm4031719          36.0           NaN
# http://www.imdb.com/name/nm4031721           NaN           NaN
# http://www.imdb.com/name/nm4031759          21.0           NaN
# http://www.imdb.com/name/nm4033934           NaN           NaN
# http://www.imdb.com/name/nm4034005          22.0           NaN
# http://www.imdb.com/name/nm4037686           1.0           NaN
# http://www.imdb.com/name/nm4040433           4.0           NaN
# http://www.imdb.com/name/nm4040725           8.0           NaN
# http://www.imdb.com/name/nm4041980           3.0           NaN
# http://www.imdb.com/name/nm4042042           NaN           NaN
# http://www.imdb.com/name/nm4043111          44.0           NaN
# http://www.imdb.com/name/nm4043618          22.0           NaN
# http://www.imdb.com/name/nm4044784          53.0           NaN
# http://www.imdb.com/name/nm4045867          16.0           NaN
# http://www.imdb.com/name/nm4046991           1.0           NaN
# http://www.imdb.com/name/nm4047586           7.0           NaN
# http://www.imdb.com/name/nm4048274           2.0           NaN
# http://www.imdb.com/name/nm4048991          13.0           NaN
# http://www.imdb.com/name/nm4050123           NaN           NaN
# http://www.imdb.com/name/nm4050470          18.0           NaN
# http://www.imdb.com/name/nm4050711           2.0           NaN
# http://www.imdb.com/name/nm4050777           6.0           NaN
# http://www.imdb.com/name/nm4051131          58.0           NaN
# http://www.imdb.com/name/nm4051277           2.0           NaN
# http://www.imdb.com/name/nm4052349           NaN           NaN
# http://www.imdb.com/name/nm4053792           NaN           NaN
# http://www.imdb.com/name/nm4055138          17.0           NaN
# http://www.imdb.com/name/nm4055926           1.0           NaN
# http://www.imdb.com/name/nm4056296          41.0           NaN
#
#                                                    Award Info Birth Country  \
# http://www.imdb.com/name/nm3449847                       None          None
# http://www.imdb.com/name/nm3452356                       None          None
# http://www.imdb.com/name/nm3453345                       None          None
# http://www.imdb.com/name/nm3453460                       None          None
# http://www.imdb.com/name/nm3453476                    2 wins.           USA
# http://www.imdb.com/name/nm3453549                       None          None
# http://www.imdb.com/name/nm3455204              1 nomination.          None
# http://www.imdb.com/name/nm3455998                       None          None
# http://www.imdb.com/name/nm3456417                       None          None
# http://www.imdb.com/name/nm3457928                       None          None
# http://www.imdb.com/name/nm3458185                       None           USA
# http://www.imdb.com/name/nm3458761              1 nomination.           USA
# http://www.imdb.com/name/nm3459140                       None           USA
# http://www.imdb.com/name/nm3459539                     1 win.          None
# http://www.imdb.com/name/nm3460467                       None           USA
# http://www.imdb.com/name/nm3460483                       None          None
# http://www.imdb.com/name/nm3461216                       None          None
# http://www.imdb.com/name/nm3462008              1 nomination.        Brazil
# http://www.imdb.com/name/nm3462228                       None          None
# http://www.imdb.com/name/nm3462447     1 win & 3 nominations.         India
# http://www.imdb.com/name/nm3462502                       None           USA
# http://www.imdb.com/name/nm3462742                    2 wins.          None
# http://www.imdb.com/name/nm3464911                       None           USA
# http://www.imdb.com/name/nm3466163                       None          None
# http://www.imdb.com/name/nm3466196              1 nomination.          None
# http://www.imdb.com/name/nm3466570                       None          None
# ...                                                                         ...
# http://www.imdb.com/name/nm4030776                                         None
# http://www.imdb.com/name/nm4031719                                         None
# http://www.imdb.com/name/nm4031721               Shasta County, California, USA
# http://www.imdb.com/name/nm4031759                                         None
# http://www.imdb.com/name/nm4033934                                         None
# http://www.imdb.com/name/nm4034005                                         None
# http://www.imdb.com/name/nm4037686                                         None
# http://www.imdb.com/name/nm4040433                                         None
# http://www.imdb.com/name/nm4040725                                         None
# http://www.imdb.com/name/nm4041980                  St. Helena, California, USA
# http://www.imdb.com/name/nm4042042                                         None
# http://www.imdb.com/name/nm4043111                                         None
# http://www.imdb.com/name/nm4043618            Kingston upon Thames, England, UK
# http://www.imdb.com/name/nm4044784                                         None
# http://www.imdb.com/name/nm4045867                     Burbank, California, USA
# http://www.imdb.com/name/nm4046991                                         None
# http://www.imdb.com/name/nm4047586                                         None
# http://www.imdb.com/name/nm4048274                                         None
# http://www.imdb.com/name/nm4048991                                         None
# http://www.imdb.com/name/nm4050123                          Houston, Texas, USA
# http://www.imdb.com/name/nm4050470                                         None
# http://www.imdb.com/name/nm4050711                                         None
# http://www.imdb.com/name/nm4050777                                         None
# http://www.imdb.com/name/nm4051131                                         None
# http://www.imdb.com/name/nm4051277                                         None
# http://www.imdb.com/name/nm4052349                                         None
# http://www.imdb.com/name/nm4053792                                         None
# http://www.imdb.com/name/nm4055138                                         None
# http://www.imdb.com/name/nm4055926                                         None
# http://www.imdb.com/name/nm4056296                                 Tokyo, Japan
#
#                                     Birthyear  Deathyear  Directing Roles  \
# http://www.imdb.com/name/nm3449847        NaN        NaN              NaN
# http://www.imdb.com/name/nm3452356        NaN        NaN              NaN
# http://www.imdb.com/name/nm3453345        NaN        NaN              NaN
# http://www.imdb.com/name/nm3453460        NaN        NaN              NaN
# http://www.imdb.com/name/nm3453476     1994.0        NaN              NaN
# http://www.imdb.com/name/nm3453549        NaN        NaN              NaN
# http://www.imdb.com/name/nm3455204        NaN        NaN              NaN
# http://www.imdb.com/name/nm3455998        NaN        NaN              NaN
# http://www.imdb.com/name/nm3456417        NaN        NaN              NaN
# http://www.imdb.com/name/nm3457928        NaN        NaN              NaN
# http://www.imdb.com/name/nm3458185     1984.0        NaN              NaN
# http://www.imdb.com/name/nm3458761     2001.0        NaN              NaN
# http://www.imdb.com/name/nm3459140     1989.0        NaN              NaN
# http://www.imdb.com/name/nm3459539        NaN        NaN              NaN
# http://www.imdb.com/name/nm3460467     1990.0        NaN              NaN
# http://www.imdb.com/name/nm3460483        NaN        NaN              NaN
# http://www.imdb.com/name/nm3461216        NaN        NaN              NaN
# http://www.imdb.com/name/nm3462008     1978.0        NaN              NaN
# http://www.imdb.com/name/nm3462228        NaN        NaN              5.0
# http://www.imdb.com/name/nm3462447     1962.0        NaN              NaN
# http://www.imdb.com/name/nm3462502     1975.0        NaN              2.0
# http://www.imdb.com/name/nm3462742        NaN        NaN              NaN
# http://www.imdb.com/name/nm3464911     1917.0     1970.0              NaN
# http://www.imdb.com/name/nm3466163        NaN        NaN              NaN
# http://www.imdb.com/name/nm3466196        NaN        NaN              NaN
# http://www.imdb.com/name/nm3466570        NaN        NaN              NaN
# http://www.imdb.com/name/nm3467401        NaN        NaN              NaN
# http://www.imdb.com/name/nm3467471     1985.0        NaN              NaN
# http://www.imdb.com/name/nm3467663     1989.0        NaN              NaN
# http://www.imdb.com/name/nm3467835        NaN        NaN              NaN
# ...                                       ...        ...              ...
# http://www.imdb.com/name/nm4030776        NaN        NaN              NaN
# http://www.imdb.com/name/nm4031719        NaN        NaN              NaN
# http://www.imdb.com/name/nm4031721     1989.0        NaN              NaN
# http://www.imdb.com/name/nm4031759        NaN        NaN              1.0
# http://www.imdb.com/name/nm4033934        NaN        NaN              1.0
# http://www.imdb.com/name/nm4034005        NaN        NaN              6.0
# http://www.imdb.com/name/nm4037686        NaN        NaN              NaN
# http://www.imdb.com/name/nm4040433        NaN        NaN              NaN
# http://www.imdb.com/name/nm4040725        NaN        NaN              NaN
# http://www.imdb.com/name/nm4041980     1986.0        NaN              NaN
# http://www.imdb.com/name/nm4042042        NaN        NaN              NaN
# http://www.imdb.com/name/nm4043111        NaN        NaN              NaN
# http://www.imdb.com/name/nm4043618     1996.0        NaN              1.0
# http://www.imdb.com/name/nm4044784        NaN        NaN              NaN
# http://www.imdb.com/name/nm4045867     1995.0        NaN              1.0
# http://www.imdb.com/name/nm4046991        NaN        NaN              NaN
# http://www.imdb.com/name/nm4047586        NaN        NaN              2.0
# http://www.imdb.com/name/nm4048274        NaN        NaN              NaN
# http://www.imdb.com/name/nm4048991        NaN        NaN              NaN
# http://www.imdb.com/name/nm4050123     1988.0        NaN              NaN
# http://www.imdb.com/name/nm4050470        NaN        NaN              NaN
# http://www.imdb.com/name/nm4050711        NaN        NaN              NaN
# http://www.imdb.com/name/nm4050777        NaN        NaN              NaN
# http://www.imdb.com/name/nm4051131        NaN        NaN              NaN
# http://www.imdb.com/name/nm4051277        NaN        NaN              NaN
# http://www.imdb.com/name/nm4052349        NaN        NaN              NaN
# http://www.imdb.com/name/nm4053792        NaN        NaN              NaN
# http://www.imdb.com/name/nm4055138        NaN        NaN              NaN
# http://www.imdb.com/name/nm4055926        NaN        NaN              NaN
# http://www.imdb.com/name/nm4056296     1977.0        NaN              NaN
#
#                                     Gender  Height in m  \
# http://www.imdb.com/name/nm3449847  Female          NaN
# http://www.imdb.com/name/nm3452356  Female          NaN
# http://www.imdb.com/name/nm3453345    Male         1.28
# http://www.imdb.com/name/nm3453460  Female         1.73
# http://www.imdb.com/name/nm3453476  Female         1.60
# http://www.imdb.com/name/nm3453549  Female          NaN
# http://www.imdb.com/name/nm3455204  Female          NaN
# http://www.imdb.com/name/nm3455998    Male         1.75
# http://www.imdb.com/name/nm3456417    Male          NaN
# http://www.imdb.com/name/nm3457928    Male          NaN
# http://www.imdb.com/name/nm3458185  Female         1.77
# http://www.imdb.com/name/nm3458761    Male         1.73
# http://www.imdb.com/name/nm3459140  Female         1.65
# http://www.imdb.com/name/nm3459539  Female          NaN
# http://www.imdb.com/name/nm3460467  Female         1.68
# http://www.imdb.com/name/nm3460483    Male          NaN
# http://www.imdb.com/name/nm3461216    Male          NaN
# http://www.imdb.com/name/nm3462008    Male          NaN
# http://www.imdb.com/name/nm3462228    None          NaN
# http://www.imdb.com/name/nm3462447    Male          NaN
# http://www.imdb.com/name/nm3462502    Male          NaN
# http://www.imdb.com/name/nm3462742  Female          NaN
# http://www.imdb.com/name/nm3464911    Male          NaN
# http://www.imdb.com/name/nm3466163    Male          NaN
# http://www.imdb.com/name/nm3466196    Male         1.88
# http://www.imdb.com/name/nm3466570    Male          NaN
# http://www.imdb.com/name/nm3467401  Female          NaN
# http://www.imdb.com/name/nm3467471    Male         1.84
# http://www.imdb.com/name/nm3467663  Female          NaN
# http://www.imdb.com/name/nm3467835  Female          NaN
# ...                                    ...          ...
# http://www.imdb.com/name/nm4030776    Male         1.57
# http://www.imdb.com/name/nm4031719    Male          NaN
# http://www.imdb.com/name/nm4031721  Female         1.78
# http://www.imdb.com/name/nm4031759    Male          NaN
# http://www.imdb.com/name/nm4033934  Female         1.83
# http://www.imdb.com/name/nm4034005    Male          NaN
# http://www.imdb.com/name/nm4037686    Male          NaN
# http://www.imdb.com/name/nm4040433    Male         1.77
# http://www.imdb.com/name/nm4040725    Male          NaN
# http://www.imdb.com/name/nm4041980    Male          NaN
# http://www.imdb.com/name/nm4042042  Female          NaN
# http://www.imdb.com/name/nm4043111    Male          NaN
# http://www.imdb.com/name/nm4043618    Male         1.73
# http://www.imdb.com/name/nm4044784    Male          NaN
# http://www.imdb.com/name/nm4045867    Male         1.80
# http://www.imdb.com/name/nm4046991    Male          NaN
# http://www.imdb.com/name/nm4047586    Male          NaN
# http://www.imdb.com/name/nm4048274    Male          NaN
# http://www.imdb.com/name/nm4048991    Male         1.83
# http://www.imdb.com/name/nm4050123  Female          NaN
# http://www.imdb.com/name/nm4050470    Male          NaN
# http://www.imdb.com/name/nm4050711    Male          NaN
# http://www.imdb.com/name/nm4050777    Male          NaN
# http://www.imdb.com/name/nm4051131    Male          NaN
# http://www.imdb.com/name/nm4051277    Male          NaN
# http://www.imdb.com/name/nm4052349  Female          NaN
# http://www.imdb.com/name/nm4053792  Female          NaN
# http://www.imdb.com/name/nm4055138    Male         1.78
# http://www.imdb.com/name/nm4055926    Male          NaN
# http://www.imdb.com/name/nm4056296    Male         1.82
#
#                                                      Name  Producing Roles  \
# http://www.imdb.com/name/nm3449847       Christy Andersen              NaN
# http://www.imdb.com/name/nm3452356        Negar Shaghaghi              NaN
# http://www.imdb.com/name/nm3453345          Maxwell Laird              NaN
# http://www.imdb.com/name/nm3453460         Sidney Allison              NaN
# http://www.imdb.com/name/nm3453476           Anne Winters              NaN
# http://www.imdb.com/name/nm3453549    Geetanjali Kulkarni              NaN
# http://www.imdb.com/name/nm3455204         Roos van Erkel              NaN
# http://www.imdb.com/name/nm3455998        Tanmay Dhanania              NaN
# http://www.imdb.com/name/nm3456417       Phillip Albrecht              1.0
# http://www.imdb.com/name/nm3457928           Sage Ranaldo              NaN
# http://www.imdb.com/name/nm3458185              Jill Evyn              2.0
# http://www.imdb.com/name/nm3458761           David Mazouz              NaN
# http://www.imdb.com/name/nm3459140        Olivia Luccardi              1.0
# http://www.imdb.com/name/nm3459539            Asur Zagada              NaN
# http://www.imdb.com/name/nm3460467          Kiko Mizuhara              NaN
# http://www.imdb.com/name/nm3460483    Maurizio Corigliano              NaN
# http://www.imdb.com/name/nm3461216        Ryûki Takahashi              NaN
# http://www.imdb.com/name/nm3462008       Rui Ricardo Diaz              NaN
# http://www.imdb.com/name/nm3462228          Blake Freeman              4.0
# http://www.imdb.com/name/nm3462447          Shivarajkumar              NaN
# http://www.imdb.com/name/nm3462502          Barak Hardley              1.0
# http://www.imdb.com/name/nm3462742      Ine Marie Wilmann              NaN
# http://www.imdb.com/name/nm3464911            John Harvey              NaN
# http://www.imdb.com/name/nm3466163     Norihiko Morishita              NaN
# http://www.imdb.com/name/nm3466196            Alan Powell              1.0
# http://www.imdb.com/name/nm3466570      Keinosuke Okamoto              NaN
# http://www.imdb.com/name/nm3467401            Minako Naka              NaN
# http://www.imdb.com/name/nm3467471            Dejan Bucin              NaN
# http://www.imdb.com/name/nm3467663           Aura Garrido              NaN
# http://www.imdb.com/name/nm3467835      Varvara Voetskova              NaN
# ...                                                   ...              ...
# http://www.imdb.com/name/nm4030776     Laurence R. Harvey              NaN
# http://www.imdb.com/name/nm4031719              Nagineedu              NaN
# http://www.imdb.com/name/nm4031721           Jessica Cook              NaN
# http://www.imdb.com/name/nm4031759          Michael Grant              1.0
# http://www.imdb.com/name/nm4033934    Synnøve Macody Lund              NaN
# http://www.imdb.com/name/nm4034005           Nick P. Ross              6.0
# http://www.imdb.com/name/nm4037686              Ian Kelly              NaN
# http://www.imdb.com/name/nm4040433           Mase Daniels              NaN
# http://www.imdb.com/name/nm4040725            Nick Renaud              1.0
# http://www.imdb.com/name/nm4041980  Nicholas J. Ainsworth              NaN
# http://www.imdb.com/name/nm4042042       Christine Donlon              NaN
# http://www.imdb.com/name/nm4043111       Vijay Sethupathi              1.0
# http://www.imdb.com/name/nm4043618            Tom Holland              NaN
# http://www.imdb.com/name/nm4044784         Damien Bonnard              NaN
# http://www.imdb.com/name/nm4045867      Garrett Backstrom              1.0
# http://www.imdb.com/name/nm4046991             Floyd Abel              NaN
# http://www.imdb.com/name/nm4047586              Raghu Ram              2.0
# http://www.imdb.com/name/nm4048274         Duncan MacNeil              NaN
# http://www.imdb.com/name/nm4048991          Michael Hough              NaN
# http://www.imdb.com/name/nm4050123             Alex Frnka              NaN
# http://www.imdb.com/name/nm4050470          Jack Cullison              NaN
# http://www.imdb.com/name/nm4050711      Bidzina Gujabidze              NaN
# http://www.imdb.com/name/nm4050777      Jason David Brown              NaN
# http://www.imdb.com/name/nm4051131           Sasi Kalinga              NaN
# http://www.imdb.com/name/nm4051277       Michael Thompson              NaN
# http://www.imdb.com/name/nm4052349        Claire Opperman              NaN
# http://www.imdb.com/name/nm4053792    Christel Pedrinelli              NaN
# http://www.imdb.com/name/nm4055138        Charlie Plummer              NaN
# http://www.imdb.com/name/nm4055926            Breno Viola              NaN
# http://www.imdb.com/name/nm4056296        Hiroki Hasegawa              NaN
#
#                                     Publicity Listings    Star Sign  \
# http://www.imdb.com/name/nm3449847                 NaN         None
# http://www.imdb.com/name/nm3452356                 NaN         None
# http://www.imdb.com/name/nm3453345                 NaN         None
# http://www.imdb.com/name/nm3453460                 NaN         None
# http://www.imdb.com/name/nm3453476                 NaN       Gemini
# http://www.imdb.com/name/nm3453549                 NaN         None
# http://www.imdb.com/name/nm3455204                 NaN         None
# http://www.imdb.com/name/nm3455998                 NaN         None
# http://www.imdb.com/name/nm3456417                 NaN         None
# http://www.imdb.com/name/nm3457928                 NaN         None
# http://www.imdb.com/name/nm3458185                 NaN    Capricorn
# http://www.imdb.com/name/nm3458761                 NaN       Pisces
# http://www.imdb.com/name/nm3459140                 NaN       Taurus
# http://www.imdb.com/name/nm3459539                 NaN         None
# http://www.imdb.com/name/nm3460467                 NaN        Libra
# http://www.imdb.com/name/nm3460483                 NaN         None
# http://www.imdb.com/name/nm3461216                 NaN         None
# http://www.imdb.com/name/nm3462008                 NaN  Sagittarius
# http://www.imdb.com/name/nm3462228                 NaN         None
# http://www.imdb.com/name/nm3462447                 NaN       Cancer
# http://www.imdb.com/name/nm3462502                 NaN          Leo
# http://www.imdb.com/name/nm3462742                 NaN         None
# http://www.imdb.com/name/nm3464911                 1.0       Cancer
# http://www.imdb.com/name/nm3466163                 NaN         None
# http://www.imdb.com/name/nm3466196                 NaN         None
# http://www.imdb.com/name/nm3466570                 NaN         None
# http://www.imdb.com/name/nm3467401                 NaN         None
# http://www.imdb.com/name/nm3467471                 NaN       Taurus
# http://www.imdb.com/name/nm3467663                 NaN       Gemini
# http://www.imdb.com/name/nm3467835                 NaN         None
# ...                                                ...          ...
# http://www.imdb.com/name/nm4030776                 NaN         None
# http://www.imdb.com/name/nm4031719                 NaN         None
# http://www.imdb.com/name/nm4031721                 NaN  Sagittarius
# http://www.imdb.com/name/nm4031759                 NaN         None
# http://www.imdb.com/name/nm4033934                 NaN         None
# http://www.imdb.com/name/nm4034005                 NaN         None
# http://www.imdb.com/name/nm4037686                 NaN         None
# http://www.imdb.com/name/nm4040433                 NaN         None
# http://www.imdb.com/name/nm4040725                 NaN         None
# http://www.imdb.com/name/nm4041980                 NaN       Gemini
# http://www.imdb.com/name/nm4042042                 NaN         None
# http://www.imdb.com/name/nm4043111                 NaN         None
# http://www.imdb.com/name/nm4043618                 3.0       Gemini
# http://www.imdb.com/name/nm4044784                 NaN         None
# http://www.imdb.com/name/nm4045867                 NaN      Scorpio
# http://www.imdb.com/name/nm4046991                 NaN         None
# http://www.imdb.com/name/nm4047586                 NaN         None
# http://www.imdb.com/name/nm4048274                 NaN         None
# http://www.imdb.com/name/nm4048991                 NaN         None
# http://www.imdb.com/name/nm4050123                 NaN      Scorpio
# http://www.imdb.com/name/nm4050470                 NaN         None
# http://www.imdb.com/name/nm4050711                 NaN         None
# http://www.imdb.com/name/nm4050777                 NaN         None
# http://www.imdb.com/name/nm4051131                 NaN         None
# http://www.imdb.com/name/nm4051277                 NaN         None
