# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %% [markdown]
# # Get List of unique Stars and URLS

# %%
star1_df = details_df[['Star1_URL','Star1']].copy()

# %%
star1_df.rename(columns = {'Star1_URL':'StarURL','Star1':'Star'}, inplace=True)

# %%
star2_df = details_df[['Star2_URL','Star2']].copy()

# %%
star2_df.rename(columns = {'Star2_URL':'StarURL','Star2':'Star'}, inplace=True)

# %%
star3_df = details_df[['Star3_URL','Star3']].copy()

# %%
star3_df.rename(columns = {'Star3_URL':'StarURL','Star3':'Star'}, inplace=True)

# %%
stars_df = pd.concat([star1_df,star2_df,star3_df])

# %%
stars_df.head()
# Out:
#                                                                  StarURL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                      Star
# http://www.imdb.com/title/tt4937564/         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/         Kamal Haasan
# http://www.imdb.com/title/tt4939066/          Liam Neeson
# http://www.imdb.com/title/tt4940370/    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/  Harshvardhan Kapoor

# %%
len(stars_df)
# Out:
# 89151

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
stars_df = stars_df.dropna(subset = ['StarURL'])

# %%
len(stars_df)
# Out:
# 89075

# %%
stars_df = stars_df.drop_duplicates(subset='StarURL',keep='first')

# %%
len(stars_df)
# Out:
# 33838

# %%
star_urls = list(stars_df['StarURL'])

# %%
star_urls = sorted(star_urls, reverse = True)

# %%
star_urls[:10]
# Out:
# ['http://www.imdb.com/name/nm9585396',
#  'http://www.imdb.com/name/nm9578606',
#  'http://www.imdb.com/name/nm9572036',
#  'http://www.imdb.com/name/nm9572029',
#  'http://www.imdb.com/name/nm9557596',
#  'http://www.imdb.com/name/nm9557587',
#  'http://www.imdb.com/name/nm9557586',
#  'http://www.imdb.com/name/nm9552585',
#  'http://www.imdb.com/name/nm9549343',
#  'http://www.imdb.com/name/nm9521432']

# %% [raw]
# star_urls.pop()

# %% [raw]
# star_urls[22525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# url = 'http://www.imdb.com/name/nm0000233/'
# # url= 'http://www.imdb.com/name/nm0002354/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# star_details = {}
# star_details[url] = {}

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a') if gender else None
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = soup.find(id='name-bio-text')
#         gender = gender.text if gender else None
#         gender = re.sub('\n', '', gender) if gender else None
#         gender = re.sub('  +',' ', gender) if gender else None
#         gender = gender.split(' ') if gender else None
#         male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
#         female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
#         if gender:
#             if male_count > female_count:
#                 gender = 'Male'
#             elif female_count > male_count:
#                 gender = 'Female'
#             else:
#                 gender = None
#
# gender

# %% [raw]
# height = soup.find('h2',text=re.compile('Personal Details'))
# height = height.parent if height else None
# height = height.find(id='details-height') if height else None
# height = height.text if height else None
# height = height.split('(')[-1] if height else None
# height = re.sub('[^0-9.]+','',height) if height else None
# # star_details[url]['Height in m'] = height
# height

# %% [raw]
# publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
# publicity_listings = publicity_listings.parent if publicity_listings else None
# publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
# publicity_listings = publicity_listings.text if publicity_listings else None
# publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
# publicity_listings = publicity_listings.strip() if publicity_listings else None
# publicity_listings = publicity_listings.split(' ') if publicity_listings else None
# publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
# publicity_listings = sum(publicity_listings) if publicity_listings else None
# star_details[url]['Publicity Listings'] = publicity_listings
# publicity_listings

# %% [raw]
# star_sign = soup.find('h4',text=re.compile('Star Sign'))
# star_sign = star_sign.parent if star_sign else None
# star_sign = star_sign.text if star_sign else None
# star_sign = star_sign.strip() if star_sign else None
# star_sign = star_sign.split('\n')[-1] if star_sign else None
# star_details[url]['Star Sign'] = star_sign
#
# star_sign

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a')
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = None
# star_details[url]['Gender'] = gender
#
# gender

# %% [raw]
# born_info = soup.find(id='name-born-info')
#
# birthdate = born_info.find('time') if born_info else None
# if birthdate.has_attr('datetime'):
#     birthdate = birthdate['datetime']
# else:
#     birthdate = None
# # star_details[url]['Birthdate'] = birthdate
#
# birthplace = born_info.findAll('a') if born_info else None
# birthplace = birthplace[-1] if birthplace else None
# birthplace = birthplace.text if birthplace else None
# # star_details[url]['Birthplace'] = birthplace
#
# birthcountry = birthplace.split(', ') if birthplace else None
# birthcountry = birthcountry[-1] if len(birthcountry)>2 else None
# # star_details[url]['Birth Country'] = birthcountry
#
# birthdate
# # birthplace
# # birthcountry

# %% [raw]
# acting_roles = soup.find(id='filmo-head-actor')
# acting_roles = acting_roles.text if acting_roles else None
# acting_roles = acting_roles.strip() if acting_roles else None
# acting_roles = acting_roles.split('(')[-1] if acting_roles else None
# acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
# acting_roles = int(acting_roles) if acting_roles else None
# # star_details[url]['Acting Roles'] = action_roles
#
# acting_roles

# %% [raw]
# tv_appearances = soup.find(id='filmo-head-self')
# tv_appearances = tv_appearances.text if tv_appearances else None
# tv_appearances = tv_appearances.strip() if tv_appearances else None
# tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
# tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
# star_details[url]['producing Roles'] = tv_appearances
# tv_appearances
#
#
# # star_details[url]['producing Roles'] = tv_appearances

# %% [raw]
# star_name = soup.find('h1')
# star_name = star_name.text if star_name else None
# star_name = star_name.strip() if star_name else None
# star_name = star_name.split('\n') if star_name else None
#
# deathyear = star_name[-1] if len(star_name)>=2 else None
# deathyear = deathyear.split('–')[-1] if deathyear else None
# deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
# deathyear = int(deathyear) if deathyear else None
#
# star_name = star_name[0] if star_name else None
#
# birthyear = birthdate[0:4] if birthdate and len(birthdate)>=10 else None
# birthyear = int(birthyear) if birthyear else None
#
# age_at_death = deathyear-birthyear if deathyear and birthyear else None
#
# birthyear

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.find('span') if award_highlight else None
# award_highlight = award_highlight.text if award_highlight else None
# award_highlight = award_highlight.strip() if award_highlight else None
# award_highlight = award_highlight.split('\n') if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# #     star_details[url]['Award Info'] = award_highlight
# award_highlight

# %% [raw]
# star_details

# %%
len(star_urls)
# Out:
# 33838

# %% [markdown]
# ## Scrape Star Details

# %%
# star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

stars_scraped = 0
star_details = {}
star_index = 7000                    
prefix = 'http://www.imdb.com'
export_number = 11
export_no = str(export_number)
load_attempts = 0

def star_scraper():
    global star_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in star_urls[star_index:9000]:
#         print(url)
        if (star_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(star_index+1, url))
        page = request_page(url)
        get_star_details(url, page)
        star_index += 1
    
    export_to_json(star_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_star_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    star_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    star_details[url]['Gender'] = gender
    
    
    star_name = soup.find('h1')
    star_name = star_name.text if star_name else None
    star_name = star_name.strip() if star_name else None
    star_name = star_name.split('\n') if star_name else None

    deathyear = star_name[-1] if len(star_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
# http://www.imdb.com/name/nm1663701          34.0           NaN
# http://www.imdb.com/name/nm1664541          79.0           NaN
# http://www.imdb.com/name/nm1664542           8.0           NaN
# http://www.imdb.com/name/nm1665054          53.0           NaN
# http://www.imdb.com/name/nm1665349          15.0           NaN
# http://www.imdb.com/name/nm1665526          60.0           NaN
# http://www.imdb.com/name/nm1665537          47.0           NaN
# http://www.imdb.com/name/nm1665588           NaN           NaN
# http://www.imdb.com/name/nm1665670           NaN           NaN
# http://www.imdb.com/name/nm1665796           NaN           NaN
# http://www.imdb.com/name/nm1665832           NaN           NaN
# http://www.imdb.com/name/nm1665871           NaN           NaN
# http://www.imdb.com/name/nm1666212          28.0           NaN
# http://www.imdb.com/name/nm1666600           4.0           NaN
# http://www.imdb.com/name/nm1666855          59.0           NaN
# http://www.imdb.com/name/nm1666939          11.0           NaN
# http://www.imdb.com/name/nm1667364           NaN           NaN
# http://www.imdb.com/name/nm1667720           NaN           NaN
# http://www.imdb.com/name/nm1668208          28.0           NaN
# http://www.imdb.com/name/nm1668265          20.0           NaN
# http://www.imdb.com/name/nm1668284          21.0           NaN
# ...                                          ...           ...
# http://www.imdb.com/name/nm1866484           NaN           NaN
# http://www.imdb.com/name/nm1866613          19.0           NaN
# http://www.imdb.com/name/nm1867472           NaN           NaN
# http://www.imdb.com/name/nm1867502          14.0           NaN
# http://www.imdb.com/name/nm1867717          23.0           NaN
# http://www.imdb.com/name/nm1868017           5.0           NaN
# http://www.imdb.com/name/nm1868114           3.0           NaN
# http://www.imdb.com/name/nm1868250           6.0           NaN
# http://www.imdb.com/name/nm1868320           NaN           NaN
# http://www.imdb.com/name/nm1868398           2.0           NaN
# http://www.imdb.com/name/nm1868581          13.0           NaN
# http://www.imdb.com/name/nm1868781           NaN           NaN
# http://www.imdb.com/name/nm1869029          44.0           NaN
# http://www.imdb.com/name/nm1869082          45.0           NaN
# http://www.imdb.com/name/nm1869101           NaN           NaN
# http://www.imdb.com/name/nm1869418           NaN           NaN
# http://www.imdb.com/name/nm1869505           NaN           NaN
# http://www.imdb.com/name/nm1869640           NaN           NaN
# http://www.imdb.com/name/nm1869684           1.0           NaN
# http://www.imdb.com/name/nm1869756           NaN           NaN
# http://www.imdb.com/name/nm1869872           NaN           NaN
# http://www.imdb.com/name/nm1870112           1.0           NaN
# http://www.imdb.com/name/nm1870434           NaN           NaN
# http://www.imdb.com/name/nm1870447           NaN           NaN
# http://www.imdb.com/name/nm1870939           NaN           NaN
# http://www.imdb.com/name/nm1871013           7.0           NaN
# http://www.imdb.com/name/nm1871320           NaN           NaN
# http://www.imdb.com/name/nm1871379          16.0           NaN
# http://www.imdb.com/name/nm1871889           1.0           NaN
# http://www.imdb.com/name/nm1871951           NaN           NaN
#
#                                                    Award Info  \
# http://www.imdb.com/name/nm1659579                       None
# http://www.imdb.com/name/nm1661274                       None
# http://www.imdb.com/name/nm1662011                     1 win.
# http://www.imdb.com/name/nm1662074                       None
# http://www.imdb.com/name/nm1662277     1 win & 2 nominations.
# http://www.imdb.com/name/nm1662572                       None
# http://www.imdb.com/name/nm1662644              1 nomination.
# http://www.imdb.com/name/nm1663205    1 win & 12 nominations.
# http://www.imdb.com/name/nm1663573     1 win & 7 nominations.
# http://www.imdb.com/name/nm1663701              1 nomination.
# http://www.imdb.com/name/nm1664541                       None
# http://www.imdb.com/name/nm1664542              1 nomination.
# http://www.imdb.com/name/nm1665054                       None
# http://www.imdb.com/name/nm1665349     1 win & 2 nominations.
# http://www.imdb.com/name/nm1665526                     1 win.
# http://www.imdb.com/name/nm1665537    6 wins & 7 nominations.
# http://www.imdb.com/name/nm1665588                       None
# http://www.imdb.com/name/nm1665670                       None
# http://www.imdb.com/name/nm1665796                       None
# http://www.imdb.com/name/nm1665832                       None
# http://www.imdb.com/name/nm1665871    6 wins & 2 nominations.
# http://www.imdb.com/name/nm1666212   2 wins & 16 nominations.
# http://www.imdb.com/name/nm1666600                       None
# http://www.imdb.com/name/nm1666855  20 wins & 21 nominations.
# http://www.imdb.com/name/nm1666939                       None
# http://www.imdb.com/name/nm1667364    5 wins & 6 nominations.
# http://www.imdb.com/name/nm1667720                       None
# http://www.imdb.com/name/nm1668208             4 nominations.
# http://www.imdb.com/name/nm1668265             2 nominations.
# http://www.imdb.com/name/nm1668284                       None
# ...                                                       ...
# http://www.imdb.com/name/nm1866484                       None
# http://www.imdb.com/name/nm1866613                       None
# http://www.imdb.com/name/nm1867472                       None
# http://www.imdb.com/name/nm1867502                       None
# http://www.imdb.com/name/nm1867717             5 nominations.
# http://www.imdb.com/name/nm1868017                       None
# http://www.imdb.com/name/nm1868114                       None
# http://www.imdb.com/name/nm1868250                       None
# http://www.imdb.com/name/nm1868320   5 wins & 13 nominations.
# http://www.imdb.com/name/nm1868398                       None
# http://www.imdb.com/name/nm1868581                       None
# http://www.imdb.com/name/nm1868781                       None
# http://www.imdb.com/name/nm1869029     1 win & 4 nominations.
# http://www.imdb.com/name/nm1869082                     1 win.
# http://www.imdb.com/name/nm1869101                       None
# http://www.imdb.com/name/nm1869418                       None
# http://www.imdb.com/name/nm1869505     2 wins & 1 nomination.
# http://www.imdb.com/name/nm1869640                       None
# http://www.imdb.com/name/nm1869684                       None
# http://www.imdb.com/name/nm1869756    4 wins & 5 nominations.
# http://www.imdb.com/name/nm1869872                       None
# http://www.imdb.com/name/nm1870112                       None
# http://www.imdb.com/name/nm1870434             3 nominations.
# http://www.imdb.com/name/nm1870447                       None
# http://www.imdb.com/name/nm1870939      1 win & 1 nomination.
# http://www.imdb.com/name/nm1871013                       None
# http://www.imdb.com/name/nm1871320                       None
# http://www.imdb.com/name/nm1871379                    2 wins.
# http://www.imdb.com/name/nm1871889                       None
# http://www.imdb.com/name/nm1871951    2 wins & 7 nominations.
#
#                                                  Birth Country   Birthdate  \
# http://www.imdb.com/name/nm1659579                         USA    1992-3-8
# http://www.imdb.com/name/nm1661274                        None        None
# http://www.imdb.com/name/nm1662011                     Morocco    1983-0-0
# http://www.imdb.com/name/nm1662074                        None        None
# http://www.imdb.com/name/nm1869418                                              None
# http://www.imdb.com/name/nm1869505                                              None
# http://www.imdb.com/name/nm1869640                                              None
# http://www.imdb.com/name/nm1869684                                              None
# http://www.imdb.com/name/nm1869756                                       South Korea
# http://www.imdb.com/name/nm1869872                        Velzeke, Flanders, Belgium
# http://www.imdb.com/name/nm1870112                                              None
# http://www.imdb.com/name/nm1870434                                       England, UK
# http://www.imdb.com/name/nm1870447                                              None
# http://www.imdb.com/name/nm1870939                               London, England, UK
# http://www.imdb.com/name/nm1871013                                              None
# http://www.imdb.com/name/nm1871320                             Denver, Colorado, USA
# http://www.imdb.com/name/nm1871379                                              None
# http://www.imdb.com/name/nm1871889                                              None
# http://www.imdb.com/name/nm1871951       Issy-les-Moulineaux, Hauts-de-Seine, France
#
#                                     Birthyear  Deathyear  Directing Roles  \
# http://www.imdb.com/name/nm1659579     1992.0        NaN              NaN
# http://www.imdb.com/name/nm1661274        NaN        NaN              NaN
# http://www.imdb.com/name/nm1662011     1983.0        NaN              NaN
# http://www.imdb.com/name/nm1662074        NaN        NaN              NaN
# http://www.imdb.com/name/nm1662277     1976.0        NaN              1.0
# http://www.imdb.com/name/nm1662572     1976.0        NaN              NaN
# http://www.imdb.com/name/nm1662644     1981.0        NaN              NaN
# http://www.imdb.com/name/nm1663205     1973.0        NaN              1.0
# http://www.imdb.com/name/nm1663573     1976.0        NaN              NaN
# http://www.imdb.com/name/nm1663701     1985.0        NaN              NaN
# http://www.imdb.com/name/nm1664541        NaN        NaN              NaN
# http://www.imdb.com/name/nm1664542     1966.0        NaN              NaN
# http://www.imdb.com/name/nm1665054        NaN        NaN              NaN
# http://www.imdb.com/name/nm1665349        NaN        NaN              NaN
# http://www.imdb.com/name/nm1665526     1942.0        NaN              NaN
# http://www.imdb.com/name/nm1665537     1977.0        NaN              NaN
# http://www.imdb.com/name/nm1665588     1971.0        NaN              NaN
# http://www.imdb.com/name/nm1665670     1976.0        NaN              NaN
# http://www.imdb.com/name/nm1665796     1985.0        NaN              NaN
# http://www.imdb.com/name/nm1665832     1986.0        NaN              NaN
# http://www.imdb.com/name/nm1665871     1984.0        NaN              NaN
# http://www.imdb.com/name/nm1666212     1982.0        NaN              NaN
# http://www.imdb.com/name/nm1666600        NaN        NaN              NaN
# http://www.imdb.com/name/nm1666855     1979.0        NaN              2.0
# http://www.imdb.com/name/nm1666939        NaN        NaN              2.0
# http://www.imdb.com/name/nm1667364     1989.0        NaN              NaN
# http://www.imdb.com/name/nm1667720     1968.0        NaN              NaN
# http://www.imdb.com/name/nm1668208     1990.0        NaN              2.0
# http://www.imdb.com/name/nm1668265     1980.0        NaN              NaN
# http://www.imdb.com/name/nm1668284     1981.0        NaN              NaN
# ...                                       ...        ...              ...
# http://www.imdb.com/name/nm1866484     1952.0        NaN              NaN
# http://www.imdb.com/name/nm1866613     1980.0        NaN              NaN
# http://www.imdb.com/name/nm1867472     1970.0        NaN              NaN
# http://www.imdb.com/name/nm1867502     1993.0        NaN              NaN
# http://www.imdb.com/name/nm1867717     1976.0        NaN              NaN
# http://www.imdb.com/name/nm1868017     1954.0        NaN              NaN
# http://www.imdb.com/name/nm1868114        NaN        NaN              NaN
# http://www.imdb.com/name/nm1868250        NaN        NaN              NaN
# http://www.imdb.com/name/nm1868320     1983.0        NaN              NaN
# http://www.imdb.com/name/nm1868398        NaN        NaN              NaN
# http://www.imdb.com/name/nm1868581        NaN        NaN              NaN
# http://www.imdb.com/name/nm1868781        NaN        NaN              NaN
# http://www.imdb.com/name/nm1869029     1995.0        NaN              NaN
# http://www.imdb.com/name/nm1869082     1985.0        NaN              1.0
# http://www.imdb.com/name/nm1869101     1988.0        NaN              NaN
# http://www.imdb.com/name/nm1869418        NaN        NaN              NaN
# http://www.imdb.com/name/nm1869505        NaN        NaN              NaN
# http://www.imdb.com/name/nm1869640        NaN        NaN              NaN
# http://www.imdb.com/name/nm1869684        NaN        NaN              NaN
# http://www.imdb.com/name/nm1869756     1983.0        NaN              NaN
# http://www.imdb.com/name/nm1869872     1979.0        NaN              NaN
# http://www.imdb.com/name/nm1870112        NaN        NaN              NaN
# http://www.imdb.com/name/nm1870434     1992.0        NaN              NaN
# http://www.imdb.com/name/nm1870447        NaN        NaN              NaN
# http://www.imdb.com/name/nm1870939     1987.0        NaN              NaN
# http://www.imdb.com/name/nm1871013        NaN        NaN              NaN
# http://www.imdb.com/name/nm1871320     1976.0        NaN              NaN
# http://www.imdb.com/name/nm1871379        NaN        NaN              NaN
# http://www.imdb.com/name/nm1871889        NaN        NaN              NaN
# http://www.imdb.com/name/nm1871951     1984.0        NaN              NaN
#
#                                     Gender  Height in m  \
# http://www.imdb.com/name/nm1659579  Female         1.60
# http://www.imdb.com/name/nm1661274  Female          NaN
# http://www.imdb.com/name/nm1662011  Female          NaN
# http://www.imdb.com/name/nm1662074    Male          NaN
# http://www.imdb.com/name/nm1662277    Male          NaN
# http://www.imdb.com/name/nm1662572  Female         1.70
# http://www.imdb.com/name/nm1662644  Female         1.66
# http://www.imdb.com/name/nm1663205    Male         1.83
# http://www.imdb.com/name/nm1663573  Female         1.65
# http://www.imdb.com/name/nm1663701    Male         1.84
# http://www.imdb.com/name/nm1664541    Male          NaN
# http://www.imdb.com/name/nm1664542    Male         1.88
# http://www.imdb.com/name/nm1665054    Male          NaN
# http://www.imdb.com/name/nm1665349    Male          NaN
# http://www.imdb.com/name/nm1665526    Male          NaN
# http://www.imdb.com/name/nm1665537    Male         1.90
# http://www.imdb.com/name/nm1665588  Female         1.75
# http://www.imdb.com/name/nm1665670  Female          NaN
# http://www.imdb.com/name/nm1665796  Female         1.69
# http://www.imdb.com/name/nm1665832  Female         1.59
# http://www.imdb.com/name/nm1665871  Female         1.68
# http://www.imdb.com/name/nm1666212    Male         1.73
# http://www.imdb.com/name/nm1666600    Male          NaN
# http://www.imdb.com/name/nm1666855    Male         1.80
# http://www.imdb.com/name/nm1666939    Male          NaN
# http://www.imdb.com/name/nm1667364  Female         1.65
# http://www.imdb.com/name/nm1667720  Female          NaN
# http://www.imdb.com/name/nm1668208    Male         1.70
# http://www.imdb.com/name/nm1668265    Male         1.78
# http://www.imdb.com/name/nm1668284    Male         1.84
# ...                                    ...          ...
# http://www.imdb.com/name/nm1866484  Female          NaN
# http://www.imdb.com/name/nm1866613    Male         1.66
# http://www.imdb.com/name/nm1867472  Female          NaN
# http://www.imdb.com/name/nm1867502    Male          NaN
# http://www.imdb.com/name/nm1867717    Male         1.85
# http://www.imdb.com/name/nm1868017    Male         1.93
# http://www.imdb.com/name/nm1868114    Male          NaN
# http://www.imdb.com/name/nm1868250    Male          NaN
# http://www.imdb.com/name/nm1868320  Female         1.65
# http://www.imdb.com/name/nm1868398    Male          NaN
# http://www.imdb.com/name/nm1868581    Male          NaN
# http://www.imdb.com/name/nm1868781  Female          NaN
# http://www.imdb.com/name/nm1869029    Male         1.88
# http://www.imdb.com/name/nm1869082    Male          NaN
# http://www.imdb.com/name/nm1869101  Female         1.68
# http://www.imdb.com/name/nm1869418  Female         1.70
# http://www.imdb.com/name/nm1869505  Female         1.60
# http://www.imdb.com/name/nm1869640  Female          NaN
# http://www.imdb.com/name/nm1869684    Male          NaN
# http://www.imdb.com/name/nm1869756  Female         1.65
# http://www.imdb.com/name/nm1869872  Female         1.75
# http://www.imdb.com/name/nm1870112    Male          NaN
# http://www.imdb.com/name/nm1870434  Female         1.71
# http://www.imdb.com/name/nm1870447  Female         1.73
# http://www.imdb.com/name/nm1870939  Female         1.63
# http://www.imdb.com/name/nm1871013    Male          NaN
# http://www.imdb.com/name/nm1871320  Female         1.65
# http://www.imdb.com/name/nm1871379    Male          NaN
# http://www.imdb.com/name/nm1871889    Male          NaN
# http://www.imdb.com/name/nm1871951  Female         1.60
#
#                                                        Name  Producing Roles  \
# http://www.imdb.com/name/nm1659579  Charlotte Ray Rosenberg              NaN
# http://www.imdb.com/name/nm1661274              Holly Lewis              NaN
# http://www.imdb.com/name/nm1662011           Morjana Alaoui              NaN
# http://www.imdb.com/name/nm1662074          Bahram Ibrahimi              NaN
# http://www.imdb.com/name/nm1662277          Shreyas Talpade              2.0
# http://www.imdb.com/name/nm1662572           Kinsey Packard              1.0
# http://www.imdb.com/name/nm1662644              Antje Traue              NaN
# http://www.imdb.com/name/nm1663205           Sharlto Copley              3.0
# http://www.imdb.com/name/nm1663573         Kierston Wareing              NaN
# http://www.imdb.com/name/nm1663701       Konstantin Kryukov              NaN
# http://www.imdb.com/name/nm1664541            Zakir Hussain              NaN
# http://www.imdb.com/name/nm1664542            Michael Irvin              NaN
# http://www.imdb.com/name/nm1665054           Dominic Bogart              NaN
# http://www.imdb.com/name/nm1665349       Nopachai Chaiyanam              NaN
# http://www.imdb.com/name/nm1665526          Mahmoud Yassine              NaN
# http://www.imdb.com/name/nm1665537          Ronald Zehrfeld              NaN
# http://www.imdb.com/name/nm1665588             Gülse Birsel              NaN
# http://www.imdb.com/name/nm1665670  Ekaterina Gorokhovskaya              NaN
# http://www.imdb.com/name/nm1665796         Yolanda Pecoraro              NaN
# http://www.imdb.com/name/nm1665832             Sayaka Kanda              NaN
# http://www.imdb.com/name/nm1665871            Anna Tsuchiya              NaN
# http://www.imdb.com/name/nm1666212                    Ne-Yo              NaN
# http://www.imdb.com/name/nm1666600      Zoltán Miklós Hajdu              1.0
# http://www.imdb.com/name/nm1666855             Raúl Arévalo              NaN
# http://www.imdb.com/name/nm1666939              Andy Hopper              2.0
# http://www.imdb.com/name/nm1667364            Ashley Benson              NaN
# http://www.imdb.com/name/nm1667720              Ramos López              NaN
# http://www.imdb.com/name/nm1668208        Charlie McDermott              1.0
# http://www.imdb.com/name/nm1668265                Matt Long              1.0
# http://www.imdb.com/name/nm1668284           Brian J. Smith              NaN
# ...                                                     ...              ...
# http://www.imdb.com/name/nm1866484                Ryôko Ema              NaN
# http://www.imdb.com/name/nm1866613             Satoshi Ohno              NaN
# http://www.imdb.com/name/nm1867472            Devrim Atmaca              NaN
# http://www.imdb.com/name/nm1867502              Yuri Chinen              NaN
# http://www.imdb.com/name/nm1867717               Abhay Deol              3.0
# http://www.imdb.com/name/nm1868017                 Tom Doty              1.0
# http://www.imdb.com/name/nm1868114           Norimizu Ameya              NaN
# http://www.imdb.com/name/nm1868250         Michaël Grégorio              NaN
# http://www.imdb.com/name/nm1868320            Ashleigh Ball              2.0
# http://www.imdb.com/name/nm1868398      Mahasamut Boonyaruk              NaN
# http://www.imdb.com/name/nm1868581      Oliver Kieran-Jones              NaN
# http://www.imdb.com/name/nm1868781               Rhoda Pell              NaN
# http://www.imdb.com/name/nm1869029         Sterling Beaumon              NaN
# http://www.imdb.com/name/nm1869082            Emrhys Cooper              4.0
# http://www.imdb.com/name/nm1869101             Ana de Armas              NaN
# http://www.imdb.com/name/nm1869418             Desiree Hall              1.0
# http://www.imdb.com/name/nm1869505      Piyathida Woramusik              NaN
# http://www.imdb.com/name/nm1869640           Kristina Pesic              NaN
# http://www.imdb.com/name/nm1869684         Þórarinn Eyfjörð              NaN
# http://www.imdb.com/name/nm1869756               Yu-mi Jung              NaN
# http://www.imdb.com/name/nm1869872               Lyne Renee              NaN
# http://www.imdb.com/name/nm1870112          Stephen Galaida              NaN
# http://www.imdb.com/name/nm1870434        Eleanor Tomlinson              NaN
# http://www.imdb.com/name/nm1870447               Zoe Gameau              NaN
# http://www.imdb.com/name/nm1870939           Nicola Posener              NaN
# http://www.imdb.com/name/nm1871013           Ugur Aslanoglu              NaN
# http://www.imdb.com/name/nm1871320            Jessica Duffy              NaN
# http://www.imdb.com/name/nm1871379              Yahya Gaier              NaN
# http://www.imdb.com/name/nm1871889           Józef Paleczka              NaN
# http://www.imdb.com/name/nm1871951             Leïla Bekhti              NaN
#
#                                     Publicity Listings    Star Sign  \
# http://www.imdb.com/name/nm1659579                 1.0       Pisces
# http://www.imdb.com/name/nm1661274                 1.0         None
# http://www.imdb.com/name/nm1662011                 NaN         None
# http://www.imdb.com/name/nm1662074                 NaN         None
# http://www.imdb.com/name/nm1662277                 NaN     Aquarius
# http://www.imdb.com/name/nm1662572                 4.0          Leo
# http://www.imdb.com/name/nm1662644                 2.0    Capricorn
# http://www.imdb.com/name/nm1663205                 1.0  Sagittarius
# http://www.imdb.com/name/nm1663573                 1.0    Capricorn
# http://www.imdb.com/name/nm1663701                 NaN     Aquarius
# http://www.imdb.com/name/nm1664541                 NaN         None
# http://www.imdb.com/name/nm1664542                 3.0       Pisces
# http://www.imdb.com/name/nm1665054                 2.0         None
# http://www.imdb.com/name/nm1665349                 NaN         None
# http://www.imdb.com/name/nm1665526                 NaN       Pisces
# http://www.imdb.com/name/nm1665537                 NaN    Capricorn
# http://www.imdb.com/name/nm1665588                 1.0       Pisces
# http://www.imdb.com/name/nm1665670                 NaN        Libra
# http://www.imdb.com/name/nm1665796                 3.0       Pisces
# http://www.imdb.com/name/nm1665832                 NaN        Libra
# http://www.imdb.com/name/nm1665871                 NaN       Pisces
# http://www.imdb.com/name/nm1666212                 6.0        Libra
# http://www.imdb.com/name/nm1666600                 NaN         None
# http://www.imdb.com/name/nm1666855                 NaN  Sagittarius
# http://www.imdb.com/name/nm1666939                 NaN         None
# http://www.imdb.com/name/nm1667364                 4.0  Sagittarius
# http://www.imdb.com/name/nm1667720                 NaN         None
# http://www.imdb.com/name/nm1668208                 1.0        Aries
# http://www.imdb.com/name/nm1668265                 2.0       Taurus
# http://www.imdb.com/name/nm1668284                 NaN        Libra
# ...                                                ...          ...
# http://www.imdb.com/name/nm1866484                 NaN       Pisces
# http://www.imdb.com/name/nm1866613                 NaN  Sagittarius
# http://www.imdb.com/name/nm1867472                 NaN      Scorpio
# http://www.imdb.com/name/nm1867502                 NaN  Sagittarius
# http://www.imdb.com/name/nm1867717                 NaN       Pisces
# http://www.imdb.com/name/nm1868017                 1.0        Libra
# http://www.imdb.com/name/nm1868114                 NaN         None
# http://www.imdb.com/name/nm1868250                 NaN         None
# http://www.imdb.com/name/nm1868320                 NaN        Aries
# http://www.imdb.com/name/nm1868398                 NaN         None
# http://www.imdb.com/name/nm1868581                 NaN         None
# http://www.imdb.com/name/nm1868781                 NaN         None
# http://www.imdb.com/name/nm1869029                 2.0       Gemini
# http://www.imdb.com/name/nm1869082                 NaN     Aquarius
# http://www.imdb.com/name/nm1869101                20.0       Taurus
# http://www.imdb.com/name/nm1869418                 NaN         None
# http://www.imdb.com/name/nm1869505                 NaN         None
# http://www.imdb.com/name/nm1869640                 NaN         None
# http://www.imdb.com/name/nm1869684                 NaN         None
# http://www.imdb.com/name/nm1869756                 NaN    Capricorn
# http://www.imdb.com/name/nm1869872                 NaN       Taurus
# http://www.imdb.com/name/nm1870112                 NaN         None
# http://www.imdb.com/name/nm1870434                 3.0       Taurus
# http://www.imdb.com/name/nm1870447                 NaN         None
# http://www.imdb.com/name/nm1870939                 1.0        Libra
# http://www.imdb.com/name/nm1871013                 NaN         None
# http://www.imdb.com/name/nm1871320                 NaN        Virgo
