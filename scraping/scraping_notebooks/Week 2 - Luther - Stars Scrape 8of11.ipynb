# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %% [markdown]
# # Get List of unique Stars and URLS

# %%
star1_df = details_df[['Star1_URL','Star1']].copy()

# %%
star1_df.rename(columns = {'Star1_URL':'StarURL','Star1':'Star'}, inplace=True)

# %%
star2_df = details_df[['Star2_URL','Star2']].copy()

# %%
star2_df.rename(columns = {'Star2_URL':'StarURL','Star2':'Star'}, inplace=True)

# %%
star3_df = details_df[['Star3_URL','Star3']].copy()

# %%
star3_df.rename(columns = {'Star3_URL':'StarURL','Star3':'Star'}, inplace=True)

# %%
stars_df = pd.concat([star1_df,star2_df,star3_df])

# %%
stars_df.head()
# Out:
#                                                                  StarURL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                      Star
# http://www.imdb.com/title/tt4937564/         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/         Kamal Haasan
# http://www.imdb.com/title/tt4939066/          Liam Neeson
# http://www.imdb.com/title/tt4940370/    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/  Harshvardhan Kapoor

# %%
len(stars_df)
# Out:
# 89151

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
stars_df = stars_df.dropna(subset = ['StarURL'])

# %%
len(stars_df)
# Out:
# 89075

# %%
stars_df = stars_df.drop_duplicates(subset='StarURL',keep='first')

# %%
len(stars_df)
# Out:
# 33838

# %%
star_urls = list(stars_df['StarURL'])

# %%
star_urls = sorted(star_urls, reverse = True)

# %%
star_urls[:10]
# Out:
# ['http://www.imdb.com/name/nm9585396',
#  'http://www.imdb.com/name/nm9578606',
#  'http://www.imdb.com/name/nm9572036',
#  'http://www.imdb.com/name/nm9572029',
#  'http://www.imdb.com/name/nm9557596',
#  'http://www.imdb.com/name/nm9557587',
#  'http://www.imdb.com/name/nm9557586',
#  'http://www.imdb.com/name/nm9552585',
#  'http://www.imdb.com/name/nm9549343',
#  'http://www.imdb.com/name/nm9521432']

# %% [raw]
# star_urls.pop()

# %% [raw]
# star_urls[22525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# url = 'http://www.imdb.com/name/nm0000233/'
# # url= 'http://www.imdb.com/name/nm0002354/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# star_details = {}
# star_details[url] = {}

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a') if gender else None
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = soup.find(id='name-bio-text')
#         gender = gender.text if gender else None
#         gender = re.sub('\n', '', gender) if gender else None
#         gender = re.sub('  +',' ', gender) if gender else None
#         gender = gender.split(' ') if gender else None
#         male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
#         female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
#         if gender:
#             if male_count > female_count:
#                 gender = 'Male'
#             elif female_count > male_count:
#                 gender = 'Female'
#             else:
#                 gender = None
#
# gender

# %% [raw]
# height = soup.find('h2',text=re.compile('Personal Details'))
# height = height.parent if height else None
# height = height.find(id='details-height') if height else None
# height = height.text if height else None
# height = height.split('(')[-1] if height else None
# height = re.sub('[^0-9.]+','',height) if height else None
# # star_details[url]['Height in m'] = height
# height

# %% [raw]
# publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
# publicity_listings = publicity_listings.parent if publicity_listings else None
# publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
# publicity_listings = publicity_listings.text if publicity_listings else None
# publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
# publicity_listings = publicity_listings.strip() if publicity_listings else None
# publicity_listings = publicity_listings.split(' ') if publicity_listings else None
# publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
# publicity_listings = sum(publicity_listings) if publicity_listings else None
# star_details[url]['Publicity Listings'] = publicity_listings
# publicity_listings

# %% [raw]
# star_sign = soup.find('h4',text=re.compile('Star Sign'))
# star_sign = star_sign.parent if star_sign else None
# star_sign = star_sign.text if star_sign else None
# star_sign = star_sign.strip() if star_sign else None
# star_sign = star_sign.split('\n')[-1] if star_sign else None
# star_details[url]['Star Sign'] = star_sign
#
# star_sign

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a')
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = None
# star_details[url]['Gender'] = gender
#
# gender

# %% [raw]
# born_info = soup.find(id='name-born-info')
#
# birthdate = born_info.find('time') if born_info else None
# if birthdate.has_attr('datetime'):
#     birthdate = birthdate['datetime']
# else:
#     birthdate = None
# # star_details[url]['Birthdate'] = birthdate
#
# birthplace = born_info.findAll('a') if born_info else None
# birthplace = birthplace[-1] if birthplace else None
# birthplace = birthplace.text if birthplace else None
# # star_details[url]['Birthplace'] = birthplace
#
# birthcountry = birthplace.split(', ') if birthplace else None
# birthcountry = birthcountry[-1] if len(birthcountry)>2 else None
# # star_details[url]['Birth Country'] = birthcountry
#
# birthdate
# # birthplace
# # birthcountry

# %% [raw]
# acting_roles = soup.find(id='filmo-head-actor')
# acting_roles = acting_roles.text if acting_roles else None
# acting_roles = acting_roles.strip() if acting_roles else None
# acting_roles = acting_roles.split('(')[-1] if acting_roles else None
# acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
# acting_roles = int(acting_roles) if acting_roles else None
# # star_details[url]['Acting Roles'] = action_roles
#
# acting_roles

# %% [raw]
# tv_appearances = soup.find(id='filmo-head-self')
# tv_appearances = tv_appearances.text if tv_appearances else None
# tv_appearances = tv_appearances.strip() if tv_appearances else None
# tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
# tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
# star_details[url]['producing Roles'] = tv_appearances
# tv_appearances
#
#
# # star_details[url]['producing Roles'] = tv_appearances

# %% [raw]
# star_name = soup.find('h1')
# star_name = star_name.text if star_name else None
# star_name = star_name.strip() if star_name else None
# star_name = star_name.split('\n') if star_name else None
#
# deathyear = star_name[-1] if len(star_name)>=2 else None
# deathyear = deathyear.split('–')[-1] if deathyear else None
# deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
# deathyear = int(deathyear) if deathyear else None
#
# star_name = star_name[0] if star_name else None
#
# birthyear = birthdate[0:4] if birthdate and len(birthdate)>=10 else None
# birthyear = int(birthyear) if birthyear else None
#
# age_at_death = deathyear-birthyear if deathyear and birthyear else None
#
# birthyear

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.find('span') if award_highlight else None
# award_highlight = award_highlight.text if award_highlight else None
# award_highlight = award_highlight.strip() if award_highlight else None
# award_highlight = award_highlight.split('\n') if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# #     star_details[url]['Award Info'] = award_highlight
# award_highlight

# %% [raw]
# star_details

# %%
len(star_urls)
# Out:
# 33838

# %% [markdown]
# ## Scrape Star Details

# %%
# star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

stars_scraped = 0
star_details = {}
star_index = 21000                    
prefix = 'http://www.imdb.com'
export_number = 35
export_no = str(export_number)
load_attempts = 0

def star_scraper():
    global star_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in star_urls[star_index:24000]:
#         print(url)
        if (star_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(star_index+1, url))
        page = request_page(url)
        get_star_details(url, page)
        star_index += 1
    
    export_to_json(star_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_star_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    star_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    star_details[url]['Gender'] = gender
    
    
    star_name = soup.find('h1')
    star_name = star_name.text if star_name else None
    star_name = star_name.strip() if star_name else None
    star_name = star_name.split('\n') if star_name else None

    deathyear = star_name[-1] if len(star_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
# http://www.imdb.com/name/nm0422546           3.0           NaN
# http://www.imdb.com/name/nm0422550          28.0           NaN
# http://www.imdb.com/name/nm0422552           4.0           NaN
# http://www.imdb.com/name/nm0422558           NaN           NaN
# http://www.imdb.com/name/nm0422566           NaN           NaN
# http://www.imdb.com/name/nm0422586           NaN           NaN
# http://www.imdb.com/name/nm0422600          10.0          43.0
# ...                                          ...           ...
# http://www.imdb.com/name/nm0463514         158.0          54.0
# http://www.imdb.com/name/nm0463539           NaN           NaN
# http://www.imdb.com/name/nm0463568          44.0           NaN
# http://www.imdb.com/name/nm0463590         102.0          89.0
# http://www.imdb.com/name/nm0463592           NaN           NaN
# http://www.imdb.com/name/nm0463649          83.0           NaN
# http://www.imdb.com/name/nm0463662          20.0           NaN
# http://www.imdb.com/name/nm0463684           NaN          62.0
# http://www.imdb.com/name/nm0463786           3.0           NaN
# http://www.imdb.com/name/nm0463814           NaN           NaN
# http://www.imdb.com/name/nm0463827           NaN           NaN
# http://www.imdb.com/name/nm0463942          62.0          61.0
# http://www.imdb.com/name/nm0464075           NaN           NaN
# http://www.imdb.com/name/nm0464143           NaN           NaN
# http://www.imdb.com/name/nm0464167           NaN          97.0
# http://www.imdb.com/name/nm0464170         204.0          81.0
# http://www.imdb.com/name/nm0464305          54.0           NaN
# http://www.imdb.com/name/nm0464392          71.0          93.0
# http://www.imdb.com/name/nm0464495           NaN           NaN
# http://www.imdb.com/name/nm0464561          38.0          66.0
# http://www.imdb.com/name/nm0464591          69.0           NaN
# http://www.imdb.com/name/nm0464670           NaN           NaN
# http://www.imdb.com/name/nm0464720           NaN          90.0
# http://www.imdb.com/name/nm0464738           NaN           NaN
# http://www.imdb.com/name/nm0464855           1.0           NaN
# http://www.imdb.com/name/nm0464945          99.0           NaN
# http://www.imdb.com/name/nm0464946          21.0          86.0
# http://www.imdb.com/name/nm0465160         250.0           NaN
# http://www.imdb.com/name/nm0465187          35.0           NaN
# http://www.imdb.com/name/nm0465235          60.0          61.0
#
#                                                                            Award Info  \
# http://www.imdb.com/name/nm0421105                                               None
# http://www.imdb.com/name/nm0421128                                               None
# http://www.imdb.com/name/nm0421218                                               None
# http://www.imdb.com/name/nm0421291                                               None
# http://www.imdb.com/name/nm0421332  Nominated for 1 Primetime Emmy. Another 4 wins...
# http://www.imdb.com/name/nm0421496                                               None
# http://www.imdb.com/name/nm0421596                                               None
# http://www.imdb.com/name/nm0421670                                               None
# http://www.imdb.com/name/nm0421709                                               None
# http://www.imdb.com/name/nm0421716                             8 wins & 1 nomination.
# http://www.imdb.com/name/nm0421722                                               None
# http://www.imdb.com/name/nm0421772                                             1 win.
# http://www.imdb.com/name/nm0421799                            9 wins & 8 nominations.
# http://www.imdb.com/name/nm0421822                           3 wins & 10 nominations.
# http://www.imdb.com/name/nm0421922                                             1 win.
# http://www.imdb.com/name/nm0422003                                               None
# http://www.imdb.com/name/nm0422151                                      1 nomination.
# http://www.imdb.com/name/nm0422185                                               None
# http://www.imdb.com/name/nm0422234                                               None
# http://www.imdb.com/name/nm0422392                                            2 wins.
# http://www.imdb.com/name/nm0422397                                               None
# http://www.imdb.com/name/nm0422436                                             1 win.
# http://www.imdb.com/name/nm0422504                                               None
# http://www.imdb.com/name/nm0422546                                               None
# http://www.imdb.com/name/nm0422550                                               None
# http://www.imdb.com/name/nm0422552                           6 wins & 13 nominations.
# http://www.imdb.com/name/nm0422558                                               None
# http://www.imdb.com/name/nm0422566                              1 win & 1 nomination.
# http://www.imdb.com/name/nm0422586                                               None
# http://www.imdb.com/name/nm0422600                                             1 win.
# ...                                                                               ...
# http://www.imdb.com/name/nm0463514                                               None
# http://www.imdb.com/name/nm0463539                            5 wins & 5 nominations.
# http://www.imdb.com/name/nm0463568                                               None
# http://www.imdb.com/name/nm0463590                                               None
# http://www.imdb.com/name/nm0463592                            9 wins & 3 nominations.
# http://www.imdb.com/name/nm0463649                                               None
# http://www.imdb.com/name/nm0463662                                               None
# http://www.imdb.com/name/nm0463684                                            6 wins.
# http://www.imdb.com/name/nm0463786                                               None
# http://www.imdb.com/name/nm0463814                                             1 win.
# http://www.imdb.com/name/nm0463827                                               None
# http://www.imdb.com/name/nm0463942                                      1 nomination.
# http://www.imdb.com/name/nm0464075                                            2 wins.
# http://www.imdb.com/name/nm0464143                                               None
# http://www.imdb.com/name/nm0464167                                               None
# http://www.imdb.com/name/nm0464170                                               None
# http://www.imdb.com/name/nm0464305                                             1 win.
# http://www.imdb.com/name/nm0464392                                             1 win.
# http://www.imdb.com/name/nm0464495                             1 win & 2 nominations.
# http://www.imdb.com/name/nm0464561                                               None
# http://www.imdb.com/name/nm0464591                                               None
# http://www.imdb.com/name/nm0464670                                               None
# http://www.imdb.com/name/nm0464720                                               None
# http://www.imdb.com/name/nm0464738                                            3 wins.
# http://www.imdb.com/name/nm0464855                                               None
# http://www.imdb.com/name/nm0464945                            6 wins & 4 nominations.
# http://www.imdb.com/name/nm0464946                                               None
# http://www.imdb.com/name/nm0465160                                               None
# http://www.imdb.com/name/nm0465187                                               None
# http://www.imdb.com/name/nm0465235                                               None
#
#                                                           Birth Country  \
# http://www.imdb.com/name/nm0421105                                   UK
# http://www.imdb.com/name/nm0421128                                  USA
# http://www.imdb.com/name/nm0421218                                  USA
# http://www.imdb.com/name/nm0421291                                  USA
# http://www.imdb.com/name/nm0421332                                   UK
# http://www.imdb.com/name/nm0421496                                  USA
# http://www.imdb.com/name/nm0421596                                  USA
# http://www.imdb.com/name/nm0421670                                 None
# http://www.imdb.com/name/nm0421709                                 None
# http://www.imdb.com/name/nm0421716                              Denmark
# http://www.imdb.com/name/nm0421722                                 None
# http://www.imdb.com/name/nm0421772                               Canada
# http://www.imdb.com/name/nm0421799                              Germany
# http://www.imdb.com/name/nm0421822                                  USA
# http://www.imdb.com/name/nm0421922                                  USA
# http://www.imdb.com/name/nm0422003                                  USA
# http://www.imdb.com/name/nm0422151                               Norway
# http://www.imdb.com/name/nm0422185                 British Crown Colony
# http://www.imdb.com/name/nm0422003                          Portsmouth, Virginia, USA
# http://www.imdb.com/name/nm0422151                                             Norway
# http://www.imdb.com/name/nm0422185                    Hong Kong, British Crown Colony
# http://www.imdb.com/name/nm0422234                                                 UK
# http://www.imdb.com/name/nm0422392   Nizhny Novgorod, Russian SFSR, USSR [now Russia]
# http://www.imdb.com/name/nm0422397                       Belgrade, Serbia, Yugoslavia
# http://www.imdb.com/name/nm0422436                             Shoshoni, Wyoming, USA
# http://www.imdb.com/name/nm0422504                        Valjevo, Serbia, Yugoslavia
# http://www.imdb.com/name/nm0422546                                               None
# http://www.imdb.com/name/nm0422550                                               None
# http://www.imdb.com/name/nm0422552                                Patna, Bihar, India
# http://www.imdb.com/name/nm0422558                                               None
# http://www.imdb.com/name/nm0422566                        Mangalore, Karnataka, India
# http://www.imdb.com/name/nm0422586                 Srinagar, Jammu and Kashmir, India
# http://www.imdb.com/name/nm0422600                               Siping, Jilin, China
# ...                                                                               ...
# http://www.imdb.com/name/nm0463514                                       Tokyo, Japan
# http://www.imdb.com/name/nm0463539                                   Kathmandu, Nepal
# http://www.imdb.com/name/nm0463568                                     Ranua, Finland
# http://www.imdb.com/name/nm0463590                                    Kamakura, Japan
# http://www.imdb.com/name/nm0463592                            Atsugi, Kanagawa, Japan
# http://www.imdb.com/name/nm0463649                       Belgrade, Serbia, Yugoslavia
# http://www.imdb.com/name/nm0463662                                               None
# http://www.imdb.com/name/nm0463684                                 Dupnitsa, Bulgaria
# http://www.imdb.com/name/nm0463786                                               None
# http://www.imdb.com/name/nm0463814                                       Osaka, Japan
# http://www.imdb.com/name/nm0463827                      Lazarevac, Serbia, Yugoslavia
# http://www.imdb.com/name/nm0463942                          Gdansk, Pomorskie, Poland
# http://www.imdb.com/name/nm0464075                                 Maharashtra, India
# http://www.imdb.com/name/nm0464143                                 Rome, Lazio, Italy
# http://www.imdb.com/name/nm0464167              Eskilstuna, Södermanlands län, Sweden
# http://www.imdb.com/name/nm0464170                                    Berlin, Germany
# http://www.imdb.com/name/nm0464305                   Moscow, RSFSR, USSR [now Russia]
# http://www.imdb.com/name/nm0464392                                       Oslo, Norway
# http://www.imdb.com/name/nm0464495          Cheb, Czechoslovakia [now Czech Republic]
# http://www.imdb.com/name/nm0464561  Vyazniki, Vyazniki uyezd, Vladimir Governorate...
# http://www.imdb.com/name/nm0464591                                     Fukuoka, Japan
# http://www.imdb.com/name/nm0464670                                               None
# http://www.imdb.com/name/nm0464720  Khvostovo, Moscow Governorate, Russian Empire ...
# http://www.imdb.com/name/nm0464738                        Warsaw, Mazowieckie, Poland
# http://www.imdb.com/name/nm0464855                                               None
# http://www.imdb.com/name/nm0464945                        Kraków, Malopolskie, Poland
# http://www.imdb.com/name/nm0464946  Prömsel, Galicia, Austria-Hungary [now Przemys...
# http://www.imdb.com/name/nm0465160                                    Wakayama, Japan
# http://www.imdb.com/name/nm0465187  Saratov, Saratovskaya oblast, RSFSR, USSR [now...
# http://www.imdb.com/name/nm0465235                            Nagaoka, Niigata, Japan
#
#                                     Birthyear  Deathyear  Directing Roles  \
# http://www.imdb.com/name/nm0421105     1957.0        NaN              NaN
# http://www.imdb.com/name/nm0421128     1949.0     1979.0              NaN
# http://www.imdb.com/name/nm0421218     1909.0     1991.0              NaN
# http://www.imdb.com/name/nm0421291     1949.0        NaN              NaN
# http://www.imdb.com/name/nm0421332     1969.0        NaN              NaN
# http://www.imdb.com/name/nm0421496     1967.0        NaN              NaN
# http://www.imdb.com/name/nm0421596     1956.0        NaN              NaN
# http://www.imdb.com/name/nm0421670        NaN        NaN              NaN
# http://www.imdb.com/name/nm0421709        NaN        NaN              NaN
# http://www.imdb.com/name/nm0421716     1971.0        NaN             15.0
# http://www.imdb.com/name/nm0421722        NaN        NaN              NaN
# http://www.imdb.com/name/nm0421772     1927.0     2007.0              NaN
# http://www.imdb.com/name/nm0421799     1978.0        NaN              NaN
# http://www.imdb.com/name/nm0421822     1969.0        NaN              1.0
# http://www.imdb.com/name/nm0421922     1917.0     2002.0              NaN
# http://www.imdb.com/name/nm0422003     1963.0        NaN              NaN
# http://www.imdb.com/name/nm0422151     1954.0        NaN              NaN
# http://www.imdb.com/name/nm0422185     1920.0     1968.0              NaN
# http://www.imdb.com/name/nm0422234     1946.0        NaN              NaN
# http://www.imdb.com/name/nm0422392     1926.0     1992.0              NaN
# http://www.imdb.com/name/nm0422397     1972.0        NaN              NaN
# http://www.imdb.com/name/nm0422436     1907.0     1972.0              NaN
# http://www.imdb.com/name/nm0422504     1972.0        NaN              NaN
# http://www.imdb.com/name/nm0422546        NaN        NaN              NaN
# http://www.imdb.com/name/nm0422550        NaN        NaN              NaN
# http://www.imdb.com/name/nm0422552     1952.0        NaN             34.0
# http://www.imdb.com/name/nm0422558        NaN        NaN              NaN
# http://www.imdb.com/name/nm0422566     1980.0        NaN              NaN
# http://www.imdb.com/name/nm0422586     1972.0        NaN              NaN
# http://www.imdb.com/name/nm0422600     1967.0     2010.0              NaN
# ...                                       ...        ...              ...
# http://www.imdb.com/name/nm0463514     1931.0     1985.0              NaN
# http://www.imdb.com/name/nm0463539     1970.0        NaN              NaN
# http://www.imdb.com/name/nm0463568     1966.0        NaN              NaN
# http://www.imdb.com/name/nm0463590     1926.0     2015.0              NaN
# http://www.imdb.com/name/nm0463592     1966.0        NaN              NaN
# http://www.imdb.com/name/nm0463649     1967.0        NaN              2.0
# http://www.imdb.com/name/nm0463662        NaN        NaN              NaN
# http://www.imdb.com/name/nm0463684     1938.0     2000.0              1.0
# http://www.imdb.com/name/nm0463786        NaN        NaN              NaN
# http://www.imdb.com/name/nm0463814     1971.0        NaN              NaN
# http://www.imdb.com/name/nm0463827     1980.0        NaN              NaN
# http://www.imdb.com/name/nm0463942     1950.0     2011.0              NaN
# http://www.imdb.com/name/nm0464075     1965.0        NaN              NaN
# http://www.imdb.com/name/nm0464143     1965.0        NaN              NaN
# http://www.imdb.com/name/nm0464167     1917.0     2014.0              NaN
# http://www.imdb.com/name/nm0464170     1914.0     1995.0              NaN
# http://www.imdb.com/name/nm0464305     1980.0        NaN              NaN
# http://www.imdb.com/name/nm0464392     1915.0     2008.0              1.0
# http://www.imdb.com/name/nm0464495     1946.0        NaN              NaN
# http://www.imdb.com/name/nm0464561     1891.0     1957.0              2.0
# http://www.imdb.com/name/nm0464591     1942.0        NaN              NaN
# http://www.imdb.com/name/nm0464670        NaN        NaN              NaN
# http://www.imdb.com/name/nm0464720     1911.0     2001.0              NaN
# http://www.imdb.com/name/nm0464738     1937.0        NaN              NaN
# http://www.imdb.com/name/nm0464855        NaN        NaN              NaN
# http://www.imdb.com/name/nm0464945     1950.0        NaN              1.0
# http://www.imdb.com/name/nm0464946     1908.0     1994.0              NaN
# http://www.imdb.com/name/nm0465160     1973.0        NaN              NaN
# http://www.imdb.com/name/nm0465187     1951.0        NaN              NaN
# http://www.imdb.com/name/nm0465235     1916.0     1977.0              NaN
#
#                                     Gender  Height in m                 Name  \
# http://www.imdb.com/name/nm0421105    Male         1.88        Alex Jennings
# http://www.imdb.com/name/nm0421128  Female         1.68     Claudia Jennings
# http://www.imdb.com/name/nm0421218  Female          NaN      Maxine Jennings
# http://www.imdb.com/name/nm0421291  Female          NaN        Rita Jenrette
# http://www.imdb.com/name/nm0421332  Female         1.60        Ashley Jensen
# http://www.imdb.com/name/nm0421496  Female         1.68          Jane Jensen
# http://www.imdb.com/name/nm0421596  Female         1.70         Maren Jensen
# http://www.imdb.com/name/nm0421670  Female          NaN   Sarah Jayne Jensen
# http://www.imdb.com/name/nm0421709    Male         1.88          Todd Jensen
# http://www.imdb.com/name/nm0421716    Male         1.70  Tomas Villum Jensen
# http://www.imdb.com/name/nm0421722    Male          NaN   Torbjörn T. Jensen
# http://www.imdb.com/name/nm0421772    Male         1.88           Roy Jenson
# http://www.imdb.com/name/nm0421799  Female         1.65        Julia Jentsch
# http://www.imdb.com/name/nm0421822    Male         1.65            Ken Jeong
# http://www.imdb.com/name/nm0421922  Female         1.75        Adele Jergens
# http://www.imdb.com/name/nm0422003    Male         1.78       Terry Jernigan
# http://www.imdb.com/name/nm0422151    Male          NaN       Otto Jespersen
# http://www.imdb.com/name/nm0422185  Female         1.69      Patricia Jessel
# http://www.imdb.com/name/nm0422234    Male          NaN          Paul Jesson
# http://www.imdb.com/name/nm0422392    Male         1.69   Evgeniy Evstigneev
# http://www.imdb.com/name/nm0422397    Male          NaN        Ivan Jevtovic
# http://www.imdb.com/name/nm0422436  Female         1.50        Isabel Jewell
# http://www.imdb.com/name/nm0422504    Male         1.85         Nenad Jezdic
# http://www.imdb.com/name/nm0422546    Male          NaN         Demno Jgenti
# http://www.imdb.com/name/nm0422550    Male          NaN           Pankaj Jha
# http://www.imdb.com/name/nm0422552    Male          NaN          Prakash Jha
# http://www.imdb.com/name/nm0422558  Female          NaN     Karishma Jhalani
# http://www.imdb.com/name/nm0422566  Female         1.65     Preeti Jhangiani
# http://www.imdb.com/name/nm0422586  Female         1.59        Ayesha Jhulka
# http://www.imdb.com/name/nm0422600    Male          NaN         Hongshen Jia
# ...                                    ...          ...                  ...
# http://www.imdb.com/name/nm0463514    Male          NaN           Asao Koike
# http://www.imdb.com/name/nm0463539  Female         1.65      Manisha Koirala
# http://www.imdb.com/name/nm0463568    Male          NaN        Ilkka Koivula
# http://www.imdb.com/name/nm0463590    Male         1.73      Hiroshi Koizumi
# http://www.imdb.com/name/nm0463592  Female          NaN        Kyôko Koizumi
# http://www.imdb.com/name/nm0463649    Male         1.84          Nikola Kojo
# http://www.imdb.com/name/nm0463662    Male          NaN         Danny de Kok
# http://www.imdb.com/name/nm0463684  Female          NaN      Nevena Kokanova
# http://www.imdb.com/name/nm0463786    Male          NaN       Berislav Kokot
# http://www.imdb.com/name/nm0463814  Female         1.62          Aya Kokumai
# http://www.imdb.com/name/nm0463827  Female         1.68      Sonja Kolacaric
# http://www.imdb.com/name/nm0463942    Male          NaN  Krzysztof Kolberger
# http://www.imdb.com/name/nm0464075  Female         1.63    Padmini Kolhapure
# http://www.imdb.com/name/nm0464143  Female         1.65         Claudia Koll
# http://www.imdb.com/name/nm0464167  Female          NaN      Barbro Kollberg
# http://www.imdb.com/name/nm0464170    Male          NaN  Reinhard Kolldehoff
# http://www.imdb.com/name/nm0464305    Male         1.96    Yuri Kolokolnikov
# http://www.imdb.com/name/nm0464392    Male          NaN        Henki Kolstad
# http://www.imdb.com/name/nm0464495  Female          NaN     Daniela Kolárová
# http://www.imdb.com/name/nm0464561    Male          NaN       Sergey Komarov
# http://www.imdb.com/name/nm0464591    Male         1.65        Masao Komatsu
# http://www.imdb.com/name/nm0464670  Female          NaN        Mitsue Komiya
# http://www.imdb.com/name/nm0464720  Female          NaN        Anna Komolova
# http://www.imdb.com/name/nm0464738  Female          NaN      Maja Komorowska
# http://www.imdb.com/name/nm0464855    Male          NaN      Christoph Koncz
# http://www.imdb.com/name/nm0464945    Male         1.76        Marek Kondrat
# http://www.imdb.com/name/nm0464946    Male          NaN      Tadeusz Kondrat
# http://www.imdb.com/name/nm0465160    Male         1.80    Katsuyuki Konishi
# http://www.imdb.com/name/nm0465187    Male          NaN      Vladimir Konkin
# http://www.imdb.com/name/nm0465235    Male          NaN        Jûshirô Konoe
#
#                                     Producing Roles  Publicity Listings  \
# http://www.imdb.com/name/nm0421105              NaN                 NaN
# http://www.imdb.com/name/nm0421128              NaN                40.0
# http://www.imdb.com/name/nm0421218              NaN                 NaN
# http://www.imdb.com/name/nm0421291              NaN                 6.0
# http://www.imdb.com/name/nm0421332              1.0                 6.0
# http://www.imdb.com/name/nm0421496              NaN                 2.0
# http://www.imdb.com/name/nm0421596              NaN                16.0
# http://www.imdb.com/name/nm0421670              2.0                 NaN
# http://www.imdb.com/name/nm0421709              NaN                 NaN
# http://www.imdb.com/name/nm0421716              6.0                 NaN
# http://www.imdb.com/name/nm0421722              NaN                 NaN
# http://www.imdb.com/name/nm0421772              NaN                 3.0
# http://www.imdb.com/name/nm0421799              NaN                 3.0
# http://www.imdb.com/name/nm0421822              6.0                 5.0
# http://www.imdb.com/name/nm0421922              NaN                 4.0
# http://www.imdb.com/name/nm0422003              7.0                 NaN
# http://www.imdb.com/name/nm0422151              NaN                 NaN
# http://www.imdb.com/name/nm0422185              NaN                 4.0
# http://www.imdb.com/name/nm0422234              NaN                 NaN
# http://www.imdb.com/name/nm0422392              NaN                 NaN
# http://www.imdb.com/name/nm0422397              NaN                 NaN
# http://www.imdb.com/name/nm0422436              NaN                 3.0
# http://www.imdb.com/name/nm0422504              NaN                 NaN
# http://www.imdb.com/name/nm0422546              NaN                 NaN
# http://www.imdb.com/name/nm0422550              NaN                 NaN
# http://www.imdb.com/name/nm0422552             16.0                 NaN
# http://www.imdb.com/name/nm0422558              NaN                 NaN
# http://www.imdb.com/name/nm0422566              1.0                 NaN
# http://www.imdb.com/name/nm0422586              NaN                 NaN
# http://www.imdb.com/name/nm0422600              NaN                 NaN
# ...                                             ...                 ...
# http://www.imdb.com/name/nm0463514              NaN                 NaN
# http://www.imdb.com/name/nm0463539              1.0                 NaN
# http://www.imdb.com/name/nm0463568              NaN                 NaN
# http://www.imdb.com/name/nm0463590              2.0                 NaN
# http://www.imdb.com/name/nm0463592              NaN                 NaN
# http://www.imdb.com/name/nm0463649              5.0                 NaN
# http://www.imdb.com/name/nm0463662              NaN                 NaN
# http://www.imdb.com/name/nm0463684              NaN                 3.0
# http://www.imdb.com/name/nm0463786              NaN                 NaN
# http://www.imdb.com/name/nm0463814              NaN                 NaN
# http://www.imdb.com/name/nm0463827              NaN                 NaN
# http://www.imdb.com/name/nm0463942              NaN                 NaN
# http://www.imdb.com/name/nm0464075              1.0                 NaN
# http://www.imdb.com/name/nm0464143              NaN                11.0
# http://www.imdb.com/name/nm0464167              NaN                 1.0
# http://www.imdb.com/name/nm0464170              NaN                 NaN
# http://www.imdb.com/name/nm0464305              1.0                 NaN
# http://www.imdb.com/name/nm0464392              NaN                 NaN
# http://www.imdb.com/name/nm0464495              NaN                 NaN
# http://www.imdb.com/name/nm0464561              NaN                 NaN
# http://www.imdb.com/name/nm0464591              NaN                 NaN
# http://www.imdb.com/name/nm0464670              NaN                 NaN
# http://www.imdb.com/name/nm0464720              NaN                 NaN
# http://www.imdb.com/name/nm0464738              NaN                 NaN
# http://www.imdb.com/name/nm0464855              NaN                 NaN
# http://www.imdb.com/name/nm0464945              NaN                 1.0
# http://www.imdb.com/name/nm0464946              NaN                 NaN
# http://www.imdb.com/name/nm0465160              NaN                 NaN
# http://www.imdb.com/name/nm0465187              NaN                 NaN
# http://www.imdb.com/name/nm0465235              NaN                 NaN
#
#                                       Star Sign  TV Appearances
# http://www.imdb.com/name/nm0421105       Taurus            15.0
# http://www.imdb.com/name/nm0421128  Sagittarius             3.0
# http://www.imdb.com/name/nm0421218       Pisces             1.0
# http://www.imdb.com/name/nm0421291  Sagittarius             2.0
# http://www.imdb.com/name/nm0421332          Leo            39.0
# http://www.imdb.com/name/nm0421496         None             1.0
