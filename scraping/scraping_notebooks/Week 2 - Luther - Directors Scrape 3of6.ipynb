# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %%
details_df['Director'].isnull().sum()
# Out:
# 6

# %%
details_df.loc[details_df['Director'].isnull()]
# Out:
#                                       Budget Country  \
# http://www.imdb.com/title/tt4342506/     NaN  Turkey
# http://www.imdb.com/title/tt2396224/     NaN     USA
# http://www.imdb.com/title/tt1552221/     NaN     USA
# http://www.imdb.com/title/tt1600429/     NaN     USA
# http://www.imdb.com/title/tt0814343/     NaN     USA
# http://www.imdb.com/title/tt0039404/     NaN     USA
#
#                                       Cumulative Worldwide Gross Director  \
# http://www.imdb.com/title/tt4342506/                         NaN     None
# http://www.imdb.com/title/tt2396224/                         NaN     None
# http://www.imdb.com/title/tt1552221/                         NaN     None
# http://www.imdb.com/title/tt1600429/                         NaN     None
# http://www.imdb.com/title/tt0814343/                         NaN     None
# http://www.imdb.com/title/tt0039404/                         NaN     None
#
#                                      Director_URL  Gross USA Language  \
# http://www.imdb.com/title/tt4342506/         None        NaN  Turkish
# http://www.imdb.com/title/tt2396224/         None        NaN  English
# http://www.imdb.com/title/tt1552221/         None        NaN  English
# http://www.imdb.com/title/tt1600429/         None        NaN  English
# http://www.imdb.com/title/tt0814343/         None        NaN  English
# http://www.imdb.com/title/tt0039404/         None        NaN  English
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4342506/                  NaN
# http://www.imdb.com/title/tt2396224/                  NaN
# http://www.imdb.com/title/tt1552221/                  NaN
# http://www.imdb.com/title/tt1600429/                  NaN
# http://www.imdb.com/title/tt0814343/                  NaN
# http://www.imdb.com/title/tt0039404/                  NaN
#
#                                                                Primary Filming Location  \
# http://www.imdb.com/title/tt4342506/                                               None
# http://www.imdb.com/title/tt2396224/                                               None
# http://www.imdb.com/title/tt1552221/                Vancouver, British Columbia, Canada
# http://www.imdb.com/title/tt1600429/           The Hamptons, Long Island, New York, USA
# http://www.imdb.com/title/tt0814343/  Cheyenne Studios - 27567 Fantastic Lane, Casta...
# http://www.imdb.com/title/tt0039404/                                               None
#
#                                            Production Company Release Date  \
# http://www.imdb.com/title/tt4342506/                     None   2015-03-18
# http://www.imdb.com/title/tt2396224/             Bitter Films   2016-05-21
# http://www.imdb.com/title/tt1552221/  Dolce Cielo Productions         2011
# http://www.imdb.com/title/tt1600429/        Big Picture Media   2015-09-29
# http://www.imdb.com/title/tt0814343/         Wind Chill Films   2013-08-14
# http://www.imdb.com/title/tt0039404/  Walt Disney Productions   1947-09-27
#
#                                                   Star1  \
# http://www.imdb.com/title/tt4342506/       Tansel Öngel
# http://www.imdb.com/title/tt2396224/                NaN
# http://www.imdb.com/title/tt1552221/   Christy Andersen
# http://www.imdb.com/title/tt1600429/        Kane Hodder
# http://www.imdb.com/title/tt0814343/  Bridget Shergalis
# http://www.imdb.com/title/tt0039404/       Edgar Bergen
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4342506/  http://www.imdb.com/name/nm2017262
# http://www.imdb.com/title/tt2396224/                                 NaN
# http://www.imdb.com/title/tt1552221/  http://www.imdb.com/name/nm3449847
# http://www.imdb.com/title/tt1600429/  http://www.imdb.com/name/nm0387987
# http://www.imdb.com/title/tt0814343/  http://www.imdb.com/name/nm2287914
# http://www.imdb.com/title/tt0039404/  http://www.imdb.com/name/nm0001944
#
#                                                  Star2  \
# http://www.imdb.com/title/tt4342506/  Nesrin Cavadzade
# http://www.imdb.com/title/tt2396224/               NaN
# http://www.imdb.com/title/tt1552221/      Ava Andersen
# http://www.imdb.com/title/tt1600429/      Bill Moseley
# http://www.imdb.com/title/tt0814343/        Tori White
# http://www.imdb.com/title/tt0039404/       Dinah Shore
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4342506/  http://www.imdb.com/name/nm1863960
# http://www.imdb.com/title/tt2396224/                                 NaN
# http://www.imdb.com/title/tt1552221/  http://www.imdb.com/name/nm3908997
# http://www.imdb.com/title/tt1600429/  http://www.imdb.com/name/nm0608405
# http://www.imdb.com/title/tt0814343/  http://www.imdb.com/name/nm1979997
# http://www.imdb.com/title/tt0039404/  http://www.imdb.com/name/nm0794918
#
#                                                  Star3  \
# http://www.imdb.com/title/tt4342506/     Bülent Sakrak
# http://www.imdb.com/title/tt2396224/               NaN
# http://www.imdb.com/title/tt1552221/    Halle Andersen
# http://www.imdb.com/title/tt1600429/      Sascha Knopf
# http://www.imdb.com/title/tt0814343/    Chauntal Lewis
# http://www.imdb.com/title/tt0039404/  Charlie McCarthy
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4342506/  http://www.imdb.com/name/nm1281073
# http://www.imdb.com/title/tt2396224/                                 NaN
# http://www.imdb.com/title/tt1552221/  http://www.imdb.com/name/nm3917038
# http://www.imdb.com/title/tt1600429/  http://www.imdb.com/name/nm0461355
# http://www.imdb.com/title/tt0814343/  http://www.imdb.com/name/nm1800445
# http://www.imdb.com/title/tt0039404/  http://www.imdb.com/name/nm1706905
#
#                                                           Title
# http://www.imdb.com/title/tt4342506/                 Son Mektup
# http://www.imdb.com/title/tt2396224/  It's Such a Beautiful Day
# http://www.imdb.com/title/tt1552221/                    Ecstasy
# http://www.imdb.com/title/tt1600429/                     Old 37
# http://www.imdb.com/title/tt0814343/                     Séance
# http://www.imdb.com/title/tt0039404/           Fun & Fancy Free

# %%
len(details_df)
# Out:
# 29717

# %% [markdown]
# # Get List of unique Directors and URLS

# %%
directors_df = details_df[['Director_URL','Director']].copy()

# %%
directors_df = directors_df.dropna(subset = ['Director_URL'])

# %%
directors_df.head()
# Out:
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                                      Director
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra

# %%
len(directors_df)
# Out:
# 29711

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
directors_df = directors_df.drop_duplicates(subset='Director_URL',keep='first')

# %%
len(directors_df)
# Out:
# 11939

# %%
director_urls = list(directors_df['Director_URL'])

# %%
director_urls = sorted(director_urls, reverse=True)

# %%
director_urls[0:5]
# Out:
# ['http://www.imdb.com/name/nm9470145',
#  'http://www.imdb.com/name/nm9350573',
#  'http://www.imdb.com/name/nm9323433',
#  'http://www.imdb.com/name/nm9323057',
#  'http://www.imdb.com/name/nm9322578']

# %%
len(director_urls)
# Out:
# 11939

# %% [raw]
# director_urls[2525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# # url = 'http://www.imdb.com/name/nm0000233/'
# url= 'http://www.imdb.com/name/nm0005086/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# director_details = {}
# director_details[url] = {}

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.findAll('span') if award_highlight else None
# award_highlight = [x.text for x in award_highlight] if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = [x.split('\n') for x in award_highlight] if award_highlight else None
# award_highlight = [''.join(x) for x in award_highlight[:-1]] if award_highlight else None
# award_highlight = [re.sub("  +", " ", x) for x in award_highlight] if award_highlight else Non
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# award_highlight

# %% [raw]
# gender = soup.find(id='name-bio-text')
# gender = gender.text if gender else None
# gender = re.sub('\n', '', gender) if gender else None
# gender = re.sub('  +',' ', gender) if gender else None
# gender = gender.split(' ') if gender else None
# male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
# female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
# if male_count > female_count:
#     gender = 'Male'
# elif female_count > male_count:
#     gender = 'Female'
# else:
#     gender = None
# gender

# %% [raw]
# len(director_urls)

# %% [markdown]
# ## Scrape Director Details

# %%
# Star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

directors_scraped = 0
director_details = {}
director_index = 4000                     
prefix = 'http://www.imdb.com'
export_number = 10
export_no = str(export_number)
load_attempts = 0

def director_scraper():
    global director_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in director_urls[director_index:6000]:
#         print(url)
        if (director_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(director_index+1, url))
        page = request_page(url)
        get_director_details(url, page)
        director_index += 1
    
    export_to_json(director_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_director_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    director_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    director_details[url]['Gender'] = gender
    
    
    director_name = soup.find('h1')
    director_name = director_name.text if director_name else None
    director_name = director_name.strip() if director_name else None
    director_name = director_name.split('\n') if director_name else None

    deathyear = director_name[-1] if len(director_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
    director_details[url]['Deathyear'] = deathyear
    

    director_name = director_name[0] if director_name else None
    director_details[url]['Name'] = director_name    
    
    
    born_info = soup.find(id='name-born-info')

    birthdate = born_info.find('time') if born_info else None
    if birthdate:
        if birthdate.has_attr('datetime'):
            birthdate = birthdate['datetime']
        else:
            birthdate = None
    director_details[url]['Birthdate'] = birthdate

    birthyear = birthdate[0:4] if birthdate and len(birthdate)>=8 else None
    birthyear = int(birthyear) if birthyear else None
    director_details[url]['Birthyear'] = birthyear

    age_at_death = deathyear-birthyear if deathyear and birthyear else None
    director_details[url]['Age at Death'] = age_at_death

    
    birthplace = born_info.findAll('a') if born_info else None
    birthplace = birthplace[-1] if birthplace else None
    birthplace = birthplace.text if birthplace else None
    director_details[url]['Birthplace'] = birthplace

    
    birthcountry = birthplace.split(', ') if birthplace else None
    birthcountry = birthcountry[-1] if birthcountry and len(birthcountry)>1 else None
    director_details[url]['Birth Country'] = birthcountry

    award_highlight = soup.find('div', class_='article highlighted')
    award_highlight = award_highlight.findAll('span') if award_highlight else None
    award_highlight = [x.text for x in award_highlight] if award_highlight else None
    award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
    award_highlight = [x.split('\n') for x in award_highlight] if award_highlight else None
    award_highlight = [''.join(x) for x in award_highlight[:-1]] if award_highlight else None
    award_highlight = [re.sub("  +", " ", x) for x in award_highlight] if award_highlight else None
    award_highlight = ' '.join(award_highlight) if award_highlight else None    
    director_details[url]['Award Info'] = award_highlight
    
    writing_roles = soup.find(id='filmo-head-writer')
    writing_roles = writing_roles.text if writing_roles else None
    writing_roles = writing_roles.strip() if writing_roles else None
    writing_roles = writing_roles.split('(')[-1] if writing_roles else None
    writing_roles = re.sub('[^0-9]+','',writing_roles) if writing_roles else None
    writing_roles = int(writing_roles) if writing_roles else None
    director_details[url]['Writing Roles'] = writing_roles
    
    editing_roles = soup.find(id='filmo-head-editor')
    editing_roles = editing_roles.text if editing_roles else None
    editing_roles = editing_roles.strip() if editing_roles else None
    editing_roles = editing_roles.split('(')[-1] if editing_roles else None
    editing_roles = re.sub('[^0-9]+','',editing_roles) if editing_roles else None
    editing_roles = int(editing_roles) if editing_roles else None
    director_details[url]['Editing Roles'] = editing_roles
    
    acting_roles = soup.find(id='filmo-head-actor')
    acting_roles = acting_roles.text if acting_roles else None
    acting_roles = acting_roles.strip() if acting_roles else None
    acting_roles = acting_roles.split('(')[-1] if acting_roles else None
    acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
    acting_roles = int(acting_roles) if acting_roles else None
    director_details[url]['Acting Roles'] = acting_roles
    
    directing_roles = soup.find(id='filmo-head-director')
    directing_roles = directing_roles.text if directing_roles else None
    directing_roles = directing_roles.strip() if directing_roles else None
    directing_roles = directing_roles.split('(')[-1] if directing_roles else None
    directing_roles = re.sub('[^0-9]+','',directing_roles) if directing_roles else None
    directing_roles = int(directing_roles) if directing_roles else None
    director_details[url]['Directing Roles'] = directing_roles  
    
    producing_roles = soup.find(id='filmo-head-producer')
    producing_roles = producing_roles.text if producing_roles else None
    producing_roles = producing_roles.strip() if producing_roles else None
    producing_roles = producing_roles.split('(')[-1] if producing_roles else None
    producing_roles = re.sub('[^0-9]+','',producing_roles) if producing_roles else None
    producing_roles = int(producing_roles) if producing_roles else None
    director_details[url]['Producing Roles'] = producing_roles
    
    cinematographic_roles = soup.find(id='filmo-head-cinematographer')
    cinematographic_roles = cinematographic_roles.text if cinematographic_roles else None
    cinematographic_roles = cinematographic_roles.strip() if cinematographic_roles else None
    cinematographic_roles = cinematographic_roles.split('(')[-1] if cinematographic_roles else None
    cinematographic_roles = re.sub('[^0-9]+','',cinematographic_roles) if cinematographic_roles else None
    cinematographic_roles = int(cinematographic_roles) if cinematographic_roles else None
    director_details[url]['Cinematographic Roles'] = cinematographic_roles
    
    tv_appearances = soup.find(id='filmo-head-self')
    tv_appearances = tv_appearances.text if tv_appearances else None
    tv_appearances = tv_appearances.strip() if tv_appearances else None
    tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
    tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
    tv_appearances = int(tv_appearances) if tv_appearances else None
    director_details[url]['TV Appearances'] = tv_appearances
    

    height = soup.find('h2',text=re.compile('Personal Details'))
    height = height.parent if height else None
    height = height.find(id='details-height') if height else None
    height = height.text if height else None
    height = height.split('(')[-1] if height else None
    height = re.sub('[^0-9.]+','',height) if height else None
    director_details[url]['Height in m'] = height

    publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
    publicity_listings = publicity_listings.parent if publicity_listings else None
    publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
    publicity_listings = publicity_listings.text if publicity_listings else None
    publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
    publicity_listings = publicity_listings.strip() if publicity_listings else None
    publicity_listings = publicity_listings.split(' ') if publicity_listings else None
    publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
    publicity_listings = sum(publicity_listings) if publicity_listings else None
    director_details[url]['Publicity Listings'] = publicity_listings
        
    star_sign = soup.find('h4',text=re.compile('Star Sign'))
    star_sign = star_sign.parent if star_sign else None
    star_sign = star_sign.text if star_sign else None
    star_sign = star_sign.strip() if star_sign else None
    star_sign = star_sign.split('\n')[-1] if star_sign else None
    director_details[url]['Star Sign'] = star_sign

    go_to_next_and_export()

def go_to_next_and_export():
    global directors_scraped
    global director_details
    
    directors_scraped+=1

    if len(director_details) == 1000:                                         
        export_to_json(director_details)
        directors_scraped = 0
        director_details = {}

def export_to_json(director_details):
    global export_no
    global export_number
    with open('director_details_exports/director_details_export_%s.json' %(export_no),'w')  as f:
        json.dump(director_details,f)

    export_number += 1
    export_no = str(export_number)
    print(str(datetime.now()),': working on export ' + export_no)

start = time.time()
director_scraper()
end = time.time()
print(round(end-start,3))
# Out:
# 2018-01-29 23:08:54.175154 : working on export 10
# 4020: http://www.imdb.com/name/nm1006419
# 4040: http://www.imdb.com/name/nm0996471
# 4060: http://www.imdb.com/name/nm0992027
# 4080: http://www.imdb.com/name/nm0969403
# 4100: http://www.imdb.com/name/nm0959034
# 4120: http://www.imdb.com/name/nm0956454
# 4140: http://www.imdb.com/name/nm0954483
# 4160: http://www.imdb.com/name/nm0951698
# 4180: http://www.imdb.com/name/nm0950226
# 4200: http://www.imdb.com/name/nm0947447
# 4220: http://www.imdb.com/name/nm0945724
# 4240: http://www.imdb.com/name/nm0943758
# 4260: http://www.imdb.com/name/nm0940790
# 4280: http://www.imdb.com/name/nm0937600
# 4300: http://www.imdb.com/name/nm0935203
# 4320: http://www.imdb.com/name/nm0932551
# 4340: http://www.imdb.com/name/nm0928010
# 4360: http://www.imdb.com/name/nm0924063
# 4380: http://www.imdb.com/name/nm0921013
# 4400: http://www.imdb.com/name/nm0918554
# 4420: http://www.imdb.com/name/nm0916424
# 4440: http://www.imdb.com/name/nm0913809
# 4460: http://www.imdb.com/name/nm0911093
# 5760: http://www.imdb.com/name/nm0723629
# 5780: http://www.imdb.com/name/nm0719208
# 5800: http://www.imdb.com/name/nm0716980
# 5820: http://www.imdb.com/name/nm0713610
# 5840: http://www.imdb.com/name/nm0711114
# 5860: http://www.imdb.com/name/nm0706800
# 5880: http://www.imdb.com/name/nm0705127
# 5900: http://www.imdb.com/name/nm0702522
# 5920: http://www.imdb.com/name/nm0699932
# 5940: http://www.imdb.com/name/nm0697934
# 5960: http://www.imdb.com/name/nm0694090
# 5980: http://www.imdb.com/name/nm0690794
# 6000: http://www.imdb.com/name/nm0688949
# 2018-01-29 23:57:10.124954 : working on export 12
# 2018-01-29 23:57:10.126450 : working on export 13
# Done
# 2895.952

# %%
import json
import pandas as pd
directors_import = pd.read_json('director_details_exports/director_details_export_10.json',orient='index')

# %%
len(directors_import)
# Out:
# 1000

# %%
directors_import
# Out:
#                                     Acting Roles  Age at Death  \
# http://www.imdb.com/name/nm0828419           4.0          71.0
# http://www.imdb.com/name/nm0828562           1.0          74.0
# http://www.imdb.com/name/nm0828623           NaN          49.0
# http://www.imdb.com/name/nm0829037           6.0           NaN
# http://www.imdb.com/name/nm0829038           2.0          81.0
# http://www.imdb.com/name/nm0829343           1.0           NaN
# http://www.imdb.com/name/nm0829518           2.0           NaN
# http://www.imdb.com/name/nm0829537          34.0           NaN
# http://www.imdb.com/name/nm0829579          21.0          67.0
# http://www.imdb.com/name/nm0829820           2.0           NaN
# http://www.imdb.com/name/nm0829925           NaN           NaN
# http://www.imdb.com/name/nm0830150           NaN          74.0
# http://www.imdb.com/name/nm0830249           7.0          45.0
# http://www.imdb.com/name/nm0830387           1.0           NaN
# http://www.imdb.com/name/nm0830629           2.0           NaN
# http://www.imdb.com/name/nm0831321           2.0           NaN
# http://www.imdb.com/name/nm0831370           NaN           NaN
# http://www.imdb.com/name/nm0831457           2.0           NaN
# http://www.imdb.com/name/nm0831546           7.0           NaN
# http://www.imdb.com/name/nm0831557           NaN           NaN
# http://www.imdb.com/name/nm0831690           2.0           NaN
# http://www.imdb.com/name/nm0831720           NaN          97.0
# http://www.imdb.com/name/nm0831847           5.0           NaN
# http://www.imdb.com/name/nm0832165          29.0           NaN
# http://www.imdb.com/name/nm0832369           NaN           NaN
# http://www.imdb.com/name/nm0832559          28.0          61.0
# http://www.imdb.com/name/nm0832573          33.0           NaN
# http://www.imdb.com/name/nm0832584          49.0          68.0
# http://www.imdb.com/name/nm0832617           NaN           NaN
# http://www.imdb.com/name/nm0832823           NaN           NaN
# ...                                          ...           ...
# http://www.imdb.com/name/nm1000820           NaN           NaN
# http://www.imdb.com/name/nm1000987           NaN           NaN
# http://www.imdb.com/name/nm1001040           NaN           NaN
# http://www.imdb.com/name/nm1001051           7.0           NaN
# http://www.imdb.com/name/nm1002207          37.0           NaN
# http://www.imdb.com/name/nm1002424           3.0           NaN
# http://www.imdb.com/name/nm1003636           NaN           NaN
# http://www.imdb.com/name/nm1004738           3.0           NaN
# http://www.imdb.com/name/nm1005607           5.0           NaN
# http://www.imdb.com/name/nm1006056           NaN           NaN
# http://www.imdb.com/name/nm1006419           1.0           NaN
# http://www.imdb.com/name/nm1006491           2.0           NaN
# http://www.imdb.com/name/nm1006796           NaN           NaN
# http://www.imdb.com/name/nm1007136           NaN           NaN
# http://www.imdb.com/name/nm1007344           1.0           NaN
# http://www.imdb.com/name/nm1007740          71.0           NaN
# http://www.imdb.com/name/nm1008619          16.0           NaN
# http://www.imdb.com/name/nm1008762           NaN           NaN
# http://www.imdb.com/name/nm1009277          48.0           NaN
# http://www.imdb.com/name/nm1009774           NaN           NaN
# http://www.imdb.com/name/nm1009775           1.0           NaN
# http://www.imdb.com/name/nm1010592           NaN           NaN
# http://www.imdb.com/name/nm1011074           1.0           NaN
# http://www.imdb.com/name/nm1011337           7.0           NaN
# http://www.imdb.com/name/nm1011749           1.0           NaN
# http://www.imdb.com/name/nm1011775           NaN           NaN
# http://www.imdb.com/name/nm1012219           NaN           NaN
# http://www.imdb.com/name/nm1012385           1.0           NaN
# http://www.imdb.com/name/nm1012501           NaN           NaN
# http://www.imdb.com/name/nm1012775           4.0           NaN
#
#                                                                            Award Info  \
# http://www.imdb.com/name/nm0828419    Won 2 Oscars. Another 10 wins & 26 nominations.
# http://www.imdb.com/name/nm0828562  Nominated for 1 Primetime Emmy. Another 1 win ...
# http://www.imdb.com/name/nm0828623  Won 6 Primetime Emmys. Another 5 wins & 12 nom...
# http://www.imdb.com/name/nm0829037                           12 wins & 5 nominations.
# http://www.imdb.com/name/nm0829038  Nominated for 1 Oscar. Another 3 wins & 6 nomi...
# http://www.imdb.com/name/nm0829343      Nominated for 1 Oscar. Another 3 nominations.
# http://www.imdb.com/name/nm0829518                                               None
# http://www.imdb.com/name/nm0829537  Won 22 Primetime Emmys. Another 18 wins & 74 n...
# http://www.imdb.com/name/nm0829579                                             1 win.
# http://www.imdb.com/name/nm0829820                                               None
# http://www.imdb.com/name/nm0829925                                      1 nomination.
# http://www.imdb.com/name/nm0830150                             1 win & 3 nominations.
# http://www.imdb.com/name/nm0830249                                             1 win.
# http://www.imdb.com/name/nm0830387                                             1 win.
# http://www.imdb.com/name/nm0830629                             1 win & 2 nominations.
# http://www.imdb.com/name/nm0831321                                               None
# http://www.imdb.com/name/nm0831370                             1 win & 2 nominations.
# http://www.imdb.com/name/nm0831457                                            2 wins.
# http://www.imdb.com/name/nm0831546                                            2 wins.
# http://www.imdb.com/name/nm0831557                            2 wins & 8 nominations.
# http://www.imdb.com/name/nm0831690                                     5 nominations.
# http://www.imdb.com/name/nm0831720              Nominated for 1 Oscar. Another 1 win.
# http://www.imdb.com/name/nm0831847                                               None
# http://www.imdb.com/name/nm0832165                                               None
# http://www.imdb.com/name/nm0832369                           5 wins & 14 nominations.
# http://www.imdb.com/name/nm0832559                             1 win & 4 nominations.
# http://www.imdb.com/name/nm0832573                                      1 nomination.
# http://www.imdb.com/name/nm0832584                                               None
# http://www.imdb.com/name/nm0832617                             5 wins & 1 nomination.
# http://www.imdb.com/name/nm0832823                                               None
# ...                                                                               ...
# http://www.imdb.com/name/nm1000820                             2 wins & 1 nomination.
# http://www.imdb.com/name/nm1000987                                               None
# http://www.imdb.com/name/nm1001040                            5 wins & 8 nominations.
# http://www.imdb.com/name/nm1001051                           9 wins & 22 nominations.
# http://www.imdb.com/name/nm1002207                                     2 nominations.
# http://www.imdb.com/name/nm1002424                            4 wins & 9 nominations.
# http://www.imdb.com/name/nm1003636                    Nominated for 1 Primetime Emmy.
# http://www.imdb.com/name/nm1004738                                               None
# http://www.imdb.com/name/nm1005607                             2 wins & 1 nomination.
# http://www.imdb.com/name/nm1006056                            7 wins & 3 nominations.
# http://www.imdb.com/name/nm1006419                                      1 nomination.
# http://www.imdb.com/name/nm1006491                                               None
# http://www.imdb.com/name/nm1006796                                     4 nominations.
# http://www.imdb.com/name/nm1007136                          16 wins & 16 nominations.
# http://www.imdb.com/name/nm1007344                                               None
# http://www.imdb.com/name/nm1007740                                            2 wins.
# http://www.imdb.com/name/nm1008619                              1 win & 1 nomination.
# http://www.imdb.com/name/nm1008762                                               None
# http://www.imdb.com/name/nm1009277                                     2 nominations.
# http://www.imdb.com/name/nm1009774                            2 wins & 5 nominations.
# http://www.imdb.com/name/nm1009775                            9 wins & 2 nominations.
# http://www.imdb.com/name/nm1010592                             1 win & 5 nominations.
# http://www.imdb.com/name/nm1011074                                      1 nomination.
# http://www.imdb.com/name/nm1011337                            2 wins & 4 nominations.
# http://www.imdb.com/name/nm1011749                                      1 nomination.
# http://www.imdb.com/name/nm1011775                                               None
# http://www.imdb.com/name/nm1012219                             7 wins & 1 nomination.
# http://www.imdb.com/name/nm1012385                             1 win & 4 nominations.
# http://www.imdb.com/name/nm1012501                            2 wins & 7 nominations.
# http://www.imdb.com/name/nm1012775                                               None
#
#                                                  Birth Country   Birthdate  \
# http://www.imdb.com/name/nm0828419                         USA  1904-12-18
# http://www.imdb.com/name/nm0828562                         USA    1924-2-3
# http://www.imdb.com/name/nm0828623                         USA  1966-11-21
# http://www.imdb.com/name/nm0829037                        None        None
# http://www.imdb.com/name/nm0829038                          UK   1905-3-31
# http://www.imdb.com/name/nm0829343                        None        None
# http://www.imdb.com/name/nm0829518                        None   1967-1-18
# http://www.imdb.com/name/nm0829537                         USA  1962-11-28
# http://www.imdb.com/name/nm0829579                         USA    1930-4-1
# http://www.imdb.com/name/nm0829820                        None        None
# http://www.imdb.com/name/nm0829925                        None        None
# http://www.imdb.com/name/nm0830150                  Yugoslavia  1919-11-12
# http://www.imdb.com/name/nm0830249                     Finland   1883-7-17
# http://www.imdb.com/name/nm0830387                        None        None
# http://www.imdb.com/name/nm0830629                       Italy   1957-3-15
# http://www.imdb.com/name/nm0831321                        None        None
# http://www.imdb.com/name/nm0831370                        None        None
# http://www.imdb.com/name/nm0831457                         USA    1971-3-7
# http://www.imdb.com/name/nm0831546                      Canada    1960-0-0
# http://www.imdb.com/name/nm0831557                        None   1976-3-19
# http://www.imdb.com/name/nm0829579     1930.0                    NaN
# http://www.imdb.com/name/nm0829820        NaN                    1.0
# http://www.imdb.com/name/nm0829925        NaN                    2.0
# http://www.imdb.com/name/nm0830150     1919.0                    NaN
# http://www.imdb.com/name/nm0830249     1883.0                    NaN
# http://www.imdb.com/name/nm0830387        NaN                    NaN
# http://www.imdb.com/name/nm0830629     1957.0                    1.0
# http://www.imdb.com/name/nm0831321        NaN                    1.0
# http://www.imdb.com/name/nm0831370        NaN                    NaN
# http://www.imdb.com/name/nm0831457     1971.0                    1.0
# http://www.imdb.com/name/nm0831546     1960.0                    1.0
# http://www.imdb.com/name/nm0831557     1976.0                    NaN
# http://www.imdb.com/name/nm0831690     1966.0                    NaN
# http://www.imdb.com/name/nm0831720     1902.0                    NaN
# http://www.imdb.com/name/nm0831847        NaN                    NaN
# http://www.imdb.com/name/nm0832165     1984.0                    4.0
# http://www.imdb.com/name/nm0832369     1964.0                    NaN
# http://www.imdb.com/name/nm0832559     1950.0                    NaN
# http://www.imdb.com/name/nm0832573     1939.0                    NaN
# http://www.imdb.com/name/nm0832584     1890.0                    NaN
# http://www.imdb.com/name/nm0832617     1966.0                    NaN
# http://www.imdb.com/name/nm0832823        NaN                    NaN
# ...                                       ...                    ...
# http://www.imdb.com/name/nm1000820        NaN                    NaN
# http://www.imdb.com/name/nm1000987     1971.0                    NaN
# http://www.imdb.com/name/nm1001040        NaN                    NaN
# http://www.imdb.com/name/nm1001051     1973.0                    NaN
# http://www.imdb.com/name/nm1002207        NaN                    NaN
# http://www.imdb.com/name/nm1002424     1974.0                    NaN
# http://www.imdb.com/name/nm1003636        NaN                    NaN
# http://www.imdb.com/name/nm1004738     1941.0                    NaN
# http://www.imdb.com/name/nm1005607        NaN                    NaN
# http://www.imdb.com/name/nm1006056        NaN                    NaN
# http://www.imdb.com/name/nm1006419        NaN                    NaN
# http://www.imdb.com/name/nm1006491        NaN                    NaN
# http://www.imdb.com/name/nm1006796        NaN                    NaN
# http://www.imdb.com/name/nm1007136     1968.0                    NaN
# http://www.imdb.com/name/nm1007344        NaN                    NaN
# http://www.imdb.com/name/nm1007740     1966.0                    NaN
# http://www.imdb.com/name/nm1008619        NaN                    8.0
# http://www.imdb.com/name/nm1008762        NaN                    NaN
# http://www.imdb.com/name/nm1009277     1975.0                    NaN
# http://www.imdb.com/name/nm1009774        NaN                    NaN
# http://www.imdb.com/name/nm1009775     1976.0                    NaN
# http://www.imdb.com/name/nm1010592        NaN                    NaN
# http://www.imdb.com/name/nm1011074        NaN                    NaN
# http://www.imdb.com/name/nm1011337        NaN                    NaN
# http://www.imdb.com/name/nm1011749     1968.0                    NaN
# http://www.imdb.com/name/nm1011775        NaN                    NaN
# http://www.imdb.com/name/nm1012219     1964.0                    NaN
# http://www.imdb.com/name/nm1012385     1973.0                    NaN
# http://www.imdb.com/name/nm1012501     1972.0                    2.0
# http://www.imdb.com/name/nm1012775        NaN                    NaN
#
#                                     Deathyear  Directing Roles  Editing Roles  \
# http://www.imdb.com/name/nm0828419     1975.0               59            NaN
# http://www.imdb.com/name/nm0828562     1998.0               13            NaN
# http://www.imdb.com/name/nm0828623     2015.0               16            NaN
# http://www.imdb.com/name/nm0829037        NaN               21            NaN
# http://www.imdb.com/name/nm0829038     1986.0               62            NaN
# http://www.imdb.com/name/nm0829343        NaN                4            NaN
# http://www.imdb.com/name/nm0829518        NaN                2            NaN
# http://www.imdb.com/name/nm0829537        NaN                1            NaN
# http://www.imdb.com/name/nm0829579     1997.0               15            NaN
# http://www.imdb.com/name/nm0829820        NaN                8            2.0
# http://www.imdb.com/name/nm0829925        NaN                5            2.0
# http://www.imdb.com/name/nm0830150     1993.0               22            2.0
# http://www.imdb.com/name/nm0830249     1928.0               48            NaN
# http://www.imdb.com/name/nm0830387        NaN               16           17.0
# http://www.imdb.com/name/nm0830629        NaN                7            NaN
# http://www.imdb.com/name/nm0831321        NaN               18            1.0
# http://www.imdb.com/name/nm0831370        NaN                2            NaN
# http://www.imdb.com/name/nm0831457        NaN                6            NaN
# http://www.imdb.com/name/nm0831546        NaN               13            3.0
# http://www.imdb.com/name/nm0831557        NaN               10            NaN
# http://www.imdb.com/name/nm0831690        NaN               14            NaN
# http://www.imdb.com/name/nm0831720     1999.0               33            NaN
# http://www.imdb.com/name/nm0831847        NaN                1            NaN
# http://www.imdb.com/name/nm0832165        NaN               11            NaN
# http://www.imdb.com/name/nm0832369        NaN               24            1.0
# http://www.imdb.com/name/nm0832559     2011.0               20            4.0
# http://www.imdb.com/name/nm0832573        NaN               50            NaN
# http://www.imdb.com/name/nm0832584     1958.0               47            NaN
# http://www.imdb.com/name/nm0832617        NaN                6            8.0
# http://www.imdb.com/name/nm0832823        NaN                2            NaN
# ...                                       ...              ...            ...
# http://www.imdb.com/name/nm1000820        NaN                5            NaN
# http://www.imdb.com/name/nm1000987        NaN                8            NaN
# http://www.imdb.com/name/nm1001040        NaN               27           13.0
# http://www.imdb.com/name/nm1001051        NaN               15            NaN
# http://www.imdb.com/name/nm1002207        NaN               11            NaN
# http://www.imdb.com/name/nm1002424        NaN                8            1.0
# http://www.imdb.com/name/nm1003636        NaN                2            NaN
# http://www.imdb.com/name/nm1004738        NaN               12            NaN
# http://www.imdb.com/name/nm1005607        NaN               16            NaN
# http://www.imdb.com/name/nm1006056        NaN                3            2.0
# http://www.imdb.com/name/nm1006419        NaN                7            NaN
# http://www.imdb.com/name/nm1006491        NaN                3            2.0
# http://www.imdb.com/name/nm1006796        NaN                9            NaN
# http://www.imdb.com/name/nm1007136        NaN                3            1.0
# http://www.imdb.com/name/nm1007344        NaN               10            NaN
# http://www.imdb.com/name/nm1007740        NaN               27            7.0
# http://www.imdb.com/name/nm1008619        NaN               13           14.0
# http://www.imdb.com/name/nm1008762        NaN                2            NaN
# http://www.imdb.com/name/nm1009277        NaN                7            1.0
# http://www.imdb.com/name/nm1009774        NaN                3            NaN
# http://www.imdb.com/name/nm1009775        NaN                4            NaN
# http://www.imdb.com/name/nm1010592        NaN                3            NaN
# http://www.imdb.com/name/nm1011074        NaN                2            NaN
# http://www.imdb.com/name/nm1011337        NaN                4            NaN
# http://www.imdb.com/name/nm1011749        NaN                3            NaN
# http://www.imdb.com/name/nm1011775        NaN               40            NaN
# http://www.imdb.com/name/nm1012219        NaN                7            NaN
# http://www.imdb.com/name/nm1012385        NaN               11            NaN
# http://www.imdb.com/name/nm1012501        NaN                9            NaN
# http://www.imdb.com/name/nm1012775        NaN                5            NaN
#
#                                     Gender  Height in m  \
# http://www.imdb.com/name/nm0828419    None         1.80
# http://www.imdb.com/name/nm0828562    Male          NaN
# http://www.imdb.com/name/nm0828623    Male          NaN
# http://www.imdb.com/name/nm0829037    Male          NaN
# http://www.imdb.com/name/nm0829038    Male          NaN
# http://www.imdb.com/name/nm0829343    Male          NaN
# http://www.imdb.com/name/nm0829518    Male          NaN
# http://www.imdb.com/name/nm0829537    Male         1.65
# http://www.imdb.com/name/nm0829579    Male          NaN
# http://www.imdb.com/name/nm0829820    None          NaN
# http://www.imdb.com/name/nm0829925    Male          NaN
# http://www.imdb.com/name/nm0830150    None          NaN
# http://www.imdb.com/name/nm0830249    Male          NaN
# http://www.imdb.com/name/nm0830387    None          NaN
# http://www.imdb.com/name/nm0830629    Male          NaN
# http://www.imdb.com/name/nm0831321    Male          NaN
# http://www.imdb.com/name/nm0831370    None          NaN
# http://www.imdb.com/name/nm0831457    Male          NaN
# http://www.imdb.com/name/nm0831546    Male          NaN
# http://www.imdb.com/name/nm0831557    Male         1.87
# http://www.imdb.com/name/nm0831690    Male          NaN
# http://www.imdb.com/name/nm0831720    Male          NaN
# http://www.imdb.com/name/nm0831847    Male          NaN
# http://www.imdb.com/name/nm0832165    Male          NaN
# http://www.imdb.com/name/nm0832369  Female          NaN
# http://www.imdb.com/name/nm0832559    Male          NaN
# http://www.imdb.com/name/nm0832573    Male          NaN
# http://www.imdb.com/name/nm0832584    Male          NaN
# http://www.imdb.com/name/nm0832617    None          NaN
# http://www.imdb.com/name/nm0832823    Male          NaN
# ...                                    ...          ...
# http://www.imdb.com/name/nm1000820    Male          NaN
# http://www.imdb.com/name/nm1000987    None          NaN
# http://www.imdb.com/name/nm1001040    Male          NaN
# http://www.imdb.com/name/nm1001051    Male          NaN
# http://www.imdb.com/name/nm1002207    Male          NaN
# http://www.imdb.com/name/nm1002424    Male          NaN
# http://www.imdb.com/name/nm1003636    None          NaN
# http://www.imdb.com/name/nm1004738    Male          NaN
# http://www.imdb.com/name/nm1005607    Male          NaN
# http://www.imdb.com/name/nm1006056    None          NaN
# http://www.imdb.com/name/nm1006419    Male         1.85
# http://www.imdb.com/name/nm1006491    Male          NaN
# http://www.imdb.com/name/nm1006796    None          NaN
# http://www.imdb.com/name/nm1007136    None          NaN
# http://www.imdb.com/name/nm1007344    Male          NaN
# http://www.imdb.com/name/nm1007740    Male          NaN
# http://www.imdb.com/name/nm1002424      Michael Dougherty              4.0
# http://www.imdb.com/name/nm1003636          Michael Caleo              3.0
# http://www.imdb.com/name/nm1004738            Tun Fei Mou              1.0
# http://www.imdb.com/name/nm1005607              Russ Parr             11.0
# http://www.imdb.com/name/nm1006056          John Mitchell              NaN
# http://www.imdb.com/name/nm1006419             Jay Alaimo              8.0
# http://www.imdb.com/name/nm1006491       John Azpilicueta              5.0
# http://www.imdb.com/name/nm1006796           Cris D'Amato              2.0
# http://www.imdb.com/name/nm1007136      Valeska Grisebach              1.0
# http://www.imdb.com/name/nm1007344                  Kantz              9.0
# http://www.imdb.com/name/nm1007740          Mike Nawrocki              3.0
# http://www.imdb.com/name/nm1008619        Michael Knowles             15.0
# http://www.imdb.com/name/nm1008762          Scott Roberts              NaN
# http://www.imdb.com/name/nm1009277            Dax Shepard              1.0
# http://www.imdb.com/name/nm1009774            María Lidón              NaN
# http://www.imdb.com/name/nm1009775            Greg Marcks              NaN
# http://www.imdb.com/name/nm1010592         Geoff Anderson              4.0
# http://www.imdb.com/name/nm1011074          Mohamed Fadel              NaN
# http://www.imdb.com/name/nm1011337          Toomas Hussar              NaN
# http://www.imdb.com/name/nm1011749              Yann Moix              NaN
# http://www.imdb.com/name/nm1011775       Keitarô Motonaga              2.0
# http://www.imdb.com/name/nm1012219          Hae-sung Song              NaN
# http://www.imdb.com/name/nm1012385            Roar Uthaug              2.0
# http://www.imdb.com/name/nm1012501           Rupert Wyatt              4.0
# http://www.imdb.com/name/nm1012775           David Murphy              9.0
#
#                                     Publicity Listings    Star Sign  \
# http://www.imdb.com/name/nm0828419                18.0  Sagittarius
# http://www.imdb.com/name/nm0828562                 1.0     Aquarius
# http://www.imdb.com/name/nm0828623                 1.0      Scorpio
# http://www.imdb.com/name/nm0829037                 NaN         None
# http://www.imdb.com/name/nm0829038                 1.0        Aries
# http://www.imdb.com/name/nm0829343                 NaN         None
# http://www.imdb.com/name/nm0829518                 NaN    Capricorn
# http://www.imdb.com/name/nm0829537                43.0  Sagittarius
# http://www.imdb.com/name/nm0829579                 4.0        Aries
# http://www.imdb.com/name/nm0829820                 NaN         None
# http://www.imdb.com/name/nm0829925                 1.0         None
# http://www.imdb.com/name/nm0830150                 NaN      Scorpio
# http://www.imdb.com/name/nm0830249                 3.0       Cancer
# http://www.imdb.com/name/nm0830387                 NaN         None
# http://www.imdb.com/name/nm0830629                 3.0       Pisces
# http://www.imdb.com/name/nm0831321                 NaN         None
# http://www.imdb.com/name/nm0831370                 1.0         None
# http://www.imdb.com/name/nm0831457                 1.0       Pisces
# http://www.imdb.com/name/nm0831546                 NaN         None
# http://www.imdb.com/name/nm0831557                 1.0       Pisces
# http://www.imdb.com/name/nm0831690                 NaN         None
# http://www.imdb.com/name/nm0831720                 1.0       Cancer
# http://www.imdb.com/name/nm0831847                 NaN         None
# http://www.imdb.com/name/nm0832165                 NaN    Capricorn
# http://www.imdb.com/name/nm0832369                 1.0         None
# http://www.imdb.com/name/nm0832559                 NaN         None
# http://www.imdb.com/name/nm0832573                 NaN  Sagittarius
# http://www.imdb.com/name/nm0832584                16.0      Scorpio
# http://www.imdb.com/name/nm0832617                 NaN        Aries
# http://www.imdb.com/name/nm0832823                 1.0         None
# ...                                                ...          ...
# http://www.imdb.com/name/nm1000820                 NaN         None
# http://www.imdb.com/name/nm1000987                 NaN    Capricorn
# http://www.imdb.com/name/nm1001040                 NaN         None
# http://www.imdb.com/name/nm1001051                 NaN        Virgo
# http://www.imdb.com/name/nm1002207                 NaN         None
# http://www.imdb.com/name/nm1002424                 NaN      Scorpio
# http://www.imdb.com/name/nm1003636                 NaN         None
# http://www.imdb.com/name/nm1004738                 1.0       Taurus
# http://www.imdb.com/name/nm1005607                 3.0         None
# http://www.imdb.com/name/nm1006056                 NaN         None
# http://www.imdb.com/name/nm1006419                 NaN         None
# http://www.imdb.com/name/nm1006491                 NaN         None
# http://www.imdb.com/name/nm1006796                 NaN         None
# http://www.imdb.com/name/nm1007136                 NaN    Capricorn
# http://www.imdb.com/name/nm1007344                 NaN         None
# http://www.imdb.com/name/nm1007740                 NaN       Cancer
# http://www.imdb.com/name/nm1008619                 7.0         None
# http://www.imdb.com/name/nm1008762                 NaN         None
# http://www.imdb.com/name/nm1009277                 5.0    Capricorn
# http://www.imdb.com/name/nm1009774                 NaN         None
# http://www.imdb.com/name/nm1009775                 NaN          Leo
# http://www.imdb.com/name/nm1010592                 NaN         None
# http://www.imdb.com/name/nm1011074                 NaN         None
# http://www.imdb.com/name/nm1011337                 NaN         None
# http://www.imdb.com/name/nm1011749                 NaN        Aries
# http://www.imdb.com/name/nm1011775                 NaN         None
# http://www.imdb.com/name/nm1012219                 NaN        Libra
# http://www.imdb.com/name/nm1012385                 NaN        Virgo
# http://www.imdb.com/name/nm1012501                 1.0      Scorpio
# http://www.imdb.com/name/nm1012775                 NaN         None
#
#                                     TV Appearances  Writing Roles
# http://www.imdb.com/name/nm0828419            12.0           16.0
# http://www.imdb.com/name/nm0828562             1.0           44.0
# http://www.imdb.com/name/nm0828623             1.0           20.0
# http://www.imdb.com/name/nm0829037             3.0            9.0
# http://www.imdb.com/name/nm0829038             NaN           28.0
# http://www.imdb.com/name/nm0829343             3.0           16.0
# http://www.imdb.com/name/nm0829518             NaN            NaN
# http://www.imdb.com/name/nm0829537           204.0           19.0
# http://www.imdb.com/name/nm0829579             NaN            1.0
# http://www.imdb.com/name/nm0829820             5.0            6.0
# http://www.imdb.com/name/nm0829925             3.0            1.0
# http://www.imdb.com/name/nm0830150             NaN           14.0
# http://www.imdb.com/name/nm0830249             NaN           30.0
# http://www.imdb.com/name/nm0830387             NaN            9.0
# http://www.imdb.com/name/nm0830629            19.0            2.0
# http://www.imdb.com/name/nm0831321             2.0           13.0
# http://www.imdb.com/name/nm0831370             NaN           24.0
# http://www.imdb.com/name/nm0831457             3.0           13.0
# http://www.imdb.com/name/nm0831546             1.0           10.0
# http://www.imdb.com/name/nm0831557             6.0           20.0
# http://www.imdb.com/name/nm0831690             6.0            NaN
# http://www.imdb.com/name/nm0831720             2.0           27.0
# http://www.imdb.com/name/nm0831847             NaN            2.0
# http://www.imdb.com/name/nm0832165            12.0            7.0
# http://www.imdb.com/name/nm0832369             2.0            6.0
# http://www.imdb.com/name/nm0832559             2.0           12.0
# http://www.imdb.com/name/nm0832573             7.0            4.0
# http://www.imdb.com/name/nm0832584             NaN            6.0
# http://www.imdb.com/name/nm0832617             2.0            2.0
# http://www.imdb.com/name/nm0832823             NaN            2.0
# ...                                            ...            ...
# http://www.imdb.com/name/nm1000820             1.0            2.0
# http://www.imdb.com/name/nm1000987             NaN           17.0
# http://www.imdb.com/name/nm1001040             1.0           29.0
# http://www.imdb.com/name/nm1001051             1.0           20.0
# http://www.imdb.com/name/nm1002207             1.0            6.0
# http://www.imdb.com/name/nm1002424            11.0           12.0
# http://www.imdb.com/name/nm1003636             NaN            7.0
# http://www.imdb.com/name/nm1004738             2.0            NaN
# http://www.imdb.com/name/nm1005607             6.0           11.0
# http://www.imdb.com/name/nm1006056             1.0            3.0
# http://www.imdb.com/name/nm1006419             NaN            6.0
# http://www.imdb.com/name/nm1006491             NaN            4.0
# http://www.imdb.com/name/nm1006796             NaN            2.0
# http://www.imdb.com/name/nm1007136             NaN            3.0
# http://www.imdb.com/name/nm1007344             NaN            9.0
# http://www.imdb.com/name/nm1007740             1.0           35.0
# http://www.imdb.com/name/nm1008619             NaN           13.0
# http://www.imdb.com/name/nm1008762             NaN            6.0
# http://www.imdb.com/name/nm1009277            71.0            4.0
# http://www.imdb.com/name/nm1009774             1.0            NaN
# http://www.imdb.com/name/nm1009775             1.0            3.0
# http://www.imdb.com/name/nm1010592             NaN            NaN
# http://www.imdb.com/name/nm1011074             NaN            3.0
# http://www.imdb.com/name/nm1011337             NaN            2.0
# http://www.imdb.com/name/nm1011749            31.0            3.0
# http://www.imdb.com/name/nm1011775             NaN            NaN
# http://www.imdb.com/name/nm1012219             NaN            4.0
# http://www.imdb.com/name/nm1012385             NaN            4.0
# http://www.imdb.com/name/nm1012501             8.0            5.0
# http://www.imdb.com/name/nm1012775             NaN            3.0
#
# [1000 rows x 19 columns]

# %%
directors_import.loc['http://www.imdb.com/name/nm8921482']
# Out:
# Acting Roles                                                   NaN
# Age at Death                                                   NaN
# Award Info                                 6 wins & 7 nominations.
# Birth Country                                                 USSR
# Birthdate                                                 1991-0-0
# Birthplace               Nalchik, Kabardino-Balkar AO, RSFSR, USSR
# Birthyear                                                     1991
# Cinematographic Roles                                            3
# Deathyear                                                      NaN
# Directing Roles                                                  4
# Editing Roles                                                    1
# Gender                                                        Male
# Height in m                                                    NaN
# Name                                              Kantemir Balagov
# Producing Roles                                                NaN
# Publicity Listings                                             NaN
# Star Sign                                                     None
# TV Appearances                                                   1
# Writing Roles                                                    3
# Name: http://www.imdb.com/name/nm8921482, dtype: object
