# %% [markdown]
# # Importing and Dropping Duplicates

# %%
import pandas as pd
import json

# %%
imports = []
import_numbers = [1,2,3,5,6,7,10,11,12,15,16,17,20,21,22,25,26,27,30,31,32,35,36,37,40,41,42,45,46,47]   
for num in import_numbers:
    imports.append('movie_details_exports/movie_details_export_%s.json' %(str(num)))

# %%
imports
# Out:
# ['movie_details_exports/movie_details_export_1.json',
#  'movie_details_exports/movie_details_export_2.json',
#  'movie_details_exports/movie_details_export_3.json',
#  'movie_details_exports/movie_details_export_5.json',
#  'movie_details_exports/movie_details_export_6.json',
#  'movie_details_exports/movie_details_export_7.json',
#  'movie_details_exports/movie_details_export_10.json',
#  'movie_details_exports/movie_details_export_11.json',
#  'movie_details_exports/movie_details_export_12.json',
#  'movie_details_exports/movie_details_export_15.json',
#  'movie_details_exports/movie_details_export_16.json',
#  'movie_details_exports/movie_details_export_17.json',
#  'movie_details_exports/movie_details_export_20.json',
#  'movie_details_exports/movie_details_export_21.json',
#  'movie_details_exports/movie_details_export_22.json',
#  'movie_details_exports/movie_details_export_25.json',
#  'movie_details_exports/movie_details_export_26.json',
#  'movie_details_exports/movie_details_export_27.json',
#  'movie_details_exports/movie_details_export_30.json',
#  'movie_details_exports/movie_details_export_31.json',
#  'movie_details_exports/movie_details_export_32.json',
#  'movie_details_exports/movie_details_export_35.json',
#  'movie_details_exports/movie_details_export_36.json',
#  'movie_details_exports/movie_details_export_37.json',
#  'movie_details_exports/movie_details_export_40.json',
#  'movie_details_exports/movie_details_export_41.json',
#  'movie_details_exports/movie_details_export_42.json',
#  'movie_details_exports/movie_details_export_45.json',
#  'movie_details_exports/movie_details_export_46.json',
#  'movie_details_exports/movie_details_export_47.json']

# %%
details_df = pd.DataFrame()

# %%
for imp in imports:
    details_df = details_df.append(pd.read_json(imp, orient='index'))

# mov = mov.append(pd.read_json('export_2.json', orient='index'))
# mov = mov.append(pd.read_json('export_3.json', orient='index'))

# %%
len(details_df)
# Out:
# 29717

# %%
details_df.head()
# Out:
#                                            Budget      Country  \
# http://www.imdb.com/title/tt4937564/    2500000.0           UK
# http://www.imdb.com/title/tt4937812/  500000000.0        India
# http://www.imdb.com/title/tt4939066/   12620000.0  South Korea
# http://www.imdb.com/title/tt4940370/   63000000.0       Sweden
# http://www.imdb.com/title/tt4940456/          NaN        India
#
#                                       Cumulative Worldwide Gross  \
# http://www.imdb.com/title/tt4937564/                         NaN
# http://www.imdb.com/title/tt4937812/                         NaN
# http://www.imdb.com/title/tt4939066/                         NaN
# http://www.imdb.com/title/tt4940370/                         NaN
# http://www.imdb.com/title/tt4940456/                         NaN
#
#                                                      Director  \
# http://www.imdb.com/title/tt4937564/          Sylvie Verheyde
# http://www.imdb.com/title/tt4937812/          Rajesh M. Selva
# http://www.imdb.com/title/tt4939066/              John H. Lee
# http://www.imdb.com/title/tt4940370/           Felix Herngren
# http://www.imdb.com/title/tt4940456/  Rakeysh Omprakash Mehra
#
#                                                             Director_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0894173
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm4301161
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497565
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0379773
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm1018493
#
#                                          Gross USA Language  \
# http://www.imdb.com/title/tt4937564/           NaN  English
# http://www.imdb.com/title/tt4937812/           NaN    Tamil
# http://www.imdb.com/title/tt4939066/  1.022720e+12   Korean
# http://www.imdb.com/title/tt4940370/           NaN  Swedish
# http://www.imdb.com/title/tt4940456/           NaN    Hindi
#
#                                       Opening Weekend USA  \
# http://www.imdb.com/title/tt4937564/                  NaN
# http://www.imdb.com/title/tt4937812/                  NaN
# http://www.imdb.com/title/tt4939066/         3.166272e+09
# http://www.imdb.com/title/tt4940370/                  NaN
# http://www.imdb.com/title/tt4940456/                  NaN
#
#                                         Primary Filming Location  \
# http://www.imdb.com/title/tt4937564/                        None
# http://www.imdb.com/title/tt4937812/  Chennai, Tamil Nadu, India
# http://www.imdb.com/title/tt4939066/          Seoul, South Korea
# http://www.imdb.com/title/tt4940370/                        None
# http://www.imdb.com/title/tt4940456/                        None
#
#                                                  Production Company  \
# http://www.imdb.com/title/tt4937564/           Les Films du Veyrier
# http://www.imdb.com/title/tt4937812/  Raajkamal Films International
# http://www.imdb.com/title/tt4939066/           Taewon Entertainment
# http://www.imdb.com/title/tt4940370/              NICE FLX Pictures
# http://www.imdb.com/title/tt4940456/         Cinestaan Film Company
#
#                                      Release Date                Star1  \
# http://www.imdb.com/title/tt4937564/   2017-02-10         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/   2015-11-13         Kamal Haasan
# http://www.imdb.com/title/tt4939066/   2016-08-12          Liam Neeson
# http://www.imdb.com/title/tt4940370/   2017-04-25    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/   2016-10-07  Harshvardhan Kapoor
#
#                                                                Star1_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                Star2  \
# http://www.imdb.com/title/tt4937564/     Ash Stymest
# http://www.imdb.com/title/tt4937812/     Prakash Raj
# http://www.imdb.com/title/tt4939066/    Jung-jae Lee
# http://www.imdb.com/title/tt4940370/  Iwar Wiklander
# http://www.imdb.com/title/tt4940456/    Saiyami Kher
#
#                                                                Star2_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm7514839
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0695177
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0497631
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0928002
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7517362
#
#                                                 Star3  \
# http://www.imdb.com/title/tt4937564/    Karole Rocher
# http://www.imdb.com/title/tt4937812/  Trisha Krishnan
# http://www.imdb.com/title/tt4939066/      Beom-su Lee
# http://www.imdb.com/title/tt4940370/     David Wiberg
# http://www.imdb.com/title/tt4940456/        Art Malik
#
#                                                                Star3_URL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm0734039
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm1375534
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm1045934
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm2433382
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm0539562
#
#                                                                                   Title
# http://www.imdb.com/title/tt4937564/                                           Sex Doll
# http://www.imdb.com/title/tt4937812/                                      Thoongaavanam
# http://www.imdb.com/title/tt4939066/             Battle for Incheon: Operation Chromite
# http://www.imdb.com/title/tt4940370/  The 101-Year-Old Man Who Skipped Out on the Bi...
# http://www.imdb.com/title/tt4940456/                                             Mirzya

# %%
details_df.columns
# Out:
# Index(['Budget', 'Country', 'Cumulative Worldwide Gross', 'Director',
#        'Director_URL', 'Gross USA', 'Language', 'Opening Weekend USA',
#        'Primary Filming Location', 'Production Company', 'Release Date',
#        'Star1', 'Star1_URL', 'Star2', 'Star2_URL', 'Star3', 'Star3_URL',
#        'Title'],
#       dtype='object')

# %% [markdown]
# # Get List of unique Stars and URLS

# %%
star1_df = details_df[['Star1_URL','Star1']].copy()

# %%
star1_df.rename(columns = {'Star1_URL':'StarURL','Star1':'Star'}, inplace=True)

# %%
star2_df = details_df[['Star2_URL','Star2']].copy()

# %%
star2_df.rename(columns = {'Star2_URL':'StarURL','Star2':'Star'}, inplace=True)

# %%
star3_df = details_df[['Star3_URL','Star3']].copy()

# %%
star3_df.rename(columns = {'Star3_URL':'StarURL','Star3':'Star'}, inplace=True)

# %%
stars_df = pd.concat([star1_df,star2_df,star3_df])

# %%
stars_df.head()
# Out:
#                                                                  StarURL  \
# http://www.imdb.com/title/tt4937564/  http://www.imdb.com/name/nm2082567
# http://www.imdb.com/title/tt4937812/  http://www.imdb.com/name/nm0352032
# http://www.imdb.com/title/tt4939066/  http://www.imdb.com/name/nm0000553
# http://www.imdb.com/title/tt4940370/  http://www.imdb.com/name/nm0349052
# http://www.imdb.com/title/tt4940456/  http://www.imdb.com/name/nm7561367
#
#                                                      Star
# http://www.imdb.com/title/tt4937564/         Hafsia Herzi
# http://www.imdb.com/title/tt4937812/         Kamal Haasan
# http://www.imdb.com/title/tt4939066/          Liam Neeson
# http://www.imdb.com/title/tt4940370/    Robert Gustafsson
# http://www.imdb.com/title/tt4940456/  Harshvardhan Kapoor

# %%
len(stars_df)
# Out:
# 89151

# %% [raw]
# counts = [type(x) for x in stars_df['StarURL']]

# %% [raw]
# counts.index(float)

# %% [raw]
# stars_df.iloc[4017]['StarURL']
# .split('?')[0]

# %%
stars_df = stars_df.dropna(subset = ['StarURL'])

# %%
len(stars_df)
# Out:
# 89075

# %%
stars_df = stars_df.drop_duplicates(subset='StarURL',keep='first')

# %%
len(stars_df)
# Out:
# 33838

# %%
star_urls = list(stars_df['StarURL'])

# %%
star_urls = sorted(star_urls, reverse = True)

# %%
star_urls[:10]
# Out:
# ['http://www.imdb.com/name/nm9585396',
#  'http://www.imdb.com/name/nm9578606',
#  'http://www.imdb.com/name/nm9572036',
#  'http://www.imdb.com/name/nm9572029',
#  'http://www.imdb.com/name/nm9557596',
#  'http://www.imdb.com/name/nm9557587',
#  'http://www.imdb.com/name/nm9557586',
#  'http://www.imdb.com/name/nm9552585',
#  'http://www.imdb.com/name/nm9549343',
#  'http://www.imdb.com/name/nm9521432']

# %% [raw]
# star_urls.pop()

# %% [raw]
# star_urls[22525]

# %% [raw]
# import re
# import requests
# from bs4 import BeautifulSoup
# url = 'http://www.imdb.com/name/nm0000233/'
# # url= 'http://www.imdb.com/name/nm0002354/'
# response = requests.get(url)
# page = response.text
# soup = BeautifulSoup(page, 'html.parser')

# %% [raw]
# star_details = {}
# star_details[url] = {}

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a') if gender else None
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = soup.find(id='name-bio-text')
#         gender = gender.text if gender else None
#         gender = re.sub('\n', '', gender) if gender else None
#         gender = re.sub('  +',' ', gender) if gender else None
#         gender = gender.split(' ') if gender else None
#         male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
#         female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
#         if gender:
#             if male_count > female_count:
#                 gender = 'Male'
#             elif female_count > male_count:
#                 gender = 'Female'
#             else:
#                 gender = None
#
# gender

# %% [raw]
# height = soup.find('h2',text=re.compile('Personal Details'))
# height = height.parent if height else None
# height = height.find(id='details-height') if height else None
# height = height.text if height else None
# height = height.split('(')[-1] if height else None
# height = re.sub('[^0-9.]+','',height) if height else None
# # star_details[url]['Height in m'] = height
# height

# %% [raw]
# publicity_listings = soup.find('h2',text=re.compile('Personal Details'))
# publicity_listings = publicity_listings.parent if publicity_listings else None
# publicity_listings = publicity_listings.find(id='details-publicity-listings') if publicity_listings else None
# publicity_listings = publicity_listings.text if publicity_listings else None
# publicity_listings = re.sub('[^0-9]+',' ',publicity_listings) if publicity_listings else None
# publicity_listings = publicity_listings.strip() if publicity_listings else None
# publicity_listings = publicity_listings.split(' ') if publicity_listings else None
# publicity_listings = [int(x) for x in publicity_listings] if publicity_listings else None
# publicity_listings = sum(publicity_listings) if publicity_listings else None
# star_details[url]['Publicity Listings'] = publicity_listings
# publicity_listings

# %% [raw]
# star_sign = soup.find('h4',text=re.compile('Star Sign'))
# star_sign = star_sign.parent if star_sign else None
# star_sign = star_sign.text if star_sign else None
# star_sign = star_sign.strip() if star_sign else None
# star_sign = star_sign.split('\n')[-1] if star_sign else None
# star_details[url]['Star Sign'] = star_sign
#
# star_sign

# %% [raw]
# gender = soup.find(id='name-job-categories')
# gender = gender.findAll('a')
# gender = [x['href'] for x in gender] if gender else None
# gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
# if gender:
#     if 'actor' in gender:
#         gender = 'Male'
#     elif 'actress' in gender:
#         gender = 'Female'
#     else:
#         gender = None
# star_details[url]['Gender'] = gender
#
# gender

# %% [raw]
# born_info = soup.find(id='name-born-info')
#
# birthdate = born_info.find('time') if born_info else None
# if birthdate.has_attr('datetime'):
#     birthdate = birthdate['datetime']
# else:
#     birthdate = None
# # star_details[url]['Birthdate'] = birthdate
#
# birthplace = born_info.findAll('a') if born_info else None
# birthplace = birthplace[-1] if birthplace else None
# birthplace = birthplace.text if birthplace else None
# # star_details[url]['Birthplace'] = birthplace
#
# birthcountry = birthplace.split(', ') if birthplace else None
# birthcountry = birthcountry[-1] if len(birthcountry)>2 else None
# # star_details[url]['Birth Country'] = birthcountry
#
# birthdate
# # birthplace
# # birthcountry

# %% [raw]
# acting_roles = soup.find(id='filmo-head-actor')
# acting_roles = acting_roles.text if acting_roles else None
# acting_roles = acting_roles.strip() if acting_roles else None
# acting_roles = acting_roles.split('(')[-1] if acting_roles else None
# acting_roles = re.sub('[^0-9]+','',acting_roles) if acting_roles else None
# acting_roles = int(acting_roles) if acting_roles else None
# # star_details[url]['Acting Roles'] = action_roles
#
# acting_roles

# %% [raw]
# tv_appearances = soup.find(id='filmo-head-self')
# tv_appearances = tv_appearances.text if tv_appearances else None
# tv_appearances = tv_appearances.strip() if tv_appearances else None
# tv_appearances = tv_appearances.split('(')[-1] if tv_appearances else None
# tv_appearances = re.sub('[^0-9]+','',tv_appearances) if tv_appearances else None
# star_details[url]['producing Roles'] = tv_appearances
# tv_appearances
#
#
# # star_details[url]['producing Roles'] = tv_appearances

# %% [raw]
# star_name = soup.find('h1')
# star_name = star_name.text if star_name else None
# star_name = star_name.strip() if star_name else None
# star_name = star_name.split('\n') if star_name else None
#
# deathyear = star_name[-1] if len(star_name)>=2 else None
# deathyear = deathyear.split('–')[-1] if deathyear else None
# deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
# deathyear = int(deathyear) if deathyear else None
#
# star_name = star_name[0] if star_name else None
#
# birthyear = birthdate[0:4] if birthdate and len(birthdate)>=10 else None
# birthyear = int(birthyear) if birthyear else None
#
# age_at_death = deathyear-birthyear if deathyear and birthyear else None
#
# birthyear

# %% [raw]
# award_highlight = soup.find('div', class_='article highlighted')
# award_highlight = award_highlight.find('span') if award_highlight else None
# award_highlight = award_highlight.text if award_highlight else None
# award_highlight = award_highlight.strip() if award_highlight else None
# award_highlight = award_highlight.split('\n') if award_highlight else None
# award_highlight = [x.strip() for x in award_highlight] if award_highlight else None
# award_highlight = ' '.join(award_highlight) if award_highlight else None
#
# #     star_details[url]['Award Info'] = award_highlight
# award_highlight

# %% [raw]
# star_details

# %%
len(star_urls)
# Out:
# 33838

# %% [markdown]
# ## Scrape Star Details

# %%
# star Details
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time

stars_scraped = 0
star_details = {}
star_index = 0                    
prefix = 'http://www.imdb.com'
export_number = 1
export_no = str(export_number)
load_attempts = 0

def star_scraper():
    global star_index
    
    print(str(datetime.now()),': working on export ' + export_no)
    
    for url in star_urls[star_index:3000]:
#         print(url)
        if (star_index+1) % 20 == 0:
            time.sleep(1.5)
            print('%d: %s' %(star_index+1, url))
        page = request_page(url)
        get_star_details(url, page)
        star_index += 1
    
    export_to_json(star_details)
    print("Done")
    
def request_page(url):
    global load_attempts
    response = requests.get(url)
    
    if response.status_code == 200:
        return(response.text)
        load_attempts = 0
    else:
        print(response.status_code,'for %s' %(url))
        if response.status_code != 404:
            if load_attempts == 10:
                time.sleep(60)
            else:
                time.sleep(10)
            request_page(url)
            load_attempts += 1

def get_star_details(url, page):
    soup = BeautifulSoup(page, 'html.parser')

    star_details[url] = {}
    
    gender = soup.find(id='name-job-categories')
    gender = gender.findAll('a') if gender else None
    gender = [x['href'] for x in gender] if gender else None
    gender = [re.sub('[^a-z]+','',x) for x in gender] if gender else None
    if gender:
        if 'actor' in gender:
            gender = 'Male'
        elif 'actress' in gender:
            gender = 'Female'
        else:
            gender = soup.find(id='name-bio-text')
            gender = gender.text if gender else None
            gender = re.sub('\n', '', gender) if gender else None
            gender = re.sub('  +',' ', gender) if gender else None
            gender = gender.split(' ') if gender else None
            male_count = gender.count('His') + gender.count('his') + gender.count('He') + gender.count('he') if gender else None
            female_count = gender.count('Her') + gender.count('her') + gender.count('She') + gender.count('she') if gender else None
            if gender:
                if male_count > female_count:
                    gender = 'Male'
                elif female_count > male_count:
                    gender = 'Female'
                else:
                    gender = None
    star_details[url]['Gender'] = gender
    
    
    star_name = soup.find('h1')
    star_name = star_name.text if star_name else None
    star_name = star_name.strip() if star_name else None
    star_name = star_name.split('\n') if star_name else None

    deathyear = star_name[-1] if len(star_name)>=2 else None
    deathyear = deathyear.split('–')[-1] if deathyear else None
    deathyear = re.sub('[^0-9]+','',deathyear) if deathyear else None
    deathyear = int(deathyear) if deathyear else None
    star_details[url]['Deathyear'] = deathyear
    

    star_name = star_name[0] if star_name else None
    star_details[url]['Name'] = star_name    
    
    
    born_info = soup.find(id='name-born-info')

    birthdate = born_info.find('time') if born_info else None
    if birthdate:
        if birthdate.has_attr('datetime'):
            birthdate = birthdate['datetime']
        else:
            birthdate = None
# 2480: http://www.imdb.com/name/nm4453291
# 2500: http://www.imdb.com/name/nm4440460
# 2520: http://www.imdb.com/name/nm4425316
# 2540: http://www.imdb.com/name/nm4408847
# 2560: http://www.imdb.com/name/nm4388400
# 2580: http://www.imdb.com/name/nm4372913
# 2600: http://www.imdb.com/name/nm4358751
# 2620: http://www.imdb.com/name/nm4340735
# 2640: http://www.imdb.com/name/nm4312440
# 2660: http://www.imdb.com/name/nm4299091
# 2680: http://www.imdb.com/name/nm4286857
# 2700: http://www.imdb.com/name/nm4274183
# 2720: http://www.imdb.com/name/nm4263213
# 2740: http://www.imdb.com/name/nm4251574
# 2760: http://www.imdb.com/name/nm4241408
# 2780: http://www.imdb.com/name/nm4225437
# 2800: http://www.imdb.com/name/nm4211652
# 2820: http://www.imdb.com/name/nm4199426
# 2840: http://www.imdb.com/name/nm4179869
# 2860: http://www.imdb.com/name/nm4162662
# 2880: http://www.imdb.com/name/nm4150847
# 2900: http://www.imdb.com/name/nm4136756
# 2920: http://www.imdb.com/name/nm4116138
# 2940: http://www.imdb.com/name/nm4103976
# 2960: http://www.imdb.com/name/nm4089510
# 2980: http://www.imdb.com/name/nm4071082
# 3000: http://www.imdb.com/name/nm4056723
# 2018-01-30 00:14:42.140371 : working on export 4
# 2018-01-30 00:14:42.141886 : working on export 5
# Done
# 3138.211

# %%
import json
import pandas as pd
stars_import = pd.read_json('star_details_exports/star_details_export_3.json',orient='index')

# %%
len(stars_import)
# Out:
# 1000

# %%
stars_import
# Out:
#                                     Acting Roles  Age at Death  \
# http://www.imdb.com/name/nm4056723           5.0           NaN
# http://www.imdb.com/name/nm4056899          16.0           NaN
# http://www.imdb.com/name/nm4058003           NaN           NaN
# http://www.imdb.com/name/nm4058955          25.0           NaN
# http://www.imdb.com/name/nm4059397           NaN           NaN
# http://www.imdb.com/name/nm4059916           3.0           NaN
# http://www.imdb.com/name/nm4060295           7.0           NaN
# http://www.imdb.com/name/nm4060935           7.0           NaN
# http://www.imdb.com/name/nm4062293           8.0           NaN
# http://www.imdb.com/name/nm4062328          24.0           NaN
# http://www.imdb.com/name/nm4063331           5.0           NaN
# http://www.imdb.com/name/nm4063710          19.0           NaN
# http://www.imdb.com/name/nm4065455          41.0           NaN
# http://www.imdb.com/name/nm4066401           NaN           NaN
# http://www.imdb.com/name/nm4068476          16.0           NaN
# http://www.imdb.com/name/nm4068487           1.0           NaN
# http://www.imdb.com/name/nm4068901           NaN           NaN
# http://www.imdb.com/name/nm4069429           2.0           NaN
# http://www.imdb.com/name/nm4069693           NaN           NaN
# http://www.imdb.com/name/nm4070086           NaN           NaN
# http://www.imdb.com/name/nm4071082           3.0           NaN
# http://www.imdb.com/name/nm4071231           2.0           NaN
# http://www.imdb.com/name/nm4073016          30.0           NaN
# http://www.imdb.com/name/nm4074645           NaN           NaN
# http://www.imdb.com/name/nm4076403           NaN           NaN
# http://www.imdb.com/name/nm4077635           NaN           NaN
# http://www.imdb.com/name/nm4078666           NaN           NaN
# http://www.imdb.com/name/nm4080531           NaN           NaN
# http://www.imdb.com/name/nm4080592          15.0           NaN
# http://www.imdb.com/name/nm4080670           NaN           NaN
# ...                                          ...           ...
# http://www.imdb.com/name/nm4876327           NaN           NaN
# http://www.imdb.com/name/nm4877001          48.0           NaN
# http://www.imdb.com/name/nm4877771           1.0           NaN
# http://www.imdb.com/name/nm4877974           5.0           NaN
# http://www.imdb.com/name/nm4878154          11.0           NaN
# http://www.imdb.com/name/nm4878199           2.0           NaN
# http://www.imdb.com/name/nm4879194           2.0           NaN
# http://www.imdb.com/name/nm4879234           1.0           NaN
# http://www.imdb.com/name/nm4879276           NaN           NaN
# http://www.imdb.com/name/nm4879824           NaN           NaN
# http://www.imdb.com/name/nm4879999           6.0           NaN
# http://www.imdb.com/name/nm4880301           NaN           NaN
# http://www.imdb.com/name/nm4881623           NaN           NaN
# http://www.imdb.com/name/nm4881741          16.0           NaN
# http://www.imdb.com/name/nm4881749           NaN           NaN
# http://www.imdb.com/name/nm4881804          18.0           NaN
# http://www.imdb.com/name/nm4884029           1.0           NaN
# http://www.imdb.com/name/nm4884095           1.0           NaN
# http://www.imdb.com/name/nm4884137           NaN           NaN
# http://www.imdb.com/name/nm4885772           6.0           NaN
# http://www.imdb.com/name/nm4885900           NaN           NaN
# http://www.imdb.com/name/nm4885949           NaN           NaN
# http://www.imdb.com/name/nm4887855           NaN           NaN
# http://www.imdb.com/name/nm4888033           NaN           NaN
# http://www.imdb.com/name/nm4888279          15.0           NaN
# http://www.imdb.com/name/nm4888388           NaN           NaN
# http://www.imdb.com/name/nm4890550           3.0           NaN
# http://www.imdb.com/name/nm4893159           NaN           NaN
# http://www.imdb.com/name/nm4894345           1.0           NaN
# http://www.imdb.com/name/nm4897618           1.0           NaN
#
#                                                  Award Info Birth Country  \
# http://www.imdb.com/name/nm4056723                     None          None
# http://www.imdb.com/name/nm4056899                     None          None
# http://www.imdb.com/name/nm4058003                   1 win.          None
# http://www.imdb.com/name/nm4058955   2 wins & 1 nomination.          None
# http://www.imdb.com/name/nm4059397                     None          None
# http://www.imdb.com/name/nm4059916                     None          None
# http://www.imdb.com/name/nm4060295                     None          None
# http://www.imdb.com/name/nm4060935                     None          None
# http://www.imdb.com/name/nm4062293                     None          None
# http://www.imdb.com/name/nm4062328           2 nominations.         Korea
# http://www.imdb.com/name/nm4063331                     None          None
# http://www.imdb.com/name/nm4063710                     None          None
# http://www.imdb.com/name/nm4065455                     None         Japan
# http://www.imdb.com/name/nm4066401                     None          None
# http://www.imdb.com/name/nm4068476                     None           USA
# http://www.imdb.com/name/nm4068487                     None          None
# http://www.imdb.com/name/nm4068901                     None           USA
# http://www.imdb.com/name/nm4069429                     None          None
# http://www.imdb.com/name/nm4069693                     None        Russia
# http://www.imdb.com/name/nm4070086            1 nomination.          None
# http://www.imdb.com/name/nm4071082                     None          None
# http://www.imdb.com/name/nm4071231            1 nomination.          None
# http://www.imdb.com/name/nm4073016                   1 win.          None
# http://www.imdb.com/name/nm4074645                     None          None
# http://www.imdb.com/name/nm4076403                     None           USA
# http://www.imdb.com/name/nm4077635                     None          None
# http://www.imdb.com/name/nm4877771                                   None
# http://www.imdb.com/name/nm4877974                                   None
# http://www.imdb.com/name/nm4878154                                   None
# http://www.imdb.com/name/nm4878199                                   None
# http://www.imdb.com/name/nm4879194                                   None
# http://www.imdb.com/name/nm4879234                                   None
# http://www.imdb.com/name/nm4879276                                   None
# http://www.imdb.com/name/nm4879824                                   None
# http://www.imdb.com/name/nm4879999                                   None
# http://www.imdb.com/name/nm4880301                                   None
# http://www.imdb.com/name/nm4881623                                   None
# http://www.imdb.com/name/nm4881741                                   2003
# http://www.imdb.com/name/nm4881749                                   None
# http://www.imdb.com/name/nm4881804                                     UK
# http://www.imdb.com/name/nm4884029                                   None
# http://www.imdb.com/name/nm4884095                                   None
# http://www.imdb.com/name/nm4884137                                   None
# http://www.imdb.com/name/nm4885772                                   None
# http://www.imdb.com/name/nm4885900                                   None
# http://www.imdb.com/name/nm4885949               Champaign, Illinois, USA
# http://www.imdb.com/name/nm4887855                                   None
# http://www.imdb.com/name/nm4888033                      Stavanger, Norway
# http://www.imdb.com/name/nm4888279         Kielce, Swietokrzyskie, Poland
# http://www.imdb.com/name/nm4888388                                   None
# http://www.imdb.com/name/nm4890550                                   None
# http://www.imdb.com/name/nm4893159                                   None
# http://www.imdb.com/name/nm4894345                                   None
# http://www.imdb.com/name/nm4897618                                   None
#
#                                     Birthyear  Deathyear  Directing Roles  \
# http://www.imdb.com/name/nm4056723        NaN        NaN              NaN
# http://www.imdb.com/name/nm4056899        NaN        NaN              NaN
# http://www.imdb.com/name/nm4058003        NaN        NaN              NaN
# http://www.imdb.com/name/nm4058955        NaN        NaN              NaN
# http://www.imdb.com/name/nm4059397        NaN        NaN              NaN
# http://www.imdb.com/name/nm4059916        NaN        NaN              NaN
# http://www.imdb.com/name/nm4060295        NaN        NaN              NaN
# http://www.imdb.com/name/nm4060935        NaN        NaN              NaN
# http://www.imdb.com/name/nm4062293        NaN        NaN              2.0
# http://www.imdb.com/name/nm4062328     1989.0        NaN              NaN
# http://www.imdb.com/name/nm4063331        NaN        NaN              NaN
# http://www.imdb.com/name/nm4063710        NaN        NaN              NaN
# http://www.imdb.com/name/nm4065455     1993.0        NaN              NaN
# http://www.imdb.com/name/nm4066401        NaN        NaN              NaN
# http://www.imdb.com/name/nm4068476     1996.0        NaN              NaN
# http://www.imdb.com/name/nm4068487        NaN        NaN              NaN
# http://www.imdb.com/name/nm4068901     2002.0        NaN              NaN
# http://www.imdb.com/name/nm4069429        NaN        NaN              NaN
# http://www.imdb.com/name/nm4069693     1992.0        NaN              NaN
# http://www.imdb.com/name/nm4070086        NaN        NaN              NaN
# http://www.imdb.com/name/nm4071082        NaN        NaN              NaN
# http://www.imdb.com/name/nm4071231        NaN        NaN              NaN
# http://www.imdb.com/name/nm4073016        NaN        NaN              3.0
# http://www.imdb.com/name/nm4074645        NaN        NaN              NaN
# http://www.imdb.com/name/nm4076403     1986.0        NaN              NaN
# http://www.imdb.com/name/nm4077635        NaN        NaN              NaN
# http://www.imdb.com/name/nm4078666        NaN        NaN              1.0
# http://www.imdb.com/name/nm4080531        NaN        NaN              NaN
# http://www.imdb.com/name/nm4080592     1994.0        NaN              NaN
# http://www.imdb.com/name/nm4080670     1983.0        NaN              NaN
# ...                                       ...        ...              ...
# http://www.imdb.com/name/nm4876327        NaN        NaN              NaN
# http://www.imdb.com/name/nm4877001     1994.0        NaN              NaN
# http://www.imdb.com/name/nm4877771        NaN        NaN              NaN
# http://www.imdb.com/name/nm4877974        NaN        NaN              NaN
# http://www.imdb.com/name/nm4878154        NaN        NaN              NaN
# http://www.imdb.com/name/nm4878199        NaN        NaN              NaN
# http://www.imdb.com/name/nm4879194        NaN        NaN              NaN
# http://www.imdb.com/name/nm4879234        NaN        NaN              NaN
# http://www.imdb.com/name/nm4879276        NaN        NaN              NaN
# http://www.imdb.com/name/nm4879824        NaN        NaN              NaN
# http://www.imdb.com/name/nm4879999        NaN        NaN              NaN
# http://www.imdb.com/name/nm4880301        NaN        NaN              NaN
# http://www.imdb.com/name/nm4881623        NaN        NaN              NaN
# http://www.imdb.com/name/nm4881741     2003.0        NaN              NaN
# http://www.imdb.com/name/nm4881749        NaN        NaN              NaN
# http://www.imdb.com/name/nm4881804        NaN        NaN              NaN
# http://www.imdb.com/name/nm4884029        NaN        NaN              NaN
# http://www.imdb.com/name/nm4884095        NaN        NaN              NaN
# http://www.imdb.com/name/nm4884137        NaN        NaN              NaN
# http://www.imdb.com/name/nm4885772        NaN        NaN              NaN
# http://www.imdb.com/name/nm4885900        NaN        NaN              NaN
# http://www.imdb.com/name/nm4885949     1992.0        NaN              NaN
# http://www.imdb.com/name/nm4887855        NaN        NaN              NaN
# http://www.imdb.com/name/nm4888033     1994.0        NaN              NaN
# http://www.imdb.com/name/nm4888279     1989.0        NaN              NaN
# http://www.imdb.com/name/nm4888388        NaN        NaN              NaN
# http://www.imdb.com/name/nm4890550        NaN        NaN              NaN
# http://www.imdb.com/name/nm4893159        NaN        NaN              NaN
# http://www.imdb.com/name/nm4894345        NaN        NaN              NaN
# http://www.imdb.com/name/nm4897618        NaN        NaN              NaN
#
#                                     Gender  Height in m  \
# http://www.imdb.com/name/nm4056723    Male          NaN
# http://www.imdb.com/name/nm4056899    Male         1.80
# http://www.imdb.com/name/nm4058003  Female          NaN
# http://www.imdb.com/name/nm4058955    Male         1.83
# http://www.imdb.com/name/nm4059397  Female          NaN
# http://www.imdb.com/name/nm4059916    Male         1.88
# http://www.imdb.com/name/nm4060295    Male          NaN
# http://www.imdb.com/name/nm4060935    Male          NaN
# http://www.imdb.com/name/nm4062293    Male          NaN
# http://www.imdb.com/name/nm4062328    Male         1.85
# http://www.imdb.com/name/nm4063331    Male          NaN
# http://www.imdb.com/name/nm4063710    Male         1.85
# http://www.imdb.com/name/nm4065455    Male         1.83
# http://www.imdb.com/name/nm4066401  Female          NaN
# http://www.imdb.com/name/nm4068476    Male         1.78
# http://www.imdb.com/name/nm4068487    Male          NaN
# http://www.imdb.com/name/nm4068901  Female         1.59
# http://www.imdb.com/name/nm4069429    Male          NaN
# http://www.imdb.com/name/nm4069693  Female          NaN
# http://www.imdb.com/name/nm4070086  Female          NaN
# http://www.imdb.com/name/nm4071082    Male          NaN
# http://www.imdb.com/name/nm4071231    Male          NaN
# http://www.imdb.com/name/nm4073016    Male          NaN
# http://www.imdb.com/name/nm4074645  Female          NaN
# http://www.imdb.com/name/nm4076403  Female         1.80
# http://www.imdb.com/name/nm4077635  Female          NaN
# http://www.imdb.com/name/nm4078666  Female         1.65
# http://www.imdb.com/name/nm4080531  Female         1.69
# http://www.imdb.com/name/nm4080592    Male         1.65
# http://www.imdb.com/name/nm4080670  Female         1.68
# ...                                    ...          ...
# http://www.imdb.com/name/nm4876327  Female          NaN
# http://www.imdb.com/name/nm4877001    Male         1.70
# http://www.imdb.com/name/nm4877771    Male          NaN
# http://www.imdb.com/name/nm4877974    Male         1.83
# http://www.imdb.com/name/nm4878154    Male          NaN
# http://www.imdb.com/name/nm4878199    Male          NaN
# http://www.imdb.com/name/nm4879194    Male          NaN
# http://www.imdb.com/name/nm4879234    Male          NaN
# http://www.imdb.com/name/nm4879276  Female          NaN
# http://www.imdb.com/name/nm4879824  Female         1.60
# http://www.imdb.com/name/nm4879999    Male          NaN
# http://www.imdb.com/name/nm4880301  Female         1.75
# http://www.imdb.com/name/nm4881623  Female          NaN
# http://www.imdb.com/name/nm4881741    Male         1.64
# http://www.imdb.com/name/nm4881749  Female          NaN
# http://www.imdb.com/name/nm4881804    Male         1.83
# http://www.imdb.com/name/nm4884029    Male          NaN
# http://www.imdb.com/name/nm4884095    Male         1.71
# http://www.imdb.com/name/nm4884137  Female          NaN
# http://www.imdb.com/name/nm4885772    Male          NaN
# http://www.imdb.com/name/nm4885900  Female          NaN
# http://www.imdb.com/name/nm4885949  Female         1.73
# http://www.imdb.com/name/nm4887855  Female          NaN
# http://www.imdb.com/name/nm4888033  Female          NaN
# http://www.imdb.com/name/nm4888279    Male          NaN
# http://www.imdb.com/name/nm4888388  Female          NaN
# http://www.imdb.com/name/nm4890550    Male          NaN
# http://www.imdb.com/name/nm4893159  Female          NaN
# http://www.imdb.com/name/nm4894345    Male          NaN
# http://www.imdb.com/name/nm4897618    Male          NaN
#
#                                                              Name  \
# http://www.imdb.com/name/nm4056723                      Ufuk Asar
# http://www.imdb.com/name/nm4056899                    Mark Gibson
# http://www.imdb.com/name/nm4058003                      Rita Pokk
# http://www.imdb.com/name/nm4058955                  Brett Edwards
# http://www.imdb.com/name/nm4059397                 Leticia Rivera
# http://www.imdb.com/name/nm4059916                    Curtis Snow
# http://www.imdb.com/name/nm4060295                  Yehuda Nahari
# http://www.imdb.com/name/nm4060935                    Owen Colgan
# http://www.imdb.com/name/nm4062293                  Chris Tordoff
# http://www.imdb.com/name/nm4062328                   Jong-Suk Lee
# http://www.imdb.com/name/nm4063331          William Patrick Riley
# http://www.imdb.com/name/nm4063710                Steven Helmkamp
# http://www.imdb.com/name/nm4065455                     Ryô Ryûsei
# http://www.imdb.com/name/nm4066401                  Aditi Vasudev
# http://www.imdb.com/name/nm4068476               Cameron McKendry
# http://www.imdb.com/name/nm4060935              NaN                 NaN
# http://www.imdb.com/name/nm4062293              NaN                 NaN
# http://www.imdb.com/name/nm4062328              NaN                 NaN
# http://www.imdb.com/name/nm4063331              NaN                 NaN
# http://www.imdb.com/name/nm4063710              NaN                 NaN
# http://www.imdb.com/name/nm4065455              NaN                 NaN
# http://www.imdb.com/name/nm4066401              NaN                 NaN
# http://www.imdb.com/name/nm4068476              NaN                 3.0
# http://www.imdb.com/name/nm4068487              NaN                 NaN
# http://www.imdb.com/name/nm4068901              NaN                 NaN
# http://www.imdb.com/name/nm4069429              NaN                 NaN
# http://www.imdb.com/name/nm4069693              NaN                 NaN
# http://www.imdb.com/name/nm4070086              NaN                 NaN
# http://www.imdb.com/name/nm4071082              NaN                 NaN
# http://www.imdb.com/name/nm4071231              NaN                 NaN
# http://www.imdb.com/name/nm4073016              3.0                 1.0
# http://www.imdb.com/name/nm4074645              NaN                 NaN
# http://www.imdb.com/name/nm4076403              2.0                 NaN
# http://www.imdb.com/name/nm4077635              NaN                 NaN
# http://www.imdb.com/name/nm4078666              1.0                 NaN
# http://www.imdb.com/name/nm4080531              NaN                 1.0
# http://www.imdb.com/name/nm4080592              NaN                 NaN
# http://www.imdb.com/name/nm4080670              NaN                 NaN
# ...                                             ...                 ...
# http://www.imdb.com/name/nm4876327              NaN                 NaN
# http://www.imdb.com/name/nm4877001              NaN                 NaN
# http://www.imdb.com/name/nm4877771              NaN                 NaN
# http://www.imdb.com/name/nm4877974              NaN                 NaN
# http://www.imdb.com/name/nm4878154              NaN                 NaN
# http://www.imdb.com/name/nm4878199              NaN                 NaN
# http://www.imdb.com/name/nm4879194              NaN                 NaN
# http://www.imdb.com/name/nm4879234              NaN                 NaN
# http://www.imdb.com/name/nm4879276              NaN                 NaN
# http://www.imdb.com/name/nm4879824              NaN                 NaN
# http://www.imdb.com/name/nm4879999              NaN                 NaN
# http://www.imdb.com/name/nm4880301              NaN                 6.0
# http://www.imdb.com/name/nm4881623              NaN                 NaN
# http://www.imdb.com/name/nm4881741              NaN                 3.0
# http://www.imdb.com/name/nm4881749              NaN                 NaN
# http://www.imdb.com/name/nm4881804              1.0                 1.0
# http://www.imdb.com/name/nm4884029              NaN                 NaN
# http://www.imdb.com/name/nm4884095              NaN                 2.0
# http://www.imdb.com/name/nm4884137              NaN                 NaN
# http://www.imdb.com/name/nm4885772              NaN                 NaN
# http://www.imdb.com/name/nm4885900              NaN                 NaN
# http://www.imdb.com/name/nm4885949              NaN                 NaN
# http://www.imdb.com/name/nm4887855              2.0                 NaN
# http://www.imdb.com/name/nm4888033              NaN                 NaN
# http://www.imdb.com/name/nm4888279              NaN                 NaN
# http://www.imdb.com/name/nm4888388              NaN                 NaN
# http://www.imdb.com/name/nm4890550              NaN                 NaN
# http://www.imdb.com/name/nm4893159              NaN                 NaN
# http://www.imdb.com/name/nm4894345              NaN                 NaN
# http://www.imdb.com/name/nm4897618              NaN                 NaN
#
#                                     Star Sign  TV Appearances
# http://www.imdb.com/name/nm4056723       None             NaN
# http://www.imdb.com/name/nm4056899       None             NaN
# http://www.imdb.com/name/nm4058003       None             NaN
# http://www.imdb.com/name/nm4058955       None             NaN
# http://www.imdb.com/name/nm4059397       None             NaN
# http://www.imdb.com/name/nm4059916       None             1.0
# http://www.imdb.com/name/nm4060295       None             NaN
# http://www.imdb.com/name/nm4060935       None             NaN
# http://www.imdb.com/name/nm4062293       None             NaN
# http://www.imdb.com/name/nm4062328      Virgo             1.0
# http://www.imdb.com/name/nm4063331       None             NaN
# http://www.imdb.com/name/nm4063710       None             2.0
# http://www.imdb.com/name/nm4065455      Aries             NaN
# http://www.imdb.com/name/nm4066401       None             NaN
# http://www.imdb.com/name/nm4068476  Capricorn             1.0
# http://www.imdb.com/name/nm4068487       None             1.0
# http://www.imdb.com/name/nm4068901      Libra             1.0
# http://www.imdb.com/name/nm4069429       None             NaN
# http://www.imdb.com/name/nm4069693     Pisces             NaN
# http://www.imdb.com/name/nm4070086       None             2.0
# http://www.imdb.com/name/nm4071082       None             NaN
# http://www.imdb.com/name/nm4071231       None             NaN
# http://www.imdb.com/name/nm4073016       None             NaN
# http://www.imdb.com/name/nm4074645       None             NaN
# http://www.imdb.com/name/nm4076403      Virgo             1.0
# http://www.imdb.com/name/nm4077635       None             NaN
# http://www.imdb.com/name/nm4078666       None             NaN
# http://www.imdb.com/name/nm4080531       None             2.0
# http://www.imdb.com/name/nm4080592     Gemini             1.0
# http://www.imdb.com/name/nm4080670      Aries             NaN
# ...                                       ...             ...
# http://www.imdb.com/name/nm4876327       None             NaN
# http://www.imdb.com/name/nm4877001   Aquarius             NaN
# http://www.imdb.com/name/nm4877771       None             NaN
# http://www.imdb.com/name/nm4877974       None             NaN
# http://www.imdb.com/name/nm4878154       None             NaN
# http://www.imdb.com/name/nm4878199       None             1.0
# http://www.imdb.com/name/nm4879194       None             NaN
# http://www.imdb.com/name/nm4879234       None             NaN
# http://www.imdb.com/name/nm4879276       None             NaN
# http://www.imdb.com/name/nm4879824       None             NaN
# http://www.imdb.com/name/nm4879999       None             2.0
# http://www.imdb.com/name/nm4880301       None             1.0
# http://www.imdb.com/name/nm4881623       None             NaN
# http://www.imdb.com/name/nm4881741     Cancer             1.0
# http://www.imdb.com/name/nm4881749       None             NaN
# http://www.imdb.com/name/nm4881804       None             NaN
# http://www.imdb.com/name/nm4884029       None             NaN
# http://www.imdb.com/name/nm4884095       None             NaN
# http://www.imdb.com/name/nm4884137       None             NaN
# http://www.imdb.com/name/nm4885772       None             9.0
# http://www.imdb.com/name/nm4885900       None             NaN
# http://www.imdb.com/name/nm4885949   Aquarius             2.0
# http://www.imdb.com/name/nm4887855       None             NaN
# http://www.imdb.com/name/nm4888033        Leo             4.0
# http://www.imdb.com/name/nm4888279     Cancer             NaN
# http://www.imdb.com/name/nm4888388       None             3.0
# http://www.imdb.com/name/nm4890550       None             NaN
# http://www.imdb.com/name/nm4893159       None             NaN
# http://www.imdb.com/name/nm4894345       None             NaN
# http://www.imdb.com/name/nm4897618       None             NaN
#
# [1000 rows x 16 columns]
